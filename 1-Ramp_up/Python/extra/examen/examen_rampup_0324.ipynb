# %% [markdown]
# # Test DS-FT Mar24

# %% [markdown]
# Antes de comenzar, cambia el nombre del archivo notebook poniéndole delante tu nombre y primer apellido:
#
# * nombre_apellido1_apellido2_rampup_0324.ipynb

# %% [markdown]
# ## Primera parte tipo test (3 puntos):
# AQUI NO HAY QUE HACER NADA

# %% [markdown]
# #### Notas y pruebas de apoyo para contestar las preguntas tipo test
# Esto no es necesario usarlo aunque verlo aquí te puede dar la respuesta a alguna de las preguntas tipo test.
#
# Cualquier código aunque no esté correcto nos dirá más de ti que no escribir nada.

# %%
# crea todas las celdas que necesites

# %% [markdown]
# -----------------

# %% [markdown]
# ## Segunda parte ejercicios prácticos (7 puntos):

# %%
# Ejemplo de como queremos ver el código para más de un intento:

# intento 1
your code
# intento 2
your code

# %% [markdown]
# ### Ejercicio 1 (1 punto)
# En este ejercicio se va a crear una lista con los siguientes elementos. Primero, crearemos las variables que luego añadiremos a la lista. Sigue las instrucciones detalladas a continuación:
#
# 1. Crea una variable llamada `puntuacion` de tipo Integer que represente la puntuación obtenida en un juego.
# 2. Crea una variable llamada `nombre_equipo` de tipo String que contenga el nombre de tu equipo favorito de deportes seguido de un espacio en blanco y el deporte que practicas.
# 3. Crea una variable llamada `promedio_tiempo` con el promedio de tiempo en horas que dedicas diariamente al estudio o trabajo, de tipo float.
# 4. Crea una variable llamada `es_habil` de tipo Boolean True si eres diestro y False si eres zurdo.
# 5. Crea una variable llamada `lista_compras` de tipo List que contenga los nombres de los cinco alimentos que más consumes. Cada elemento debe ser de tipo String.
# 6. Crea una variable llamada `tupla_mascotas` de tipo Tuple que incluya el nombre, la edad y la especie de tus dos mascotas en dos tuplas una por mascota.
# 7. Crea una variable llamada `dict_contactos` con tres keys y tres values. Una key es `amigos`, con los nombres y apellidos ("juan perez") de tus dos amigos o amigas como value. Otra key es `telefonos`, con sus números de teléfono como value. La última key es `emails`, con sus direcciones de correo electrónico como value.
# 8. Añade todos estos elementos en una lista llamada `lista_actividades` en el orden de aparición **usando una función de lista**.
# 9. Responde en un comentario a la siguiente pregunta: ¿Cómo podrías verificar si un elemento está presente en `lista_actividades` antes de agregarlo a la lista para evitar duplicados?

# %% [markdown]
# ### Ejercicio 2 (2 puntos)
#
# Para resolver este ejercicio necesitarás la lista del ejercicio anterior (`lista_actividades`). Se recomienda leer cada punto hasta el final antes de resolver el ejercicio.
#
# Se repite para que quede aún más claro: **SOLO USAR LA VARIABLE** `lista_actividades`. Usar las demás variables se calificará como error.
#
# 1. Mostrar por pantalla, sin uso de funciones (puedes usar print) ni bucles:
#     - Un mensaje de presentación de los nombres de tus dos mascotas.
#     - El promedio de tiempo diario que dedicas al estudio o trabajo.
#     - La segunda y la penultima cosa de la lista de la compra.
#     - Si eres diestro, muestra el nombre de uno de tus mejores amigos o amigas, si no, muestra su número de teléfono.
#     - Muestra el nombre y telefonos de tus amigos. En el caso de que el telefono sea par, mostrar tambien su email.
#
#
# 2. Mostrar por pantalla, con uso de un bucle `for`:
#     - Todos los elementos de `lista_actividades`.
#     - Todos los elementos de `lista_actividades` al revés.
#     - Todos aquellos elementos que se encuentren dentro de otra colección ordenada y ocupen un índice par (incluido el 0 como posicion par).
#     - La primera letra de cada objeto de la lista de la compra si empiezan por consonante y la ultima si empiezan por vocal".
#
# 3. Con uso del bucle `while`, borra las cosas de la compra por la cabeza hasta que tengas solo dos cosas para comprar y guarda esas cosas borradas en una nueva lista llamada `lista_no_compra`.
#
# <!-- 4. Añade esas dos cosas que te quedan en la lista de la compra y sustituye las dos arrobas "@" de los correos de tus amigos por estas cosas en mayusculas. E.g. "juan@jotmail.com" -> "juanMANZANASjotmail.com". Recuerda usar el metodo replace de las strings. -->

# %% [markdown]
# ## Ejercicio 3: Simulación de caída libre (2 puntos)
#
# En este ejercicio, se simulará la caída libre de un objeto, utilizando la siguiente fórmula para calcular la distancia recorrida en función del tiempo:
#
# **distancia = (1/2) * gravedad * tiempo^2**
#
# y la velocidad final con la siguiente ecuacion:
#
# **velocidad_final = sqrt(2 * gravedad * distancia)** # Usaremos math.sqrt
#
#
# **1. Cálculo distancia con funcion:**
#
# - Crear una función `calcular_distancia_caida_libre(...):`
#     - Esta función recibe como argumentos el tiempo de caida y la gravedad con un valor por defecto.
#     - Calcula la distancia recorrida (altura_inicial) utilizando la fórmula indicada.
#     - Retorna la distancia recorrida (altura_inicial).
#
# - Solicitar al usuario los datos tiempo.
# - Invocar la función `calcular_distancia_caida_libre(...)` con los datos correspondientes.
# - Mostrar la distancia recorrida por el objeto.
#
# **2. Cálculo tiempo_caida con funcion:**
#
# - Crear una función `calcular_tiempo_caida_libre(...):`
#     - Esta función recibe como argumentos la altura_inicial y la gravedad con un valor por defecto.
#     - Calcula tiempo_caida utilizando la fórmula indicada.
#     - Retorna tiempo_caida.
#
# - Solicitar al usuario los datos de altura_inicial.
# - Invocar la función `calcular_tiempo_caida_libre` con los datos correspondientes.
# - Mostrar el tiempo de caida del objeto.
#
# **3. Cálculo velocidad_final con funcion:**
#
# - Crear una función `calcular_velocidad_final(...):`
#     - Esta función recibe como argumentos la altura_inicial y la gravedad con un valor por defecto.
#     - Calcula velocidad_final utilizando la fórmula indicada.
#     - Retorna velocidad_final.
#
# - Solicitar al usuario los datos de altura_inicial.
# - Invocar la función `calcular_velocidad_final` con los datos correspondientes.
# - Mostrar la velocidad final del objeto.
#
#
# **4. Funcion final:**
#
# - Implementa una funcion `calculo_total(...)` que tenga una variable `valor`, una variable `gravedad` con default y una variable `modo` con default.
#     - La variable valor sera o la altura o el tiempo.
#     - Si la variable modo == "distancia" (default):
#         - asumimos que la variable valor es el tiempo y calculamos la distancia llamando a la funcion `calcular_distancia_caida_libre`
#     - Si la variable modo == "tiempo":
#         - asumimos que la variable valor es la altura_inicial y calculamos el tiempo llamando a la funcion `calcular_tiempo_caida_libre`
#
# - En ambos casos, implementar el calculo de la velocidad final del objeto al llegar al suelo, utilizando la siguiente fórmula:
#
# **velocidad_final = sqrt(2 * gravedad * distancia)**
#
# - La funcion debe devolver un diccionario con los 3 pares de claves y valores `{"altura_inicial": XX, "tiempo_caida": YY, "velocidad_final": ZZ}`

# %% [markdown]
# ## Ejercicio 4: Simulación de un videojuego con clases en Python (2 puntos)
#
# En este ejercicio, se creará una clase para simular un personaje en un videojuego.
#
# **1. Diseño de la clase:**
#
# - **Nombre:** `Personaje`
#
# **Atributos:**
#
# * `nombre`: Nombre del personaje (str)
# * `vida`: Puntos de vida (int) 50 o 100 por ejemplo
# * `nivel`: Nivel del personaje (int) 1
# * `experiencia`: Experiencia acumulada (int) 0
#
# **Métodos:**
#
# * `mision(dificultad)`: Gana 10, 20 o 30 de experiencia (llamar metodo ganar experiencia) en funcion de la dificultad ("baja", "media", "alta").
# * `defender(ataque)`: Reduce el daño recibido del enemigo en función del nivel del personaje (vida -= ataque/nivel)
# * `ganar_experiencia(experiencia)`: Aumenta la experiencia del personaje. Si la experiencia acumulada supera un umbral (50), el personaje sube de nivel.
# * `subir_nivel()`: Aumenta el nivel del personaje +1 y sus puntos de vida un 10%. Resetea la experiencia a 0.

# %%
# CREA UN PERSONAJE
# QUE HAGA UN PAR DE MISIONES
# QUE SE DEFIENDA UN PAR DE VECES 
# HASTA QUE AL MENOS SUBA DE NIVEL UNA VEZ

# %%
# %matplotlib inline
from PIL import Image
import requests
from io import BytesIO

url=R'https://estaticos.muyinteresante.es/media/cache/760x570_thumb/uploads/images/pyr/5cd405db5cafe829df48e212/funimation-1.jpg'


response = requests.get(url)
img = Image.open(BytesIO(response.content))

img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=760x570 at 0x28899E591C8>
