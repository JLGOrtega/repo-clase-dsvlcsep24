# %% [markdown]
# # Ensembles
# ## Carga de datos

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import seaborn as sns

df = pd.read_csv('data/titanic_modified.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Survived    891 non-null    int64
#  1   Pclass      891 non-null    int64
#  2   Sex         891 non-null    int64
#  3   Age         891 non-null    float64
#  4   SibSp       891 non-null    int64
#  5   Parch       891 non-null    int64
#  6   MissingAge  891 non-null    int64
#  7   Spouse      891 non-null    int64
# dtypes: float64(1), int64(7)
# memory usage: 55.8 KB

# %%
from sklearn.model_selection import train_test_split

classes = list(df.loc[:, 'Pclass':].columns)

X = df.loc[:, 'Pclass':].values
y = df['Survived'].values
X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    test_size = 0.20,
                                                    random_state=55)

# %% [markdown]
# ## Voting classifier
# 1. Primero declaramos todos los clasificadores que participarán en el voting classifier.
# 2. A continuación agrupamos los estimadores en una lista de tuplas, con sus identificadores.
# 3. Declaramos el VotingClassifier
#
# En primer lugar, probaremos un `hard` VotingClassifier, es decir, tendrá en cuenta las predicciones de los clasificadores, no sus probabilidades.

# %%
SVC??
# Out:
# Init signature:
# SVC(
#     *,
#     C=1.0,
#     kernel='rbf',
#     degree=3,
#     gamma='scale',
#     coef0=0.0,
#     shrinking=True,
#     probability=False,
#     tol=0.001,
#     cache_size=200,
#     class_weight=None,
#     verbose=False,
#     max_iter=-1,
#     decision_function_shape='ovr',
#     break_ties=False,
#     random_state=None,
# )
# Source:
# class SVC(BaseSVC):
#     """C-Support Vector Classification.
#
#     The implementation is based on libsvm. The fit time scales at least
#     quadratically with the number of samples and may be impractical
#     beyond tens of thousands of samples. For large datasets
#     consider using :class:`~sklearn.svm.LinearSVC` or
#     :class:`~sklearn.linear_model.SGDClassifier` instead, possibly after a
#     :class:`~sklearn.kernel_approximation.Nystroem` transformer.
#
#     The multiclass support is handled according to a one-vs-one scheme.
#
#     For details on the precise mathematical formulation of the provided
#     kernel functions and how `gamma`, `coef0` and `degree` affect each
#     other, see the corresponding section in the narrative documentation:
#     :ref:`svm_kernels`.
#
#     Read more in the :ref:`User Guide <svm_classification>`.
#
#     Parameters
#     ----------
#     C : float, default=1.0
#         Regularization parameter. The strength of the regularization is
#         inversely proportional to C. Must be strictly positive. The penalty
#         is a squared l2 penalty.
#
#     kernel : {'linear', 'poly', 'rbf', 'sigmoid', 'precomputed'} or callable,  \
#         default='rbf'
#         Specifies the kernel type to be used in the algorithm.
#         If none is given, 'rbf' will be used. If a callable is given it is
#         used to pre-compute the kernel matrix from data matrices; that matrix
#         should be an array of shape ``(n_samples, n_samples)``.
#
#     degree : int, default=3
#         Degree of the polynomial kernel function ('poly').
#         Ignored by all other kernels.
#
#     gamma : {'scale', 'auto'} or float, default='scale'
#         Kernel coefficient for 'rbf', 'poly' and 'sigmoid'.
#
#         - if ``gamma='scale'`` (default) is passed then it uses
#           1 / (n_features * X.var()) as value of gamma,
#         - if 'auto', uses 1 / n_features.
#
#         .. versionchanged:: 0.22
#            The default value of ``gamma`` changed from 'auto' to 'scale'.
#
#     coef0 : float, default=0.0
#         Independent term in kernel function.
#         It is only significant in 'poly' and 'sigmoid'.
#
#     shrinking : bool, default=True
#         Whether to use the shrinking heuristic.
#         See the :ref:`User Guide <shrinking_svm>`.
#
#     probability : bool, default=False
#         Whether to enable probability estimates. This must be enabled prior
#         to calling `fit`, will slow down that method as it internally uses
#         5-fold cross-validation, and `predict_proba` may be inconsistent with
#         `predict`. Read more in the :ref:`User Guide <scores_probabilities>`.
#
#     tol : float, default=1e-3
#         Tolerance for stopping criterion.
#
#     cache_size : float, default=200
#         Specify the size of the kernel cache (in MB).
#
#     class_weight : dict or 'balanced', default=None
#         Set the parameter C of class i to class_weight[i]*C for
#         SVC. If not given, all classes are supposed to have
#         weight one.
#         The "balanced" mode uses the values of y to automatically adjust
#         weights inversely proportional to class frequencies in the input data
#         as ``n_samples / (n_classes * np.bincount(y))``.
#
#     verbose : bool, default=False
#         Enable verbose output. Note that this setting takes advantage of a
#         per-process runtime setting in libsvm that, if enabled, may not work
#         properly in a multithreaded context.
#
#     max_iter : int, default=-1
#         Hard limit on iterations within solver, or -1 for no limit.
#
#     decision_function_shape : {'ovo', 'ovr'}, default='ovr'
#         Whether to return a one-vs-rest ('ovr') decision function of shape
#         (n_samples, n_classes) as all other classifiers, or the original
#         one-vs-one ('ovo') decision function of libsvm which has shape
#         (n_samples, n_classes * (n_classes - 1) / 2). However, one-vs-one
#         ('ovo') is always used as multi-class strategy. The parameter is
#         ignored for binary classification.
#
#         .. versionchanged:: 0.19
#             decision_function_shape is 'ovr' by default.
#
#         .. versionadded:: 0.17
#            *decision_function_shape='ovr'* is recommended.
#
#         .. versionchanged:: 0.17
#            Deprecated *decision_function_shape='ovo' and None*.
#
#     break_ties : bool, default=False
#         If true, ``decision_function_shape='ovr'``, and number of classes > 2,
#         :term:`predict` will break ties according to the confidence values of
#         :term:`decision_function`; otherwise the first class among the tied
#         classes is returned. Please note that breaking ties comes at a
#         relatively high computational cost compared to a simple predict.
#
#         .. versionadded:: 0.22
#
#     random_state : int, RandomState instance or None, default=None
#         Controls the pseudo random number generation for shuffling the data for
#         probability estimates. Ignored when `probability` is False.
#         Pass an int for reproducible output across multiple function calls.
#         See :term:`Glossary <random_state>`.
#
#     Attributes
#     ----------
#     class_weight_ : ndarray of shape (n_classes,)
#         Multipliers of parameter C for each class.
#         Computed based on the ``class_weight`` parameter.
#
#     classes_ : ndarray of shape (n_classes,)
#         The classes labels.
#
#     coef_ : ndarray of shape (n_classes * (n_classes - 1) / 2, n_features)
#         Weights assigned to the features (coefficients in the primal
#         problem). This is only available in the case of a linear kernel.
#
#         `coef_` is a readonly property derived from `dual_coef_` and
#         `support_vectors_`.
#
#     dual_coef_ : ndarray of shape (n_classes -1, n_SV)
#         Dual coefficients of the support vector in the decision
#         function (see :ref:`sgd_mathematical_formulation`), multiplied by
#         their targets.
#         For multiclass, coefficient for all 1-vs-1 classifiers.
#         The layout of the coefficients in the multiclass case is somewhat
#         non-trivial. See the :ref:`multi-class section of the User Guide
#         <svm_multi_class>` for details.
#
#     fit_status_ : int
#         0 if correctly fitted, 1 otherwise (will raise warning)
#
#     intercept_ : ndarray of shape (n_classes * (n_classes - 1) / 2,)
#         Constants in decision function.
#
#     n_features_in_ : int
#         Number of features seen during :term:`fit`.
#
#         .. versionadded:: 0.24
#
#     feature_names_in_ : ndarray of shape (`n_features_in_`,)
#         Names of features seen during :term:`fit`. Defined only when `X`
#         has feature names that are all strings.
#
#         .. versionadded:: 1.0
#
#     support_ : ndarray of shape (n_SV)
#         Indices of support vectors.
#
#     support_vectors_ : ndarray of shape (n_SV, n_features)
#         Support vectors.
#
#     n_support_ : ndarray of shape (n_classes,), dtype=int32
#         Number of support vectors for each class.
#
#     probA_ : ndarray of shape (n_classes * (n_classes - 1) / 2)
#     probB_ : ndarray of shape (n_classes * (n_classes - 1) / 2)
#         If `probability=True`, it corresponds to the parameters learned in
#         Platt scaling to produce probability estimates from decision values.
#         If `probability=False`, it's an empty array. Platt scaling uses the
#         logistic function
#         ``1 / (1 + exp(decision_value * probA_ + probB_))``
#         where ``probA_`` and ``probB_`` are learned from the dataset [2]_. For
#         more information on the multiclass case and training procedure see
#         section 8 of [1]_.
#
#     shape_fit_ : tuple of int of shape (n_dimensions_of_X,)
#         Array dimensions of training vector ``X``.
#
#     See Also
#     --------
#     SVR : Support Vector Machine for Regression implemented using libsvm.
#
#     LinearSVC : Scalable Linear Support Vector Machine for classification
#         implemented using liblinear. Check the See Also section of
#         LinearSVC for more comparison element.
#
#     References
#     ----------
#     .. [1] `LIBSVM: A Library for Support Vector Machines
#         <http://www.csie.ntu.edu.tw/~cjlin/papers/libsvm.pdf>`_
#
#     .. [2] `Platt, John (1999). "Probabilistic outputs for support vector
#         machines and comparison to regularizedlikelihood methods."
#         <http://citeseer.ist.psu.edu/viewdoc/summary?doi=10.1.1.41.1639>`_
#
#     Examples
#     --------
#     >>> import numpy as np
#     >>> from sklearn.pipeline import make_pipeline
#     >>> from sklearn.preprocessing import StandardScaler
#     >>> X = np.array([[-1, -1], [-2, -1], [1, 1], [2, 1]])
#     >>> y = np.array([1, 1, 2, 2])
#     >>> from sklearn.svm import SVC
#     >>> clf = make_pipeline(StandardScaler(), SVC(gamma='auto'))
#     >>> clf.fit(X, y)
#     Pipeline(steps=[('standardscaler', StandardScaler()),
#                     ('svc', SVC(gamma='auto'))])
#
#     >>> print(clf.predict([[-0.8, -1]]))
#     [1]
#     """
#
#     _impl = "c_svc"
#
#     def __init__(
#         self,
#         *,
#         C=1.0,
#         kernel="rbf",
#         degree=3,
#         gamma="scale",
#         coef0=0.0,
#         shrinking=True,
#         probability=False,
#         tol=1e-3,
#         cache_size=200,
#         class_weight=None,
#         verbose=False,
#         max_iter=-1,
#         decision_function_shape="ovr",
#         break_ties=False,
#         random_state=None,
#     ):
#
#         super().__init__(
#             kernel=kernel,
#             degree=degree,
#             gamma=gamma,
#             coef0=coef0,
#             tol=tol,
#             C=C,
#             nu=0.0,
#             shrinking=shrinking,
#             probability=probability,
#             cache_size=cache_size,
#             class_weight=class_weight,
#             verbose=verbose,
#             max_iter=max_iter,
#             decision_function_shape=decision_function_shape,
#             break_ties=break_ties,
#             random_state=random_state,
#         )
#
#     def _more_tags(self):
#         return {
#             "_xfail_checks": {
#                 "check_sample_weights_invariance": (
#                     "zero sample_weight is not equivalent to removing samples"
#                 ),
#             }
#         }
# File:           c:\users\josel\anaconda3\envs\basic_ds\lib\site-packages\sklearn\svm\_classes.py
# Type:           ABCMeta
# Subclasses:

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier

'''
Por defecto coge soft voting, si pueden todos los clasificadores.
En el caso del SVM tiene que realizar una validación cruzada ya que
no soporta el predict_proba()
'''

log_clf = LogisticRegression(random_state=42) # Mezcla los datos
rnd_clf = RandomForestClassifier(n_estimators=100, random_state=42) # Se usa en combinación con otro arg
#rnd2_clf = RandomForestClassifier(n_estimators=500, max_depth = 3, random_state=42) # Se usa en combinación con otro arg
dt = DecisionTreeClassifier(max_depth=5)
svm_clf = SVC(gamma="scale", random_state=42)

estimators = [('lr', log_clf), 
                ('rf', rnd_clf), 
                #('rf2', rnd2_clf),  
                #("dt", dt),
                ('svc', svm_clf)]

# %%
# Train the model
voting_clf = VotingClassifier(estimators=estimators)
voting_clf.fit(X_train, y_train)
# Out:
# VotingClassifier(estimators=[('lr', LogisticRegression(random_state=42)),
#                              ('rf', RandomForestClassifier(random_state=42)),
#                              ('svc', SVC(random_state=42))])

# %%
from sklearn.metrics import accuracy_score

# %% [markdown]
# Vemos los aciertos (accuracy score) de todos los clasificadores + el voting classifier

# %%
from sklearn.metrics import accuracy_score

# estimators = [('lr', log_clf), 
#                 ('rf', rnd_clf), 
#                 #('rf2', rnd2_clf),  
                
#                 ('svc', svm_clf)
#                 ("bag", bag_clf)
#                 ]

for clf in estimators:
    clf = clf[1]
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    print(clf.__class__.__name__, accuracy_score(y_test, y_pred))


voting_clf = VotingClassifier(estimators=estimators, voting='soft')
voting_clf.fit(X_train, y_train)
y_pred = voting_clf.predict(X_test)
print(voting_clf.__class__.__name__, accuracy_score(y_test, y_pred))
# Out:
# LogisticRegression 0.7988826815642458
# RandomForestClassifier 0.7877094972067039
# DecisionTreeClassifier 0.8044692737430168
# BaggingClassifier 0.8100558659217877
# VotingClassifier 0.8268156424581006

# %% [markdown]
# Probaremos ahora con el `soft` VotingClassifier, es decir, teniendo e cuenta las probabilidades, no los votos.

# %%
log_clf = LogisticRegression(random_state=42)
rnd_clf = RandomForestClassifier(n_estimators=100, random_state=42)
svm_clf = SVC(gamma="scale", probability=True, random_state=42) # PROBABILITY = TRUE

estimators = [('lr', log_clf), ('rf', rnd_clf), ('svc', svm_clf)]

voting_clf = VotingClassifier(estimators=estimators, voting='hard')

# Train the model
voting_clf.fit(X_train, y_train)
# Out:
# VotingClassifier(estimators=[('lr', LogisticRegression(random_state=42)),
#                              ('rf', RandomForestClassifier(random_state=42)),
#                              ('svc', SVC(probability=True, random_state=42))])

# %%
for clf in (log_clf, rnd_clf, svm_clf, voting_clf):
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    print(clf.__class__.__name__, accuracy_score(y_test, y_pred))
# Out:
# LogisticRegression 0.7988826815642458
# RandomForestClassifier 0.7932960893854749
# SVC 0.6145251396648045
# VotingClassifier 0.8044692737430168

# %%
RandomForestClassifier??
# Out:
# Init signature:
# RandomForestClassifier(
#     n_estimators=100,
#     *,
#     criterion='gini',
#     max_depth=None,
#     min_samples_split=2,
#     min_samples_leaf=1,
#     min_weight_fraction_leaf=0.0,
#     max_features='auto',
#     max_leaf_nodes=None,
#     min_impurity_decrease=0.0,
#     bootstrap=True,
#     oob_score=False,
#     n_jobs=None,
#     random_state=None,
#     verbose=0,
#     warm_start=False,
#     class_weight=None,
#     ccp_alpha=0.0,
#     max_samples=None,
# )
# Source:
# class RandomForestClassifier(ForestClassifier):
#     """
#     A random forest classifier.
#
#     A random forest is a meta estimator that fits a number of decision tree
#     classifiers on various sub-samples of the dataset and uses averaging to
#     improve the predictive accuracy and control over-fitting.
#     The sub-sample size is controlled with the `max_samples` parameter if
#     `bootstrap=True` (default), otherwise the whole dataset is used to build
#     each tree.
#
#     Read more in the :ref:`User Guide <forest>`.
#
#     Parameters
#     ----------
#     n_estimators : int, default=100
#         The number of trees in the forest.
#
#         .. versionchanged:: 0.22
#            The default value of ``n_estimators`` changed from 10 to 100
#            in 0.22.
#
#     criterion : {"gini", "entropy"}, default="gini"
#         The function to measure the quality of a split. Supported criteria are
#         "gini" for the Gini impurity and "entropy" for the information gain.
#         Note: this parameter is tree-specific.
#
#     max_depth : int, default=None
#         The maximum depth of the tree. If None, then nodes are expanded until
#         all leaves are pure or until all leaves contain less than
#         min_samples_split samples.
#
#     min_samples_split : int or float, default=2
#         The minimum number of samples required to split an internal node:
#
#         - If int, then consider `min_samples_split` as the minimum number.
#         - If float, then `min_samples_split` is a fraction and
#           `ceil(min_samples_split * n_samples)` are the minimum
#           number of samples for each split.
#
#         .. versionchanged:: 0.18
#            Added float values for fractions.
#
#     min_samples_leaf : int or float, default=1
#         The minimum number of samples required to be at a leaf node.
#         A split point at any depth will only be considered if it leaves at
#         least ``min_samples_leaf`` training samples in each of the left and
#         right branches.  This may have the effect of smoothing the model,
#         especially in regression.
#
#         - If int, then consider `min_samples_leaf` as the minimum number.
#         - If float, then `min_samples_leaf` is a fraction and
#           `ceil(min_samples_leaf * n_samples)` are the minimum
#           number of samples for each node.
#
#         .. versionchanged:: 0.18
#            Added float values for fractions.
#
#     min_weight_fraction_leaf : float, default=0.0
#         The minimum weighted fraction of the sum total of weights (of all
#         the input samples) required to be at a leaf node. Samples have
#         equal weight when sample_weight is not provided.
#
#     max_features : {"auto", "sqrt", "log2"}, int or float, default="auto"
#         The number of features to consider when looking for the best split:
#
#         - If int, then consider `max_features` features at each split.
#         - If float, then `max_features` is a fraction and
#           `round(max_features * n_features)` features are considered at each
#           split.
#         - If "auto", then `max_features=sqrt(n_features)`.
#         - If "sqrt", then `max_features=sqrt(n_features)` (same as "auto").
#         - If "log2", then `max_features=log2(n_features)`.
#         - If None, then `max_features=n_features`.
#
#         Note: the search for a split does not stop until at least one
#         valid partition of the node samples is found, even if it requires to
#         effectively inspect more than ``max_features`` features.
#
#     max_leaf_nodes : int, default=None
#         Grow trees with ``max_leaf_nodes`` in best-first fashion.
#         Best nodes are defined as relative reduction in impurity.
#         If None then unlimited number of leaf nodes.
#
#     min_impurity_decrease : float, default=0.0
#         A node will be split if this split induces a decrease of the impurity
#         greater than or equal to this value.
#
#         The weighted impurity decrease equation is the following::
#
#             N_t / N * (impurity - N_t_R / N_t * right_impurity
#                                 - N_t_L / N_t * left_impurity)
#
#         where ``N`` is the total number of samples, ``N_t`` is the number of
#         samples at the current node, ``N_t_L`` is the number of samples in the
#         left child, and ``N_t_R`` is the number of samples in the right child.
#
#         ``N``, ``N_t``, ``N_t_R`` and ``N_t_L`` all refer to the weighted sum,
#         if ``sample_weight`` is passed.
#
#         .. versionadded:: 0.19
#
#     bootstrap : bool, default=True
#         Whether bootstrap samples are used when building trees. If False, the
#         whole dataset is used to build each tree.
#
#     oob_score : bool, default=False
#         Whether to use out-of-bag samples to estimate the generalization score.
#         Only available if bootstrap=True.
#
#     n_jobs : int, default=None
#         The number of jobs to run in parallel. :meth:`fit`, :meth:`predict`,
#         :meth:`decision_path` and :meth:`apply` are all parallelized over the
#         trees. ``None`` means 1 unless in a :obj:`joblib.parallel_backend`
#         context. ``-1`` means using all processors. See :term:`Glossary
#         <n_jobs>` for more details.
#
#     random_state : int, RandomState instance or None, default=None
#         Controls both the randomness of the bootstrapping of the samples used
#         when building trees (if ``bootstrap=True``) and the sampling of the
#         features to consider when looking for the best split at each node
#         (if ``max_features < n_features``).
#         See :term:`Glossary <random_state>` for details.
#
#     verbose : int, default=0
#         Controls the verbosity when fitting and predicting.
#
#     warm_start : bool, default=False
#         When set to ``True``, reuse the solution of the previous call to fit
#         and add more estimators to the ensemble, otherwise, just fit a whole
#         new forest. See :term:`the Glossary <warm_start>`.
#
#     class_weight : {"balanced", "balanced_subsample"}, dict or list of dicts, \
#             default=None
#         Weights associated with classes in the form ``{class_label: weight}``.
#         If not given, all classes are supposed to have weight one. For
#         multi-output problems, a list of dicts can be provided in the same
#         order as the columns of y.
#
#         Note that for multioutput (including multilabel) weights should be
#         defined for each class of every column in its own dict. For example,
#         for four-class multilabel classification weights should be
#         [{0: 1, 1: 1}, {0: 1, 1: 5}, {0: 1, 1: 1}, {0: 1, 1: 1}] instead of
#         [{1:1}, {2:5}, {3:1}, {4:1}].
#
#         The "balanced" mode uses the values of y to automatically adjust
#         weights inversely proportional to class frequencies in the input data
#         as ``n_samples / (n_classes * np.bincount(y))``
#
#         The "balanced_subsample" mode is the same as "balanced" except that
#         weights are computed based on the bootstrap sample for every tree
#         grown.
#
#         For multi-output, the weights of each column of y will be multiplied.
#
#         Note that these weights will be multiplied with sample_weight (passed
#         through the fit method) if sample_weight is specified.
#
#     ccp_alpha : non-negative float, default=0.0
#         Complexity parameter used for Minimal Cost-Complexity Pruning. The
#         subtree with the largest cost complexity that is smaller than
#         ``ccp_alpha`` will be chosen. By default, no pruning is performed. See
#         :ref:`minimal_cost_complexity_pruning` for details.
#
#         .. versionadded:: 0.22
#
#     max_samples : int or float, default=None
#         If bootstrap is True, the number of samples to draw from X
#         to train each base estimator.
#
#         - If None (default), then draw `X.shape[0]` samples.
#         - If int, then draw `max_samples` samples.
#         - If float, then draw `max_samples * X.shape[0]` samples. Thus,
#           `max_samples` should be in the interval `(0.0, 1.0]`.
#
#         .. versionadded:: 0.22
#
#     Attributes
#     ----------
#     base_estimator_ : DecisionTreeClassifier
#         The child estimator template used to create the collection of fitted
#         sub-estimators.
#
#     estimators_ : list of DecisionTreeClassifier
#         The collection of fitted sub-estimators.
#
#     classes_ : ndarray of shape (n_classes,) or a list of such arrays
#         The classes labels (single output problem), or a list of arrays of
#         class labels (multi-output problem).
#
#     n_classes_ : int or list
#         The number of classes (single output problem), or a list containing the
#         number of classes for each output (multi-output problem).
#
#     n_features_ : int
#         The number of features when ``fit`` is performed.
#
#         .. deprecated:: 1.0
#             Attribute `n_features_` was deprecated in version 1.0 and will be
#             removed in 1.2. Use `n_features_in_` instead.
#
#     n_features_in_ : int
#         Number of features seen during :term:`fit`.
#
#         .. versionadded:: 0.24
#
#     feature_names_in_ : ndarray of shape (`n_features_in_`,)
#         Names of features seen during :term:`fit`. Defined only when `X`
#         has feature names that are all strings.
#
#         .. versionadded:: 1.0
#
#     n_outputs_ : int
#         The number of outputs when ``fit`` is performed.
#
#     feature_importances_ : ndarray of shape (n_features,)
#         The impurity-based feature importances.
#         The higher, the more important the feature.
#         The importance of a feature is computed as the (normalized)
#         total reduction of the criterion brought by that feature.  It is also
#         known as the Gini importance.
#
#         Warning: impurity-based feature importances can be misleading for
#         high cardinality features (many unique values). See
#         :func:`sklearn.inspection.permutation_importance` as an alternative.
#
#     oob_score_ : float
#         Score of the training dataset obtained using an out-of-bag estimate.
#         This attribute exists only when ``oob_score`` is True.
#
#     oob_decision_function_ : ndarray of shape (n_samples, n_classes) or \
#             (n_samples, n_classes, n_outputs)
#         Decision function computed with out-of-bag estimate on the training
#         set. If n_estimators is small it might be possible that a data point
#         was never left out during the bootstrap. In this case,
#         `oob_decision_function_` might contain NaN. This attribute exists
#         only when ``oob_score`` is True.
#
#     See Also
#     --------
#     sklearn.tree.DecisionTreeClassifier : A decision tree classifier.
#     sklearn.ensemble.ExtraTreesClassifier : Ensemble of extremely randomized
#         tree classifiers.
#
#     Notes
#     -----
#     The default values for the parameters controlling the size of the trees
#     (e.g. ``max_depth``, ``min_samples_leaf``, etc.) lead to fully grown and
#     unpruned trees which can potentially be very large on some data sets. To
#     reduce memory consumption, the complexity and size of the trees should be
#     controlled by setting those parameter values.
#
#     The features are always randomly permuted at each split. Therefore,
#     the best found split may vary, even with the same training data,
#     ``max_features=n_features`` and ``bootstrap=False``, if the improvement
#     of the criterion is identical for several splits enumerated during the
#     search of the best split. To obtain a deterministic behaviour during
#     fitting, ``random_state`` has to be fixed.
#
#     References
#     ----------
#     .. [1] L. Breiman, "Random Forests", Machine Learning, 45(1), 5-32, 2001.
#
#     Examples
#     --------
#     >>> from sklearn.ensemble import RandomForestClassifier
#     >>> from sklearn.datasets import make_classification
#     >>> X, y = make_classification(n_samples=1000, n_features=4,
#     ...                            n_informative=2, n_redundant=0,
#     ...                            random_state=0, shuffle=False)
#     >>> clf = RandomForestClassifier(max_depth=2, random_state=0)
#     >>> clf.fit(X, y)
#     RandomForestClassifier(...)
#     >>> print(clf.predict([[0, 0, 0, 0]]))
#     [1]
#     """
#
#     def __init__(
#         self,
#         n_estimators=100,
#         *,
#         criterion="gini",
#         max_depth=None,
#         min_samples_split=2,
#         min_samples_leaf=1,
#         min_weight_fraction_leaf=0.0,
#         max_features="auto",
#         max_leaf_nodes=None,
#         min_impurity_decrease=0.0,
#         bootstrap=True,
#         oob_score=False,
#         n_jobs=None,
#         random_state=None,
#         verbose=0,
#         warm_start=False,
#         class_weight=None,
#         ccp_alpha=0.0,
#         max_samples=None,
#     ):
#         super().__init__(
#             base_estimator=DecisionTreeClassifier(),
#             n_estimators=n_estimators,
#             estimator_params=(
#                 "criterion",
#                 "max_depth",
#                 "min_samples_split",
#                 "min_samples_leaf",
#                 "min_weight_fraction_leaf",
#                 "max_features",
#                 "max_leaf_nodes",
#                 "min_impurity_decrease",
#                 "random_state",
#                 "ccp_alpha",
#             ),
#             bootstrap=bootstrap,
#             oob_score=oob_score,
#             n_jobs=n_jobs,
#             random_state=random_state,
#             verbose=verbose,
#             warm_start=warm_start,
#             class_weight=class_weight,
#             max_samples=max_samples,
#         )
#
#         self.criterion = criterion
#         self.max_depth = max_depth
#         self.min_samples_split = min_samples_split
#         self.min_samples_leaf = min_samples_leaf
#         self.min_weight_fraction_leaf = min_weight_fraction_leaf
#         self.max_features = max_features
#         self.max_leaf_nodes = max_leaf_nodes
#         self.min_impurity_decrease = min_impurity_decrease
#         self.ccp_alpha = ccp_alpha
# File:           c:\users\josel\anaconda3\envs\basic_ds\lib\site-packages\sklearn\ensemble\_forest.py
# Type:           ABCMeta
# Subclasses:

# %%
log_clf = LogisticRegression(random_state=42)
rnd_clf = RandomForestClassifier(n_estimators=100, random_state=42)
svm_clf = SVC(gamma="scale", probability=True, random_state=42) # PROBABILITY = TRUE

estimators = [('lr', log_clf), ('rf', rnd_clf), ('svc', svm_clf)]

soft_voting_clf = VotingClassifier(estimators=estimators, voting='soft')

# Train the model
soft_voting_clf.fit(X_train, y_train)
# Out:
# VotingClassifier(estimators=[('lr', LogisticRegression(random_state=42)),
#                              ('rf', RandomForestClassifier(random_state=42)),
#                              ('svc', SVC(probability=True, random_state=42))],
#                  voting='soft')

# %%
for clf in (log_clf, rnd_clf, svm_clf, soft_voting_clf):
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    print(clf.__class__.__name__, accuracy_score(y_test, y_pred))
# Out:
# LogisticRegression 0.7988826815642458
# RandomForestClassifier 0.7932960893854749
# SVC 0.6145251396648045
# VotingClassifier 0.8044692737430168

# %% [markdown]
# ## Bagging Classifier
# Sistema de clasificación por votación de algoritmos. En este caso siempre es el mismo tipo de algoritmo, habitualmente árboles de decisión.
#
# El siguiente ejemplo sería un algoritmo muy similar a un RandomForest.

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier

estimator = DecisionTreeClassifier(max_depth=3,random_state=42)
#estimator = LogisticRegression()

bag_clf = BaggingClassifier(
    base_estimator = estimator,
    n_estimators=1000, # Cantidad de árboles
    max_samples=100, # Muestras utilizadas en boostrapping
    bootstrap=True, # Usamos boostrapping
    # max_features = 3 # Features que utiliza en el boostrapping. Cuanto más bajo, mejor generalizará y menos overfitting
    random_state=42)


bag_clf.fit(X_train, y_train)
y_pred = bag_clf.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.8100558659217877

# %% [markdown]
# Mejor que un DecisionTree por separado

# %%
tree_clf = DecisionTreeClassifier(random_state=42)
tree_clf.fit(X_train, y_train)
y_pred_tree = tree_clf.predict(X_test)
print(accuracy_score(y_test, y_pred_tree))
# Out:
# 0.776536312849162

# %% [markdown]
# ## Random Forest
#
# Los RandomForest cuentan con todos los hiperparámetros de un DecissionTree y los de un algoritmo de Bagging.
#
# **RandomForestClassifier**

# %%
from sklearn.ensemble import RandomForestClassifier

rnd_clf = RandomForestClassifier(n_estimators=500,
                                 max_leaf_nodes=16,
                                 random_state=42)
rnd_clf.fit(X_train, y_train)

y_pred_rf = rnd_clf.predict(X_test)
# np.sum(y_test == y_pred_rf) / len(y_test) 
accuracy_score(y_test, y_pred_rf)
# Out:
# 0.8100558659217877

# %% [markdown]
# Mejor que el Bagging Classifier, al llevar parámetros por defecto aplicados al DecisionTree que funcionan mejor para estos datos.
#
# Veamos el feature importance. En cada split de los árboles se calcula el IG (Information Gained) teniendo en cuenta la entropía antes y después del split. Se realiza una ponderación del IG en cada spllit, teniendo en cuenta la feature del split y con ello sklearn consigue el feature importance

# %%
sns.barplot(x=classes, y=rnd_clf.feature_importances_);

# %% [markdown]
# Ejemplo de feature importance en imagenes

# %%
from sklearn.datasets import fetch_openml
import matplotlib.pyplot as plt

mnist = fetch_openml('mnist_784', version=1)
mnist.target = mnist.target.astype(np.uint8)

rnd_clf = RandomForestClassifier(n_estimators=100, random_state=42)
rnd_clf.fit(mnist["data"], mnist["target"])

def plot_digit(data):
    image = data.reshape(28, 28)
    plt.imshow(image, cmap = mpl.cm.hot,
               interpolation="nearest")
    plt.axis("off")
    
plot_digit(rnd_clf.feature_importances_)

cbar = plt.colorbar(ticks=[rnd_clf.feature_importances_.min(), rnd_clf.feature_importances_.max()])
cbar.ax.set_yticklabels(['Not important', 'Very important'])

plt.show()

# %%
mnist["data"].shape
# Out:
# (70000, 784)

# %% [markdown]
# **¿Qué hiperparámetros debería tocar en el RandomForest?**
# 1. `n_estimators`: número de árboles que participarán en las votaciones. Cuantos más mejor. NO producen overfitting. Cuanto más complejo es el dataset, mejor vendrá que haya muchos árboles. Más de 200 suele ser redundante.
# 2. `max_depth`: profundida de los árboles. Cuanto más profundos, más complejo es el modelo, pero menos generaliza. De  nuevo, cuanto más complejo es el problema, mayor profundidad necesitaremos. No más de 20/30 es lo normal.
# 3. `max_features`: features a tener en cuenta en los splits del árbol. Cuanto más bajo, mejor generalizará y menos overfitting. Numero menor a la cantidad de features del dataset, sino dará error.
# 4. `min_samples_split`: mínima cantidad de muestras en un nodo antes de ser spliteado. 2 por defecto. Números bajos suelen dar buenos resultados (<50). Cuanto más alto, mejor generaliza, pero más baja la precisión.
# 5. `min_samples_leaf`: mínima cantidad de puntos permitidos en un `leaf node`, es decir, un nodo que no va a volver a ser spliteado. Valores bajos funcionan bien (<50).

# %% [markdown]
# **RandomForestRegressor**

# %%
df_reg = pd.read_csv('data/USA_Housing.csv')

X_reg = df_reg.loc[:, 'Avg. Area Income': 'Area Population'].values
Y_reg = df_reg['Price'].values
df_reg.head(2)
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\r\nLaurabury, NE 37...
# 1  188 Johnson Views Suite 079\r\nLake Kathleen, ...

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error

rnd_reg = RandomForestRegressor(n_estimators=500,
                                 max_leaf_nodes=16,
                                 random_state=42)
rnd_reg.fit(X_reg, Y_reg)

y_pred_reg = rnd_reg.predict(X_reg)
mean_absolute_error(Y_reg, y_pred_reg)
# Out:
# 147827.0018536551

# %%
rnd_reg.score(X_reg, Y_reg)
# Out:
# 0.718187762051737

# %% [markdown]
# ## AdaBoost
#
# **AdaBoostClassifier**

# %%
X_train[:5]
# Out:
# array([[ 2.,  1., 43.,  1.,  1.,  0.,  1.],
#        [ 1.,  0., 32.,  0.,  0.,  0.,  0.],
#        [ 3.,  0., 16.,  0.,  0.,  0.,  0.],
#        [ 1.,  1., 47.,  0.,  0.,  0.,  0.],
#        [ 1.,  1., 34.,  0.,  0.,  0.,  0.]])

# %%
from sklearn.ensemble import AdaBoostClassifier

from sklearn.ensemble import ExtraTreesClassifier, GradientBoostingClassifier

estimator = DecisionTreeClassifier(max_depth=1)

ada_clf = AdaBoostClassifier(base_estimator = estimator,
                             n_estimators=500,
                             learning_rate=0.3,
                             random_state=42)

ada_clf = GradientBoostingClassifier(n_estimators=100)




ada_clf.fit(X_train, y_train)

y_pred = ada_clf.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.8156424581005587

# %% [markdown]
# También tenemos feature importance

# %%
sns.barplot(x=classes, y=ada_clf.feature_importances_);

# %% [markdown]
# **¿Qué hiperparámetros debería tocar en el AdaBoostClassifier?**
# 1. `n_estimators`: número de árboles que participarán en la corrección secuencial del error del modelo. Si corregimos el error a la perfección el algoritmo termina de entrenar. Cuantos más estimadores, mejor corregiremos el error pero mayor probabilidad de caer en overfitting. Valores superiores a 100 suelen sobreajustar el modelo aunque dependerá de la complejidad y volumen de los datos.
# 2. `learning_rate`: no suele tener valores superiores a 1. Cuanto más alto, más aporta cada nuevo árbol, más preciso, pero caemos en overfitting. **Importante**: un learning rate bajo y alto número de estimadores no necesariamente tiene por qué aumentar la precisión y si va a inducir en altos costes computacionales.
# 3. `algorithm`: 'SAME' o 'SAME.R'. 'SAME.R' utiliza la probabilidad para actualizar los modelos aditivos, mientras que 'SAME' usa los valores de clasificación. Similar a soft vs hard voting. 'SAMME.R' converge antes que 'SAMME'
# 4. `base_estimator`: se suele dejar por defecto, aunque podría encajar un SVM o una RegresiónLogística
# 5. `max_depth`: **OJO**, no es un hiperparámetro del AdaBoostClassifier, sino del DecisionTreeClassifier. Habrá que probar varios árboles con diferentes `max_depth` y después ponerlos como `base_estimator` en el AdaBoost. Cuanto mayor es este hiperparámetro, más preciso, pero también más overfitting.

# %% [markdown]
# **AdaBoostRegressor**

# %%
from sklearn.ensemble import AdaBoostRegressor

ada_reg = AdaBoostRegressor(n_estimators=200,
                            random_state=42)
ada_reg.fit(X_reg, Y_reg)

y_pred_ada_reg = ada_reg.predict(X_reg)
mean_absolute_error(Y_reg, y_pred_ada_reg)
# Out:
# 100809.79130779192

# %% [markdown]
# ## GradientBoosting
#
# **GradientBoostingRegressor**
#
# El GradientBoosting funciona sólo con árboles, por eso no es posible cambiar el estimador. Directamente los hiperparámetros a configurar en en GradientBoosting son los del DecissionTree.
#
# En este caso, vamos a probar primero con un regresor, que se entiende mejor.

# %%
np.random.seed(42)
X = np.random.rand(100, 1) - 0.5
y = 3*X[:, 0]**2 + 0.05 * np.random.randn(100)

# %%
from sklearn.tree import DecisionTreeRegressor

tree_reg1 = DecisionTreeRegressor(max_depth=2, random_state=42)
tree_reg1.fit(X, y)
# Out:
# DecisionTreeRegressor(max_depth=2, random_state=42)

# %%
y2 = y - tree_reg1.predict(X)
tree_reg2 = DecisionTreeRegressor(max_depth=2, random_state=42)
tree_reg2.fit(X, y2)
# Out:
# DecisionTreeRegressor(max_depth=2, random_state=42)

# %%
y3 = y2 - tree_reg2.predict(X)
tree_reg3 = DecisionTreeRegressor(max_depth=2, random_state=42)
tree_reg3.fit(X, y3)
# Out:
# DecisionTreeRegressor(max_depth=2, random_state=42)

# %%
X_new = np.array([[0.8]])

# %%
y_pred = sum(tree.predict(X_new) for tree in (tree_reg1, tree_reg2, tree_reg3))

# %%
y_pred
# Out:
# array([0.75026781])

# %%
import matplotlib.pyplot as plt

# %%
def plot_predictions(regressors, X, y, axes, label=None, style="r-", data_style="b.", data_label=None):
    x1 = np.linspace(axes[0], axes[1], 500)
    y_pred = sum(regressor.predict(x1.reshape(-1, 1)) for regressor in regressors)
    plt.plot(X[:, 0], y, data_style, label=data_label)
    plt.plot(x1, y_pred, style, linewidth=2, label=label)
    if label or data_label:
        plt.legend(loc="upper center", fontsize=16)
    plt.axis(axes)

# %%
plt.figure(figsize=(11,11))

plt.subplot(321)
plot_predictions([tree_reg1], X, y, axes=[-0.5, 0.5, -0.1, 0.8], label="$h_1(x_1)$", style="g-", data_label="Training set")
plt.ylabel("$y$", fontsize=16, rotation=0)
plt.title("Residuals and tree predictions", fontsize=16)

plt.subplot(322)
plot_predictions([tree_reg1], X, y, axes=[-0.5, 0.5, -0.1, 0.8], label="$h(x_1) = h_1(x_1)$", data_label="Training set")
plt.ylabel("$y$", fontsize=16, rotation=0)
plt.title("Ensemble predictions", fontsize=16)

plt.subplot(323)
plot_predictions([tree_reg2], X, y2, axes=[-0.5, 0.5, -0.5, 0.5], label="$h_2(x_1)$", style="g-", data_style="k+", data_label="Residuals")
plt.ylabel("$y - h_1(x_1)$", fontsize=16)

plt.subplot(324)
plot_predictions([tree_reg1, tree_reg2], X, y, axes=[-0.5, 0.5, -0.1, 0.8], label="$h(x_1) = h_1(x_1) + h_2(x_1)$")
plt.ylabel("$y$", fontsize=16, rotation=0)

plt.subplot(325)
plot_predictions([tree_reg3], X, y3, axes=[-0.5, 0.5, -0.5, 0.5], label="$h_3(x_1)$", style="g-", data_style="k+")
plt.ylabel("$y - h_1(x_1) - h_2(x_1)$", fontsize=16)
plt.xlabel("$x_1$", fontsize=16)

plt.subplot(326)
plot_predictions([tree_reg1, tree_reg2, tree_reg3], X, y, axes=[-0.5, 0.5, -0.1, 0.8], label="$h(x_1) = h_1(x_1) + h_2(x_1) + h_3(x_1)$")
plt.xlabel("$x_1$", fontsize=16)
plt.ylabel("$y$", fontsize=16, rotation=0)

plt.show()

# %%
from sklearn.ensemble import GradientBoostingRegressor

gbrt = GradientBoostingRegressor(max_depth=2,
                                 n_estimators=3,
                                 learning_rate=1.0,
                                 random_state=42)
gbrt.fit(X_reg, Y_reg)


y_pred_gbrt = gbrt.predict(X_reg)
mean_absolute_error(Y_reg, y_pred_gbrt)
# Out:
# 158608.16086318

# %% [markdown]
# **GradientBoostingClassifier**

# %%
from sklearn.ensemble import GradientBoostingClassifier

gbct = GradientBoostingClassifier(
                                 random_state=42)
gbct.fit(X_train, y_train)


y_pred_gbct = gbct.predict(X_test)
accuracy_score(y_test, y_pred_gbct)
# Out:
# 0.8156424581005587

# %% [markdown]
# **¿Qué hiperparámetros debería tocar en el GradientBoosting?**
# 1. `n_estimators`: número de árboles que participarán en la corrección secuencial del error del modelo. Si corregimos el error a la perfección el algoritmo termina de entrenar. Cuantos más estimadores, mejor corregiremos el error pero mayor probabilidad de caer en overfitting. Valores superiores a 100 suelen sobreajustar el modelo aunque dependerá de la complejidad y volumen de los datos.
# 2. `learning_rate`: no suele tener valores superiores a 1. Cuanto más alto, más aporta cada nuevo árbol, más preciso, pero caemos en overfitting. **Importante**: un learning rate bajo y alto número de estimadores no necesariamente tiene por qué aumentar la precisión y si va a inducir en altos costes computacionales.
# 3. `max_depth`: Cuanto mayor es este hyperparámetro, más preciso, pero también más overfitting.
#
# Se puede iterar sobre todos los hiperparámetros recorridos en el RandomForest

# %% [markdown]
# ## XGBoost
#
# **XGBRegressor**
#
# https://xgboost.readthedocs.io/en/latest/python/python_api.html#module-xgboost.sklearn
#
# XGBoost permite regularizar el modelo, puede manejar missings, por lo que no es necesario tener el dataset perfectamente limpio

# %%
#!pip install xgboost

# %%
import catboost

# %%
import xgboost

xgb_reg = xgboost.XGBRegressor(random_state=42)

xgb_reg.fit(X_reg, Y_reg)
y_pred = xgb_reg.predict(X_reg)
mean_absolute_error(Y_reg, y_pred)
# Out:
# 43347.53348686592

# %%
xgb_reg.score(X_reg, Y_reg)
# Out:
# 0.9737127694450987

# %%
catboost.CatBoostRegressor

# %%
import catboost

xgb_reg = catboost.CatBoostRegressor(random_state=42)

xgb_reg.fit(X_reg, Y_reg)
y_pred = xgb_reg.predict(X_reg)
mean_absolute_error(Y_reg, y_pred)
# Out:
# Learning rate set to 0.052798
# 0:	learn: 341618.6883263	total: 268ms	remaining: 4m 27s
# 1:	learn: 330764.3378042	total: 402ms	remaining: 3m 20s
# 2:	learn: 320810.8530185	total: 432ms	remaining: 2m 23s
# 3:	learn: 310669.1373831	total: 585ms	remaining: 2m 25s
# 4:	learn: 301324.2682752	total: 719ms	remaining: 2m 23s
# 5:	learn: 291877.5401154	total: 748ms	remaining: 2m 3s
# 6:	learn: 283193.5394697	total: 829ms	remaining: 1m 57s
# 7:	learn: 274707.0696581	total: 848ms	remaining: 1m 45s
# 8:	learn: 266815.4896633	total: 913ms	remaining: 1m 40s
# 9:	learn: 258999.4689661	total: 933ms	remaining: 1m 32s
# 10:	learn: 251867.7068682	total: 944ms	remaining: 1m 24s
# 11:	learn: 244866.8680888	total: 947ms	remaining: 1m 17s
# 12:	learn: 238384.6529828	total: 951ms	remaining: 1m 12s
# 13:	learn: 232053.7692774	total: 956ms	remaining: 1m 7s
# 14:	learn: 226210.1083093	total: 961ms	remaining: 1m 3s
# 15:	learn: 220449.0297242	total: 964ms	remaining: 59.3s
# 16:	learn: 214849.6317581	total: 971ms	remaining: 56.1s
# 17:	learn: 209635.9742790	total: 973ms	remaining: 53.1s
# 18:	learn: 204934.8792947	total: 978ms	remaining: 50.5s
# 19:	learn: 200637.5966731	total: 988ms	remaining: 48.4s
# 20:	learn: 196265.7149257	total: 1s	remaining: 46.8s
# 21:	learn: 191875.5653014	total: 1.01s	remaining: 44.9s
# 22:	learn: 187876.2308699	total: 1.02s	remaining: 43.5s
# 23:	learn: 184168.7659621	total: 1.05s	remaining: 42.6s
# 24:	learn: 180373.5130113	total: 1.05s	remaining: 41.2s
# 25:	learn: 177001.5254004	total: 1.06s	remaining: 39.7s
# 26:	learn: 173701.5912601	total: 1.07s	remaining: 38.6s
# 27:	learn: 170551.9280916	total: 1.08s	remaining: 37.4s
# 28:	learn: 167507.3556131	total: 1.08s	remaining: 36.2s
# 29:	learn: 164527.2657842	total: 1.08s	remaining: 35s
# 30:	learn: 161732.2169269	total: 1.09s	remaining: 34s
# 31:	learn: 159211.6697149	total: 1.09s	remaining: 33s
# 32:	learn: 156630.5578419	total: 1.09s	remaining: 32.1s
# 33:	learn: 154200.0950254	total: 1.1s	remaining: 31.2s
# 34:	learn: 152027.0574227	total: 1.1s	remaining: 30.4s
# 35:	learn: 149941.4938985	total: 1.1s	remaining: 29.6s
# 36:	learn: 147763.7555156	total: 1.11s	remaining: 28.9s
# 37:	learn: 145832.5860108	total: 1.11s	remaining: 28.2s
# 38:	learn: 144211.7977573	total: 1.12s	remaining: 27.5s
# 39:	learn: 142298.2959876	total: 1.12s	remaining: 26.9s
# 40:	learn: 140420.5766796	total: 1.12s	remaining: 26.3s
# 41:	learn: 138737.5078461	total: 1.13s	remaining: 25.8s
# 42:	learn: 137142.3150393	total: 1.14s	remaining: 25.3s
# 43:	learn: 135479.4151177	total: 1.14s	remaining: 24.8s
# 44:	learn: 134052.5534643	total: 1.14s	remaining: 24.3s
# 45:	learn: 132723.3092095	total: 1.15s	remaining: 23.9s
# 46:	learn: 131393.4301992	total: 1.17s	remaining: 23.7s
# 47:	learn: 130016.0713923	total: 1.18s	remaining: 23.4s
# 48:	learn: 128782.4292272	total: 1.18s	remaining: 22.9s
# 49:	learn: 127534.9448782	total: 1.19s	remaining: 22.6s
# 50:	learn: 126380.2554568	total: 1.2s	remaining: 22.2s
# 51:	learn: 125288.7575097	total: 1.2s	remaining: 21.9s
# 52:	learn: 124320.7913289	total: 1.21s	remaining: 21.6s
# 53:	learn: 123301.9212568	total: 1.22s	remaining: 21.5s
# 54:	learn: 122359.4593845	total: 1.23s	remaining: 21.1s
# 55:	learn: 121429.9647482	total: 1.24s	remaining: 20.9s
# 56:	learn: 120505.3187371	total: 1.25s	remaining: 20.6s
# 57:	learn: 119632.7479014	total: 1.25s	remaining: 20.4s
# 58:	learn: 118759.3868759	total: 1.28s	remaining: 20.4s
# 59:	learn: 117991.9555820	total: 1.3s	remaining: 20.4s
# 60:	learn: 117280.4958534	total: 1.32s	remaining: 20.3s
# 61:	learn: 116605.1037958	total: 1.32s	remaining: 20s
# 62:	learn: 115921.3162633	total: 1.34s	remaining: 19.9s
# 63:	learn: 115275.4835808	total: 1.35s	remaining: 19.7s
# 64:	learn: 114684.7148964	total: 1.35s	remaining: 19.4s
# 65:	learn: 114129.5038821	total: 1.35s	remaining: 19.1s
# 66:	learn: 113573.1306247	total: 1.35s	remaining: 18.9s
# 67:	learn: 113058.9171647	total: 1.36s	remaining: 18.6s
# 68:	learn: 112498.1371594	total: 1.36s	remaining: 18.4s
# 69:	learn: 112048.3316325	total: 1.37s	remaining: 18.2s
# 70:	learn: 111632.7139630	total: 1.37s	remaining: 17.9s
# 71:	learn: 111183.9411711	total: 1.38s	remaining: 17.7s
# 72:	learn: 110825.3402378	total: 1.38s	remaining: 17.5s
# 73:	learn: 110363.8255606	total: 1.39s	remaining: 17.4s
# 74:	learn: 109950.6557389	total: 1.42s	remaining: 17.5s
# 75:	learn: 109565.6164603	total: 1.43s	remaining: 17.4s
# 76:	learn: 109246.7129651	total: 1.45s	remaining: 17.3s
# 77:	learn: 108932.5773390	total: 1.48s	remaining: 17.5s
# 78:	learn: 108565.7467143	total: 1.51s	remaining: 17.6s
# 79:	learn: 108267.9740024	total: 1.51s	remaining: 17.4s
# 80:	learn: 107945.8757671	total: 1.52s	remaining: 17.3s
# 81:	learn: 107647.3631368	total: 1.53s	remaining: 17.1s
# 82:	learn: 107340.8994665	total: 1.54s	remaining: 17s
# 83:	learn: 107063.3160006	total: 1.54s	remaining: 16.8s
# 84:	learn: 106832.9627100	total: 1.54s	remaining: 16.6s
# 85:	learn: 106606.1659258	total: 1.55s	remaining: 16.5s
# 86:	learn: 106337.6914970	total: 1.55s	remaining: 16.3s
# 87:	learn: 106084.2656317	total: 1.57s	remaining: 16.2s
# 88:	learn: 105855.6730021	total: 1.57s	remaining: 16.1s
# 89:	learn: 105674.1753149	total: 1.57s	remaining: 15.9s
# 90:	learn: 105455.7038191	total: 1.58s	remaining: 15.8s
# 91:	learn: 105232.4702060	total: 1.58s	remaining: 15.6s
# 92:	learn: 105059.3002903	total: 1.59s	remaining: 15.5s
# 93:	learn: 104862.0978901	total: 1.6s	remaining: 15.4s
# 94:	learn: 104642.6495283	total: 1.63s	remaining: 15.5s
# 95:	learn: 104504.7149528	total: 1.64s	remaining: 15.4s
# 96:	learn: 104319.9383582	total: 1.65s	remaining: 15.3s
# 97:	learn: 104141.8511615	total: 1.65s	remaining: 15.2s
# 98:	learn: 103988.4591608	total: 1.67s	remaining: 15.2s
# 99:	learn: 103852.2462769	total: 1.69s	remaining: 15.2s
# 100:	learn: 103708.9656432	total: 1.71s	remaining: 15.2s
# 101:	learn: 103546.7837526	total: 1.71s	remaining: 15.1s
# 102:	learn: 103419.6308123	total: 1.72s	remaining: 15s
# 103:	learn: 103273.1984300	total: 1.73s	remaining: 14.9s
# 104:	learn: 103142.7580881	total: 1.74s	remaining: 14.8s
# 105:	learn: 103019.2695274	total: 1.75s	remaining: 14.7s
# 106:	learn: 102898.6250594	total: 1.75s	remaining: 14.6s
# 107:	learn: 102796.3688646	total: 1.76s	remaining: 14.5s
# 108:	learn: 102697.7223230	total: 1.77s	remaining: 14.5s
# 109:	learn: 102598.3257211	total: 1.78s	remaining: 14.4s
# 110:	learn: 102484.5061554	total: 1.78s	remaining: 14.3s
# 111:	learn: 102382.0902127	total: 1.79s	remaining: 14.2s
# 112:	learn: 102299.1485398	total: 1.8s	remaining: 14.1s
# 113:	learn: 102225.5182567	total: 1.8s	remaining: 14s
# 114:	learn: 102126.0769521	total: 1.81s	remaining: 13.9s
# 115:	learn: 102037.4747520	total: 1.81s	remaining: 13.8s
# 116:	learn: 101957.2891188	total: 1.82s	remaining: 13.8s
# 117:	learn: 101870.2619449	total: 1.83s	remaining: 13.7s
# 118:	learn: 101783.3712936	total: 1.83s	remaining: 13.5s
# 119:	learn: 101695.4339464	total: 1.84s	remaining: 13.5s
# 120:	learn: 101616.1550261	total: 1.84s	remaining: 13.4s
# 121:	learn: 101547.2855017	total: 1.84s	remaining: 13.3s
# 122:	learn: 101456.5270508	total: 1.85s	remaining: 13.2s
# 123:	learn: 101378.9360727	total: 1.85s	remaining: 13.1s
# 124:	learn: 101320.2820864	total: 1.86s	remaining: 13s
# 125:	learn: 101265.3581262	total: 1.86s	remaining: 12.9s
# 126:	learn: 101209.8202600	total: 1.86s	remaining: 12.8s
# 127:	learn: 101141.5606092	total: 1.87s	remaining: 12.7s
# 128:	learn: 101066.7305944	total: 1.87s	remaining: 12.6s
# 129:	learn: 100999.5761996	total: 1.87s	remaining: 12.5s
# 130:	learn: 100944.5306545	total: 1.88s	remaining: 12.4s
# 131:	learn: 100884.7372542	total: 1.88s	remaining: 12.4s
# 132:	learn: 100817.8936804	total: 1.89s	remaining: 12.3s
# 133:	learn: 100757.0307758	total: 1.89s	remaining: 12.2s
# 134:	learn: 100715.8025966	total: 1.89s	remaining: 12.1s
# 135:	learn: 100656.0982335	total: 1.9s	remaining: 12.1s
# 136:	learn: 100615.9233326	total: 1.9s	remaining: 12s
# 137:	learn: 100573.5060247	total: 1.9s	remaining: 11.9s
# 138:	learn: 100521.8598763	total: 1.91s	remaining: 11.9s
# 139:	learn: 100474.2726127	total: 1.92s	remaining: 11.8s
# 140:	learn: 100427.2173762	total: 1.93s	remaining: 11.8s
# 141:	learn: 100383.4200170	total: 1.94s	remaining: 11.7s
# 142:	learn: 100339.4967252	total: 1.94s	remaining: 11.6s
# 143:	learn: 100291.7641155	total: 1.95s	remaining: 11.6s
# 144:	learn: 100243.1495256	total: 1.95s	remaining: 11.5s
# 145:	learn: 100198.5792248	total: 1.96s	remaining: 11.4s
# 146:	learn: 100151.7100563	total: 1.96s	remaining: 11.4s
# 147:	learn: 100105.6221450	total: 1.97s	remaining: 11.3s
# 148:	learn: 100065.0709963	total: 1.97s	remaining: 11.2s
# 149:	learn: 100012.2130723	total: 1.97s	remaining: 11.2s
# 150:	learn: 99974.2616866	total: 1.98s	remaining: 11.1s
# 151:	learn: 99934.0219448	total: 1.98s	remaining: 11.1s
# 152:	learn: 99894.3635559	total: 1.98s	remaining: 11s
# 153:	learn: 99856.4686705	total: 1.99s	remaining: 10.9s
# 154:	learn: 99823.0627698	total: 1.99s	remaining: 10.9s
# 155:	learn: 99781.4973415	total: 1.99s	remaining: 10.8s
# 156:	learn: 99747.6245548	total: 2s	remaining: 10.7s
# 157:	learn: 99710.5090690	total: 2s	remaining: 10.7s
# 158:	learn: 99677.1026144	total: 2s	remaining: 10.6s
# 159:	learn: 99631.7416496	total: 2.01s	remaining: 10.5s
# 160:	learn: 99599.1956225	total: 2.01s	remaining: 10.5s
# 161:	learn: 99561.1470497	total: 2.01s	remaining: 10.4s
# 162:	learn: 99519.8650434	total: 2.02s	remaining: 10.4s
# 163:	learn: 99483.2548308	total: 2.02s	remaining: 10.3s
# 164:	learn: 99447.9650905	total: 2.03s	remaining: 10.3s
# 165:	learn: 99418.3321259	total: 2.03s	remaining: 10.2s
# 166:	learn: 99386.0213696	total: 2.03s	remaining: 10.1s
# 167:	learn: 99349.9713933	total: 2.04s	remaining: 10.1s
# 168:	learn: 99321.9157014	total: 2.04s	remaining: 10s
# 169:	learn: 99283.7477810	total: 2.04s	remaining: 9.97s
# 170:	learn: 99245.6346722	total: 2.04s	remaining: 9.91s
# 171:	learn: 99208.9951750	total: 2.05s	remaining: 9.86s
# 172:	learn: 99179.8710559	total: 2.05s	remaining: 9.81s
# 173:	learn: 99145.0678325	total: 2.05s	remaining: 9.75s
# 174:	learn: 99121.1597982	total: 2.06s	remaining: 9.7s
# 175:	learn: 99091.7991916	total: 2.06s	remaining: 9.64s
# 176:	learn: 99061.8321217	total: 2.06s	remaining: 9.59s
# 177:	learn: 99031.9080251	total: 2.07s	remaining: 9.54s
# 178:	learn: 98993.5227434	total: 2.07s	remaining: 9.5s
# 179:	learn: 98959.1807547	total: 2.07s	remaining: 9.45s
# 180:	learn: 98928.0817582	total: 2.08s	remaining: 9.41s
# 181:	learn: 98897.3599488	total: 2.08s	remaining: 9.36s
# 182:	learn: 98869.3539950	total: 2.08s	remaining: 9.31s
# 183:	learn: 98836.1683128	total: 2.09s	remaining: 9.26s
# 184:	learn: 98794.9600267	total: 2.09s	remaining: 9.21s
# 185:	learn: 98769.0947578	total: 2.1s	remaining: 9.17s
# 186:	learn: 98735.9377140	total: 2.1s	remaining: 9.12s
# 187:	learn: 98696.5122537	total: 2.1s	remaining: 9.08s
# 188:	learn: 98652.1629681	total: 2.1s	remaining: 9.03s
# 189:	learn: 98618.5897509	total: 2.11s	remaining: 8.99s
# 190:	learn: 98593.0338349	total: 2.11s	remaining: 8.95s
# 191:	learn: 98558.9124663	total: 2.12s	remaining: 8.9s
# 192:	learn: 98530.6446197	total: 2.12s	remaining: 8.85s
# 193:	learn: 98496.0183814	total: 2.12s	remaining: 8.81s
# 194:	learn: 98454.7220926	total: 2.13s	remaining: 8.78s
# 195:	learn: 98422.3943700	total: 2.13s	remaining: 8.73s
# 196:	learn: 98391.6308088	total: 2.13s	remaining: 8.69s
# 197:	learn: 98355.1684940	total: 2.13s	remaining: 8.65s
# 198:	learn: 98326.5362369	total: 2.14s	remaining: 8.6s
# 199:	learn: 98297.1992541	total: 2.14s	remaining: 8.57s
# 200:	learn: 98264.5884220	total: 2.15s	remaining: 8.53s
# 201:	learn: 98241.3742026	total: 2.15s	remaining: 8.49s
# 202:	learn: 98209.4821988	total: 2.15s	remaining: 8.44s
# 203:	learn: 98164.7181758	total: 2.15s	remaining: 8.4s
# 204:	learn: 98126.8762684	total: 2.16s	remaining: 8.39s
# 205:	learn: 98090.1470209	total: 2.17s	remaining: 8.35s
# 206:	learn: 98054.2715351	total: 2.17s	remaining: 8.31s
# 207:	learn: 98025.0968884	total: 2.18s	remaining: 8.29s
# 208:	learn: 97996.7880628	total: 2.18s	remaining: 8.25s
# 209:	learn: 97967.8226357	total: 2.18s	remaining: 8.21s
# 210:	learn: 97934.1118777	total: 2.19s	remaining: 8.19s
# 211:	learn: 97906.0639990	total: 2.19s	remaining: 8.15s
# 212:	learn: 97869.9847470	total: 2.19s	remaining: 8.11s
# 213:	learn: 97844.7821365	total: 2.2s	remaining: 8.07s
# 214:	learn: 97823.1521410	total: 2.2s	remaining: 8.05s
# 215:	learn: 97802.0298121	total: 2.21s	remaining: 8.01s
# 216:	learn: 97773.7230671	total: 2.21s	remaining: 7.97s
# 217:	learn: 97744.3168939	total: 2.21s	remaining: 7.94s
# 218:	learn: 97719.8490674	total: 2.21s	remaining: 7.9s
# 219:	learn: 97696.2802744	total: 2.22s	remaining: 7.88s
# 220:	learn: 97668.2415411	total: 2.23s	remaining: 7.85s
# 221:	learn: 97635.6324891	total: 2.23s	remaining: 7.81s
# 222:	learn: 97604.6006449	total: 2.23s	remaining: 7.79s
# 223:	learn: 97572.1298028	total: 2.24s	remaining: 7.76s
# 224:	learn: 97528.3505456	total: 2.24s	remaining: 7.72s
# 225:	learn: 97497.4412023	total: 2.24s	remaining: 7.69s
# 226:	learn: 97467.8246352	total: 2.25s	remaining: 7.66s
# 227:	learn: 97448.5516810	total: 2.25s	remaining: 7.63s
# 228:	learn: 97422.1275777	total: 2.26s	remaining: 7.6s
# 229:	learn: 97385.0891974	total: 2.26s	remaining: 7.57s
# 230:	learn: 97342.5511877	total: 2.26s	remaining: 7.53s
# 231:	learn: 97319.7937805	total: 2.27s	remaining: 7.51s
# 232:	learn: 97292.9757449	total: 2.27s	remaining: 7.47s
# 233:	learn: 97264.6222555	total: 2.27s	remaining: 7.44s
# 234:	learn: 97217.5335649	total: 2.28s	remaining: 7.41s
# 235:	learn: 97181.6062372	total: 2.28s	remaining: 7.39s
# 236:	learn: 97148.4592423	total: 2.29s	remaining: 7.36s
# 237:	learn: 97097.7085909	total: 2.29s	remaining: 7.34s
# 238:	learn: 97069.6847095	total: 2.3s	remaining: 7.32s
# 239:	learn: 97046.0780938	total: 2.31s	remaining: 7.3s
# 240:	learn: 97021.6925368	total: 2.32s	remaining: 7.31s
# 241:	learn: 96988.2379857	total: 2.33s	remaining: 7.29s
# 242:	learn: 96950.3173086	total: 2.33s	remaining: 7.27s
# 243:	learn: 96910.5478640	total: 2.34s	remaining: 7.26s
# 244:	learn: 96891.2962096	total: 2.35s	remaining: 7.23s
# 245:	learn: 96866.2939487	total: 2.35s	remaining: 7.2s
# 246:	learn: 96828.6529354	total: 2.35s	remaining: 7.17s
# 247:	learn: 96793.9808737	total: 2.36s	remaining: 7.15s
# 248:	learn: 96763.1598210	total: 2.36s	remaining: 7.12s
# 249:	learn: 96723.9323401	total: 2.36s	remaining: 7.09s
# 250:	learn: 96694.3394541	total: 2.37s	remaining: 7.06s
# 251:	learn: 96651.1973352	total: 2.37s	remaining: 7.04s
# 252:	learn: 96612.7291973	total: 2.38s	remaining: 7.02s
# 253:	learn: 96582.1066766	total: 2.38s	remaining: 6.99s
# 254:	learn: 96554.9511007	total: 2.38s	remaining: 6.96s
# 255:	learn: 96530.9762807	total: 2.38s	remaining: 6.93s
# 256:	learn: 96503.3509651	total: 2.39s	remaining: 6.91s
# 257:	learn: 96479.9637833	total: 2.39s	remaining: 6.88s
# 258:	learn: 96446.4452204	total: 2.4s	remaining: 6.86s
# 259:	learn: 96408.0889671	total: 2.4s	remaining: 6.84s
# 260:	learn: 96385.5906044	total: 2.41s	remaining: 6.83s
# 261:	learn: 96352.4346022	total: 2.42s	remaining: 6.81s
# 262:	learn: 96319.1016326	total: 2.42s	remaining: 6.79s
# 263:	learn: 96302.6617320	total: 2.43s	remaining: 6.78s
# 264:	learn: 96286.0820541	total: 2.44s	remaining: 6.75s
# 265:	learn: 96249.0020712	total: 2.44s	remaining: 6.73s
# 266:	learn: 96219.7414875	total: 2.44s	remaining: 6.7s
# 267:	learn: 96196.3724731	total: 2.45s	remaining: 6.69s
# 268:	learn: 96172.7104053	total: 2.45s	remaining: 6.66s
# 269:	learn: 96151.4883181	total: 2.45s	remaining: 6.63s
# 270:	learn: 96128.2931407	total: 2.46s	remaining: 6.61s
# 271:	learn: 96097.2394315	total: 2.46s	remaining: 6.58s
# 272:	learn: 96072.0314124	total: 2.46s	remaining: 6.56s
# 273:	learn: 96033.0614159	total: 2.47s	remaining: 6.54s
# 274:	learn: 96000.0834533	total: 2.47s	remaining: 6.51s
# 275:	learn: 95974.1363935	total: 2.47s	remaining: 6.49s
# 276:	learn: 95947.8802172	total: 2.48s	remaining: 6.47s
# 277:	learn: 95913.7640083	total: 2.48s	remaining: 6.45s
# 278:	learn: 95891.5722691	total: 2.49s	remaining: 6.42s
# 279:	learn: 95860.4804348	total: 2.49s	remaining: 6.4s
# 280:	learn: 95839.8085434	total: 2.5s	remaining: 6.39s
# 281:	learn: 95816.1859260	total: 2.5s	remaining: 6.37s
# 282:	learn: 95779.5647537	total: 2.5s	remaining: 6.35s
# 283:	learn: 95746.0501180	total: 2.51s	remaining: 6.33s
# 284:	learn: 95723.6967033	total: 2.52s	remaining: 6.31s
# 285:	learn: 95697.6048247	total: 2.52s	remaining: 6.29s
# 286:	learn: 95682.7278974	total: 2.52s	remaining: 6.27s
# 287:	learn: 95664.1021746	total: 2.53s	remaining: 6.25s
# 288:	learn: 95626.5705281	total: 2.53s	remaining: 6.23s
# 289:	learn: 95612.1506784	total: 2.53s	remaining: 6.21s
# 290:	learn: 95588.2925905	total: 2.54s	remaining: 6.18s
# 291:	learn: 95560.4821681	total: 2.54s	remaining: 6.16s
# 292:	learn: 95541.7367615	total: 2.54s	remaining: 6.14s
# 293:	learn: 95510.9278168	total: 2.55s	remaining: 6.12s
# 294:	learn: 95497.0520229	total: 2.55s	remaining: 6.09s
# 295:	learn: 95469.5423052	total: 2.55s	remaining: 6.07s
# 296:	learn: 95435.4122421	total: 2.56s	remaining: 6.05s
# 297:	learn: 95410.9822461	total: 2.56s	remaining: 6.03s
# 298:	learn: 95369.2213319	total: 2.56s	remaining: 6.01s
# 299:	learn: 95320.1043353	total: 2.56s	remaining: 5.99s
# 300:	learn: 95285.6820193	total: 2.57s	remaining: 5.96s
# 301:	learn: 95268.5094092	total: 2.58s	remaining: 5.95s
# 302:	learn: 95240.0115058	total: 2.58s	remaining: 5.93s
# 303:	learn: 95203.8618241	total: 2.58s	remaining: 5.92s
# 304:	learn: 95173.1746773	total: 2.59s	remaining: 5.91s
# 305:	learn: 95143.0561196	total: 2.6s	remaining: 5.89s
# 306:	learn: 95122.8134819	total: 2.6s	remaining: 5.86s
# 307:	learn: 95090.9847065	total: 2.6s	remaining: 5.84s
# 308:	learn: 95057.4252514	total: 2.61s	remaining: 5.83s
# 309:	learn: 95027.5528730	total: 2.61s	remaining: 5.81s
# 310:	learn: 94997.0076546	total: 2.61s	remaining: 5.79s
# 311:	learn: 94976.0376785	total: 2.62s	remaining: 5.78s
# 312:	learn: 94958.2398823	total: 2.62s	remaining: 5.75s
# 313:	learn: 94922.6448272	total: 2.63s	remaining: 5.74s
# 314:	learn: 94898.5088109	total: 2.63s	remaining: 5.72s
# 315:	learn: 94865.7425006	total: 2.63s	remaining: 5.71s
# 316:	learn: 94841.0535978	total: 2.64s	remaining: 5.68s
# 317:	learn: 94819.3581276	total: 2.64s	remaining: 5.66s
# 318:	learn: 94784.0535613	total: 2.64s	remaining: 5.64s
# 319:	learn: 94759.5484666	total: 2.65s	remaining: 5.62s
# 320:	learn: 94709.0825396	total: 2.65s	remaining: 5.62s
# 321:	learn: 94680.9401347	total: 2.66s	remaining: 5.6s
# 322:	learn: 94663.6909151	total: 2.67s	remaining: 5.59s
# 323:	learn: 94636.4450793	total: 2.67s	remaining: 5.57s
# 324:	learn: 94611.9264600	total: 2.67s	remaining: 5.55s
# 325:	learn: 94579.0072166	total: 2.68s	remaining: 5.54s
# 326:	learn: 94558.7867533	total: 2.68s	remaining: 5.52s
# 327:	learn: 94523.4616108	total: 2.69s	remaining: 5.5s
# 328:	learn: 94504.4145870	total: 2.69s	remaining: 5.49s
# 329:	learn: 94477.4806679	total: 2.7s	remaining: 5.47s
# 330:	learn: 94457.8595195	total: 2.7s	remaining: 5.46s
# 331:	learn: 94436.6491195	total: 2.7s	remaining: 5.44s
# 332:	learn: 94422.0593543	total: 2.71s	remaining: 5.42s
# 333:	learn: 94381.1642493	total: 2.71s	remaining: 5.41s
# 334:	learn: 94346.6269430	total: 2.72s	remaining: 5.39s
# 335:	learn: 94327.3325985	total: 2.72s	remaining: 5.38s
# 336:	learn: 94317.1273710	total: 2.73s	remaining: 5.37s
# 337:	learn: 94298.5929154	total: 2.73s	remaining: 5.35s
# 338:	learn: 94268.3922155	total: 2.73s	remaining: 5.33s
# 339:	learn: 94216.9565478	total: 2.73s	remaining: 5.31s
# 340:	learn: 94181.5618120	total: 2.74s	remaining: 5.29s
# 341:	learn: 94161.3363364	total: 2.74s	remaining: 5.28s
# 342:	learn: 94145.7142226	total: 2.75s	remaining: 5.26s
# 343:	learn: 94123.1172003	total: 2.75s	remaining: 5.24s
# 344:	learn: 94092.7871937	total: 2.75s	remaining: 5.22s
# 345:	learn: 94060.1918873	total: 2.76s	remaining: 5.21s
# 346:	learn: 94029.2995692	total: 2.76s	remaining: 5.2s
# 347:	learn: 93990.2151806	total: 2.76s	remaining: 5.18s
# 348:	learn: 93965.1364365	total: 2.77s	remaining: 5.16s
# 349:	learn: 93909.0770824	total: 2.77s	remaining: 5.14s
# 350:	learn: 93860.3140528	total: 2.78s	remaining: 5.13s
# 351:	learn: 93818.3607098	total: 2.78s	remaining: 5.12s
# 352:	learn: 93801.9699044	total: 2.78s	remaining: 5.1s
# 353:	learn: 93776.8461511	total: 2.78s	remaining: 5.08s
# 354:	learn: 93757.9793173	total: 2.79s	remaining: 5.07s
# 355:	learn: 93733.7926516	total: 2.79s	remaining: 5.05s
# 356:	learn: 93706.9800430	total: 2.79s	remaining: 5.03s
# 357:	learn: 93681.5210336	total: 2.8s	remaining: 5.02s
# 358:	learn: 93627.8566786	total: 2.8s	remaining: 5s
# 359:	learn: 93607.8205805	total: 2.81s	remaining: 4.99s
# 360:	learn: 93585.6832193	total: 2.81s	remaining: 4.97s
# 361:	learn: 93541.0116954	total: 2.81s	remaining: 4.95s
# 362:	learn: 93517.2910469	total: 2.81s	remaining: 4.94s
# 363:	learn: 93483.4873689	total: 2.82s	remaining: 4.92s
# 364:	learn: 93467.1923937	total: 2.82s	remaining: 4.91s
# 365:	learn: 93438.9197687	total: 2.82s	remaining: 4.89s
# 366:	learn: 93405.1630670	total: 2.83s	remaining: 4.87s
# 367:	learn: 93392.2531959	total: 2.83s	remaining: 4.86s
# 368:	learn: 93358.4952413	total: 2.83s	remaining: 4.84s
# 369:	learn: 93328.4667880	total: 2.84s	remaining: 4.83s
# 370:	learn: 93302.4150673	total: 2.84s	remaining: 4.82s
# 371:	learn: 93264.3416895	total: 2.84s	remaining: 4.8s
# 372:	learn: 93238.7763253	total: 2.85s	remaining: 4.78s
# 373:	learn: 93203.8019043	total: 2.85s	remaining: 4.77s
# 374:	learn: 93168.6376638	total: 2.85s	remaining: 4.76s
# 375:	learn: 93131.1728618	total: 2.86s	remaining: 4.74s
# 376:	learn: 93104.2668392	total: 2.86s	remaining: 4.72s
# 377:	learn: 93069.2518382	total: 2.86s	remaining: 4.71s
# 378:	learn: 93047.0288478	total: 2.87s	remaining: 4.7s
# 379:	learn: 93026.6085434	total: 2.87s	remaining: 4.68s
# 380:	learn: 92998.9489735	total: 2.88s	remaining: 4.67s
# 381:	learn: 92980.0967617	total: 2.88s	remaining: 4.66s
# 382:	learn: 92960.7305345	total: 2.89s	remaining: 4.65s
# 383:	learn: 92942.3904195	total: 2.89s	remaining: 4.63s
# 384:	learn: 92916.1399440	total: 2.9s	remaining: 4.63s
# 385:	learn: 92874.9412631	total: 2.9s	remaining: 4.62s
# 386:	learn: 92837.0267521	total: 2.91s	remaining: 4.62s
# 387:	learn: 92802.9613986	total: 2.92s	remaining: 4.6s
# 388:	learn: 92773.1359995	total: 2.92s	remaining: 4.59s
# 389:	learn: 92743.5744389	total: 2.93s	remaining: 4.58s
# 390:	learn: 92712.7821994	total: 2.93s	remaining: 4.57s
# 391:	learn: 92678.1685497	total: 2.94s	remaining: 4.55s
# 392:	learn: 92661.0294246	total: 2.94s	remaining: 4.54s
# 393:	learn: 92635.9736947	total: 2.94s	remaining: 4.53s
# 394:	learn: 92606.7778382	total: 2.94s	remaining: 4.51s
# 395:	learn: 92572.9942681	total: 2.95s	remaining: 4.5s
# 396:	learn: 92552.8637029	total: 2.95s	remaining: 4.48s
# 397:	learn: 92537.8513710	total: 2.95s	remaining: 4.47s
# 398:	learn: 92510.4749178	total: 2.96s	remaining: 4.45s
# 399:	learn: 92489.3964164	total: 2.96s	remaining: 4.44s
# 400:	learn: 92455.1651164	total: 2.96s	remaining: 4.43s
# 401:	learn: 92425.0944751	total: 2.97s	remaining: 4.42s
# 402:	learn: 92390.6654517	total: 2.97s	remaining: 4.4s
# 403:	learn: 92365.4495040	total: 2.98s	remaining: 4.39s
# 404:	learn: 92347.0864869	total: 2.98s	remaining: 4.38s
# 405:	learn: 92304.9945276	total: 2.98s	remaining: 4.37s
# 406:	learn: 92282.5361226	total: 2.99s	remaining: 4.35s
# 407:	learn: 92275.4700253	total: 2.99s	remaining: 4.34s
# 408:	learn: 92261.6651880	total: 3s	remaining: 4.33s
# 409:	learn: 92230.9160221	total: 3s	remaining: 4.32s
# 410:	learn: 92222.8016822	total: 3s	remaining: 4.31s
# 411:	learn: 92195.2852827	total: 3.01s	remaining: 4.29s
# 412:	learn: 92169.0609341	total: 3.01s	remaining: 4.28s
# 413:	learn: 92138.3550592	total: 3.01s	remaining: 4.26s
# 414:	learn: 92116.9932999	total: 3.01s	remaining: 4.25s
# 415:	learn: 92079.4261092	total: 3.02s	remaining: 4.23s
# 416:	learn: 92041.3637106	total: 3.02s	remaining: 4.22s
# 417:	learn: 92005.4743098	total: 3.03s	remaining: 4.21s
# 418:	learn: 91982.3617180	total: 3.03s	remaining: 4.2s
# 419:	learn: 91947.9311882	total: 3.03s	remaining: 4.18s
# 420:	learn: 91921.6290726	total: 3.04s	remaining: 4.17s
# 421:	learn: 91901.0273229	total: 3.04s	remaining: 4.16s
# 422:	learn: 91860.7648597	total: 3.04s	remaining: 4.15s
# 423:	learn: 91838.7563906	total: 3.04s	remaining: 4.13s
# 424:	learn: 91822.4706684	total: 3.04s	remaining: 4.12s
# 425:	learn: 91802.4359964	total: 3.05s	remaining: 4.11s
# 426:	learn: 91779.3388773	total: 3.05s	remaining: 4.1s
# 427:	learn: 91754.5072831	total: 3.06s	remaining: 4.08s
# 428:	learn: 91728.6696465	total: 3.06s	remaining: 4.07s
# 429:	learn: 91697.7424370	total: 3.06s	remaining: 4.06s
# 430:	learn: 91689.9310800	total: 3.06s	remaining: 4.04s
# 431:	learn: 91668.7246282	total: 3.07s	remaining: 4.04s
# 432:	learn: 91652.7857885	total: 3.07s	remaining: 4.02s
# 433:	learn: 91613.8860466	total: 3.07s	remaining: 4.01s
# 434:	learn: 91591.9168390	total: 3.08s	remaining: 4s
# 435:	learn: 91574.2241729	total: 3.08s	remaining: 3.98s
# 436:	learn: 91542.4827447	total: 3.08s	remaining: 3.97s
# 437:	learn: 91520.4517601	total: 3.09s	remaining: 3.96s
# 438:	learn: 91491.6773150	total: 3.09s	remaining: 3.95s
# 439:	learn: 91460.4986387	total: 3.1s	remaining: 3.94s
# 440:	learn: 91433.9923433	total: 3.1s	remaining: 3.93s
# 441:	learn: 91411.1657812	total: 3.1s	remaining: 3.92s
# 442:	learn: 91382.2149527	total: 3.11s	remaining: 3.91s
# 443:	learn: 91355.2108130	total: 3.12s	remaining: 3.9s
# 444:	learn: 91328.0256761	total: 3.12s	remaining: 3.89s
# 445:	learn: 91299.2225744	total: 3.12s	remaining: 3.88s
# 446:	learn: 91268.0304938	total: 3.12s	remaining: 3.86s
# 447:	learn: 91234.7593222	total: 3.13s	remaining: 3.85s
# 448:	learn: 91213.3534359	total: 3.13s	remaining: 3.84s
# 449:	learn: 91194.9300350	total: 3.13s	remaining: 3.83s
# 450:	learn: 91178.1468714	total: 3.13s	remaining: 3.82s
# 451:	learn: 91146.4356477	total: 3.14s	remaining: 3.8s
# 452:	learn: 91115.7264604	total: 3.14s	remaining: 3.79s
# 453:	learn: 91078.6109610	total: 3.15s	remaining: 3.79s
# 454:	learn: 91055.1874169	total: 3.15s	remaining: 3.78s
# 455:	learn: 91038.5685776	total: 3.16s	remaining: 3.77s
# 456:	learn: 91016.8010396	total: 3.17s	remaining: 3.76s
# 457:	learn: 90995.9455791	total: 3.17s	remaining: 3.75s
# 458:	learn: 90980.4014079	total: 3.17s	remaining: 3.74s
# 459:	learn: 90960.3551349	total: 3.18s	remaining: 3.73s
# 460:	learn: 90941.9599137	total: 3.18s	remaining: 3.72s
# 461:	learn: 90913.7575474	total: 3.19s	remaining: 3.71s
# 462:	learn: 90888.7989236	total: 3.19s	remaining: 3.7s
# 463:	learn: 90867.1385591	total: 3.19s	remaining: 3.69s
# 464:	learn: 90849.5358382	total: 3.2s	remaining: 3.68s
# 465:	learn: 90812.3086970	total: 3.2s	remaining: 3.67s
# 466:	learn: 90784.5066462	total: 3.2s	remaining: 3.65s
# 467:	learn: 90754.5578621	total: 3.21s	remaining: 3.65s
# 468:	learn: 90724.8605981	total: 3.21s	remaining: 3.63s
# 469:	learn: 90695.4499967	total: 3.21s	remaining: 3.62s
# 470:	learn: 90678.9414363	total: 3.21s	remaining: 3.61s
# 471:	learn: 90658.9267030	total: 3.22s	remaining: 3.6s
# 472:	learn: 90631.6085934	total: 3.22s	remaining: 3.59s
# 473:	learn: 90597.7103728	total: 3.22s	remaining: 3.58s
# 474:	learn: 90569.1609838	total: 3.23s	remaining: 3.57s
# 475:	learn: 90527.1969495	total: 3.23s	remaining: 3.55s
# 476:	learn: 90500.2160808	total: 3.23s	remaining: 3.54s
# 477:	learn: 90478.8867338	total: 3.24s	remaining: 3.53s
# 478:	learn: 90460.7774829	total: 3.24s	remaining: 3.52s
# 479:	learn: 90424.7790548	total: 3.24s	remaining: 3.51s
# 480:	learn: 90408.3212690	total: 3.24s	remaining: 3.5s
# 481:	learn: 90396.1999422	total: 3.25s	remaining: 3.49s
# 482:	learn: 90371.7723529	total: 3.25s	remaining: 3.48s
# 483:	learn: 90333.0816147	total: 3.25s	remaining: 3.47s
# 484:	learn: 90311.4431962	total: 3.26s	remaining: 3.46s
# 485:	learn: 90286.1612729	total: 3.26s	remaining: 3.45s
# 486:	learn: 90259.7645789	total: 3.26s	remaining: 3.44s
# 487:	learn: 90243.7147928	total: 3.27s	remaining: 3.43s
# 488:	learn: 90217.6161860	total: 3.27s	remaining: 3.42s
# 489:	learn: 90190.3055106	total: 3.27s	remaining: 3.41s
# 490:	learn: 90169.9456377	total: 3.28s	remaining: 3.4s
# 491:	learn: 90144.0933905	total: 3.28s	remaining: 3.39s
# 492:	learn: 90123.2817283	total: 3.28s	remaining: 3.38s
# 493:	learn: 90108.2661878	total: 3.29s	remaining: 3.37s
# 494:	learn: 90083.4994738	total: 3.29s	remaining: 3.36s
# 495:	learn: 90055.2708489	total: 3.29s	remaining: 3.35s
# 496:	learn: 90027.8243147	total: 3.3s	remaining: 3.34s
# 497:	learn: 89995.8534801	total: 3.3s	remaining: 3.33s
# 498:	learn: 89973.9392391	total: 3.3s	remaining: 3.31s
# 499:	learn: 89954.0047281	total: 3.31s	remaining: 3.31s
# 500:	learn: 89928.4693984	total: 3.31s	remaining: 3.3s
# 501:	learn: 89904.8520155	total: 3.31s	remaining: 3.29s
# 502:	learn: 89877.1243112	total: 3.32s	remaining: 3.28s
# 503:	learn: 89856.3301720	total: 3.32s	remaining: 3.27s
# 504:	learn: 89827.3473744	total: 3.33s	remaining: 3.26s
# 505:	learn: 89801.2155877	total: 3.33s	remaining: 3.25s
# 506:	learn: 89764.4269472	total: 3.33s	remaining: 3.24s
# 507:	learn: 89733.0740694	total: 3.33s	remaining: 3.23s
# 508:	learn: 89706.4958245	total: 3.34s	remaining: 3.22s
# 509:	learn: 89677.5864866	total: 3.34s	remaining: 3.21s
# 510:	learn: 89658.2207910	total: 3.34s	remaining: 3.2s
# 511:	learn: 89628.6641389	total: 3.35s	remaining: 3.19s
# 512:	learn: 89591.5101614	total: 3.35s	remaining: 3.18s
# 513:	learn: 89575.2830098	total: 3.35s	remaining: 3.17s
# 514:	learn: 89542.6942170	total: 3.36s	remaining: 3.16s
# 515:	learn: 89519.8301312	total: 3.36s	remaining: 3.15s
# 516:	learn: 89491.7699435	total: 3.36s	remaining: 3.14s
# 517:	learn: 89460.8968308	total: 3.37s	remaining: 3.13s
# 518:	learn: 89441.4645129	total: 3.37s	remaining: 3.13s
# 519:	learn: 89411.3465003	total: 3.38s	remaining: 3.12s
# 520:	learn: 89397.0983155	total: 3.38s	remaining: 3.1s
# 521:	learn: 89379.7223588	total: 3.39s	remaining: 3.1s
# 522:	learn: 89351.9670637	total: 3.39s	remaining: 3.09s
# 523:	learn: 89325.9345271	total: 3.39s	remaining: 3.08s
# 524:	learn: 89311.1452938	total: 3.4s	remaining: 3.08s
# 525:	learn: 89280.3882438	total: 3.4s	remaining: 3.07s
# 526:	learn: 89268.2006153	total: 3.41s	remaining: 3.06s
# 527:	learn: 89240.9608981	total: 3.41s	remaining: 3.05s
# 528:	learn: 89219.5116745	total: 3.42s	remaining: 3.04s
# 529:	learn: 89190.5127362	total: 3.42s	remaining: 3.03s
# 530:	learn: 89169.0883357	total: 3.42s	remaining: 3.02s
# 531:	learn: 89135.4658096	total: 3.42s	remaining: 3.01s
# 532:	learn: 89100.1201457	total: 3.43s	remaining: 3s
# 533:	learn: 89070.9067831	total: 3.43s	remaining: 3s
# 534:	learn: 89047.1479989	total: 3.44s	remaining: 2.98s
# 535:	learn: 89019.4669838	total: 3.44s	remaining: 2.98s
# 536:	learn: 88998.1761109	total: 3.44s	remaining: 2.96s
# 537:	learn: 88973.3616227	total: 3.44s	remaining: 2.96s
# 538:	learn: 88952.3182947	total: 3.45s	remaining: 2.95s
# 539:	learn: 88914.0079712	total: 3.45s	remaining: 2.94s
# 540:	learn: 88877.7886793	total: 3.45s	remaining: 2.93s
# 541:	learn: 88850.4330035	total: 3.45s	remaining: 2.92s
# 542:	learn: 88821.4986651	total: 3.46s	remaining: 2.91s
# 543:	learn: 88798.1779212	total: 3.46s	remaining: 2.9s
# 544:	learn: 88776.9391830	total: 3.47s	remaining: 2.89s
# 545:	learn: 88741.1517301	total: 3.47s	remaining: 2.88s
# 546:	learn: 88723.3755322	total: 3.48s	remaining: 2.88s
# 547:	learn: 88695.8167368	total: 3.48s	remaining: 2.87s
# 548:	learn: 88663.9483905	total: 3.48s	remaining: 2.86s
# 549:	learn: 88633.4698148	total: 3.48s	remaining: 2.85s
# 550:	learn: 88616.3162090	total: 3.49s	remaining: 2.84s
# 551:	learn: 88578.1823769	total: 3.49s	remaining: 2.83s
# 552:	learn: 88560.6294028	total: 3.5s	remaining: 2.83s
# 553:	learn: 88548.4692343	total: 3.5s	remaining: 2.82s
# 554:	learn: 88524.0185490	total: 3.5s	remaining: 2.81s
# 555:	learn: 88507.1019368	total: 3.51s	remaining: 2.8s
# 556:	learn: 88468.6622684	total: 3.51s	remaining: 2.79s
# 557:	learn: 88447.8297038	total: 3.52s	remaining: 2.78s
# 558:	learn: 88421.8948238	total: 3.52s	remaining: 2.77s
# 559:	learn: 88390.8626153	total: 3.52s	remaining: 2.77s
# 560:	learn: 88358.2320900	total: 3.53s	remaining: 2.76s
# 561:	learn: 88327.4409348	total: 3.53s	remaining: 2.75s
# 562:	learn: 88311.1727974	total: 3.54s	remaining: 2.75s
# 563:	learn: 88285.5210349	total: 3.54s	remaining: 2.74s
# 564:	learn: 88252.5876118	total: 3.55s	remaining: 2.73s
# 565:	learn: 88234.1145391	total: 3.55s	remaining: 2.72s
# 566:	learn: 88220.7560535	total: 3.56s	remaining: 2.72s
# 567:	learn: 88203.4925736	total: 3.56s	remaining: 2.71s
# 568:	learn: 88179.6783086	total: 3.56s	remaining: 2.7s
# 569:	learn: 88151.1461022	total: 3.56s	remaining: 2.69s
# 570:	learn: 88121.6086921	total: 3.57s	remaining: 2.68s
# 571:	learn: 88088.5000281	total: 3.57s	remaining: 2.67s
# 572:	learn: 88059.4229584	total: 3.58s	remaining: 2.67s
# 573:	learn: 88023.0901964	total: 3.58s	remaining: 2.66s
# 574:	learn: 87997.2988693	total: 3.58s	remaining: 2.65s
# 575:	learn: 87975.4826252	total: 3.59s	remaining: 2.64s
# 576:	learn: 87958.1686052	total: 3.59s	remaining: 2.63s
# 577:	learn: 87942.0869279	total: 3.59s	remaining: 2.62s
# 578:	learn: 87911.2629271	total: 3.6s	remaining: 2.61s
# 579:	learn: 87880.7978042	total: 3.6s	remaining: 2.6s
# 580:	learn: 87847.6962045	total: 3.6s	remaining: 2.6s
# 581:	learn: 87835.6673787	total: 3.61s	remaining: 2.59s
# 582:	learn: 87809.4230619	total: 3.61s	remaining: 2.58s
# 583:	learn: 87777.3130634	total: 3.61s	remaining: 2.57s
# 584:	learn: 87759.3372839	total: 3.62s	remaining: 2.57s
# 585:	learn: 87727.0625156	total: 3.62s	remaining: 2.56s
# 586:	learn: 87699.2626951	total: 3.62s	remaining: 2.55s
# 587:	learn: 87687.2156900	total: 3.63s	remaining: 2.54s
# 588:	learn: 87656.8411172	total: 3.63s	remaining: 2.53s
# 589:	learn: 87628.7676204	total: 3.63s	remaining: 2.53s
# 590:	learn: 87603.8769025	total: 3.64s	remaining: 2.52s
# 591:	learn: 87590.7027648	total: 3.65s	remaining: 2.51s
# 592:	learn: 87571.1663048	total: 3.65s	remaining: 2.5s
# 593:	learn: 87542.3022300	total: 3.65s	remaining: 2.5s
# 594:	learn: 87522.8028081	total: 3.66s	remaining: 2.49s
# 595:	learn: 87505.2050233	total: 3.66s	remaining: 2.48s
# 596:	learn: 87475.4185185	total: 3.67s	remaining: 2.48s
# 597:	learn: 87462.9914887	total: 3.67s	remaining: 2.47s
# 598:	learn: 87441.9915631	total: 3.68s	remaining: 2.46s
# 599:	learn: 87422.2538338	total: 3.68s	remaining: 2.45s
# 600:	learn: 87406.3558823	total: 3.68s	remaining: 2.44s
# 601:	learn: 87370.4506548	total: 3.69s	remaining: 2.44s
# 602:	learn: 87344.2601003	total: 3.69s	remaining: 2.43s
# 603:	learn: 87319.6511885	total: 3.7s	remaining: 2.42s
# 604:	learn: 87298.6341418	total: 3.7s	remaining: 2.42s
# 605:	learn: 87254.5234550	total: 3.7s	remaining: 2.41s
# 606:	learn: 87234.1408840	total: 3.71s	remaining: 2.4s
# 607:	learn: 87213.8825715	total: 3.71s	remaining: 2.39s
# 608:	learn: 87185.2695661	total: 3.71s	remaining: 2.38s
# 609:	learn: 87169.2261775	total: 3.72s	remaining: 2.38s
# 610:	learn: 87129.3017333	total: 3.72s	remaining: 2.37s
# 611:	learn: 87113.1704099	total: 3.72s	remaining: 2.36s
# 612:	learn: 87083.2427216	total: 3.73s	remaining: 2.35s
# 613:	learn: 87067.6174381	total: 3.73s	remaining: 2.34s
# 614:	learn: 87044.1372397	total: 3.73s	remaining: 2.34s
# 615:	learn: 87027.0804076	total: 3.73s	remaining: 2.33s
# 616:	learn: 87011.5261890	total: 3.74s	remaining: 2.32s
# 617:	learn: 86984.1549680	total: 3.74s	remaining: 2.31s
# 618:	learn: 86959.2402005	total: 3.75s	remaining: 2.31s
# 619:	learn: 86935.0523476	total: 3.75s	remaining: 2.3s
# 620:	learn: 86917.5203943	total: 3.75s	remaining: 2.29s
# 621:	learn: 86896.7353843	total: 3.76s	remaining: 2.29s
# 622:	learn: 86886.1410232	total: 3.77s	remaining: 2.28s
# 623:	learn: 86870.2854398	total: 3.77s	remaining: 2.27s
# 624:	learn: 86842.7904152	total: 3.78s	remaining: 2.27s
# 625:	learn: 86815.8629757	total: 3.78s	remaining: 2.26s
# 626:	learn: 86800.2640151	total: 3.78s	remaining: 2.25s
# 627:	learn: 86763.6846876	total: 3.79s	remaining: 2.24s
# 628:	learn: 86739.4787153	total: 3.79s	remaining: 2.23s
# 629:	learn: 86702.2926326	total: 3.79s	remaining: 2.23s
# 630:	learn: 86682.3393721	total: 3.8s	remaining: 2.22s
# 631:	learn: 86658.1520512	total: 3.8s	remaining: 2.21s
# 632:	learn: 86629.5348421	total: 3.8s	remaining: 2.21s
# 633:	learn: 86601.1858732	total: 3.81s	remaining: 2.2s
# 634:	learn: 86577.1217332	total: 3.81s	remaining: 2.19s
# 635:	learn: 86560.9952220	total: 3.81s	remaining: 2.18s
# 636:	learn: 86544.2453002	total: 3.81s	remaining: 2.17s
# 637:	learn: 86517.1004992	total: 3.82s	remaining: 2.17s
# 638:	learn: 86498.4842735	total: 3.82s	remaining: 2.16s
# 639:	learn: 86472.7326859	total: 3.83s	remaining: 2.15s
# 640:	learn: 86446.2135730	total: 3.83s	remaining: 2.14s
# 641:	learn: 86427.9589115	total: 3.83s	remaining: 2.13s
# 642:	learn: 86413.6314626	total: 3.83s	remaining: 2.13s
# 643:	learn: 86398.3615912	total: 3.84s	remaining: 2.12s
# 644:	learn: 86376.1575234	total: 3.84s	remaining: 2.11s
# 645:	learn: 86351.0691536	total: 3.84s	remaining: 2.11s
# 646:	learn: 86330.0326386	total: 3.85s	remaining: 2.1s
# 647:	learn: 86307.1191349	total: 3.85s	remaining: 2.09s
# 648:	learn: 86283.9480891	total: 3.85s	remaining: 2.08s
# 649:	learn: 86269.9467775	total: 3.86s	remaining: 2.08s
# 650:	learn: 86244.5145585	total: 3.86s	remaining: 2.07s
# 651:	learn: 86219.1450075	total: 3.87s	remaining: 2.06s
# 652:	learn: 86196.3509312	total: 3.87s	remaining: 2.06s
# 653:	learn: 86175.8178486	total: 3.87s	remaining: 2.05s
# 654:	learn: 86147.9669537	total: 3.88s	remaining: 2.04s
# 655:	learn: 86131.6509975	total: 3.88s	remaining: 2.04s
# 656:	learn: 86111.4604113	total: 3.89s	remaining: 2.03s
# 657:	learn: 86091.5749527	total: 3.9s	remaining: 2.03s
# 658:	learn: 86072.8134195	total: 3.91s	remaining: 2.02s
# 659:	learn: 86054.6389971	total: 3.91s	remaining: 2.02s
# 660:	learn: 86035.8423152	total: 3.92s	remaining: 2.01s
# 661:	learn: 86017.6183339	total: 3.93s	remaining: 2s
# 662:	learn: 86007.9711485	total: 3.93s	remaining: 2s
# 663:	learn: 85975.5743789	total: 3.93s	remaining: 1.99s
# 664:	learn: 85942.8847913	total: 3.93s	remaining: 1.98s
# 665:	learn: 85922.2061092	total: 3.94s	remaining: 1.98s
# 666:	learn: 85906.5776168	total: 3.94s	remaining: 1.97s
# 667:	learn: 85867.8334957	total: 3.95s	remaining: 1.96s
# 668:	learn: 85828.3498010	total: 3.95s	remaining: 1.95s
# 669:	learn: 85803.3854987	total: 3.96s	remaining: 1.95s
# 670:	learn: 85785.8759266	total: 3.96s	remaining: 1.94s
# 671:	learn: 85772.3332120	total: 3.96s	remaining: 1.94s
# 672:	learn: 85762.5079950	total: 3.97s	remaining: 1.93s
# 673:	learn: 85738.0739106	total: 3.98s	remaining: 1.92s
# 674:	learn: 85716.3172760	total: 3.98s	remaining: 1.92s
# 675:	learn: 85691.4327324	total: 3.98s	remaining: 1.91s
# 676:	learn: 85668.6054773	total: 3.98s	remaining: 1.9s
# 677:	learn: 85633.7733917	total: 3.99s	remaining: 1.9s
# 678:	learn: 85613.9374810	total: 3.99s	remaining: 1.89s
# 679:	learn: 85589.0955123	total: 4s	remaining: 1.88s
# 680:	learn: 85564.2869933	total: 4s	remaining: 1.87s
# 681:	learn: 85537.9928035	total: 4.01s	remaining: 1.87s
# 682:	learn: 85512.6897232	total: 4.01s	remaining: 1.86s
# 683:	learn: 85485.5212060	total: 4.01s	remaining: 1.85s
# 684:	learn: 85465.6444992	total: 4.02s	remaining: 1.85s
# 685:	learn: 85441.1111822	total: 4.02s	remaining: 1.84s
# 686:	learn: 85414.6547699	total: 4.03s	remaining: 1.83s
# 687:	learn: 85389.1648457	total: 4.03s	remaining: 1.83s
# 688:	learn: 85364.0410147	total: 4.03s	remaining: 1.82s
# 689:	learn: 85345.6122779	total: 4.04s	remaining: 1.81s
# 690:	learn: 85321.4109179	total: 4.04s	remaining: 1.81s
# 691:	learn: 85307.0888486	total: 4.04s	remaining: 1.8s
# 692:	learn: 85293.8984819	total: 4.04s	remaining: 1.79s
# 693:	learn: 85264.1718737	total: 4.05s	remaining: 1.78s
# 694:	learn: 85245.0751757	total: 4.05s	remaining: 1.78s
# 695:	learn: 85223.6698179	total: 4.05s	remaining: 1.77s
# 696:	learn: 85207.2876932	total: 4.06s	remaining: 1.76s
# 697:	learn: 85186.5186547	total: 4.06s	remaining: 1.76s
# 698:	learn: 85164.2342172	total: 4.07s	remaining: 1.75s
# 699:	learn: 85132.7424207	total: 4.07s	remaining: 1.75s
# 700:	learn: 85115.0174007	total: 4.08s	remaining: 1.74s
# 701:	learn: 85099.1119669	total: 4.08s	remaining: 1.73s
# 702:	learn: 85080.7506786	total: 4.09s	remaining: 1.73s
# 703:	learn: 85051.6783397	total: 4.09s	remaining: 1.72s
# 704:	learn: 85035.3364815	total: 4.1s	remaining: 1.71s
# 705:	learn: 85018.7807890	total: 4.1s	remaining: 1.71s
# 706:	learn: 84992.1910784	total: 4.11s	remaining: 1.7s
# 707:	learn: 84967.3867655	total: 4.11s	remaining: 1.7s
# 708:	learn: 84950.7299037	total: 4.12s	remaining: 1.69s
# 709:	learn: 84926.3442098	total: 4.12s	remaining: 1.68s
# 710:	learn: 84910.3209714	total: 4.13s	remaining: 1.68s
# 711:	learn: 84883.9079262	total: 4.14s	remaining: 1.67s
# 712:	learn: 84865.4594937	total: 4.15s	remaining: 1.67s
# 713:	learn: 84845.8337024	total: 4.15s	remaining: 1.66s
# 714:	learn: 84822.9613016	total: 4.15s	remaining: 1.66s
# 715:	learn: 84815.6606657	total: 4.16s	remaining: 1.65s
# 716:	learn: 84795.5144516	total: 4.17s	remaining: 1.64s
# 717:	learn: 84778.1262211	total: 4.17s	remaining: 1.64s
# 718:	learn: 84757.7489817	total: 4.18s	remaining: 1.63s
# 719:	learn: 84719.2542773	total: 4.18s	remaining: 1.63s
# 720:	learn: 84708.7590580	total: 4.18s	remaining: 1.62s
# 721:	learn: 84688.4545724	total: 4.18s	remaining: 1.61s
# 722:	learn: 84670.2710835	total: 4.19s	remaining: 1.6s
# 723:	learn: 84642.5513124	total: 4.19s	remaining: 1.6s
# 724:	learn: 84620.7174294	total: 4.2s	remaining: 1.59s
# 725:	learn: 84603.3390849	total: 4.2s	remaining: 1.58s
# 726:	learn: 84574.7031973	total: 4.2s	remaining: 1.58s
# 727:	learn: 84546.1780909	total: 4.21s	remaining: 1.57s
# 728:	learn: 84521.4801464	total: 4.21s	remaining: 1.56s
# 729:	learn: 84505.5363034	total: 4.21s	remaining: 1.56s
# 730:	learn: 84487.9590292	total: 4.22s	remaining: 1.55s
# 731:	learn: 84473.9203791	total: 4.22s	remaining: 1.55s
# 732:	learn: 84449.8037030	total: 4.23s	remaining: 1.54s
# 733:	learn: 84422.5185340	total: 4.23s	remaining: 1.53s
# 734:	learn: 84401.8024468	total: 4.24s	remaining: 1.53s
# 735:	learn: 84391.0165671	total: 4.24s	remaining: 1.52s
# 736:	learn: 84376.6541787	total: 4.24s	remaining: 1.51s
# 737:	learn: 84353.0932597	total: 4.25s	remaining: 1.51s
# 738:	learn: 84338.3145805	total: 4.25s	remaining: 1.5s
# 739:	learn: 84317.7148615	total: 4.25s	remaining: 1.5s
# 740:	learn: 84295.8332497	total: 4.26s	remaining: 1.49s
# 741:	learn: 84264.4791561	total: 4.26s	remaining: 1.48s
# 742:	learn: 84247.2544676	total: 4.27s	remaining: 1.48s
# 743:	learn: 84225.1266344	total: 4.27s	remaining: 1.47s
# 744:	learn: 84195.1733944	total: 4.28s	remaining: 1.46s
# 745:	learn: 84174.6453815	total: 4.28s	remaining: 1.46s
# 746:	learn: 84153.3697622	total: 4.29s	remaining: 1.45s
# 747:	learn: 84137.5849007	total: 4.29s	remaining: 1.44s
# 748:	learn: 84112.2919738	total: 4.29s	remaining: 1.44s
# 749:	learn: 84095.2430871	total: 4.29s	remaining: 1.43s
# 750:	learn: 84078.1624338	total: 4.3s	remaining: 1.43s
# 751:	learn: 84055.2878321	total: 4.3s	remaining: 1.42s
# 752:	learn: 84027.1218120	total: 4.31s	remaining: 1.41s
# 753:	learn: 84003.1439293	total: 4.31s	remaining: 1.41s
# 754:	learn: 83976.7090371	total: 4.32s	remaining: 1.4s
# 755:	learn: 83943.3092069	total: 4.32s	remaining: 1.4s
# 756:	learn: 83919.6037837	total: 4.32s	remaining: 1.39s
# 757:	learn: 83902.0882438	total: 4.33s	remaining: 1.38s
# 758:	learn: 83887.6953528	total: 4.33s	remaining: 1.38s
# 759:	learn: 83865.0091652	total: 4.33s	remaining: 1.37s
# 760:	learn: 83848.9400402	total: 4.34s	remaining: 1.36s
# 761:	learn: 83827.9271960	total: 4.34s	remaining: 1.35s
# 762:	learn: 83814.3088556	total: 4.35s	remaining: 1.35s
# 763:	learn: 83795.7440524	total: 4.35s	remaining: 1.34s
# 764:	learn: 83779.1203639	total: 4.36s	remaining: 1.34s
# 765:	learn: 83754.0586356	total: 4.36s	remaining: 1.33s
# 766:	learn: 83733.3900493	total: 4.37s	remaining: 1.33s
# 767:	learn: 83709.9992917	total: 4.37s	remaining: 1.32s
# 768:	learn: 83676.8854795	total: 4.38s	remaining: 1.31s
# 769:	learn: 83658.4389019	total: 4.38s	remaining: 1.31s
# 770:	learn: 83631.0773412	total: 4.39s	remaining: 1.3s
# 771:	learn: 83609.4313815	total: 4.4s	remaining: 1.3s
# 772:	learn: 83581.0595582	total: 4.4s	remaining: 1.29s
# 773:	learn: 83560.2404662	total: 4.41s	remaining: 1.29s
# 774:	learn: 83544.8994117	total: 4.41s	remaining: 1.28s
# 775:	learn: 83527.7937474	total: 4.42s	remaining: 1.27s
# 776:	learn: 83505.1225034	total: 4.42s	remaining: 1.27s
# 777:	learn: 83486.7185188	total: 4.43s	remaining: 1.26s
# 778:	learn: 83469.9014091	total: 4.43s	remaining: 1.26s
# 779:	learn: 83448.0706093	total: 4.43s	remaining: 1.25s
# 780:	learn: 83419.1461439	total: 4.44s	remaining: 1.25s
# 781:	learn: 83407.8518266	total: 4.45s	remaining: 1.24s
# 782:	learn: 83398.7784793	total: 4.45s	remaining: 1.23s
# 783:	learn: 83383.6479449	total: 4.46s	remaining: 1.23s
# 784:	learn: 83366.3387255	total: 4.46s	remaining: 1.22s
# 785:	learn: 83342.7945381	total: 4.46s	remaining: 1.21s
# 786:	learn: 83321.4596505	total: 4.47s	remaining: 1.21s
# 787:	learn: 83291.8565187	total: 4.47s	remaining: 1.2s
# 788:	learn: 83279.6444613	total: 4.48s	remaining: 1.2s
# 789:	learn: 83244.9274495	total: 4.48s	remaining: 1.19s
# 790:	learn: 83224.9923612	total: 4.49s	remaining: 1.19s
# 791:	learn: 83206.3438584	total: 4.49s	remaining: 1.18s
# 792:	learn: 83185.7581835	total: 4.49s	remaining: 1.17s
# 793:	learn: 83156.9109817	total: 4.5s	remaining: 1.17s
# 794:	learn: 83131.5323053	total: 4.5s	remaining: 1.16s
# 795:	learn: 83109.3722902	total: 4.5s	remaining: 1.15s
# 796:	learn: 83086.8610853	total: 4.51s	remaining: 1.15s
# 797:	learn: 83067.3031295	total: 4.52s	remaining: 1.14s
# 798:	learn: 83054.3881354	total: 4.52s	remaining: 1.14s
# 799:	learn: 83040.1781011	total: 4.53s	remaining: 1.13s
# 800:	learn: 83023.1572722	total: 4.53s	remaining: 1.13s
# 801:	learn: 83002.4310587	total: 4.54s	remaining: 1.12s
# 802:	learn: 82982.8998813	total: 4.54s	remaining: 1.11s
# 803:	learn: 82941.3269794	total: 4.55s	remaining: 1.11s
# 804:	learn: 82918.5196965	total: 4.55s	remaining: 1.1s
# 805:	learn: 82897.4847464	total: 4.55s	remaining: 1.1s
# 806:	learn: 82883.5486390	total: 4.56s	remaining: 1.09s
# 807:	learn: 82867.9550485	total: 4.57s	remaining: 1.08s
# 808:	learn: 82849.9156935	total: 4.57s	remaining: 1.08s
# 809:	learn: 82829.6111308	total: 4.57s	remaining: 1.07s
# 810:	learn: 82804.5835852	total: 4.57s	remaining: 1.06s
# 811:	learn: 82787.3131755	total: 4.58s	remaining: 1.06s
# 812:	learn: 82764.5142397	total: 4.58s	remaining: 1.05s
# 813:	learn: 82747.4825220	total: 4.59s	remaining: 1.05s
# 814:	learn: 82723.1592701	total: 4.59s	remaining: 1.04s
# 815:	learn: 82709.2604581	total: 4.59s	remaining: 1.04s
# 816:	learn: 82693.0098961	total: 4.6s	remaining: 1.03s
# 817:	learn: 82674.3163519	total: 4.6s	remaining: 1.02s
# 818:	learn: 82657.5170327	total: 4.6s	remaining: 1.02s
# 819:	learn: 82626.5886438	total: 4.6s	remaining: 1.01s
# 820:	learn: 82596.7444262	total: 4.61s	remaining: 1s
# 821:	learn: 82578.7699738	total: 4.62s	remaining: 999ms
# 822:	learn: 82556.1890564	total: 4.62s	remaining: 993ms
# 823:	learn: 82545.6287901	total: 4.62s	remaining: 987ms
# 824:	learn: 82531.7051636	total: 4.63s	remaining: 982ms
# 825:	learn: 82508.8861877	total: 4.64s	remaining: 977ms
# 826:	learn: 82475.6542955	total: 4.65s	remaining: 972ms
# 827:	learn: 82451.8315210	total: 4.65s	remaining: 966ms
# 828:	learn: 82430.0088713	total: 4.66s	remaining: 961ms
# 829:	learn: 82409.8849291	total: 4.66s	remaining: 955ms
# 830:	learn: 82397.7615118	total: 4.67s	remaining: 949ms
# 831:	learn: 82379.7553670	total: 4.67s	remaining: 944ms
# 832:	learn: 82351.4431427	total: 4.68s	remaining: 938ms
# 833:	learn: 82337.3917022	total: 4.68s	remaining: 932ms
# 834:	learn: 82314.4911424	total: 4.69s	remaining: 927ms
# 835:	learn: 82287.7058386	total: 4.69s	remaining: 921ms
# 836:	learn: 82258.3989261	total: 4.7s	remaining: 915ms
# 837:	learn: 82239.4056649	total: 4.7s	remaining: 909ms
# 838:	learn: 82224.0732448	total: 4.71s	remaining: 903ms
# 839:	learn: 82205.0012258	total: 4.71s	remaining: 897ms
# 840:	learn: 82192.6146330	total: 4.71s	remaining: 891ms
# 841:	learn: 82183.4698520	total: 4.71s	remaining: 885ms
# 842:	learn: 82172.0758297	total: 4.72s	remaining: 879ms
# 843:	learn: 82160.1236425	total: 4.72s	remaining: 873ms
# 844:	learn: 82135.3155657	total: 4.73s	remaining: 867ms
# 845:	learn: 82113.0668220	total: 4.73s	remaining: 861ms
# 846:	learn: 82097.5738940	total: 4.74s	remaining: 856ms
# 847:	learn: 82074.2666443	total: 4.74s	remaining: 850ms
# 848:	learn: 82061.8773683	total: 4.74s	remaining: 843ms
# 849:	learn: 82041.4137264	total: 4.74s	remaining: 837ms
# 850:	learn: 82021.5072942	total: 4.75s	remaining: 832ms
# 851:	learn: 81998.7671377	total: 4.75s	remaining: 826ms
# 852:	learn: 81978.9053078	total: 4.76s	remaining: 820ms
# 853:	learn: 81971.4223465	total: 4.76s	remaining: 814ms
# 854:	learn: 81941.9873450	total: 4.77s	remaining: 809ms
# 855:	learn: 81920.1799289	total: 4.77s	remaining: 803ms
# 856:	learn: 81908.7278731	total: 4.78s	remaining: 797ms
# 857:	learn: 81894.2870703	total: 4.78s	remaining: 792ms
# 858:	learn: 81883.4644896	total: 4.79s	remaining: 786ms
# 859:	learn: 81866.7153331	total: 4.79s	remaining: 780ms
# 860:	learn: 81841.1481594	total: 4.79s	remaining: 774ms
# 861:	learn: 81820.1619245	total: 4.8s	remaining: 768ms
# 862:	learn: 81804.8891577	total: 4.8s	remaining: 762ms
# 863:	learn: 81790.7829773	total: 4.8s	remaining: 756ms
# 864:	learn: 81768.9425220	total: 4.81s	remaining: 750ms
# 865:	learn: 81754.3256801	total: 4.81s	remaining: 744ms
# 866:	learn: 81724.6378186	total: 4.82s	remaining: 739ms
# 867:	learn: 81706.3669303	total: 4.82s	remaining: 733ms
# 868:	learn: 81674.0846491	total: 4.82s	remaining: 727ms
# 869:	learn: 81651.6522346	total: 4.83s	remaining: 722ms
# 870:	learn: 81629.9967651	total: 4.83s	remaining: 716ms
# 871:	learn: 81603.4101117	total: 4.83s	remaining: 710ms
# 872:	learn: 81585.1144666	total: 4.84s	remaining: 704ms
# 873:	learn: 81566.0722390	total: 4.84s	remaining: 698ms
# 874:	learn: 81538.5130866	total: 4.85s	remaining: 692ms
# 875:	learn: 81527.4439443	total: 4.85s	remaining: 686ms
# 876:	learn: 81513.6239244	total: 4.85s	remaining: 681ms
# 877:	learn: 81498.2676761	total: 4.86s	remaining: 675ms
# 878:	learn: 81482.3188570	total: 4.86s	remaining: 669ms
# 879:	learn: 81458.8867771	total: 4.86s	remaining: 663ms
# 880:	learn: 81442.2098982	total: 4.87s	remaining: 657ms
# 881:	learn: 81416.0974654	total: 4.87s	remaining: 652ms
# 882:	learn: 81398.3072547	total: 4.9s	remaining: 649ms
# 883:	learn: 81378.4045756	total: 4.9s	remaining: 644ms
# 884:	learn: 81355.5567978	total: 4.91s	remaining: 639ms
# 885:	learn: 81316.8479398	total: 4.93s	remaining: 634ms
# 886:	learn: 81295.8174575	total: 4.93s	remaining: 629ms
# 887:	learn: 81282.6935930	total: 4.94s	remaining: 624ms
# 888:	learn: 81244.8649045	total: 4.95s	remaining: 618ms
# 889:	learn: 81231.2825428	total: 4.95s	remaining: 612ms
# 890:	learn: 81216.4119440	total: 4.96s	remaining: 607ms
# 891:	learn: 81191.9258566	total: 4.96s	remaining: 601ms
# 892:	learn: 81170.3437335	total: 4.96s	remaining: 595ms
# 893:	learn: 81148.5124522	total: 4.97s	remaining: 589ms
# 894:	learn: 81126.8167339	total: 4.97s	remaining: 584ms
# 895:	learn: 81105.8494416	total: 4.98s	remaining: 578ms
# 896:	learn: 81085.0663650	total: 4.98s	remaining: 572ms
# 897:	learn: 81063.5421055	total: 4.98s	remaining: 566ms
# 898:	learn: 81049.5667712	total: 4.99s	remaining: 560ms
# 899:	learn: 81030.3025520	total: 4.99s	remaining: 555ms
# 900:	learn: 81011.7367468	total: 5s	remaining: 549ms
# 901:	learn: 80988.1778262	total: 5s	remaining: 543ms
# 902:	learn: 80960.0142628	total: 5s	remaining: 538ms
# 903:	learn: 80941.0838382	total: 5.01s	remaining: 532ms
# 904:	learn: 80933.0472158	total: 5.01s	remaining: 526ms
# 905:	learn: 80898.2499940	total: 5.01s	remaining: 520ms
# 906:	learn: 80879.8421379	total: 5.02s	remaining: 515ms
# 907:	learn: 80872.4723906	total: 5.02s	remaining: 509ms
# 908:	learn: 80838.6086118	total: 5.03s	remaining: 503ms
# 909:	learn: 80823.6158940	total: 5.03s	remaining: 497ms
# 910:	learn: 80808.5304007	total: 5.03s	remaining: 492ms
# 911:	learn: 80790.1537207	total: 5.04s	remaining: 486ms
# 912:	learn: 80762.5494888	total: 5.04s	remaining: 480ms
# 913:	learn: 80740.4191432	total: 5.04s	remaining: 475ms
# 914:	learn: 80716.0434414	total: 5.04s	remaining: 469ms
# 915:	learn: 80696.1034855	total: 5.05s	remaining: 463ms
# 916:	learn: 80666.3842810	total: 5.05s	remaining: 457ms
# 917:	learn: 80652.2767548	total: 5.06s	remaining: 452ms
# 918:	learn: 80628.5436675	total: 5.06s	remaining: 446ms
# 919:	learn: 80615.7192313	total: 5.07s	remaining: 441ms
# 920:	learn: 80597.3277264	total: 5.07s	remaining: 435ms
# 921:	learn: 80573.0625963	total: 5.07s	remaining: 429ms
# 922:	learn: 80561.1728379	total: 5.08s	remaining: 424ms
# 923:	learn: 80535.3642428	total: 5.09s	remaining: 418ms
# 924:	learn: 80512.0450669	total: 5.09s	remaining: 413ms
# 925:	learn: 80501.6343415	total: 5.09s	remaining: 407ms
# 926:	learn: 80484.5688264	total: 5.1s	remaining: 402ms
# 927:	learn: 80464.5913329	total: 5.1s	remaining: 396ms
# 928:	learn: 80446.9929790	total: 5.11s	remaining: 390ms
# 929:	learn: 80425.0461835	total: 5.11s	remaining: 385ms
# 930:	learn: 80414.1865064	total: 5.12s	remaining: 379ms
# 931:	learn: 80400.1387006	total: 5.12s	remaining: 373ms
# 932:	learn: 80377.7815224	total: 5.12s	remaining: 368ms
# 933:	learn: 80360.7876944	total: 5.13s	remaining: 363ms
# 934:	learn: 80349.4871247	total: 5.14s	remaining: 357ms
# 935:	learn: 80338.0498897	total: 5.14s	remaining: 352ms
# 936:	learn: 80329.9833449	total: 5.15s	remaining: 346ms
# 937:	learn: 80311.9086249	total: 5.15s	remaining: 341ms
# 938:	learn: 80287.2910332	total: 5.16s	remaining: 335ms
# 939:	learn: 80269.5614417	total: 5.16s	remaining: 330ms
# 940:	learn: 80254.4956603	total: 5.17s	remaining: 324ms
# 941:	learn: 80245.9014211	total: 5.17s	remaining: 318ms
# 942:	learn: 80219.5376476	total: 5.17s	remaining: 313ms
# 943:	learn: 80195.8949043	total: 5.18s	remaining: 307ms
# 944:	learn: 80174.9669528	total: 5.18s	remaining: 302ms
# 945:	learn: 80159.5460358	total: 5.18s	remaining: 296ms
# 946:	learn: 80138.3299649	total: 5.18s	remaining: 290ms
# 947:	learn: 80116.8308270	total: 5.19s	remaining: 285ms
# 948:	learn: 80096.5353119	total: 5.19s	remaining: 279ms
# 949:	learn: 80075.6408938	total: 5.2s	remaining: 274ms
# 950:	learn: 80052.7172233	total: 5.2s	remaining: 268ms
# 951:	learn: 80030.2713831	total: 5.2s	remaining: 262ms
# 952:	learn: 80011.2141920	total: 5.21s	remaining: 257ms
# 953:	learn: 79993.9722762	total: 5.21s	remaining: 251ms
# 954:	learn: 79980.6055880	total: 5.21s	remaining: 246ms
# 955:	learn: 79966.2553317	total: 5.21s	remaining: 240ms
# 956:	learn: 79941.9643031	total: 5.22s	remaining: 234ms
# 957:	learn: 79925.2967422	total: 5.22s	remaining: 229ms
# 958:	learn: 79897.8452702	total: 5.22s	remaining: 223ms
# 959:	learn: 79886.2812187	total: 5.23s	remaining: 218ms
# 960:	learn: 79875.3057924	total: 5.23s	remaining: 212ms
# 961:	learn: 79856.2556160	total: 5.23s	remaining: 207ms
# 962:	learn: 79841.5029952	total: 5.24s	remaining: 201ms
# 963:	learn: 79823.1334430	total: 5.24s	remaining: 196ms
# 964:	learn: 79800.7835656	total: 5.24s	remaining: 190ms
# 965:	learn: 79779.3825021	total: 5.25s	remaining: 185ms
# 966:	learn: 79767.2985780	total: 5.25s	remaining: 179ms
# 967:	learn: 79757.2911088	total: 5.25s	remaining: 174ms
# 968:	learn: 79734.7268165	total: 5.25s	remaining: 168ms
# 969:	learn: 79712.4772979	total: 5.26s	remaining: 163ms
# 970:	learn: 79689.6472298	total: 5.26s	remaining: 157ms
# 971:	learn: 79658.2811236	total: 5.26s	remaining: 152ms
# 972:	learn: 79640.6079723	total: 5.27s	remaining: 146ms
# 973:	learn: 79627.5407638	total: 5.27s	remaining: 141ms
# 974:	learn: 79602.7404524	total: 5.27s	remaining: 135ms
# 975:	learn: 79590.3116432	total: 5.28s	remaining: 130ms
# 976:	learn: 79569.7653609	total: 5.28s	remaining: 124ms
# 977:	learn: 79551.0396095	total: 5.28s	remaining: 119ms
# 978:	learn: 79537.8779932	total: 5.29s	remaining: 113ms
# 979:	learn: 79516.0951842	total: 5.29s	remaining: 108ms
# 980:	learn: 79495.5642096	total: 5.29s	remaining: 103ms
# 981:	learn: 79471.2314737	total: 5.3s	remaining: 97.1ms
# 982:	learn: 79457.5816482	total: 5.3s	remaining: 91.7ms
# 983:	learn: 79428.6574978	total: 5.3s	remaining: 86.3ms
# 984:	learn: 79409.6573050	total: 5.31s	remaining: 80.8ms
# 985:	learn: 79391.0957758	total: 5.31s	remaining: 75.4ms
# 986:	learn: 79368.0862551	total: 5.32s	remaining: 70ms
# 987:	learn: 79355.3534190	total: 5.32s	remaining: 64.6ms
# 988:	learn: 79332.3294650	total: 5.32s	remaining: 59.2ms
# 989:	learn: 79314.7105039	total: 5.33s	remaining: 53.8ms
# 990:	learn: 79303.8952629	total: 5.33s	remaining: 48.4ms
# 991:	learn: 79283.9090957	total: 5.34s	remaining: 43ms
# 992:	learn: 79266.2338931	total: 5.34s	remaining: 37.6ms
# 993:	learn: 79252.8738016	total: 5.34s	remaining: 32.2ms
# 994:	learn: 79235.8010636	total: 5.35s	remaining: 26.9ms
# 995:	learn: 79223.2010034	total: 5.35s	remaining: 21.5ms
# 996:	learn: 79192.7791330	total: 5.35s	remaining: 16.1ms
# 997:	learn: 79172.2623541	total: 5.35s	remaining: 10.7ms
# 998:	learn: 79162.0881720	total: 5.36s	remaining: 5.36ms
# 999:	learn: 79136.8117627	total: 5.37s	remaining: 0us
# 63166.91283982816

# %%
xgb_reg.score(X_reg, Y_reg)
# Out:
# 0.9497651429188281

# %%
import catboost
xgb_clas = catboost.CatBoostClassifier(random_state=42)

xgb_clas.fit(X_train, y_train)
y_pred = xgb_clas.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# Learning rate set to 0.008911
# 0:	learn: 0.6880721	total: 4.73ms	remaining: 4.73s
# 1:	learn: 0.6847118	total: 5.67ms	remaining: 2.83s
# 2:	learn: 0.6794068	total: 7.83ms	remaining: 2.6s
# 3:	learn: 0.6740718	total: 11ms	remaining: 2.74s
# 4:	learn: 0.6679044	total: 14.8ms	remaining: 2.95s
# 5:	learn: 0.6631298	total: 15.8ms	remaining: 2.62s
# 6:	learn: 0.6579282	total: 17ms	remaining: 2.41s
# 7:	learn: 0.6531104	total: 18.2ms	remaining: 2.25s
# 8:	learn: 0.6482386	total: 19.1ms	remaining: 2.11s
# 9:	learn: 0.6450419	total: 20.9ms	remaining: 2.06s
# 10:	learn: 0.6400555	total: 23.1ms	remaining: 2.08s
# 11:	learn: 0.6351652	total: 24.7ms	remaining: 2.03s
# 12:	learn: 0.6304302	total: 26ms	remaining: 1.98s
# 13:	learn: 0.6260697	total: 27.3ms	remaining: 1.92s
# 14:	learn: 0.6213343	total: 28.7ms	remaining: 1.88s
# 15:	learn: 0.6170068	total: 30ms	remaining: 1.84s
# 16:	learn: 0.6126812	total: 31.3ms	remaining: 1.81s
# 17:	learn: 0.6082963	total: 32.6ms	remaining: 1.78s
# 18:	learn: 0.6041403	total: 33.9ms	remaining: 1.75s
# 19:	learn: 0.6001157	total: 37.7ms	remaining: 1.85s
# 20:	learn: 0.5959780	total: 40.4ms	remaining: 1.88s
# 21:	learn: 0.5916135	total: 43.5ms	remaining: 1.94s
# 22:	learn: 0.5869302	total: 56.8ms	remaining: 2.41s
# 23:	learn: 0.5827086	total: 59.2ms	remaining: 2.41s
# 24:	learn: 0.5786026	total: 61.6ms	remaining: 2.4s
# 25:	learn: 0.5753473	total: 65.9ms	remaining: 2.47s
# 26:	learn: 0.5717681	total: 69ms	remaining: 2.48s
# 27:	learn: 0.5681443	total: 72.3ms	remaining: 2.51s
# 28:	learn: 0.5647192	total: 74ms	remaining: 2.48s
# 29:	learn: 0.5610407	total: 75.6ms	remaining: 2.44s
# 30:	learn: 0.5579119	total: 77.4ms	remaining: 2.42s
# 31:	learn: 0.5548109	total: 81.2ms	remaining: 2.46s
# 32:	learn: 0.5512510	total: 83.4ms	remaining: 2.44s
# 33:	learn: 0.5486851	total: 85ms	remaining: 2.41s
# 34:	learn: 0.5469780	total: 86.5ms	remaining: 2.38s
# 35:	learn: 0.5441463	total: 88.5ms	remaining: 2.37s
# 36:	learn: 0.5409101	total: 92.8ms	remaining: 2.42s
# 37:	learn: 0.5378031	total: 95.2ms	remaining: 2.41s
# 38:	learn: 0.5348010	total: 97.4ms	remaining: 2.4s
# 39:	learn: 0.5318820	total: 99.4ms	remaining: 2.38s
# 40:	learn: 0.5295507	total: 101ms	remaining: 2.36s
# 41:	learn: 0.5268229	total: 105ms	remaining: 2.4s
# 42:	learn: 0.5251626	total: 110ms	remaining: 2.44s
# 43:	learn: 0.5223616	total: 111ms	remaining: 2.42s
# 44:	learn: 0.5200398	total: 113ms	remaining: 2.4s
# 45:	learn: 0.5173798	total: 115ms	remaining: 2.38s
# 46:	learn: 0.5147013	total: 117ms	remaining: 2.36s
# 47:	learn: 0.5123958	total: 123ms	remaining: 2.44s
# 48:	learn: 0.5101578	total: 124ms	remaining: 2.41s
# 49:	learn: 0.5085400	total: 126ms	remaining: 2.39s
# 50:	learn: 0.5074315	total: 127ms	remaining: 2.36s
# 51:	learn: 0.5056187	total: 128ms	remaining: 2.33s
# 52:	learn: 0.5036020	total: 130ms	remaining: 2.31s
# 53:	learn: 0.5014093	total: 133ms	remaining: 2.32s
# 54:	learn: 0.4999836	total: 137ms	remaining: 2.35s
# 55:	learn: 0.4973778	total: 139ms	remaining: 2.34s
# 56:	learn: 0.4949606	total: 141ms	remaining: 2.33s
# 57:	learn: 0.4930767	total: 147ms	remaining: 2.39s
# 58:	learn: 0.4907651	total: 149ms	remaining: 2.38s
# 59:	learn: 0.4888243	total: 152ms	remaining: 2.38s
# 60:	learn: 0.4870465	total: 153ms	remaining: 2.36s
# 61:	learn: 0.4855134	total: 158ms	remaining: 2.38s
# 62:	learn: 0.4840178	total: 160ms	remaining: 2.39s
# 63:	learn: 0.4819030	total: 163ms	remaining: 2.38s
# 64:	learn: 0.4808502	total: 167ms	remaining: 2.4s
# 65:	learn: 0.4787765	total: 171ms	remaining: 2.42s
# 66:	learn: 0.4777831	total: 172ms	remaining: 2.4s
# 67:	learn: 0.4759986	total: 174ms	remaining: 2.38s
# 68:	learn: 0.4740811	total: 175ms	remaining: 2.37s
# 69:	learn: 0.4723844	total: 176ms	remaining: 2.34s
# 70:	learn: 0.4707609	total: 178ms	remaining: 2.33s
# 71:	learn: 0.4688831	total: 179ms	remaining: 2.31s
# 72:	learn: 0.4672817	total: 182ms	remaining: 2.31s
# 73:	learn: 0.4654865	total: 184ms	remaining: 2.3s
# 74:	learn: 0.4641558	total: 186ms	remaining: 2.29s
# 75:	learn: 0.4624981	total: 187ms	remaining: 2.27s
# 76:	learn: 0.4610000	total: 188ms	remaining: 2.26s
# 77:	learn: 0.4599655	total: 189ms	remaining: 2.24s
# 78:	learn: 0.4586095	total: 191ms	remaining: 2.22s
# 79:	learn: 0.4577702	total: 192ms	remaining: 2.21s
# 80:	learn: 0.4570016	total: 195ms	remaining: 2.21s
# 81:	learn: 0.4553891	total: 198ms	remaining: 2.22s
# 82:	learn: 0.4543184	total: 200ms	remaining: 2.21s
# 83:	learn: 0.4528340	total: 205ms	remaining: 2.23s
# 84:	learn: 0.4512579	total: 209ms	remaining: 2.25s
# 85:	learn: 0.4500968	total: 214ms	remaining: 2.27s
# 86:	learn: 0.4487397	total: 216ms	remaining: 2.27s
# 87:	learn: 0.4476787	total: 218ms	remaining: 2.25s
# 88:	learn: 0.4462235	total: 220ms	remaining: 2.25s
# 89:	learn: 0.4451219	total: 223ms	remaining: 2.26s
# 90:	learn: 0.4439020	total: 226ms	remaining: 2.25s
# 91:	learn: 0.4427951	total: 227ms	remaining: 2.24s
# 92:	learn: 0.4419843	total: 228ms	remaining: 2.23s
# 93:	learn: 0.4404902	total: 230ms	remaining: 2.22s
# 94:	learn: 0.4391657	total: 232ms	remaining: 2.21s
# 95:	learn: 0.4382879	total: 233ms	remaining: 2.2s
# 96:	learn: 0.4370422	total: 237ms	remaining: 2.21s
# 97:	learn: 0.4362253	total: 240ms	remaining: 2.21s
# 98:	learn: 0.4351153	total: 241ms	remaining: 2.19s
# 99:	learn: 0.4341197	total: 243ms	remaining: 2.18s
# 100:	learn: 0.4332494	total: 244ms	remaining: 2.17s
# 101:	learn: 0.4321965	total: 245ms	remaining: 2.16s
# 102:	learn: 0.4311933	total: 247ms	remaining: 2.15s
# 103:	learn: 0.4305164	total: 250ms	remaining: 2.15s
# 104:	learn: 0.4297141	total: 253ms	remaining: 2.16s
# 105:	learn: 0.4288964	total: 255ms	remaining: 2.15s
# 106:	learn: 0.4277072	total: 257ms	remaining: 2.14s
# 107:	learn: 0.4265388	total: 259ms	remaining: 2.14s
# 108:	learn: 0.4256398	total: 260ms	remaining: 2.13s
# 109:	learn: 0.4250223	total: 262ms	remaining: 2.12s
# 110:	learn: 0.4240773	total: 267ms	remaining: 2.13s
# 111:	learn: 0.4231011	total: 271ms	remaining: 2.15s
# 112:	learn: 0.4226124	total: 272ms	remaining: 2.14s
# 113:	learn: 0.4217732	total: 274ms	remaining: 2.13s
# 114:	learn: 0.4208055	total: 277ms	remaining: 2.13s
# 115:	learn: 0.4200088	total: 287ms	remaining: 2.18s
# 116:	learn: 0.4192831	total: 302ms	remaining: 2.28s
# 117:	learn: 0.4185773	total: 306ms	remaining: 2.29s
# 118:	learn: 0.4180348	total: 311ms	remaining: 2.3s
# 119:	learn: 0.4173525	total: 313ms	remaining: 2.3s
# 120:	learn: 0.4163132	total: 319ms	remaining: 2.31s
# 121:	learn: 0.4155801	total: 326ms	remaining: 2.34s
# 122:	learn: 0.4145431	total: 330ms	remaining: 2.35s
# 123:	learn: 0.4137282	total: 332ms	remaining: 2.34s
# 124:	learn: 0.4129864	total: 335ms	remaining: 2.35s
# 125:	learn: 0.4121278	total: 337ms	remaining: 2.34s
# 126:	learn: 0.4114508	total: 339ms	remaining: 2.33s
# 127:	learn: 0.4113055	total: 340ms	remaining: 2.32s
# 128:	learn: 0.4106204	total: 342ms	remaining: 2.31s
# 129:	learn: 0.4099296	total: 345ms	remaining: 2.31s
# 130:	learn: 0.4092408	total: 350ms	remaining: 2.32s
# 131:	learn: 0.4086083	total: 352ms	remaining: 2.31s
# 132:	learn: 0.4078018	total: 354ms	remaining: 2.31s
# 133:	learn: 0.4070348	total: 356ms	remaining: 2.3s
# 134:	learn: 0.4063753	total: 364ms	remaining: 2.33s
# 135:	learn: 0.4057762	total: 369ms	remaining: 2.35s
# 136:	learn: 0.4052944	total: 371ms	remaining: 2.34s
# 137:	learn: 0.4048352	total: 373ms	remaining: 2.33s
# 138:	learn: 0.4042065	total: 377ms	remaining: 2.33s
# 139:	learn: 0.4039732	total: 382ms	remaining: 2.35s
# 140:	learn: 0.4031442	total: 385ms	remaining: 2.34s
# 141:	learn: 0.4029818	total: 386ms	remaining: 2.33s
# 142:	learn: 0.4025272	total: 396ms	remaining: 2.37s
# 143:	learn: 0.4018442	total: 398ms	remaining: 2.37s
# 144:	learn: 0.4010728	total: 400ms	remaining: 2.36s
# 145:	learn: 0.4005524	total: 404ms	remaining: 2.36s
# 146:	learn: 0.4003449	total: 408ms	remaining: 2.37s
# 147:	learn: 0.3999822	total: 410ms	remaining: 2.36s
# 148:	learn: 0.3993789	total: 412ms	remaining: 2.35s
# 149:	learn: 0.3989370	total: 413ms	remaining: 2.34s
# 150:	learn: 0.3985909	total: 415ms	remaining: 2.33s
# 151:	learn: 0.3980134	total: 416ms	remaining: 2.32s
# 152:	learn: 0.3976227	total: 421ms	remaining: 2.33s
# 153:	learn: 0.3969561	total: 422ms	remaining: 2.32s
# 154:	learn: 0.3965656	total: 425ms	remaining: 2.31s
# 155:	learn: 0.3961797	total: 427ms	remaining: 2.31s
# 156:	learn: 0.3960219	total: 428ms	remaining: 2.3s
# 157:	learn: 0.3955203	total: 429ms	remaining: 2.29s
# 158:	learn: 0.3950231	total: 432ms	remaining: 2.28s
# 159:	learn: 0.3944862	total: 436ms	remaining: 2.29s
# 160:	learn: 0.3942823	total: 437ms	remaining: 2.28s
# 161:	learn: 0.3939848	total: 439ms	remaining: 2.27s
# 162:	learn: 0.3936699	total: 440ms	remaining: 2.26s
# 163:	learn: 0.3932701	total: 442ms	remaining: 2.25s
# 164:	learn: 0.3929979	total: 445ms	remaining: 2.25s
# 165:	learn: 0.3926158	total: 448ms	remaining: 2.25s
# 166:	learn: 0.3924005	total: 450ms	remaining: 2.24s
# 167:	learn: 0.3920068	total: 453ms	remaining: 2.24s
# 168:	learn: 0.3919075	total: 458ms	remaining: 2.25s
# 169:	learn: 0.3914521	total: 464ms	remaining: 2.27s
# 170:	learn: 0.3908377	total: 475ms	remaining: 2.3s
# 171:	learn: 0.3903507	total: 482ms	remaining: 2.32s
# 172:	learn: 0.3900128	total: 502ms	remaining: 2.4s
# 173:	learn: 0.3895391	total: 510ms	remaining: 2.42s
# 174:	learn: 0.3893349	total: 514ms	remaining: 2.42s
# 175:	learn: 0.3891857	total: 518ms	remaining: 2.42s
# 176:	learn: 0.3887680	total: 525ms	remaining: 2.44s
# 177:	learn: 0.3883328	total: 538ms	remaining: 2.48s
# 178:	learn: 0.3881108	total: 547ms	remaining: 2.51s
# 179:	learn: 0.3876623	total: 552ms	remaining: 2.52s
# 180:	learn: 0.3874154	total: 555ms	remaining: 2.51s
# 181:	learn: 0.3870289	total: 558ms	remaining: 2.51s
# 182:	learn: 0.3866897	total: 562ms	remaining: 2.51s
# 183:	learn: 0.3862895	total: 566ms	remaining: 2.51s
# 184:	learn: 0.3860168	total: 568ms	remaining: 2.5s
# 185:	learn: 0.3859267	total: 569ms	remaining: 2.49s
# 186:	learn: 0.3856923	total: 571ms	remaining: 2.48s
# 187:	learn: 0.3853377	total: 574ms	remaining: 2.48s
# 188:	learn: 0.3851115	total: 578ms	remaining: 2.48s
# 189:	learn: 0.3845754	total: 580ms	remaining: 2.47s
# 190:	learn: 0.3842441	total: 581ms	remaining: 2.46s
# 191:	learn: 0.3839990	total: 583ms	remaining: 2.45s
# 192:	learn: 0.3835592	total: 585ms	remaining: 2.44s
# 193:	learn: 0.3833004	total: 586ms	remaining: 2.44s
# 194:	learn: 0.3830019	total: 588ms	remaining: 2.43s
# 195:	learn: 0.3826417	total: 597ms	remaining: 2.45s
# 196:	learn: 0.3824390	total: 599ms	remaining: 2.44s
# 197:	learn: 0.3821308	total: 601ms	remaining: 2.43s
# 198:	learn: 0.3816445	total: 603ms	remaining: 2.43s
# 199:	learn: 0.3812363	total: 609ms	remaining: 2.44s
# 200:	learn: 0.3810565	total: 613ms	remaining: 2.44s
# 201:	learn: 0.3808656	total: 619ms	remaining: 2.45s
# 202:	learn: 0.3806218	total: 624ms	remaining: 2.45s
# 203:	learn: 0.3803821	total: 626ms	remaining: 2.44s
# 204:	learn: 0.3799432	total: 628ms	remaining: 2.44s
# 205:	learn: 0.3797422	total: 630ms	remaining: 2.43s
# 206:	learn: 0.3794947	total: 633ms	remaining: 2.42s
# 207:	learn: 0.3792047	total: 635ms	remaining: 2.42s
# 208:	learn: 0.3789595	total: 637ms	remaining: 2.41s
# 209:	learn: 0.3785882	total: 638ms	remaining: 2.4s
# 210:	learn: 0.3783822	total: 640ms	remaining: 2.39s
# 211:	learn: 0.3782508	total: 641ms	remaining: 2.38s
# 212:	learn: 0.3779778	total: 643ms	remaining: 2.37s
# 213:	learn: 0.3776318	total: 645ms	remaining: 2.37s
# 214:	learn: 0.3773046	total: 647ms	remaining: 2.36s
# 215:	learn: 0.3771720	total: 648ms	remaining: 2.35s
# 216:	learn: 0.3767826	total: 650ms	remaining: 2.34s
# 217:	learn: 0.3764596	total: 651ms	remaining: 2.33s
# 218:	learn: 0.3763388	total: 652ms	remaining: 2.33s
# 219:	learn: 0.3760724	total: 654ms	remaining: 2.32s
# 220:	learn: 0.3759018	total: 656ms	remaining: 2.31s
# 221:	learn: 0.3757175	total: 658ms	remaining: 2.31s
# 222:	learn: 0.3753792	total: 664ms	remaining: 2.31s
# 223:	learn: 0.3751182	total: 666ms	remaining: 2.31s
# 224:	learn: 0.3749993	total: 667ms	remaining: 2.3s
# 225:	learn: 0.3748941	total: 669ms	remaining: 2.29s
# 226:	learn: 0.3748110	total: 670ms	remaining: 2.28s
# 227:	learn: 0.3745717	total: 675ms	remaining: 2.29s
# 228:	learn: 0.3743662	total: 676ms	remaining: 2.28s
# 229:	learn: 0.3741104	total: 678ms	remaining: 2.27s
# 230:	learn: 0.3739145	total: 680ms	remaining: 2.26s
# 231:	learn: 0.3737181	total: 681ms	remaining: 2.25s
# 232:	learn: 0.3736947	total: 681ms	remaining: 2.24s
# 233:	learn: 0.3736325	total: 682ms	remaining: 2.23s
# 234:	learn: 0.3733944	total: 683ms	remaining: 2.22s
# 235:	learn: 0.3732005	total: 684ms	remaining: 2.21s
# 236:	learn: 0.3729899	total: 689ms	remaining: 2.22s
# 237:	learn: 0.3727353	total: 706ms	remaining: 2.26s
# 238:	learn: 0.3724298	total: 711ms	remaining: 2.26s
# 239:	learn: 0.3722949	total: 717ms	remaining: 2.27s
# 240:	learn: 0.3722570	total: 719ms	remaining: 2.27s
# 241:	learn: 0.3721409	total: 720ms	remaining: 2.26s
# 242:	learn: 0.3719445	total: 722ms	remaining: 2.25s
# 243:	learn: 0.3716795	total: 723ms	remaining: 2.24s
# 244:	learn: 0.3715230	total: 724ms	remaining: 2.23s
# 245:	learn: 0.3713238	total: 725ms	remaining: 2.22s
# 246:	learn: 0.3710316	total: 727ms	remaining: 2.21s
# 247:	learn: 0.3708659	total: 728ms	remaining: 2.21s
# 248:	learn: 0.3706606	total: 730ms	remaining: 2.2s
# 249:	learn: 0.3704909	total: 733ms	remaining: 2.2s
# 250:	learn: 0.3701590	total: 735ms	remaining: 2.19s
# 251:	learn: 0.3697541	total: 736ms	remaining: 2.19s
# 252:	learn: 0.3697322	total: 737ms	remaining: 2.18s
# 253:	learn: 0.3696216	total: 738ms	remaining: 2.17s
# 254:	learn: 0.3694711	total: 740ms	remaining: 2.16s
# 255:	learn: 0.3691363	total: 741ms	remaining: 2.15s
# 256:	learn: 0.3690003	total: 743ms	remaining: 2.15s
# 257:	learn: 0.3687876	total: 752ms	remaining: 2.16s
# 258:	learn: 0.3684137	total: 754ms	remaining: 2.16s
# 259:	learn: 0.3682095	total: 755ms	remaining: 2.15s
# 260:	learn: 0.3679322	total: 757ms	remaining: 2.14s
# 261:	learn: 0.3677791	total: 759ms	remaining: 2.14s
# 262:	learn: 0.3676965	total: 763ms	remaining: 2.14s
# 263:	learn: 0.3675002	total: 765ms	remaining: 2.13s
# 264:	learn: 0.3674066	total: 766ms	remaining: 2.12s
# 265:	learn: 0.3672809	total: 767ms	remaining: 2.12s
# 266:	learn: 0.3670861	total: 768ms	remaining: 2.11s
# 267:	learn: 0.3669743	total: 769ms	remaining: 2.1s
# 268:	learn: 0.3667951	total: 771ms	remaining: 2.09s
# 269:	learn: 0.3666982	total: 773ms	remaining: 2.09s
# 270:	learn: 0.3664573	total: 776ms	remaining: 2.09s
# 271:	learn: 0.3661265	total: 778ms	remaining: 2.08s
# 272:	learn: 0.3659130	total: 780ms	remaining: 2.08s
# 273:	learn: 0.3658052	total: 781ms	remaining: 2.07s
# 274:	learn: 0.3656565	total: 782ms	remaining: 2.06s
# 275:	learn: 0.3654191	total: 783ms	remaining: 2.05s
# 276:	learn: 0.3652258	total: 784ms	remaining: 2.05s
# 277:	learn: 0.3651081	total: 785ms	remaining: 2.04s
# 278:	learn: 0.3649175	total: 789ms	remaining: 2.04s
# 279:	learn: 0.3646420	total: 791ms	remaining: 2.03s
# 280:	learn: 0.3645154	total: 793ms	remaining: 2.03s
# 281:	learn: 0.3643408	total: 796ms	remaining: 2.02s
# 282:	learn: 0.3640788	total: 797ms	remaining: 2.02s
# 283:	learn: 0.3640312	total: 798ms	remaining: 2.01s
# 284:	learn: 0.3637493	total: 800ms	remaining: 2s
# 285:	learn: 0.3636593	total: 806ms	remaining: 2.01s
# 286:	learn: 0.3635526	total: 810ms	remaining: 2.01s
# 287:	learn: 0.3633824	total: 812ms	remaining: 2.01s
# 288:	learn: 0.3631765	total: 817ms	remaining: 2.01s
# 289:	learn: 0.3629958	total: 821ms	remaining: 2.01s
# 290:	learn: 0.3628224	total: 824ms	remaining: 2.01s
# 291:	learn: 0.3626713	total: 826ms	remaining: 2s
# 292:	learn: 0.3626284	total: 828ms	remaining: 2s
# 293:	learn: 0.3625754	total: 831ms	remaining: 2s
# 294:	learn: 0.3624063	total: 834ms	remaining: 1.99s
# 295:	learn: 0.3621943	total: 839ms	remaining: 2s
# 296:	learn: 0.3620788	total: 841ms	remaining: 1.99s
# 297:	learn: 0.3620140	total: 847ms	remaining: 2s
# 298:	learn: 0.3619707	total: 864ms	remaining: 2.02s
# 299:	learn: 0.3618815	total: 867ms	remaining: 2.02s
# 300:	learn: 0.3618089	total: 872ms	remaining: 2.03s
# 301:	learn: 0.3616185	total: 875ms	remaining: 2.02s
# 302:	learn: 0.3613594	total: 877ms	remaining: 2.02s
# 303:	learn: 0.3612435	total: 878ms	remaining: 2.01s
# 304:	learn: 0.3611355	total: 881ms	remaining: 2.01s
# 305:	learn: 0.3611018	total: 887ms	remaining: 2.01s
# 306:	learn: 0.3610141	total: 889ms	remaining: 2.01s
# 307:	learn: 0.3608282	total: 891ms	remaining: 2s
# 308:	learn: 0.3605889	total: 892ms	remaining: 1.99s
# 309:	learn: 0.3604559	total: 893ms	remaining: 1.99s
# 310:	learn: 0.3603219	total: 897ms	remaining: 1.99s
# 311:	learn: 0.3602479	total: 898ms	remaining: 1.98s
# 312:	learn: 0.3601737	total: 900ms	remaining: 1.97s
# 313:	learn: 0.3600901	total: 901ms	remaining: 1.97s
# 314:	learn: 0.3599670	total: 902ms	remaining: 1.96s
# 315:	learn: 0.3597351	total: 903ms	remaining: 1.96s
# 316:	learn: 0.3595671	total: 904ms	remaining: 1.95s
# 317:	learn: 0.3594810	total: 905ms	remaining: 1.94s
# 318:	learn: 0.3594475	total: 906ms	remaining: 1.93s
# 319:	learn: 0.3593885	total: 907ms	remaining: 1.93s
# 320:	learn: 0.3592587	total: 910ms	remaining: 1.93s
# 321:	learn: 0.3591700	total: 912ms	remaining: 1.92s
# 322:	learn: 0.3590960	total: 914ms	remaining: 1.92s
# 323:	learn: 0.3589924	total: 916ms	remaining: 1.91s
# 324:	learn: 0.3587338	total: 918ms	remaining: 1.91s
# 325:	learn: 0.3585268	total: 919ms	remaining: 1.9s
# 326:	learn: 0.3583445	total: 921ms	remaining: 1.9s
# 327:	learn: 0.3581079	total: 924ms	remaining: 1.89s
# 328:	learn: 0.3580849	total: 925ms	remaining: 1.89s
# 329:	learn: 0.3579387	total: 927ms	remaining: 1.88s
# 330:	learn: 0.3577707	total: 928ms	remaining: 1.88s
# 331:	learn: 0.3575048	total: 929ms	remaining: 1.87s
# 332:	learn: 0.3574741	total: 930ms	remaining: 1.86s
# 333:	learn: 0.3574201	total: 932ms	remaining: 1.86s
# 334:	learn: 0.3573496	total: 935ms	remaining: 1.86s
# 335:	learn: 0.3572993	total: 939ms	remaining: 1.85s
# 336:	learn: 0.3572842	total: 940ms	remaining: 1.85s
# 337:	learn: 0.3571714	total: 942ms	remaining: 1.84s
# 338:	learn: 0.3571207	total: 944ms	remaining: 1.84s
# 339:	learn: 0.3568906	total: 946ms	remaining: 1.83s
# 340:	learn: 0.3568766	total: 948ms	remaining: 1.83s
# 341:	learn: 0.3568154	total: 950ms	remaining: 1.83s
# 342:	learn: 0.3567300	total: 952ms	remaining: 1.82s
# 343:	learn: 0.3566676	total: 954ms	remaining: 1.82s
# 344:	learn: 0.3565155	total: 955ms	remaining: 1.81s
# 345:	learn: 0.3563733	total: 958ms	remaining: 1.81s
# 346:	learn: 0.3562857	total: 960ms	remaining: 1.8s
# 347:	learn: 0.3562221	total: 966ms	remaining: 1.81s
# 348:	learn: 0.3561503	total: 968ms	remaining: 1.8s
# 349:	learn: 0.3560216	total: 970ms	remaining: 1.8s
# 350:	learn: 0.3558296	total: 972ms	remaining: 1.8s
# 351:	learn: 0.3556737	total: 974ms	remaining: 1.79s
# 352:	learn: 0.3553048	total: 978ms	remaining: 1.79s
# 353:	learn: 0.3551406	total: 981ms	remaining: 1.79s
# 354:	learn: 0.3550389	total: 983ms	remaining: 1.79s
# 355:	learn: 0.3550232	total: 985ms	remaining: 1.78s
# 356:	learn: 0.3549567	total: 987ms	remaining: 1.78s
# 357:	learn: 0.3548005	total: 989ms	remaining: 1.77s
# 358:	learn: 0.3545687	total: 995ms	remaining: 1.78s
# 359:	learn: 0.3544026	total: 997ms	remaining: 1.77s
# 360:	learn: 0.3542952	total: 999ms	remaining: 1.77s
# 361:	learn: 0.3542197	total: 1s	remaining: 1.76s
# 362:	learn: 0.3542002	total: 1s	remaining: 1.76s
# 363:	learn: 0.3540765	total: 1.01s	remaining: 1.76s
# 364:	learn: 0.3538770	total: 1.01s	remaining: 1.77s
# 365:	learn: 0.3537264	total: 1.02s	remaining: 1.76s
# 366:	learn: 0.3536610	total: 1.02s	remaining: 1.77s
# 367:	learn: 0.3535824	total: 1.04s	remaining: 1.79s
# 368:	learn: 0.3535087	total: 1.05s	remaining: 1.79s
# 369:	learn: 0.3534175	total: 1.05s	remaining: 1.79s
# 370:	learn: 0.3533245	total: 1.05s	remaining: 1.79s
# 371:	learn: 0.3532341	total: 1.05s	remaining: 1.78s
# 372:	learn: 0.3531312	total: 1.06s	remaining: 1.78s
# 373:	learn: 0.3529894	total: 1.06s	remaining: 1.78s
# 374:	learn: 0.3529044	total: 1.06s	remaining: 1.77s
# 375:	learn: 0.3527214	total: 1.06s	remaining: 1.77s
# 376:	learn: 0.3526615	total: 1.07s	remaining: 1.76s
# 377:	learn: 0.3525825	total: 1.07s	remaining: 1.76s
# 378:	learn: 0.3524942	total: 1.07s	remaining: 1.76s
# 379:	learn: 0.3524121	total: 1.08s	remaining: 1.76s
# 380:	learn: 0.3520873	total: 1.08s	remaining: 1.75s
# 381:	learn: 0.3520730	total: 1.08s	remaining: 1.75s
# 382:	learn: 0.3520331	total: 1.08s	remaining: 1.74s
# 383:	learn: 0.3519778	total: 1.08s	remaining: 1.74s
# 384:	learn: 0.3518852	total: 1.08s	remaining: 1.73s
# 385:	learn: 0.3517932	total: 1.09s	remaining: 1.74s
# 386:	learn: 0.3516758	total: 1.1s	remaining: 1.74s
# 387:	learn: 0.3513746	total: 1.1s	remaining: 1.74s
# 388:	learn: 0.3511608	total: 1.1s	remaining: 1.74s
# 389:	learn: 0.3510692	total: 1.11s	remaining: 1.73s
# 390:	learn: 0.3509855	total: 1.11s	remaining: 1.73s
# 391:	learn: 0.3508701	total: 1.11s	remaining: 1.72s
# 392:	learn: 0.3508211	total: 1.11s	remaining: 1.72s
# 393:	learn: 0.3507573	total: 1.12s	remaining: 1.72s
# 394:	learn: 0.3506783	total: 1.12s	remaining: 1.71s
# 395:	learn: 0.3506028	total: 1.12s	remaining: 1.71s
# 396:	learn: 0.3505101	total: 1.12s	remaining: 1.7s
# 397:	learn: 0.3504199	total: 1.12s	remaining: 1.7s
# 398:	learn: 0.3502347	total: 1.12s	remaining: 1.69s
# 399:	learn: 0.3501802	total: 1.12s	remaining: 1.69s
# 400:	learn: 0.3500308	total: 1.13s	remaining: 1.68s
# 401:	learn: 0.3499129	total: 1.13s	remaining: 1.68s
# 402:	learn: 0.3498962	total: 1.13s	remaining: 1.68s
# 403:	learn: 0.3497165	total: 1.13s	remaining: 1.67s
# 404:	learn: 0.3497010	total: 1.13s	remaining: 1.67s
# 405:	learn: 0.3495421	total: 1.14s	remaining: 1.66s
# 406:	learn: 0.3493901	total: 1.14s	remaining: 1.66s
# 407:	learn: 0.3493589	total: 1.14s	remaining: 1.65s
# 408:	learn: 0.3491203	total: 1.14s	remaining: 1.65s
# 409:	learn: 0.3490778	total: 1.14s	remaining: 1.64s
# 410:	learn: 0.3490014	total: 1.15s	remaining: 1.64s
# 411:	learn: 0.3489663	total: 1.15s	remaining: 1.64s
# 412:	learn: 0.3488687	total: 1.15s	remaining: 1.64s
# 413:	learn: 0.3488015	total: 1.15s	remaining: 1.63s
# 414:	learn: 0.3487049	total: 1.15s	remaining: 1.63s
# 415:	learn: 0.3486537	total: 1.16s	remaining: 1.63s
# 416:	learn: 0.3486381	total: 1.17s	remaining: 1.63s
# 417:	learn: 0.3485422	total: 1.17s	remaining: 1.63s
# 418:	learn: 0.3485203	total: 1.18s	remaining: 1.63s
# 419:	learn: 0.3483871	total: 1.18s	remaining: 1.63s
# 420:	learn: 0.3483412	total: 1.18s	remaining: 1.63s
# 421:	learn: 0.3481674	total: 1.19s	remaining: 1.63s
# 422:	learn: 0.3479020	total: 1.19s	remaining: 1.62s
# 423:	learn: 0.3477697	total: 1.2s	remaining: 1.63s
# 424:	learn: 0.3477108	total: 1.24s	remaining: 1.68s
# 425:	learn: 0.3476012	total: 1.25s	remaining: 1.68s
# 426:	learn: 0.3475850	total: 1.25s	remaining: 1.68s
# 427:	learn: 0.3475545	total: 1.26s	remaining: 1.68s
# 428:	learn: 0.3473361	total: 1.26s	remaining: 1.68s
# 429:	learn: 0.3473053	total: 1.27s	remaining: 1.69s
# 430:	learn: 0.3471179	total: 1.28s	remaining: 1.7s
# 431:	learn: 0.3470913	total: 1.29s	remaining: 1.7s
# 432:	learn: 0.3469915	total: 1.29s	remaining: 1.69s
# 433:	learn: 0.3468939	total: 1.3s	remaining: 1.69s
# 434:	learn: 0.3468306	total: 1.3s	remaining: 1.69s
# 435:	learn: 0.3467204	total: 1.3s	remaining: 1.68s
# 436:	learn: 0.3466243	total: 1.3s	remaining: 1.68s
# 437:	learn: 0.3465544	total: 1.3s	remaining: 1.68s
# 438:	learn: 0.3464578	total: 1.31s	remaining: 1.68s
# 439:	learn: 0.3463621	total: 1.31s	remaining: 1.67s
# 440:	learn: 0.3462758	total: 1.32s	remaining: 1.67s
# 441:	learn: 0.3461578	total: 1.32s	remaining: 1.67s
# 442:	learn: 0.3461528	total: 1.33s	remaining: 1.67s
# 443:	learn: 0.3461231	total: 1.34s	remaining: 1.68s
# 444:	learn: 0.3461053	total: 1.34s	remaining: 1.67s
# 445:	learn: 0.3460365	total: 1.34s	remaining: 1.67s
# 446:	learn: 0.3457989	total: 1.35s	remaining: 1.67s
# 447:	learn: 0.3456198	total: 1.36s	remaining: 1.67s
# 448:	learn: 0.3453509	total: 1.36s	remaining: 1.67s
# 449:	learn: 0.3451787	total: 1.36s	remaining: 1.67s
# 450:	learn: 0.3449899	total: 1.38s	remaining: 1.68s
# 451:	learn: 0.3448983	total: 1.39s	remaining: 1.68s
# 452:	learn: 0.3448130	total: 1.39s	remaining: 1.68s
# 453:	learn: 0.3447489	total: 1.4s	remaining: 1.68s
# 454:	learn: 0.3446504	total: 1.4s	remaining: 1.67s
# 455:	learn: 0.3444732	total: 1.41s	remaining: 1.68s
# 456:	learn: 0.3444590	total: 1.41s	remaining: 1.68s
# 457:	learn: 0.3444477	total: 1.41s	remaining: 1.67s
# 458:	learn: 0.3442851	total: 1.42s	remaining: 1.67s
# 459:	learn: 0.3441539	total: 1.42s	remaining: 1.67s
# 460:	learn: 0.3440891	total: 1.42s	remaining: 1.66s
# 461:	learn: 0.3440759	total: 1.42s	remaining: 1.66s
# 462:	learn: 0.3440023	total: 1.44s	remaining: 1.67s
# 463:	learn: 0.3439273	total: 1.45s	remaining: 1.68s
# 464:	learn: 0.3437767	total: 1.46s	remaining: 1.68s
# 465:	learn: 0.3436011	total: 1.46s	remaining: 1.68s
# 466:	learn: 0.3435185	total: 1.46s	remaining: 1.67s
# 467:	learn: 0.3434050	total: 1.47s	remaining: 1.67s
# 468:	learn: 0.3431608	total: 1.48s	remaining: 1.67s
# 469:	learn: 0.3431598	total: 1.48s	remaining: 1.67s
# 470:	learn: 0.3430820	total: 1.49s	remaining: 1.68s
# 471:	learn: 0.3430021	total: 1.5s	remaining: 1.67s
# 472:	learn: 0.3429220	total: 1.5s	remaining: 1.67s
# 473:	learn: 0.3428690	total: 1.5s	remaining: 1.67s
# 474:	learn: 0.3428653	total: 1.5s	remaining: 1.66s
# 475:	learn: 0.3427040	total: 1.5s	remaining: 1.66s
# 476:	learn: 0.3426540	total: 1.51s	remaining: 1.66s
# 477:	learn: 0.3426290	total: 1.51s	remaining: 1.65s
# 478:	learn: 0.3425812	total: 1.52s	remaining: 1.66s
# 479:	learn: 0.3425727	total: 1.52s	remaining: 1.65s
# 480:	learn: 0.3425002	total: 1.53s	remaining: 1.65s
# 481:	learn: 0.3424210	total: 1.53s	remaining: 1.64s
# 482:	learn: 0.3423329	total: 1.53s	remaining: 1.64s
# 483:	learn: 0.3421823	total: 1.53s	remaining: 1.64s
# 484:	learn: 0.3421060	total: 1.54s	remaining: 1.64s
# 485:	learn: 0.3421014	total: 1.54s	remaining: 1.63s
# 486:	learn: 0.3420767	total: 1.55s	remaining: 1.64s
# 487:	learn: 0.3419000	total: 1.56s	remaining: 1.64s
# 488:	learn: 0.3418063	total: 1.57s	remaining: 1.64s
# 489:	learn: 0.3416243	total: 1.57s	remaining: 1.64s
# 490:	learn: 0.3415448	total: 1.57s	remaining: 1.63s
# 491:	learn: 0.3414150	total: 1.57s	remaining: 1.63s
# 492:	learn: 0.3412896	total: 1.58s	remaining: 1.63s
# 493:	learn: 0.3411711	total: 1.58s	remaining: 1.62s
# 494:	learn: 0.3411604	total: 1.58s	remaining: 1.62s
# 495:	learn: 0.3410726	total: 1.59s	remaining: 1.61s
# 496:	learn: 0.3409529	total: 1.59s	remaining: 1.61s
# 497:	learn: 0.3409216	total: 1.59s	remaining: 1.6s
# 498:	learn: 0.3408807	total: 1.59s	remaining: 1.6s
# 499:	learn: 0.3407631	total: 1.59s	remaining: 1.59s
# 500:	learn: 0.3405881	total: 1.6s	remaining: 1.59s
# 501:	learn: 0.3404466	total: 1.6s	remaining: 1.59s
# 502:	learn: 0.3403979	total: 1.6s	remaining: 1.58s
# 503:	learn: 0.3403095	total: 1.6s	remaining: 1.58s
# 504:	learn: 0.3402414	total: 1.6s	remaining: 1.57s
# 505:	learn: 0.3401560	total: 1.61s	remaining: 1.57s
# 506:	learn: 0.3401399	total: 1.61s	remaining: 1.56s
# 507:	learn: 0.3399880	total: 1.61s	remaining: 1.56s
# 508:	learn: 0.3399158	total: 1.61s	remaining: 1.55s
# 509:	learn: 0.3398366	total: 1.61s	remaining: 1.55s
# 510:	learn: 0.3396828	total: 1.61s	remaining: 1.54s
# 511:	learn: 0.3395638	total: 1.61s	remaining: 1.54s
# 512:	learn: 0.3395173	total: 1.61s	remaining: 1.53s
# 513:	learn: 0.3395091	total: 1.62s	remaining: 1.53s
# 514:	learn: 0.3394421	total: 1.62s	remaining: 1.52s
# 515:	learn: 0.3393813	total: 1.62s	remaining: 1.52s
# 516:	learn: 0.3393488	total: 1.62s	remaining: 1.51s
# 517:	learn: 0.3392441	total: 1.62s	remaining: 1.51s
# 518:	learn: 0.3392009	total: 1.62s	remaining: 1.5s
# 519:	learn: 0.3390011	total: 1.63s	remaining: 1.5s
# 520:	learn: 0.3389645	total: 1.63s	remaining: 1.5s
# 521:	learn: 0.3389439	total: 1.63s	remaining: 1.49s
# 522:	learn: 0.3389060	total: 1.63s	remaining: 1.49s
# 523:	learn: 0.3388504	total: 1.63s	remaining: 1.48s
# 524:	learn: 0.3388042	total: 1.63s	remaining: 1.48s
# 525:	learn: 0.3387443	total: 1.64s	remaining: 1.48s
# 526:	learn: 0.3386911	total: 1.64s	remaining: 1.47s
# 527:	learn: 0.3386226	total: 1.64s	remaining: 1.47s
# 528:	learn: 0.3385926	total: 1.64s	remaining: 1.46s
# 529:	learn: 0.3385532	total: 1.64s	remaining: 1.46s
# 530:	learn: 0.3384992	total: 1.64s	remaining: 1.45s
# 531:	learn: 0.3384332	total: 1.64s	remaining: 1.45s
# 532:	learn: 0.3383714	total: 1.65s	remaining: 1.45s
# 533:	learn: 0.3382934	total: 1.65s	remaining: 1.44s
# 534:	learn: 0.3382794	total: 1.66s	remaining: 1.44s
# 535:	learn: 0.3382645	total: 1.67s	remaining: 1.44s
# 536:	learn: 0.3382627	total: 1.67s	remaining: 1.44s
# 537:	learn: 0.3382421	total: 1.67s	remaining: 1.44s
# 538:	learn: 0.3381264	total: 1.68s	remaining: 1.44s
# 539:	learn: 0.3380460	total: 1.68s	remaining: 1.43s
# 540:	learn: 0.3377613	total: 1.68s	remaining: 1.43s
# 541:	learn: 0.3375536	total: 1.69s	remaining: 1.43s
# 542:	learn: 0.3375335	total: 1.69s	remaining: 1.43s
# 543:	learn: 0.3375115	total: 1.7s	remaining: 1.43s
# 544:	learn: 0.3375015	total: 1.71s	remaining: 1.43s
# 545:	learn: 0.3374389	total: 1.72s	remaining: 1.43s
# 546:	learn: 0.3374074	total: 1.73s	remaining: 1.43s
# 547:	learn: 0.3373704	total: 1.73s	remaining: 1.43s
# 548:	learn: 0.3373338	total: 1.73s	remaining: 1.42s
# 549:	learn: 0.3372479	total: 1.74s	remaining: 1.42s
# 550:	learn: 0.3372435	total: 1.74s	remaining: 1.42s
# 551:	learn: 0.3372267	total: 1.75s	remaining: 1.42s
# 552:	learn: 0.3372001	total: 1.75s	remaining: 1.41s
# 553:	learn: 0.3371690	total: 1.75s	remaining: 1.41s
# 554:	learn: 0.3370117	total: 1.75s	remaining: 1.41s
# 555:	learn: 0.3369644	total: 1.75s	remaining: 1.4s
# 556:	learn: 0.3369144	total: 1.76s	remaining: 1.4s
# 557:	learn: 0.3368283	total: 1.76s	remaining: 1.39s
# 558:	learn: 0.3367152	total: 1.76s	remaining: 1.39s
# 559:	learn: 0.3365667	total: 1.76s	remaining: 1.38s
# 560:	learn: 0.3364514	total: 1.76s	remaining: 1.38s
# 561:	learn: 0.3362574	total: 1.76s	remaining: 1.38s
# 562:	learn: 0.3362200	total: 1.77s	remaining: 1.37s
# 563:	learn: 0.3361053	total: 1.77s	remaining: 1.37s
# 564:	learn: 0.3360115	total: 1.77s	remaining: 1.36s
# 565:	learn: 0.3359507	total: 1.77s	remaining: 1.36s
# 566:	learn: 0.3358505	total: 1.78s	remaining: 1.36s
# 567:	learn: 0.3357467	total: 1.78s	remaining: 1.35s
# 568:	learn: 0.3356086	total: 1.78s	remaining: 1.35s
# 569:	learn: 0.3354589	total: 1.78s	remaining: 1.34s
# 570:	learn: 0.3353889	total: 1.78s	remaining: 1.34s
# 571:	learn: 0.3353683	total: 1.78s	remaining: 1.33s
# 572:	learn: 0.3353483	total: 1.79s	remaining: 1.33s
# 573:	learn: 0.3351460	total: 1.79s	remaining: 1.33s
# 574:	learn: 0.3350951	total: 1.79s	remaining: 1.32s
# 575:	learn: 0.3350360	total: 1.79s	remaining: 1.32s
# 576:	learn: 0.3349911	total: 1.79s	remaining: 1.32s
# 577:	learn: 0.3348053	total: 1.8s	remaining: 1.31s
# 578:	learn: 0.3346662	total: 1.8s	remaining: 1.31s
# 579:	learn: 0.3346023	total: 1.81s	remaining: 1.31s
# 580:	learn: 0.3345532	total: 1.82s	remaining: 1.31s
# 581:	learn: 0.3344877	total: 1.82s	remaining: 1.31s
# 582:	learn: 0.3344545	total: 1.82s	remaining: 1.3s
# 583:	learn: 0.3343490	total: 1.83s	remaining: 1.3s
# 584:	learn: 0.3342866	total: 1.84s	remaining: 1.3s
# 585:	learn: 0.3342718	total: 1.84s	remaining: 1.3s
# 586:	learn: 0.3341750	total: 1.84s	remaining: 1.29s
# 587:	learn: 0.3341566	total: 1.85s	remaining: 1.29s
# 588:	learn: 0.3340977	total: 1.86s	remaining: 1.29s
# 589:	learn: 0.3340694	total: 1.86s	remaining: 1.29s
# 590:	learn: 0.3339155	total: 1.86s	remaining: 1.29s
# 591:	learn: 0.3338943	total: 1.87s	remaining: 1.29s
# 592:	learn: 0.3338869	total: 1.88s	remaining: 1.29s
# 593:	learn: 0.3338581	total: 1.89s	remaining: 1.29s
# 594:	learn: 0.3338173	total: 1.9s	remaining: 1.29s
# 595:	learn: 0.3335226	total: 1.9s	remaining: 1.29s
# 596:	learn: 0.3332526	total: 1.91s	remaining: 1.29s
# 597:	learn: 0.3330718	total: 1.92s	remaining: 1.29s
# 598:	learn: 0.3329913	total: 1.92s	remaining: 1.28s
# 599:	learn: 0.3329695	total: 1.92s	remaining: 1.28s
# 600:	learn: 0.3329134	total: 1.92s	remaining: 1.27s
# 601:	learn: 0.3328999	total: 1.92s	remaining: 1.27s
# 602:	learn: 0.3326998	total: 1.93s	remaining: 1.27s
# 603:	learn: 0.3326323	total: 1.93s	remaining: 1.27s
# 604:	learn: 0.3325607	total: 1.94s	remaining: 1.27s
# 605:	learn: 0.3324607	total: 1.94s	remaining: 1.26s
# 606:	learn: 0.3324519	total: 1.95s	remaining: 1.26s
# 607:	learn: 0.3323004	total: 1.95s	remaining: 1.26s
# 608:	learn: 0.3321822	total: 1.95s	remaining: 1.25s
# 609:	learn: 0.3321579	total: 1.96s	remaining: 1.26s
# 610:	learn: 0.3320636	total: 1.97s	remaining: 1.25s
# 611:	learn: 0.3319859	total: 1.97s	remaining: 1.25s
# 612:	learn: 0.3319011	total: 1.97s	remaining: 1.24s
# 613:	learn: 0.3317399	total: 1.98s	remaining: 1.24s
# 614:	learn: 0.3317046	total: 1.98s	remaining: 1.24s
# 615:	learn: 0.3314969	total: 1.98s	remaining: 1.24s
# 616:	learn: 0.3314264	total: 1.99s	remaining: 1.23s
# 617:	learn: 0.3313563	total: 1.99s	remaining: 1.23s
# 618:	learn: 0.3313170	total: 1.99s	remaining: 1.23s
# 619:	learn: 0.3312483	total: 1.99s	remaining: 1.22s
# 620:	learn: 0.3311959	total: 2s	remaining: 1.22s
# 621:	learn: 0.3311696	total: 2s	remaining: 1.21s
# 622:	learn: 0.3311113	total: 2s	remaining: 1.21s
# 623:	learn: 0.3310635	total: 2s	remaining: 1.21s
# 624:	learn: 0.3310165	total: 2.01s	remaining: 1.2s
# 625:	learn: 0.3309654	total: 2.01s	remaining: 1.2s
# 626:	learn: 0.3308237	total: 2.01s	remaining: 1.19s
# 627:	learn: 0.3307574	total: 2.01s	remaining: 1.19s
# 628:	learn: 0.3307236	total: 2.01s	remaining: 1.19s
# 629:	learn: 0.3305734	total: 2.01s	remaining: 1.18s
# 630:	learn: 0.3304076	total: 2.02s	remaining: 1.18s
# 631:	learn: 0.3303778	total: 2.02s	remaining: 1.17s
# 632:	learn: 0.3302339	total: 2.02s	remaining: 1.17s
# 633:	learn: 0.3300936	total: 2.02s	remaining: 1.17s
# 634:	learn: 0.3300475	total: 2.02s	remaining: 1.16s
# 635:	learn: 0.3300194	total: 2.02s	remaining: 1.16s
# 636:	learn: 0.3300131	total: 2.02s	remaining: 1.15s
# 637:	learn: 0.3299293	total: 2.02s	remaining: 1.15s
# 638:	learn: 0.3298834	total: 2.02s	remaining: 1.14s
# 639:	learn: 0.3297821	total: 2.03s	remaining: 1.14s
# 640:	learn: 0.3297176	total: 2.03s	remaining: 1.14s
# 641:	learn: 0.3296438	total: 2.03s	remaining: 1.13s
# 642:	learn: 0.3294978	total: 2.03s	remaining: 1.13s
# 643:	learn: 0.3294082	total: 2.03s	remaining: 1.12s
# 644:	learn: 0.3293780	total: 2.03s	remaining: 1.12s
# 645:	learn: 0.3293484	total: 2.04s	remaining: 1.11s
# 646:	learn: 0.3293149	total: 2.04s	remaining: 1.11s
# 647:	learn: 0.3292533	total: 2.04s	remaining: 1.11s
# 648:	learn: 0.3290832	total: 2.05s	remaining: 1.11s
# 649:	learn: 0.3290609	total: 2.05s	remaining: 1.1s
# 650:	learn: 0.3290359	total: 2.06s	remaining: 1.1s
# 651:	learn: 0.3289545	total: 2.06s	remaining: 1.1s
# 652:	learn: 0.3289494	total: 2.07s	remaining: 1.1s
# 653:	learn: 0.3288783	total: 2.07s	remaining: 1.09s
# 654:	learn: 0.3288565	total: 2.07s	remaining: 1.09s
# 655:	learn: 0.3288467	total: 2.07s	remaining: 1.09s
# 656:	learn: 0.3287017	total: 2.08s	remaining: 1.08s
# 657:	learn: 0.3285629	total: 2.08s	remaining: 1.08s
# 658:	learn: 0.3284847	total: 2.08s	remaining: 1.08s
# 659:	learn: 0.3284400	total: 2.09s	remaining: 1.07s
# 660:	learn: 0.3283752	total: 2.1s	remaining: 1.07s
# 661:	learn: 0.3282034	total: 2.1s	remaining: 1.07s
# 662:	learn: 0.3280096	total: 2.1s	remaining: 1.07s
# 663:	learn: 0.3279436	total: 2.1s	remaining: 1.06s
# 664:	learn: 0.3279186	total: 2.1s	remaining: 1.06s
# 665:	learn: 0.3279129	total: 2.1s	remaining: 1.05s
# 666:	learn: 0.3278552	total: 2.1s	remaining: 1.05s
# 667:	learn: 0.3278009	total: 2.1s	remaining: 1.04s
# 668:	learn: 0.3277498	total: 2.11s	remaining: 1.04s
# 669:	learn: 0.3277212	total: 2.11s	remaining: 1.04s
# 670:	learn: 0.3276804	total: 2.11s	remaining: 1.04s
# 671:	learn: 0.3276114	total: 2.12s	remaining: 1.03s
# 672:	learn: 0.3276037	total: 2.12s	remaining: 1.03s
# 673:	learn: 0.3274946	total: 2.13s	remaining: 1.03s
# 674:	learn: 0.3273981	total: 2.13s	remaining: 1.02s
# 675:	learn: 0.3272844	total: 2.13s	remaining: 1.02s
# 676:	learn: 0.3272562	total: 2.13s	remaining: 1.02s
# 677:	learn: 0.3271884	total: 2.14s	remaining: 1.01s
# 678:	learn: 0.3271543	total: 2.14s	remaining: 1.01s
# 679:	learn: 0.3271265	total: 2.14s	remaining: 1.01s
# 680:	learn: 0.3271165	total: 2.14s	remaining: 1s
# 681:	learn: 0.3270166	total: 2.14s	remaining: 998ms
# 682:	learn: 0.3269187	total: 2.14s	remaining: 994ms
# 683:	learn: 0.3268199	total: 2.14s	remaining: 990ms
# 684:	learn: 0.3268052	total: 2.14s	remaining: 986ms
# 685:	learn: 0.3266729	total: 2.15s	remaining: 982ms
# 686:	learn: 0.3265556	total: 2.15s	remaining: 979ms
# 687:	learn: 0.3265278	total: 2.15s	remaining: 975ms
# 688:	learn: 0.3263963	total: 2.15s	remaining: 971ms
# 689:	learn: 0.3263868	total: 2.15s	remaining: 967ms
# 690:	learn: 0.3263092	total: 2.15s	remaining: 963ms
# 691:	learn: 0.3262694	total: 2.15s	remaining: 959ms
# 692:	learn: 0.3262624	total: 2.15s	remaining: 955ms
# 693:	learn: 0.3261751	total: 2.15s	remaining: 951ms
# 694:	learn: 0.3261001	total: 2.16s	remaining: 946ms
# 695:	learn: 0.3259933	total: 2.16s	remaining: 943ms
# 696:	learn: 0.3259479	total: 2.16s	remaining: 939ms
# 697:	learn: 0.3258830	total: 2.17s	remaining: 937ms
# 698:	learn: 0.3257834	total: 2.17s	remaining: 933ms
# 699:	learn: 0.3257766	total: 2.17s	remaining: 929ms
# 700:	learn: 0.3256749	total: 2.17s	remaining: 925ms
# 701:	learn: 0.3256195	total: 2.17s	remaining: 922ms
# 702:	learn: 0.3255440	total: 2.17s	remaining: 918ms
# 703:	learn: 0.3255094	total: 2.17s	remaining: 914ms
# 704:	learn: 0.3254440	total: 2.17s	remaining: 910ms
# 705:	learn: 0.3253277	total: 2.18s	remaining: 907ms
# 706:	learn: 0.3252340	total: 2.18s	remaining: 903ms
# 707:	learn: 0.3252034	total: 2.18s	remaining: 899ms
# 708:	learn: 0.3251413	total: 2.18s	remaining: 895ms
# 709:	learn: 0.3250754	total: 2.18s	remaining: 891ms
# 710:	learn: 0.3249664	total: 2.18s	remaining: 888ms
# 711:	learn: 0.3249081	total: 2.18s	remaining: 884ms
# 712:	learn: 0.3248477	total: 2.19s	remaining: 880ms
# 713:	learn: 0.3247658	total: 2.19s	remaining: 876ms
# 714:	learn: 0.3247205	total: 2.19s	remaining: 873ms
# 715:	learn: 0.3246707	total: 2.19s	remaining: 870ms
# 716:	learn: 0.3245413	total: 2.19s	remaining: 866ms
# 717:	learn: 0.3243749	total: 2.19s	remaining: 862ms
# 718:	learn: 0.3243180	total: 2.2s	remaining: 859ms
# 719:	learn: 0.3242906	total: 2.2s	remaining: 855ms
# 720:	learn: 0.3241823	total: 2.2s	remaining: 851ms
# 721:	learn: 0.3239583	total: 2.2s	remaining: 847ms
# 722:	learn: 0.3239005	total: 2.2s	remaining: 844ms
# 723:	learn: 0.3238637	total: 2.2s	remaining: 840ms
# 724:	learn: 0.3238274	total: 2.21s	remaining: 837ms
# 725:	learn: 0.3237292	total: 2.21s	remaining: 833ms
# 726:	learn: 0.3237195	total: 2.21s	remaining: 829ms
# 727:	learn: 0.3236604	total: 2.21s	remaining: 826ms
# 728:	learn: 0.3236353	total: 2.21s	remaining: 822ms
# 729:	learn: 0.3235781	total: 2.21s	remaining: 818ms
# 730:	learn: 0.3235474	total: 2.21s	remaining: 814ms
# 731:	learn: 0.3234269	total: 2.21s	remaining: 811ms
# 732:	learn: 0.3233568	total: 2.22s	remaining: 810ms
# 733:	learn: 0.3232402	total: 2.23s	remaining: 806ms
# 734:	learn: 0.3232049	total: 2.23s	remaining: 803ms
# 735:	learn: 0.3231696	total: 2.23s	remaining: 799ms
# 736:	learn: 0.3229962	total: 2.23s	remaining: 796ms
# 737:	learn: 0.3228815	total: 2.23s	remaining: 793ms
# 738:	learn: 0.3228606	total: 2.24s	remaining: 790ms
# 739:	learn: 0.3227645	total: 2.24s	remaining: 786ms
# 740:	learn: 0.3227034	total: 2.24s	remaining: 782ms
# 741:	learn: 0.3225791	total: 2.24s	remaining: 779ms
# 742:	learn: 0.3225478	total: 2.24s	remaining: 775ms
# 743:	learn: 0.3224374	total: 2.24s	remaining: 771ms
# 744:	learn: 0.3224068	total: 2.24s	remaining: 768ms
# 745:	learn: 0.3223463	total: 2.25s	remaining: 765ms
# 746:	learn: 0.3222855	total: 2.25s	remaining: 762ms
# 747:	learn: 0.3221284	total: 2.25s	remaining: 758ms
# 748:	learn: 0.3220843	total: 2.25s	remaining: 754ms
# 749:	learn: 0.3220563	total: 2.25s	remaining: 751ms
# 750:	learn: 0.3219631	total: 2.25s	remaining: 747ms
# 751:	learn: 0.3219443	total: 2.25s	remaining: 743ms
# 752:	learn: 0.3217989	total: 2.25s	remaining: 740ms
# 753:	learn: 0.3216578	total: 2.26s	remaining: 736ms
# 754:	learn: 0.3216109	total: 2.26s	remaining: 733ms
# 755:	learn: 0.3215572	total: 2.26s	remaining: 730ms
# 756:	learn: 0.3214715	total: 2.26s	remaining: 727ms
# 757:	learn: 0.3214135	total: 2.27s	remaining: 723ms
# 758:	learn: 0.3213788	total: 2.27s	remaining: 720ms
# 759:	learn: 0.3212993	total: 2.27s	remaining: 716ms
# 760:	learn: 0.3212989	total: 2.27s	remaining: 713ms
# 761:	learn: 0.3211464	total: 2.27s	remaining: 709ms
# 762:	learn: 0.3211306	total: 2.27s	remaining: 706ms
# 763:	learn: 0.3210871	total: 2.27s	remaining: 703ms
# 764:	learn: 0.3209748	total: 2.28s	remaining: 699ms
# 765:	learn: 0.3208609	total: 2.28s	remaining: 696ms
# 766:	learn: 0.3207923	total: 2.28s	remaining: 692ms
# 767:	learn: 0.3207813	total: 2.28s	remaining: 689ms
# 768:	learn: 0.3207717	total: 2.28s	remaining: 685ms
# 769:	learn: 0.3206475	total: 2.28s	remaining: 682ms
# 770:	learn: 0.3206155	total: 2.28s	remaining: 678ms
# 771:	learn: 0.3205632	total: 2.28s	remaining: 675ms
# 772:	learn: 0.3205511	total: 2.28s	remaining: 671ms
# 773:	learn: 0.3205292	total: 2.29s	remaining: 668ms
# 774:	learn: 0.3203488	total: 2.29s	remaining: 664ms
# 775:	learn: 0.3202454	total: 2.29s	remaining: 661ms
# 776:	learn: 0.3201377	total: 2.29s	remaining: 658ms
# 777:	learn: 0.3199736	total: 2.29s	remaining: 654ms
# 778:	learn: 0.3198305	total: 2.31s	remaining: 655ms
# 779:	learn: 0.3197005	total: 2.31s	remaining: 652ms
# 780:	learn: 0.3196171	total: 2.31s	remaining: 648ms
# 781:	learn: 0.3195589	total: 2.31s	remaining: 645ms
# 782:	learn: 0.3195202	total: 2.31s	remaining: 642ms
# 783:	learn: 0.3194561	total: 2.32s	remaining: 638ms
# 784:	learn: 0.3193445	total: 2.32s	remaining: 635ms
# 785:	learn: 0.3193392	total: 2.32s	remaining: 632ms
# 786:	learn: 0.3193290	total: 2.32s	remaining: 628ms
# 787:	learn: 0.3191132	total: 2.32s	remaining: 625ms
# 788:	learn: 0.3189546	total: 2.32s	remaining: 621ms
# 789:	learn: 0.3189090	total: 2.33s	remaining: 618ms
# 790:	learn: 0.3188394	total: 2.33s	remaining: 615ms
# 791:	learn: 0.3187739	total: 2.33s	remaining: 611ms
# 792:	learn: 0.3187515	total: 2.33s	remaining: 608ms
# 793:	learn: 0.3186621	total: 2.33s	remaining: 605ms
# 794:	learn: 0.3185297	total: 2.33s	remaining: 601ms
# 795:	learn: 0.3185249	total: 2.33s	remaining: 598ms
# 796:	learn: 0.3184696	total: 2.33s	remaining: 595ms
# 797:	learn: 0.3183300	total: 2.34s	remaining: 591ms
# 798:	learn: 0.3182897	total: 2.34s	remaining: 588ms
# 799:	learn: 0.3182600	total: 2.34s	remaining: 585ms
# 800:	learn: 0.3182541	total: 2.34s	remaining: 582ms
# 801:	learn: 0.3181689	total: 2.34s	remaining: 578ms
# 802:	learn: 0.3181321	total: 2.34s	remaining: 575ms
# 803:	learn: 0.3181284	total: 2.34s	remaining: 572ms
# 804:	learn: 0.3180066	total: 2.35s	remaining: 568ms
# 805:	learn: 0.3179797	total: 2.35s	remaining: 565ms
# 806:	learn: 0.3179712	total: 2.35s	remaining: 562ms
# 807:	learn: 0.3179597	total: 2.35s	remaining: 559ms
# 808:	learn: 0.3179351	total: 2.35s	remaining: 556ms
# 809:	learn: 0.3178669	total: 2.35s	remaining: 553ms
# 810:	learn: 0.3178002	total: 2.36s	remaining: 549ms
# 811:	learn: 0.3177374	total: 2.36s	remaining: 546ms
# 812:	learn: 0.3177350	total: 2.36s	remaining: 543ms
# 813:	learn: 0.3174977	total: 2.36s	remaining: 540ms
# 814:	learn: 0.3173052	total: 2.36s	remaining: 537ms
# 815:	learn: 0.3171937	total: 2.37s	remaining: 534ms
# 816:	learn: 0.3171309	total: 2.37s	remaining: 530ms
# 817:	learn: 0.3170739	total: 2.37s	remaining: 527ms
# 818:	learn: 0.3170586	total: 2.37s	remaining: 524ms
# 819:	learn: 0.3169104	total: 2.37s	remaining: 520ms
# 820:	learn: 0.3167954	total: 2.37s	remaining: 517ms
# 821:	learn: 0.3166141	total: 2.37s	remaining: 514ms
# 822:	learn: 0.3166098	total: 2.38s	remaining: 511ms
# 823:	learn: 0.3165941	total: 2.38s	remaining: 508ms
# 824:	learn: 0.3165693	total: 2.38s	remaining: 505ms
# 825:	learn: 0.3165657	total: 2.38s	remaining: 501ms
# 826:	learn: 0.3164465	total: 2.38s	remaining: 498ms
# 827:	learn: 0.3163833	total: 2.38s	remaining: 495ms
# 828:	learn: 0.3163508	total: 2.38s	remaining: 492ms
# 829:	learn: 0.3162784	total: 2.39s	remaining: 489ms
# 830:	learn: 0.3162151	total: 2.39s	remaining: 486ms
# 831:	learn: 0.3161505	total: 2.39s	remaining: 483ms
# 832:	learn: 0.3160952	total: 2.39s	remaining: 480ms
# 833:	learn: 0.3159062	total: 2.4s	remaining: 477ms
# 834:	learn: 0.3158786	total: 2.4s	remaining: 474ms
# 835:	learn: 0.3157785	total: 2.4s	remaining: 471ms
# 836:	learn: 0.3156816	total: 2.4s	remaining: 468ms
# 837:	learn: 0.3156195	total: 2.41s	remaining: 465ms
# 838:	learn: 0.3155131	total: 2.41s	remaining: 462ms
# 839:	learn: 0.3153910	total: 2.41s	remaining: 459ms
# 840:	learn: 0.3152804	total: 2.41s	remaining: 455ms
# 841:	learn: 0.3152666	total: 2.41s	remaining: 452ms
# 842:	learn: 0.3152604	total: 2.41s	remaining: 449ms
# 843:	learn: 0.3150590	total: 2.42s	remaining: 446ms
# 844:	learn: 0.3150070	total: 2.42s	remaining: 443ms
# 845:	learn: 0.3149767	total: 2.42s	remaining: 440ms
# 846:	learn: 0.3149659	total: 2.42s	remaining: 437ms
# 847:	learn: 0.3148254	total: 2.42s	remaining: 434ms
# 848:	learn: 0.3147376	total: 2.42s	remaining: 431ms
# 849:	learn: 0.3147131	total: 2.42s	remaining: 427ms
# 850:	learn: 0.3145849	total: 2.42s	remaining: 424ms
# 851:	learn: 0.3144836	total: 2.42s	remaining: 421ms
# 852:	learn: 0.3143626	total: 2.43s	remaining: 418ms
# 853:	learn: 0.3143041	total: 2.43s	remaining: 415ms
# 854:	learn: 0.3142321	total: 2.43s	remaining: 412ms
# 855:	learn: 0.3142115	total: 2.43s	remaining: 409ms
# 856:	learn: 0.3140446	total: 2.43s	remaining: 406ms
# 857:	learn: 0.3139003	total: 2.43s	remaining: 403ms
# 858:	learn: 0.3138743	total: 2.44s	remaining: 400ms
# 859:	learn: 0.3138149	total: 2.44s	remaining: 397ms
# 860:	learn: 0.3137919	total: 2.44s	remaining: 394ms
# 861:	learn: 0.3137823	total: 2.44s	remaining: 390ms
# 862:	learn: 0.3136498	total: 2.44s	remaining: 387ms
# 863:	learn: 0.3135927	total: 2.44s	remaining: 385ms
# 864:	learn: 0.3135269	total: 2.44s	remaining: 381ms
# 865:	learn: 0.3134638	total: 2.44s	remaining: 378ms
# 866:	learn: 0.3133604	total: 2.45s	remaining: 375ms
# 867:	learn: 0.3133311	total: 2.45s	remaining: 372ms
# 868:	learn: 0.3131737	total: 2.45s	remaining: 369ms
# 869:	learn: 0.3130303	total: 2.45s	remaining: 366ms
# 870:	learn: 0.3130045	total: 2.45s	remaining: 363ms
# 871:	learn: 0.3129881	total: 2.45s	remaining: 360ms
# 872:	learn: 0.3128213	total: 2.45s	remaining: 357ms
# 873:	learn: 0.3127425	total: 2.46s	remaining: 354ms
# 874:	learn: 0.3127161	total: 2.46s	remaining: 351ms
# 875:	learn: 0.3126264	total: 2.46s	remaining: 348ms
# 876:	learn: 0.3126045	total: 2.46s	remaining: 345ms
# 877:	learn: 0.3125844	total: 2.46s	remaining: 342ms
# 878:	learn: 0.3125659	total: 2.46s	remaining: 339ms
# 879:	learn: 0.3125288	total: 2.46s	remaining: 336ms
# 880:	learn: 0.3124330	total: 2.46s	remaining: 333ms
# 881:	learn: 0.3123773	total: 2.46s	remaining: 330ms
# 882:	learn: 0.3122602	total: 2.47s	remaining: 327ms
# 883:	learn: 0.3122318	total: 2.47s	remaining: 324ms
# 884:	learn: 0.3120771	total: 2.47s	remaining: 321ms
# 885:	learn: 0.3120030	total: 2.47s	remaining: 318ms
# 886:	learn: 0.3119168	total: 2.47s	remaining: 315ms
# 887:	learn: 0.3118306	total: 2.48s	remaining: 312ms
# 888:	learn: 0.3118189	total: 2.48s	remaining: 309ms
# 889:	learn: 0.3117183	total: 2.48s	remaining: 306ms
# 890:	learn: 0.3116498	total: 2.48s	remaining: 303ms
# 891:	learn: 0.3116341	total: 2.48s	remaining: 301ms
# 892:	learn: 0.3115850	total: 2.48s	remaining: 298ms
# 893:	learn: 0.3115213	total: 2.49s	remaining: 295ms
# 894:	learn: 0.3114414	total: 2.49s	remaining: 292ms
# 895:	learn: 0.3113365	total: 2.49s	remaining: 289ms
# 896:	learn: 0.3113221	total: 2.49s	remaining: 286ms
# 897:	learn: 0.3112582	total: 2.49s	remaining: 283ms
# 898:	learn: 0.3112162	total: 2.49s	remaining: 280ms
# 899:	learn: 0.3111523	total: 2.5s	remaining: 277ms
# 900:	learn: 0.3111504	total: 2.5s	remaining: 274ms
# 901:	learn: 0.3110403	total: 2.5s	remaining: 272ms
# 902:	learn: 0.3109787	total: 2.5s	remaining: 269ms
# 903:	learn: 0.3108776	total: 2.5s	remaining: 266ms
# 904:	learn: 0.3108105	total: 2.5s	remaining: 263ms
# 905:	learn: 0.3107589	total: 2.51s	remaining: 260ms
# 906:	learn: 0.3107318	total: 2.51s	remaining: 257ms
# 907:	learn: 0.3106815	total: 2.51s	remaining: 254ms
# 908:	learn: 0.3105925	total: 2.51s	remaining: 251ms
# 909:	learn: 0.3105473	total: 2.51s	remaining: 249ms
# 910:	learn: 0.3104768	total: 2.52s	remaining: 246ms
# 911:	learn: 0.3104205	total: 2.52s	remaining: 243ms
# 912:	learn: 0.3103825	total: 2.52s	remaining: 240ms
# 913:	learn: 0.3102493	total: 2.52s	remaining: 237ms
# 914:	learn: 0.3102361	total: 2.52s	remaining: 235ms
# 915:	learn: 0.3100872	total: 2.53s	remaining: 232ms
# 916:	learn: 0.3100151	total: 2.53s	remaining: 229ms
# 917:	learn: 0.3098428	total: 2.53s	remaining: 226ms
# 918:	learn: 0.3097308	total: 2.54s	remaining: 224ms
# 919:	learn: 0.3096829	total: 2.55s	remaining: 221ms
# 920:	learn: 0.3096354	total: 2.55s	remaining: 219ms
# 921:	learn: 0.3095234	total: 2.56s	remaining: 217ms
# 922:	learn: 0.3094489	total: 2.56s	remaining: 214ms
# 923:	learn: 0.3094321	total: 2.56s	remaining: 211ms
# 924:	learn: 0.3093713	total: 2.56s	remaining: 208ms
# 925:	learn: 0.3092184	total: 2.57s	remaining: 205ms
# 926:	learn: 0.3091691	total: 2.58s	remaining: 203ms
# 927:	learn: 0.3091402	total: 2.6s	remaining: 202ms
# 928:	learn: 0.3091099	total: 2.62s	remaining: 200ms
# 929:	learn: 0.3090330	total: 2.63s	remaining: 198ms
# 930:	learn: 0.3088530	total: 2.64s	remaining: 195ms
# 931:	learn: 0.3086503	total: 2.64s	remaining: 193ms
# 932:	learn: 0.3085899	total: 2.65s	remaining: 190ms
# 933:	learn: 0.3085137	total: 2.65s	remaining: 187ms
# 934:	learn: 0.3084204	total: 2.65s	remaining: 185ms
# 935:	learn: 0.3083297	total: 2.66s	remaining: 182ms
# 936:	learn: 0.3083096	total: 2.67s	remaining: 179ms
# 937:	learn: 0.3082894	total: 2.67s	remaining: 177ms
# 938:	learn: 0.3082865	total: 2.68s	remaining: 174ms
# 939:	learn: 0.3081022	total: 2.69s	remaining: 172ms
# 940:	learn: 0.3080489	total: 2.69s	remaining: 169ms
# 941:	learn: 0.3078971	total: 2.7s	remaining: 166ms
# 942:	learn: 0.3078249	total: 2.7s	remaining: 163ms
# 943:	learn: 0.3077972	total: 2.71s	remaining: 161ms
# 944:	learn: 0.3077688	total: 2.71s	remaining: 158ms
# 945:	learn: 0.3076149	total: 2.72s	remaining: 155ms
# 946:	learn: 0.3075784	total: 2.72s	remaining: 152ms
# 947:	learn: 0.3074567	total: 2.72s	remaining: 149ms
# 948:	learn: 0.3073918	total: 2.73s	remaining: 147ms
# 949:	learn: 0.3073822	total: 2.73s	remaining: 144ms
# 950:	learn: 0.3073598	total: 2.73s	remaining: 141ms
# 951:	learn: 0.3072405	total: 2.74s	remaining: 138ms
# 952:	learn: 0.3072314	total: 2.75s	remaining: 135ms
# 953:	learn: 0.3071795	total: 2.75s	remaining: 132ms
# 954:	learn: 0.3071308	total: 2.75s	remaining: 130ms
# 955:	learn: 0.3070914	total: 2.76s	remaining: 127ms
# 956:	learn: 0.3070450	total: 2.76s	remaining: 124ms
# 957:	learn: 0.3069973	total: 2.77s	remaining: 121ms
# 958:	learn: 0.3069596	total: 2.77s	remaining: 119ms
# 959:	learn: 0.3068839	total: 2.77s	remaining: 116ms
# 960:	learn: 0.3068515	total: 2.78s	remaining: 113ms
# 961:	learn: 0.3067879	total: 2.78s	remaining: 110ms
# 962:	learn: 0.3067206	total: 2.79s	remaining: 107ms
# 963:	learn: 0.3066208	total: 2.79s	remaining: 104ms
# 964:	learn: 0.3066177	total: 2.8s	remaining: 102ms
# 965:	learn: 0.3065554	total: 2.8s	remaining: 98.6ms
# 966:	learn: 0.3065292	total: 2.81s	remaining: 95.8ms
# 967:	learn: 0.3064170	total: 2.81s	remaining: 93ms
# 968:	learn: 0.3063103	total: 2.81s	remaining: 90ms
# 969:	learn: 0.3061851	total: 2.81s	remaining: 87.1ms
# 970:	learn: 0.3061323	total: 2.82s	remaining: 84.2ms
# 971:	learn: 0.3061125	total: 2.82s	remaining: 81.3ms
# 972:	learn: 0.3060402	total: 2.83s	remaining: 78.4ms
# 973:	learn: 0.3058647	total: 2.83s	remaining: 75.5ms
# 974:	learn: 0.3058291	total: 2.83s	remaining: 72.7ms
# 975:	learn: 0.3058156	total: 2.84s	remaining: 69.8ms
# 976:	learn: 0.3056558	total: 2.84s	remaining: 66.8ms
# 977:	learn: 0.3056486	total: 2.84s	remaining: 63.9ms
# 978:	learn: 0.3055062	total: 2.84s	remaining: 61ms
# 979:	learn: 0.3054029	total: 2.84s	remaining: 58ms
# 980:	learn: 0.3053654	total: 2.85s	remaining: 55.1ms
# 981:	learn: 0.3053019	total: 2.85s	remaining: 52.2ms
# 982:	learn: 0.3052547	total: 2.85s	remaining: 49.4ms
# 983:	learn: 0.3051859	total: 2.86s	remaining: 46.4ms
# 984:	learn: 0.3051074	total: 2.86s	remaining: 43.6ms
# 985:	learn: 0.3050290	total: 2.86s	remaining: 40.7ms
# 986:	learn: 0.3050152	total: 2.86s	remaining: 37.7ms
# 987:	learn: 0.3050055	total: 2.87s	remaining: 34.8ms
# 988:	learn: 0.3049784	total: 2.87s	remaining: 31.9ms
# 989:	learn: 0.3048709	total: 2.87s	remaining: 29ms
# 990:	learn: 0.3048585	total: 2.88s	remaining: 26.2ms
# 991:	learn: 0.3047289	total: 2.88s	remaining: 23.2ms
# 992:	learn: 0.3046390	total: 2.88s	remaining: 20.3ms
# 993:	learn: 0.3044915	total: 2.89s	remaining: 17.4ms
# 994:	learn: 0.3043176	total: 2.89s	remaining: 14.5ms
# 995:	learn: 0.3042807	total: 2.89s	remaining: 11.6ms
# 996:	learn: 0.3042547	total: 2.89s	remaining: 8.71ms
# 997:	learn: 0.3040992	total: 2.9s	remaining: 5.8ms
# 998:	learn: 0.3040735	total: 2.9s	remaining: 2.9ms
# 999:	learn: 0.3040463	total: 2.9s	remaining: 0us
# 0.8100558659217877

# %% [markdown]
# **¿Qué hiperparámetros debería tocar en el XGB?**
# 1. `n_estimators`: igual que para el GradientBoosting.
# 2. `booster`: tipo de modelo que correrá en cada iteración. Arboles o regresiones. `gbtree` or `gblinear`. Los árboles suelen ir bien.
# 3. `learning_rate`: o también llamado `eta`. Como el learning rate del GradientBoosting.
# 4. `max_depth`: nada nuevo
#
# Si quieres afinar más todavía el XGBoost consulta [esta completa guía](https://www.analyticsvidhya.com/blog/2016/03/complete-guide-parameter-tuning-xgboost-with-codes-python/).
