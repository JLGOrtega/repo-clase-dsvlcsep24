# %% [markdown]
# # Web Scraping Workshop with Python Demo

# %% [markdown]
# If you have dabbled even a little bit in the world of data science, you have likely heard of the term *web scraping*. **Web scraping** is the process of using automation to obtain vast amounts of data simply from sources publicly available on the internet.
#
# There are three steps required to successfully scrape a website:
#
# 1) **Retreiving the data**
#
#     When you enter a URL into your browser and load a website on your computer, the contents of and the structure of the webpage is downloaded to your computer and displayed by your browser. This data is stored in an *HTML* file. To successfully web scrape a webpage, we must get access to this HTML data so that we can further analyze its contents.
#
# 2) **Parsing the data**
#
#     How that you have access to a website's HTML data, you now have to make sense of this data. Oftentimes, a big part of this step is figuring out which components of the HTML you need -- and which ones you don't. This is often the hardest and most tedious part of web scraping, but this is where the magic really happens.
#
# 3) **Using the data**
#
#     Congratulations! Now that you have you data, you can now do something cool with it. You can analyze this data, gain new insights and knowledge, even work on your very own data science app with this data as well (with proper attribution, of course!)
#
# In this workshop, you will learn the basics of creating your own web scraping script using the `BeautifulSoup` and `requests` package for the Python programming language. You will learn how to perform all three tasks of web scraping - retreiving the raw source HTML from a webpage, parsing that data to gain valuable data and knowledge, and storing that data to develop new insights or work on your very own data science app. We will also discuss how web scraping has been used in technologies and software commonly used today, as well as the potential ethical implications of the practice.
#
# This workshop is meant to be **introductory** and is open to all skill levels. No prior knowledge of web scraping or any of the Python packages mentioned are required.

# %% [markdown]
# ## Getting Started

# %% [markdown]
# This workshop heavily uses the `requests` and `beautifulsoup4` package for Python. To install this, run the cell below:

# %%
# !pip install requests
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: requests in /Users/ajaygandecha/opt/anaconda3/lib/python3.9/site-packages (2.28.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/ajaygandecha/opt/anaconda3/lib/python3.9/site-packages (from requests) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ajaygandecha/opt/anaconda3/lib/python3.9/site-packages (from requests) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /Users/ajaygandecha/opt/anaconda3/lib/python3.9/site-packages (from requests) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/ajaygandecha/opt/anaconda3/lib/python3.9/site-packages (from requests) (1.26.7)
# Requirement already satisfied: beautifulsoup4 in /Users/ajaygandecha/opt/anaconda3/lib/python3.9/site-packages (4.10.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/ajaygandecha/opt/anaconda3/lib/python3.9/site-packages (from beautifulsoup4) (2.2.1)

# %% [markdown]
# Now that you have installed the `requests` and `beautifulsoup4` package, import them below:

# %%
# Import the `requests` package
import requests

# Import `BeautifulSoup` from the `bs4` package
from bs4 import BeautifulSoup

# %% [markdown]
# As you noticed above, `beautifulsoup4` is abbreviated as `bs4`. Then from there, we can import `BeautifulSoup`.

# %% [markdown]
# **Congratulations!** You are now ready to start web scraping.

# %% [markdown]
# ## Part 1: Retrieving the Data

# %% [markdown]
# Remember, when you enter a URL into your browser and load a website on your computer, the contents of and the structure of the webpage is downloaded to your computer and displayed by your browser.
#
# This data is stored in an *HTML* file! To successfully web scrape a webpage, we must get access to this HTML data so that we can further analyze its contents.
#
# In Python, we can use the `requests` package to download and store the HTML from a URL!
#
# Which URL?

# %%
# URL for Professor Eskandarian's course explorer tool:
url = "https://www.cs.unc.edu/~saba/COMP_classes/spring2023/"

# %% [markdown]
# Now, we want to fetch the data from this URL! Let's use the `requests.get()` function:

# %%
# Get data from the URL
data = requests.get(url)
data
# Out:
# <Response [200]>

# %% [markdown]
# As you can see, we received a response! Have you ever heard of the *404 Not Found* error? That is a response as well. 200 means all is well.
#
# Now, let's find that HTML:

# %%
# Find data text (the HTML!) 
html = data.text
html
# Out:
# '<html>\n<head>\n    <title>\n        Class Information\n    </title>\n\t<style>\n\t\tbody{\n            font-family: Arial, Helvetica, sans-serif;\n            padding: 30px;\n\t\t}\n\t\t#main{\n\t\t\t\t//background-color: #fffafa;\n            margin: auto;\n\t\t}\n        ul{\n        list-style-type:none;\n        }\n        table{\n            border: none;\n        }\n        th{\n            font-weight: bold;\n            padding-bottom: 1em;\n            text-align: left;\n            padding-right: 2em;\n\n        }\n        td{\n            padding-bottom: 1em;\n            padding-right: 2em;\n        }\n\t\th1{\n            font-weight: normal;\n\t\t}\n        h2{\n            font-weight: normal;\n\t\t}\n        h3{\n            font-weight: normal;\n            margin-bottom: 0px;\n            margin-top: 0px;\n\t\t}\n\t\ta{\n            color: #337ab7;\n            outline:none;\n\t\t}\n\t\ta:hover {\n            color: hotpink;\n        }\n        .expandable {\n            display: none;\n        }\n        tr:nth-child(4n+2) {\n            background-color: #F2F7FB;\n        }\n\t</style>\n\n\t<script type="text/javascript">\n        window.onload = function() {\n            var showLink = document.getElementById("show");\n            var hideLink = document.getElementById("hide");\n\n            show.onclick = function() {\n                rows = document.getElementsByClassName(\'expandable\');\n                for(i = 0; i < rows.length; i++) {\n                    rows[i].style.display = \'table-row\';\n                }\n                //important that the tr style be in position 12 or this will break\n                document.styleSheets[0].cssRules[12].selectorText = \'tr:nth-child(even)\';\n                return false;\n            }\n\n            hide.onclick = function() {\n                rows = document.getElementsByClassName(\'expandable\');\n                for(i = 0; i < rows.length; i++) {\n                    rows[i].style.display = \'none\';\n                }\n                //important that the tr style be in position 12 or this will break\n                document.styleSheets[0].cssRules[12].selectorText = \'tr:nth-child(4n+2)\';\n                return false;\n            }\n        }\n\n    </script>\n</head>\n<body>\n\n<!-- Everything from here on will be filled in by the python script-->\n\n\n\n\n\n<h1>COMP Courses</h1>\n\n<p>Here is information about COMP class enrollment for <strong>spring 2023</strong>. Classes with no meeting time listed are not shown. Feel free to <a href=\'https://cs.unc.edu/~saba\'>contact me</a> with any questions/comments/issues.</p>\n\n<p><strong>Click <a id=\'show\'>here</a> to show class descriptions</strong>. Click <a id=\'hide\'>here</a> to hide them.</p>\n\n<script src=\'../choose_term.js\'></script>\n<p> Data also available for: <a href=\'index.html\'>COMP</a>, <a href=\'AAAD_classes.html\'>AAAD</a>, <a href=\'AMST_classes.html\'>AMST</a>, <a href=\'APPL_classes.html\'>APPL</a>, <a href=\'BIOL_classes.html\'>BIOL</a>, <a href=\'BIOS_classes.html\'>BIOS</a>, <a href=\'BMME_classes.html\'>BMME</a>, <a href=\'CHEM_classes.html\'>CHEM</a>, <a href=\'CMPL_classes.html\'>CMPL</a>, <a href=\'COMM_classes.html\'>COMM</a>, <a href=\'DRAM_classes.html\'>DRAM</a>, <a href=\'EDUC_classes.html\'>EDUC</a>, <a href=\'ENGL_classes.html\'>ENGL</a>, <a href=\'EPID_classes.html\'>EPID</a>, <a href=\'INLS_classes.html\'>INLS</a>, <a href=\'MATH_classes.html\'>MATH</a>, <a href=\'MEJO_classes.html\'>MEJO</a>, <a href=\'NURS_classes.html\'>NURS</a>, <a href=\'PSYC_classes.html\'>PSYC</a>, <a href=\'STOR_classes.html\'>STOR</a>, <a href=\'WGST_classes.html\'>WGST</a></p>\n<p>Data last updated: 2023-01-27 21:11:19.604326</p>\n<table>\n<tr>\n<th>Class Number</th>\n<th>Class</th>\n<th>Meeting Time</th>\n<th>Instructor</th>\n<th>Room</th>\n<th>Unreserved Enrollment</th>\n<th>Reserved Enrollment</th>\n<th>Wait List</th>\n</tr>\n<tr><td>4290</td><td>COMP&nbsp; 110 - 001&nbsp;& ...

# %% [markdown]
# Wow, that is quite long! Congratulations, you have now completed step 1 -- retrieving the data! But now, how do we make sense of all that gibberish?

# %% [markdown]
# ## Part 2: Parsing the Data

# %% [markdown]
# Now that we have the HTML data, we now unleash the full power of `BeautifulSoup` to parse this data.

# %%
# Parse data using the HTML that we extracted using the `html.parser`, and save output to soup.
soup = BeautifulSoup(html, 'html.parser')

# %%
# Now, let's print out the "prettified" version of that HTML!
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    Class Information
#   </title>
#   <style>
#    body{
#             font-family: Arial, Helvetica, sans-serif;
#             padding: 30px;
# 		}
# 		#main{
# 				//background-color: #fffafa;
#             margin: auto;
# 		}
#         ul{
#         list-style-type:none;
#         }
#         table{
#             border: none;
#         }
#         th{
#             font-weight: bold;
#             padding-bottom: 1em;
#             text-align: left;
#             padding-right: 2em;
#
#         }
#         td{
#             padding-bottom: 1em;
#             padding-right: 2em;
#         }
# 		h1{
#             font-weight: normal;
# 		}
#         h2{
#             font-weight: normal;
# 		}
#         h3{
#             font-weight: normal;
#             margin-bottom: 0px;
#             margin-top: 0px;
# 		}
# 		a{
#             color: #337ab7;
#             outline:none;
# 		}
# 		a:hover {
#             color: hotpink;
#         }
#         .expandable {
#             display: none;
#         }
#         tr:nth-child(4n+2) {
#             background-color: #F2F7FB;
#         }
#   </style>
#   <script type="text/javascript">
#    window.onload = function() {
#             var showLink = document.getElementById("show");
#             var hideLink = document.getElementById("hide");
#
#             show.onclick = function() {
#                 rows = document.getElementsByClassName('expandable');
#                 for(i = 0; i < rows.length; i++) {
#                     rows[i].style.display = 'table-row';
#                 }
#                 //important that the tr style be in position 12 or this will break
#                 document.styleSheets[0].cssRules[12].selectorText = 'tr:nth-child(even)';
#                 return false;
#             }
#
#             hide.onclick = function() {
#                 rows = document.getElementsByClassName('expandable');
#                 for(i = 0; i < rows.length; i++) {
#                     rows[i].style.display = 'none';
#                 }
#                 //important that the tr style be in position 12 or this will break
#                 document.styleSheets[0].cssRules[12].selectorText = 'tr:nth-child(4n+2)';
#                 return false;
#             }
#         }
#   </script>
#  </head>
#  <body>
#   <!-- Everything from here on will be filled in by the python script-->
#   <h1>
#    COMP Courses
#   </h1>
#   <p>
#    Here is information about COMP class enrollment for
#    <strong>
#     spring 2023
#    </strong>
#    . Classes with no meeting time listed are not shown. Feel free to
#    <a href="https://cs.unc.edu/~saba">
#     contact me
#    </a>
#    with any questions/comments/issues.
#   </p>
#   <p>
#    <strong>
#     Click
#     <a id="show">
#      here
#     </a>
#     to show class descriptions
#    </strong>
#    . Click
#    <a id="hide">
#     here
#    </a>
#    to hide them.
#   </p>
#   <script src="../choose_term.js">
#   </script>
#   <p>
#    Data also available for:
#    <a href="index.html">
#     COMP
#    </a>
#    ,
#    <a href="AAAD_classes.html">
#     AAAD
#    </a>
#    ,
#    <a href="AMST_classes.html">
#     AMST
#    </a>
#    ,
#    <a href="APPL_classes.html">
#     APPL
#    </a>
#    ,
#    <a href="BIOL_classes.html">
#     BIOL
#    </a>
#    ,
#    <a href="BIOS_classes.html">
#     BIOS
#    </a>
#    ,
#    <a href="BMME_classes.html">
#     BMME
#    </a>
#    ,
#    <a href="CHEM_classes.html">
#     CHEM
#    </a>
#    ,
#    <a href="CMPL_classes.html">
#     CMPL
#    </a>
#    ,
#    <a href="COMM_classes.html">
#     COMM
#    </a>
#    ,
#    <a href="DRAM_classes.html">
#     DRAM
#    </a>
#    ,
#    <a href="EDUC_classes.html">
#     EDUC
#    </a>
#    ,
#    <a href="ENGL_classes.html">
#     ENGL
#    </a>
#    ,
#    <a href="EPID_classes.html">
#     EPID
#    </a>
#    ,
#    <a href="INLS_classes.html">
#     INLS
#    </a>
#    ,
#    <a href="MATH_classes.html">
#     MATH
#    </a>
#    ,
#    <a href="MEJO_classes.html">
#     MEJO
#    </a>
#    ,
#    <a href="NURS_classes.html">
#     NURS
#    </a>
#    ,
#    <a href="PSYC_classes.html">
#     PSYC
#    </a>
#    ,
#    <a href="STOR_classes.html">
#     STOR
#    </a>
#    ,
#    <a href="WGST_classes.html">
#     WGST
#    </a>
#   </p>
#   <p>
#    Data last updated: 2023-01-27 21:11:19.604326
#   </p>
#   <table>
#    <tr>
#     <th>
#      Class Number
#     </th>
#     <th>
#      Class
#     </th>
#     <th>
#      Meeting Time
#     </th>
#     <th>
#      Instructor
#     </th>
#     <th>
#      Room
#     </th>
#     <th>
#      Unreserved Enrollment
#     </th>
#     <th>
#      Reserved Enrollment
#     </th>
#     <th>
#      Wait List
#     </th>
#    </tr>
#    <tr>
#     <td>
#      4290
#     </td>
#     <td>
#      COMP  110 - 001   Introduction to Programming and Data Science
#     </td>
#     <td>
#      TuTh 8:00AM - 9:15AM
#     </td>
#     <td>
#      Alyssa Byrnes
#     </td>
#     <td>
#      Hamilton Hall - Rm 0100
#     </td>
#     <td style="color:orange">
#      217/219
#     </td>
#     <td style="color:red">
#      81/81
#     </td>
#     <td>
#      0/30
#     </td>
#    </tr>
#    <tr class="expandable">
#     <td colspan="7">
#      <strong>
#       Description:
#      </strong>
#      Prerequisite, A C or better in one of the following courses: MATH 130, 152, 210, 231, 129P, or PHIL 155, or STOR 120, 151, 155. Introduces students to programming and data science from a computational perspective. With an emphasis on modern applications in society, students gain experience with problem decomposition, algorithms for data analysis, abstraction design, and ethics in computing. No prior programming experience expected. Foundational concepts include data types, sequences, boolean logic, control flow, functions/methods, recursion, classes/objects, input/output, data organization, transformations, and visualizations. Students may not enroll in COMP 110 after receiving credit for COMP 210 or greater. 3 units.
#     </td>
#    </tr>
#    <tr>
#     <td>
#      10266
#     </td>
#     <td>
#      COMP  110 - 002   Introduction to Programming and Data Science
#     </td>
#     <td>
#      TuTh 2:00PM - 3:15PM
#     </td>
#     <td>
#      Alyssa Byrnes
#     </td>
#     <td>
#      Hamilton Hall - Rm 0100
#     </td>
#     <td style="color:red">
#      90/90
#     </td>
#     <td style="color:red">
#      210/210
#     </td>
#     <td>
#      0/30
#     </td>
#    </tr>
#    <tr class="expandable">
#     <td colspan="7">
#      <strong>
#       Description:
#      </strong>
#      Prerequisite, A C or better in one of the following courses: MATH 130, 152, 210, 231, 129P, or PHIL 155, or STOR 120, 151, 155. Introduces students to programming and data science from a computational perspective. With an emphasis on modern applications in society, students gain experience with problem decomposition, algorithms for data analysis, abstraction design, and ethics in computing. No prior programming experience expected. Foundational concepts include data types, sequences, boolean logic, control flow, functions/methods, recursion, classes/objects, input/output, data organization, transformations, and visualizations. Students may not enroll in COMP 110 after receiving credit for COMP 210 or greater. 3 units.
#     </td>
#    </tr>
#    <tr>
#     <td>
#      9610
#     </td>
#     <td>
#      COMP  116 - 001   Introduction to Scientific Programming
#     </td>
#     <td>
#      TuTh 8:00AM - 9:15AM
#     </td>
#     <td>
#      John Majikes
#     </td>
#     <td>
#      Hanes Art Center - Rm 0121
#     </td>
#     <td>
#      153/240
#     </td>
#     <td>
#      0/0
#     </td>
#     <td>
#      0/24
#     </td>
#    </tr>
#    <tr class="expandable">
#     <td colspan="7">
#      <strong>
#       Description:
#      </strong>
#      Prerequisite, MATH 231 or 241; a grade of C or better is required. An introduction to programming for computationally oriented scientists. Fundamental programming skills, typically using MATLAB or Python. Problem analysis and algorithm design with examples drawn from simple numerical and discrete problems. 3 units.
#     </td>
#    </tr>
#    <tr>
#     <td>
#      5130
#     </td>
#     <td>
#      COMP  126 - 001   Practical Web Design and Development for Everyone
#     </td>
#     <td>
#      TuTh 11:00AM - 12:15PM
#     </td>
#     <td>
#      Tessa Joseph-Nicholas
#     </td>
#     <td>
#      Sitterson - Rm 0014
#     </td>
#     <td style="color:orange">
#      101/105
#     </td>
#     <td>
#      0/0
#     </td>
#     <td>
#      0/11
#     </td>
#    </tr>
#    <tr class="expandable">
#     <td colspan="7">
#      <strong>
#       Description:
#      </strong>
#      A ground-up introduction to current principles, standards, and best practice in website design, usability, accessibility, development, and management through project-based skills development in HTML5, CSS, and basic JavaScript. Intended for nonmajors. 3 units.
#     </td>
#    </tr>
#    <tr>
#     <td>
#      13454
#     </td>
#     <td>
#      COMP  210 - 001   Data Structures and Analysis
#     </td>
#     <td>
#      MoWe 2:05PM - 3:20PM
#     </td>
#     <td>
#      Paul Stotts
#     </td>
#     <td>
#      Hanes Art Center - Rm 0121
#     </td>
#     <td style="color:orange">
#      235/240
#     </td>
#     <td>
#      0/0
#     </td>
#     <td>
#      0/21
#     </td>
#    </tr>
#    <tr class="expandable">
#     <td colspan="7">
#      <strong>
#       Description:
#      </strong>
#      Prerequisites, COMP 110 and MATH 231; Pre- or corequisite, COMP 283 or MATH 381. This course will teach you how to organize the data used in computer programs so that manipulation of that data can be done efficiently on large problems and large data instances.  Rather than learning to use the data structures found in the libraries of programming languages, you will be learning how those libraries are constructed, and why the items that are included in them are there (and why some are excluded). 3 units.
#     </td>
#    </tr>
#    <tr>
#     <td>
#      9609
#     </td>
#     <td>
#      COMP  210 - 002   Data Structures and Analysis
#     </td>
#     <td>
#      TuTh 3:30PM - 4:45PM
#     </td>
#     <td>
#      Muhammad Ghani
#     </td>
#     <td>
#      Coker - Rm 0201
#     </td>
#     <td style="color:orange">
#      191/195
#     </td>
#     <td>
#      0/0
#     </td>
#     <td>
#      0/20
#     </td>
#    </tr>
#    <tr class="expandable">
#     <td colspan="7">
#      <strong>
#       Description:
#      </strong>
#      Prerequisites, COMP 110 and MATH 231; Pre- or corequisite, COMP 283 or MATH 381. This course will teach you how to organize the data used in computer programs so that manipulation of that data can be done efficiently on large problems and large data instances.  Rather than learning to use the data structures found in the libraries of programming languages, you will be learning how those libraries are constructed, and why the items that are included in them are there (and why some are excluded). 3 units.
#     </td>
#    </tr>
#    <tr>
#     <td>
#      9611
#     </td>
#     <td>
#      COMP  211 - 001   Systems Fundamentals
#     </td>
#     <td>
#      TuTh 11:00AM - 12:15PM
#     </td>
#     <td>
#      Brent Munsell
#     </td>
#     <td>
#      Murray Hall - Rm G202
#     </td>
#     <td style="color:orange">
#      175/183
#     </td>
#     <td style="color:red">
#      26/26
#     </td>
#     <td>
#      0/11
#     </td>
#    </tr>
#    <tr class="expandable">
#     <td colspan="7">
#      <strong>
#       Description:
#      </strong>
#      Prerequisites, COMP 210; COMP 283 or MATH 381; a grade of C or better is required in both prerequisite courses. This is the first course in the introductory systems sequence. Students enter the course having taken an introductory programming course in a high-level programming language (COMP 110) and a course in discrete structures. The overarching goal is to bridge the gap between a students' knowledge of a high-level programming language (COMP 110) and computer organization (COMP 311). 3 units.
#     </td>
#    </tr>
#    <tr>
#     <td>
#      14454
#     </td>
#     <td>
#      COMP  211 - 002   Systems Fundamentals
#     </td>
#     <td>
#      TuTh 2:00PM - 3:15PM
#     </td>
#     <td>
#      Joshua Bakita
#     </td>
#     <td>
#      Chapman Hall - Rm 0201
#     </td>
#     <td style="color:red">
#      120/120
#     </td>
#     <td style="color:red">
#      30/30
#     </td>
#     <td>
#      0/10
#     </td>
#    </tr>
#    <tr class="expandable">
#     <td colspan="7">
#      <strong>
#       Description:
#      </strong>
#      Prerequisites, COMP 210; COMP 283 or MATH 381; a grade of C or better is required in both prerequisite courses. This is the first course in the introductory systems sequence. Students enter the course having taken an introductory programming course in a high-level programming language (COMP 110) and a course in discrete structures. The overarching goal is to bridge the gap between a students' knowledge of a high-level programming language (COMP 110) and computer organization (COMP 311). 3 units.
#     </td>
#    </tr>
#    <tr>
#     <td>
#      5040
#     </td>
#     <td>
#      COMP  283 - 001   Discrete Structures
#     </td>
#     <td>
#      TuTh 2:00PM - 3:15PM
#     </td>
#     <td>
#      Jack Snoeyink
#     </td>
#     <td>
#      Hanes Art Center - Rm 0121
#     </td>
#     <td>
#      126/195
#     </td>
#     <td>
#      0/0
#     </td>
#     <td>
#      0/20
#     </td>
#    </tr>
#    <tr class="expandable">
#     <td colspan="7">
#      <strong>
#       Description:
#      </strong>
#      Prerequisite, MATH 231 or MATH 241; a grade of C or better is required. Introduces discrete structures (sets, tuples, relations, functions, graphs, trees) and the formal mathematics (logic, proof, induction) used to establish their properties and those of algorithms that work with them. Develops problem-solving skills through puzzles and applications central to computer science. 3 units.
#     </td>
#    </tr>
#    <tr>
#     <td>
#      10200
#     </td>
#     <td>
#      COMP  283H - 001   Discrete Structures
#     </td>
#     <td>
#      TuTh 2:00PM - 3:15PM
#     </td>
#     <td>
#      Jack Snoeyink
#     </td>
#     <td>
#      Hanes Art Center - Rm 0121
#     </td>
#     <td>
#      0/19
#     </td>
#     <td style="color:red">
#      5/5
#     </td>
#     <td>
#      0/5
#     </td>
#    </tr>
#    <tr class="expandable">
#     <td colspan="7">
#      <strong>
#       Description:
#      </strong>
#      Prerequisite, MATH 231 or MATH 241; a grade of C or better is required. Introduces discrete structures (sets, tuples, relations, functions, graphs, trees) and the formal mathematics (logic, proof, induction) used to establish their properties and those of algorithms that work with them. Develops problem-solving skills through puzzles and applications central to computer science. 3 units.
#     </td>
#    </tr>
#    <tr>
#     <td>
#      9612
#     </td>
#     <td>
#      COMP  301 - 001   Foundations of Programming
#     </td>
#     <td>
#      TuTh 8:00AM - 9:15AM
#     </td>
#     <td>
#      KETAN MAYER-PATEL
#     </td>
#     <td>
#      Genome Sciences Bldg -Rm G100
#     </td>
#     <td>
#      271/308
#     </td>
#     <td style="color:red">
#      55/55
#     </td>
#     <td>
#      0/21
#     </td>
#    </tr>
#    <tr class="expandable">
#     <td colspan="7">
#      <strong>
#       Description:
#      </strong>
#      Prerequisites, COMP 210; COMP 283 or MATH 381; a grade of C or better is required in both prerequisite courses. Students will learn how to reason about how their code is structured, identify whether a given structure is effective in a given context, and look at ways of organizing units of code that support larger programs. In a nutshell, the primary goal of the course is to equip students with tools and techniques that will help them not only in later courses in the major but also in their careers afterwards. 3 units.
#     </td>
#    </tr>
#    <tr>
#     <td>
#      9613
#     </td>
#     <td>
#      COMP  311 - 001   Computer Organization
#     </td>
#     <td>
#      TuTh 2:00PM - 3:15PM
#     </td>
#     <td>
#      Brent Munsell
#     </td>
#     <td>
#      Manning - Rm 0209
#     </td>
#     <td>
#      14/52
#     </td>
#     <td style="color:red">
#      128/128
#     </td>
#     <td>
#      0/18
#     </td>
#    </tr>
#    <tr class="expandable">
#     <td colspan="7">
#      <strong>
#       Description:
#      </strong>
#      Prerequisite, COMP 211; a grade of C or better is required. Introduction to computer organization and design. Students will be introduced to the conceptual design of a basic microprocessor, along with assembly programming.  The course includes fundamental concepts such as binary numbers, binary arithmetic, and representing information as well as instructions. Students learn to program in assembly (i.e., machine) language.  The course covers the fundamentals of computer hardware design,  transistors and logic gates, progressing through basic combinational and sequential components, culminating in the conceptual design CPU. 3 units.
#     </td>
#    </tr>
#    <tr>
#     <td>
#      3426
#     </td>
#     <td>
#      COMP  380 - 001   Introduction to Digital Culture
#     </td>
#     <td>
#      TuTh 9:30AM - 10:45AM
#     </td>
#     <td>
#      Multiple
#     </td>
#     <td>
#      F Brooks - Sitterson - Rm F009
#     </td>
#     <td style="color:red">
#      77/77
#     </td>
#     <td>
#      0/0
#     </td>
#     <td>
#      0/20
#     </td>
#    </tr>
#    <tr class="expandable">
#     <td colspan="7">
#      <strong>
#       Description:
#      </strong>
#      An introduction to digital technology and computer science issues in society. Topics may include Internet history, privacy, security, usability, graphics, games, computers in the media, development, economics, social media, AI, IP, computer and Internet ethics, global ethics, current legal issues, etc. 3 units.
#     </td>
#    </tr>
#    <tr>
#     <td>
#      3765
#     </td>
#     <td>
#      COMP  380H - 001   Introduction to Digital Culture
#     </td>
#     <td>
#      TuTh 2:00PM - 3:15PM
#     </td>
#     <td>
#      Tessa Joseph-Nicholas
#     </td>
#     <td>
#      Sitterson - Rm 0115
#     </td>
#     <td style="color:red">
#      2/2
#     </td>
#     <td style="color:red">
#      22/22
#     </td>
#     <td>
#      0/3
#     </td>
#    </tr>
#    <tr class="expandable">
#     <td colspan="7">
#      <strong>
#       Description:
#      </strong>
#      An introduction to digital technology and computer science issues in society. Topics may include Internet history, privacy, security, usability, graphics, games, computers in the media, development, economics, social media, AI, IP, computer and Internet ethics, global ethics, current legal issues, etc. 3 units.
#     </td>
#    </tr>
#    <tr>
#     <td>
#      10238
#     </td>
#     <td>
#      COMP  421 - 001   Files and Databases
#     </td>
#     <td>
#      TuTh 9:30AM - 10:45AM
#     </td>
#     <td>
#      John Majikes
#     </td>
#     <td>
#      Murphey - Rm 0116
#     </td>
#     <td style="color:orange">
#      41/44
#     </td>
#     <td style="color:red">
#      126/126
#     </td>
#     <td>
#      0/15
#     </td>
#    </tr>
#    <tr class="expandable">
#     <td colspan="7">
#      <strong>
#       Description:
#      </strong>
#      Prerequisites, COMP 210, 211, and 301; or COMP 401, 410, and 411; a grade of C or better is required in all prerequisite courses. Placement of data on secondary storage. File organization. Database history, practice, major models, system structure and design. Previously offered as COMP 521. 3 units.
#     </td>
#    </tr>
#    <tr>
#     <td>
#      9614
#     </td>
#     <td>
#      COMP  426 - 001   Modern Web Programming
#     </td>
#     <td>
#      TuTh 5:00PM - 6:15PM
#     </td>
#     <td>
#      John Martin
#     </td>
#     <td>
#      Hanes Art Center - Rm 0121
#     </td>
#     <td style="color:orange">
#      40/42
#     </td>
#     <td style="color:red">
#      163/163
#     </td>
#     <td>
#      0/21
#     </td>
#    </tr>
#    <tr class="expandable">
#     <td colspan="7">
#      <strong>
#       Description:
#      </strong>
#      Prerequisites, COMP 211 and 301; or COMP 401 and 410; a grade of C or better is required in all prerequisite courses. Developing applications for the World Wide Web including both client-side and server-side programming. Emphasis on Model-View-Controller architecture, AJAX, RESTful Web services, and database interaction. 3 units.
#     </td>
#    </tr>
#    <tr>
#     <td>
#      2168
#     </td>
#     <td>
#      COMP  431 - 001   Internet Services and Protocols
#     </td>
#     <td>
#      TuTh 12:30PM - 1:45PM
#     </td>
#     <td>
#      KEVIN JEFFAY
#     </td>
#     <td>
#      Sitterson - Rm 0014
#     </td>
#     <td>
#      9/81
#     </td>
#     <td style="color:red">
#      24/24
#     </td>
#     <td>
#      0/11
#     </td>
#    </tr>
#    <tr class="expandable">
#     <td colspan="7">
#      <strong>
#       Description:
#      </strong>
#      Prerequisites, COMP 210, 211, and 301; or COMP 401, 410, and 411; a grade of C or better is required in all prerequisite courses. Application-level protocols HTTP, SMTP, FTP, transport protocols TCP and UDP, and the network-level protocol IP. Internet architecture, naming, addressing, routing, and DNS. Sockets programming. Physical-layer technologies. Ethernet, ATM, and wireless. 3 units.
#     </td>
#    </tr>
#    <tr>
#     <td>
#      13015
#     </td>
#     <td>
#      COMP  447 - 001   Quantum Computing
#     </td>
#     <td>
#      MoWeFr 3:35PM - 4:25PM
#     </td>
#     <td>
#      Multiple
#     </td>
#     <td>
#      Phillips - Rm 0215
#     </td>
#     <td>
#      41/74
#     </td>
#     <td>
#      0/0
#     </td>
#     <td>
#      0/0
#     </td>
#    </tr>
#    <tr class="expandable">
#     <td colspan="7">
#      <strong>
#       Description:
#      </strong>
#      Prerequisites, MATH 232, and PHYS 116 or 118. Recommended preparation, some knowledge of basic linear algebra. An introduction to quantum computing. Basic math and quantum mechanics necessary to understand the operation of quantum bits. Quantum gates, circuits, and algorithms, including Shor's algorithm for factoring and Grover's search algorithm. Entanglement and error correction. Quantum encryption, annealing, and simulation. Brief discussion of technologies. 3 units.
#     </td>
#    </tr>
#    <tr>
#     <td>
#      2166
#     </td>
#     <td>
#      COMP  455 - 001   Models of Languages and Computation
#     </td>
#     <td>
#      TuTh 9:30AM - 10:45AM
#     </td>
#     <td>
#      Thiagarajan Subramanian
#     </td>
#     <td>
#      Sitterson - Rm 0014
#     </td>
#     <td style="color:red">
#      26/26
#     </td>
#     <td style="color:red">
#      64/64
#     </td>
#     <td>
#      0/18
#     </td>
#    </tr>
#    <tr class="expandable">
#     <td colspan="7">
#      <strong>
#       Description:
#      </strong>
#      Prerequisites, COMP 210 or 410 and COMP 283 or MATH 381; a grade of C or better in all prerequisite courses is required. Introduction to the theory of computation. Finite automata, regular languages, pushdown automata, context-free languages, and Turing machines. Undecidable problems. 3 units.
#     </td>
#    </tr>
#    <tr>
#     <td>
#      9615
#     </td>
#     <td>
#      COMP  455 - 002   Models of Languages and Computation
#     </td>
#     <td>
#      TuTh 2:00PM - 3:15PM
#     </td>
#     <td>
#      Thiagarajan Subramanian
#     </td>
#     <td>
#      Sitterson - Rm 0014
#     </td>
#     <td>
#      32/80
#     </td>
#     <td style="color:red">
#      15/15
#     </td>
#     <td>
#      0/10
#     </td>
#    </tr>
#    <tr class="expandable">
#     <td colspan="7">
#      <strong>
#       Description:
#      </strong>
#      Prerequisites, COMP 210 or 410 and COMP 283 or MATH 381; a grade of C or better in all prerequisite courses is required. Introduction to the theory of computation. Finite automata, regular languages, pushdown automata, context-free languages, and Turing machines. Undecidable problems. 3 units.
#     </td>
#    </tr>
#    <tr>
#     <td>
#      6439
#     </td>
#     <td>
#      COMP  488 - 001   Data Science in the Business World
#     </td>
#     <td>
#      TuTh 2:00PM - 3:15PM
#     </td>
#     <td>
#      Daniel Ringel
#     </td>
#     <td>
#      McColl Building - Rm 3250
#     </td>
#     <td>
#      0/0
#     </td>
#     <td>
#      19/22
#     </td>
#     <td>
#      0/1
#     </td>
#    </tr>
#    <tr class="expandable">
#     <td colspan="7">
#      <strong>
#       Description:
#      </strong>
#      Students will acquire hands-on data science skills enabling them to solve real-world business problems. Since data science is an interdisciplinary field, business and computer science students learn and work together in this course. Leveraging each other's skills and knowledge, students create data-driven business insights using modern analytics. 3 units.
#     </td>
#    </tr>
#    <tr>
#     <td>
#      6440
#     </td>
#     <td>
#      COMP  488 - 002   Data Science in the Business World
#     </td>
#     <td>
#      TuTh 3:30PM - 4:45PM
#     </td>
#     <td>
#      Daniel Ringel
#     </td>
#     <td>
#      McColl Building - Rm 3250
#     </td>
#     <td>
#      0/0
#     </td>
#     <td style="color:orange">
#      23/24
#     </td>
#     <td>
#      0/2
#     </td>
#    </tr>
#    <tr class="expandable">
#     <td colspan="7">
#      <strong>
#       Description:
#      </strong>
#      Students will acquire hands-on data science skills enabling them to solve real-world business problems. Since data science is an interdisciplinary field, business and computer science students learn and work together in this course. Leveraging each other's skills and knowledge, students create data-driven business insights using modern analytics. 3 units.
#     </td>
#    </tr>
#    <tr>
#     <td>
#      6441
#     </td>
#     <td>
#      COMP  488 - 003   Data Science in the Business World
#     </td>
#     <td>
#      MoWe 3:30PM - 4:45PM
#     </td>
#     <td>
#      Jack Snoeyink
#     </td>
#     <td>
#      Sitterson - Rm 0014
#     </td>
#     <td>
#      0/0
#     </td>
#     <td>
#      27/37
#     </td>
#     <td>
#      0/3
#     </td>
#    </tr>
#    <tr class="expandable">
#     <td colspan="7">
#      <strong>
#       Description:
#      </strong>
#      Students will acquire hands-on data science skills enabling them to solve real-world business problems. Since data science is an interdisciplinary field, business and computer science students learn and work together in this course. Leveraging each other's skills and knowledge, students create data-driven business insights using modern analytics. 3 units.
#     </td>
#    </tr>
#    <tr>
#     <td>
#      3110
#     </td>
#     <td>
#      COMP  523 - 001   Software Engineering Laboratory
#     </td>
#     <td>
#      MoWeFr 8:45AM - 10:00AM
#     </td>
#     <td>
#      Paul Stotts
#     </td>
#     <td>
#      F Brooks - Sitterson - Rm F009
#     </td>
#     <td style="color:red">
#      13/13
#     </td>
#     <td style="color:red">
#      47/47
#     </td>
#     <td>
#      0/6
#     </td>
#    </tr>
#    <tr class="expandable">
#     <td colspan="7">
#      <strong>
#       Description:
#      </strong>
#      Prerequisites, COMP 301 and 311; or COMP 401, 410, and 411; as well as at least two chosen from COMP 421, 426, 431, 433, 520, 530, 535, 575, 580. Organization and scheduling of software engineering projects, structured programming, and design. Each team designs, codes, and debugs program components and synthesizes them into a tested, documented program product. 4 units.
#     </td>
#    </tr>
#    <tr>
#     <td>
#      3362
#     </td>
#     <td>
#      COMP  541 - 001   Digital Logic and Computer Design
#     </td>
#     <td>
#      MoWeFr 2:05PM - 3:20PM
#     </td>
#     <td>
#      MONTEK SINGH
#     </td>
#     <td>
#      F Brooks - Sitterson - Rm F007
#     </td>
#     <td>
#      11/14
#     </td>
#     <td style="color:red">
#      31/31
#     </td>
#     <td>
#      0/5
#     </td>
#    </tr>
#    <tr class="expandable">
#     <td colspan="7">
#      <strong>
#       Description:
#      </strong>
#      Prerequisites, COMP 301 and 311; or COMP 401, 410, and 411; a grade of C or better is required in all prerequisite courses. This course is an introduction to digital logic as well as the structure and electronic design of modern processors. Students will implement a working computer during the laboratory sessions. 4 units.
#     </td>
#    </tr>
#    <tr>
#     <td>
#      2182
#     </td>
#     <td>
#      COMP  550 - 001   Algorithms and Analysis
#     </td>
#     <td>
#      TuTh 12:30PM - 1:45PM
#     </td>
#     <td>
#      Muhammad Ghani
#     </td>
#     <td>
#      Hanes Art Center - Rm 0121
#     </td>
#     <td style="color:orange">
#      36/38
#     </td>
#     <td style="color:red">
#      157/157
#     </td>
#     <td>
#      0/20
#     </td>
#    </tr>
#    <tr class="expandable">
#     <td colspan="7">
#      <strong>
#       Description:
#      </strong>
#      Prerequisites, COMP 211 and 301; or COMP 410; a grade of C or better is required in all prerequisite courses. Formal specification and verification of programs. Techniques of algorithm analysis. Problem-solving paradigms. Survey of selected algorithms. 3 units.
#     </td>
#    </tr>
#    <tr>
#     <td>
#      3886
#     </td>
#     <td>
#      COMP  555 - 001   Bioalgorithms
#     </td>
#     <td>
#      MoWe 2:05PM - 3:20PM
#     </td>
#     <td>
#      Anwica Kashfeen
#     </td>
#     <td>
#      Sitterson - Rm 0014
#     </td>
#     <td>
#      17/57
#     </td>
#     <td style="color:red">
#      3/3
#     </td>
#     <td>
#      0/0
#     </td>
#    </tr>
#    <tr class="expandable">
#     <td colspan="7">
#      <strong>
#       Description:
#      </strong>
#      Prerequisites, COMP 210, and 211; or COMP 401, and 410; and MATH 231, or 241; or BIOL 452; or MATH 553; or BIOL 525; a grade of C or better is required in all prerequisite courses. Bioinformatics algorithms. Topics include DNA restriction mapping, finding regulatory motifs, genome rearrangements, sequence alignments, gene prediction, graph algorithms, DNA sequencing, protein sequencing, combinatorial pattern matching, approximate pattern matching, clustering and evolution, tree construction, Hidden Markov Models, randomized algorithms. 3 units.
#     </td>
#    </tr>
#    <tr>
#     <td>
#      5605
#     </td>
#     <td>
#      COMP  562 - 001   Introduction to Machine Learning
#     </td>
#     <td>
#      TuTh 5:00PM - 6:15PM
#     </td>
#     <td>
#      Jorge Silva
#     </td>
#     <td>
#      Sitterson - Rm 0014
#     </td>
#     <td>
#      35/68
#     </td>
#     <td style="color:red">
#      52/52
#     </td>
#     <td>
#      0/12
#     </td>
#    </tr>
#    <tr class="expandable">
#     <td colspan="7">
#      <strong>
#       Description:
#      </strong>
#      Prerequisites, COMP 211 and 301; or COMP 401 and 410; as well as MATH 233, 347, and STOR 435; a grade of C or better is required in all prerequisite courses; permission of the instructor for students lacking the prerequisites. Machine learning as applied to speech recognition, tracking, collaborative filtering, and recommendation systems. Classification, regression, support vector machines, hidden Markov models, principal component analysis, and deep learning. 3 units.
#     </td>
#    </tr>
#    <tr>
#     <td>
#      14665
#     </td>
#     <td>
#      COMP  562H - 002   Introduction to Machine Learning
#     </td>
#     <td>
#      TuTh 12:30PM - 1:45PM
#     </td>
#     <td>
#      Junier Oliva
#     </td>
#     <td>
#      Sitterson - Rm 0011
#     </td>
#     <td>
#      10/22
#     </td>
#     <td style="color:red">
#      2/2
#     </td>
#     <td>
#      0/5
#     </td>
#    </tr>
#    <tr class="expandable">
#     <td colspan="7">
#      <strong>
#       Description:
#      </strong>
#      Prerequisites, COMP 211 and 301; or COMP 401 and 410; as well as MATH 233, 347, and STOR 435; a grade of C or better is required in all prerequisite courses; permission of the instructor for students lacking the prerequisites. Machine learning as applied to speech recognition, tracking, collaborative filtering, and recommendation systems. Classification, regression, support vector machines, hidden Markov models, principal component analysis, and deep learning. 3 units.
#     </td>
#    </tr>
#    <tr>
#     <td>
#      10207
#     </td>
#     <td>
#      COMP  590 - 093   Special Topics: User Interfaces
#     </td>
#     <td>
#      TuTh 9:30AM - 10:45AM
#     </td>
#     <td>
#      Diane Pozefsky
#     </td>
#     <td>
#      Sitterson - Rm 0011
#     </td>
#     <td style="color:red">
#      7/7
#     </td>
#     <td style="color:red">
#      33/33
#     </td>
#     <td>
#      0/5
#     </td>
#    </tr>
#    <tr class="expandable">
#     <td colspan="7">
#      <strong>
#       Description:
#      </strong>
#      Permission of the instructor. This course has variable content and may be taken multiple times for credit. Different sections may be taken in the same semester. 3 units.
#      <br/>
#      <strong>
#       Notes:
#      </strong>
#      Prerequisites, COMP 301 and COMP 311. Self-registration.
#     </td>
#    </tr>
#    <tr>
#     <td>
#      12217
#     </td>
#     <td>
#      COMP  590 - 132   Special Topics: Formal Methods and Security
#     </td>
#     <td>
#      MoWe 11:00AM - 12:15PM
#     </td>
#     <td>
#      Cynthia Sturton
#     </td>
#     <td>
#      F Brooks - Sitterson - Rm F009
#     </td>
#     <td>
#      7/8
#     </td>
#     <td style="color:red">
#      7/7
#     </td>
#     <td>
#      0/2
#     </td>
#    </tr>
#    <tr class="expandable">
#     <td colspan="7">
#      <strong>
#       Description:
#      </strong>
#      Permission of the instructor. This course has variable content and may be taken multiple times for credit. Different sections may be taken in the same semester. 3 units.
#      <br/>
#      <strong>
#       Notes:
#      </strong>
#      Instructor permission required. For more information, see
#      <a href="https://docs.google.com/document/d/1MUDD6y7y2y87DssPeLU_wmlPwkJs3LYzFjDjqzfaHJU/edit#heading=h.h8vorb0okj2">
#       https://docs.google.com/document/d/1MUDD6y7y2y87DssPeLU_wmlPwkJs3LYzFjDjqzfaHJU/edit#heading=h.h8vorb0okj2
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td>
#      13476
#     </td>
#     <td>
#      COMP  590 - 139   Special Topics: Connecting Language to Vision
#     </td>
#     <td>
#      We 11:00AM - 1:30PM
#     </td>
#     <td>
#      Mohit Bansal
#     </td>
#     <td>
#      Sitterson - Rm 0115
#     </td>
#     <td>
#      2/8
#     </td>
#     <td style="color:red">
#      2/2
#     </td>
#     <td>
#      0/1
#     </td>
#    </tr>
#    <tr class="expandable">
#     <td colspan="7">
#      <strong>
#       Description:
#      </strong>
#      Permission of the instructor. This course has variable content and may be taken multiple times for credit. Different sections may be taken in the same semester. 3 units.
#      <br/>
#      <strong>
#       Notes:
#      </strong>
#      Prerequisites, COMP 301 and COMP 211. Self-registration.
#     </td>
#    </tr>
#    <tr>
#     <td>
#      13477
#     </td>
#     <td>
#      COMP  590 - 140   Special Topics: Foundations of Software Engineering
#     </td>
#     <td>
#      MoWeFr 1:25PM - 2:15PM
#     </td>
#     <td>
#      Kris Jordan
#     </td>
#     <td>
#      Carroll - Rm 0111
#     </td>
#     <td>
#      24/29
#     </td>
#     <td style="color:red">
#      179/179
#     </td>
#     <td>
#      0/6
#     </td>
#    </tr>
#    <tr class="expandable">
#     <td colspan="7">
#      <strong>
#       Description:
#      </strong>
#      Permission of the instructor. This course has variable content and may be taken multiple times for credit. Different sections may be taken in the same semester. 3 units.
#      <br/>
#      <strong>
#       Notes:
#      </strong>
#      Prerequisites, COMP 301 and COMP 211. Registration request:
#      <a href="https://bit.ly/comp590-kj-23s">
#       https://bit.ly/comp590-kj-23s
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td>
#      14988
#     </td>
#     <td>
#      COMP  590 - 157   Topics in Computer Science
#     </td>
#     <td>
#      TuTh 11:00AM - 12:15PM
#     </td>
#     <td>
#      Shashank Srivastava
#     </td>
#     <td>
#      Sitterson - Rm 0011
#     </td>
#     <td>
#      17/38
#     </td>
#     <td style="color:red">
#      22/22
#     </td>
#     <td>
#      0/0
#     </td>
#    </tr>
#    <tr class="expandable">
#     <td colspan="7">
#      <strong>
#       Description:
#      </strong>
#      Permission of the instructor. This course has variable content and may be taken multiple times for credit. Different sections may be taken in the same semester. 3 units.
#     </td>
#    </tr>
#    <tr>
#     <td>
#      11958
#     </td>
#     <td>
#      COMP  590 - 171   Special Topics: Privacy Preserving Technologies
#     </td>
#     <td>
#      MoWe 2:05PM - 3:20PM
#     </td>
#     <td>
#      SABA ESKANDARIAN
#     </td>
#     <td>
#      Sitterson - Rm 0011
#     </td>
#     <td>
#      11/13
#     </td>
#     <td style="color:red">
#      16/16
#     </td>
#     <td>
#      0/3
#     </td>
#    </tr>
#    <tr class="expandable">
#     <td colspan="7">
#      <strong>
#       Description:
#      </strong>
#      Permission of the instructor. This course has variable content and may be taken multiple times for credit. Different sections may be taken in the same semester. 3 units.
#      <br/>
#      <strong>
#       Notes:
#      </strong>
#      Prerequisites, COMP 283, COMP 210, COMP 211, and COMP 301 (or their equivalents). Self-registration. Course website:
#      <a href="https://www.cs.unc.edu/~saba/priv_class/index.html">
#       https://www.cs.unc.edu/~saba/priv_class/index.html
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td>
#      13478
#     </td>
#     <td>
#      COMP  590 - 173   Special Topics: Visualization Design Methods
#     </td>
#     <td>
#      TuTh 12:30PM - 1:45PM
#     </td>
#     <td>
#      Danielle Szafir
#     </td>
#     <td>
#      F Brooks - Sitterson - Rm F007
#     </td>
#     <td style="color:red">
#      4/4
#     </td>
#     <td style="color:red">
#      16/16
#     </td>
#     <td>
#      0/2
#     </td>
#    </tr>
#    <tr class="expandable">
#     <td colspan="7">
#      <strong>
#       Description:
#      </strong>
#      Permission of the instructor. This course has variable content and may be taken multiple times for credit. Different sections may be taken in the same semester. 3 units.
#      <br/>
#      <strong>
#       Notes:
#      </strong>
#      Prerequisites, COMP 301 and COMP 211. Self-registration.
#     </td>
#    </tr>
#    <tr>
#     <td>
#      14446
#     </td>
#     <td>
#      COMP  590 - 177   Special Topics: Computer Vision in the 3D World
#     </td>
#     <td>
#      TuTh 2:00PM - 3:15PM
#     </td>
#     <td>
#      Soumyadip Sengupta
#     </td>
#     <td>
#      F Brooks - Sitterson - Rm F009
#     </td>
#     <td>
#      10/33
#     </td>
#     <td style="color:red">
#      27/27
#     </td>
#     <td>
#      0/10
#     </td>
#    </tr>
#    <tr class="expandable">
#     <td colspan="7">
#      <strong>
#       Description:
#      </strong>
#      Permission of the instructor. This course has variable content and may be taken multiple times for credit. Different sections may be taken in the same semester. 3 units.
#      <br/>
#      <strong>
#       Notes:
#      </strong>
#      Prerequisites, COMP 301, COMP 311, MATH 233, and MATH 347. Self-registration.
#     </td>
#    </tr>
#    <tr>
#     <td>
#      13479
#     </td>
#     <td>
#      COMP  631 - 001   Computer Networks
#     </td>
#     <td>
#      TuTh 11:00AM - 12:15PM
#     </td>
#     <td>
#      Jasleen Kaur
#     </td>
#     <td>
#      F Brooks - Sitterson - Rm F009
#     </td>
#     <td>
#      11/60
#     </td>
#     <td>
#      0/0
#     </td>
#     <td>
#      0/6
#     </td>
#    </tr>
#    <tr class="expandable">
#     <td colspan="7">
#      <strong>
#       Description:
#      </strong>
#      Required preparation, a first course in operating systems, a first course in networking (e.g., COMP 431 and 530), and knowledge of probability and statistics. Topics in computer networks, including link layer protocols, switching, IP, TCP, and congestion control. Additional topics may include peer-to-peer infrastructures, network security, and multimedia applications. 3 units.
#     </td>
#    </tr>
#    <tr>
#     <td>
#      3386
#     </td>
#     <td>
#      COMP  662 - 001   Scientific Computation II
#     </td>
#     <td>
#      TuTh 12:30PM - 1:45PM
#     </td>
#     <td>
#      JINGFANG HUANG
#     </td>
#     <td>
#      Phillips - Rm 0224
#     </td>
#     <td>
#      1/4
#     </td>
#     <td>
#      0/0
#     </td>
#     <td>
#      0/0
#     </td>
#    </tr>
#    <tr class="expandable">
#     <td colspan="7">
#      <strong>
#       Description:
#      </strong>
#      Prerequisite, MATH 661. Theory and practical issues arising in linear algebra problems derived from physical applications, e.g., discretization of ODEs and PDEs. Linear systems, linear least squares, eigenvalue problems, singular value decomposition. 3 units.
#     </td>
#    </tr>
#    <tr>
#     <td>
#      13485
#     </td>
#     <td>
#      COMP  664 - 101   Deep Learning
#     </td>
#     <td>
#      MoWe 12:30PM - 1:45PM
#     </td>
#     <td>
#      Colin Raffel
#     </td>
#     <td>
#      F Brooks - Sitterson - Rm F009
#     </td>
#     <td style="color:orange">
#      56/60
#     </td>
#     <td>
#      0/0
#     </td>
#     <td>
#      0/6
#     </td>
#    </tr>
#    <tr class="expandable">
#     <td colspan="7">
#      <strong>
#       Description:
#      </strong>
#      Prerequisites, COMP 562, 755, or 565 and MATH 201, 347, or 577 and MATH 233 or 522; permission of the instructor for student lacking the prerequisites. Introduction to the field of deep learning and its applications. Basics of building and optimizing neural networks, including model architectures and training schemes. 3 units.
#     </td>
#    </tr>
#    <tr>
#     <td>
#      13495
#     </td>
#     <td>
#      COMP  730 - 138   Operating Systems
#     </td>
#     <td>
#      TuTh 9:30AM - 10:45AM
#     </td>
#     <td>
#      Donald Porter
#     </td>
#     <td>
#      F Brooks - Sitterson - Rm F007
#     </td>
#     <td>
#      14/30
#     </td>
#     <td>
#      0/0
#     </td>
#     <td>
#      0/3
#     </td>
#    </tr>
#    <tr class="expandable">
#     <td colspan="7">
#      <strong>
#       Description:
#      </strong>
#      Prerequisite, COMP 530. Theory, structuring, and design of operating systems. Sequential and cooperating processes. Single processor, multiprocessor, and distributed operating systems. 3 units.
#     </td>
#    </tr>
#    <tr>
#     <td>
#      13497
#     </td>
#     <td>
#      COMP  735 - 080   Distributed and Concurrent Algorithms
#     </td>
#     <td>
#      TuTh 2:00PM - 3:15PM
#     </td>
#     <td>
#      JAMES ANDERSON
#     </td>
#     <td>
#      F Brooks - Sitterson - Rm F007
#     </td>
#     <td>
#      13/30
#     </td>
#     <td>
#      0/0
#     </td>
#     <td>
#      0/3
#     </td>
#    </tr>
#    <tr class="expandable">
#     <td colspan="7">
#      <strong>
#       Description:
#      </strong>
#      Prerequisites, COMP 530 and 550. Verification of concurrent systems. Synchronization; mutual exclusion and related problems, barriers, rendezvous, nonblocking algorithms. Fault tolerance: consensus, Byzantine agreement, self-stabilization. Broadcast algorithms. Termination and deadlock detection. Clock synchronization. 3 units.
#     </td>
#    </tr>
#    <tr>
#     <td>
#      13512
#     </td>
#     <td>
#      COMP  776 - 001   Computer Vision in our 3D World
#     </td>
#     <td>
#      TuTh 2:00PM - 3:15PM
#     </td>
#     <td>
#      Soumyadip Sengupta
#     </td>
#     <td>
#      F Brooks - Sitterson - Rm F009
#     </td>
#     <td>
#      18/30
#     </td>
#     <td>
#      0/0
#     </td>
#     <td>
#      0/0
#     </td>
#    </tr>
#    <tr class="expandable">
#     <td colspan="7">
#      <strong>
#       Description:
#      </strong>
#      Prerequisites, MATH 566, COMP 550, 665, and 775; permission of the instructor for students lacking the prerequisites. Fundamental problems of computer vision. Projective geometry. Camera models, camera calibration. Shape from stereo, epipolar geometry. Photometric stereo. Optical flow, tracking, motion. Range finders, structured light. Object recognition. 3 units.
#     </td>
#    </tr>
#    <tr>
#     <td>
#      13513
#     </td>
#     <td>
#      COMP  777 - 98   Optimal Estimation in Image Analysis
#     </td>
#     <td>
#      TuTh 11:00AM - 12:15PM
#     </td>
#     <td>
#      MARC NIETHAMMER
#     </td>
#     <td>
#      F Brooks - Sitterson - Rm F007
#     </td>
#     <td>
#      12/30
#     </td>
#     <td>
#      0/0
#     </td>
#     <td>
#      0/3
#     </td>
#    </tr>
#    <tr class="expandable">
#     <td colspan="7">
#      <strong>
#       Description:
#      </strong>
#      Prerequisites, MATH 233, MATH 347/547, and MATH 535 or STOR 435. Formulation and numerical solution of optimization problems in image analysis. 3 units.
#     </td>
#    </tr>
#    <tr>
#     <td>
#      13514
#     </td>
#     <td>
#      COMP  781 - 001   Robotics
#     </td>
#     <td>
#      MoWe 2:05PM - 3:20PM
#     </td>
#     <td>
#      RON ALTEROVITZ
#     </td>
#     <td>
#      TBA
#     </td>
#     <td>
#      18/24
#     </td>
#     <td>
#      0/0
#     </td>
#     <td>
#      0/0
#     </td>
#    </tr>
#    <tr class="expandable">
#     <td colspan="7">
#      <strong>
#       Description:
#      </strong>
#      Prerequisites, COMP 550 and MATH 347/547; Permission of the instructor for students lacking the prerequisites. Introduction to the design, programming, and control of robotic systems. Topics include kinematics, dynamics, sensing, actuation, control, robot learning, tele-operation, and motion planning. Applications will be discussed including industrial, mobile, assistive, personal, and medical robots. 3 units.
#     </td>
#    </tr>
#    <tr>
#     <td>
#      13519
#     </td>
#     <td>
#      COMP  790 - 006   Topics in Computer Science
#     </td>
#     <td>
#      TuTh 3:30PM - 4:45PM
#     </td>
#     <td>
#      STEPHEN PIZER
#     </td>
#     <td>
#      F Brooks - Sitterson - Rm F007
#     </td>
#     <td>
#      6/30
#     </td>
#     <td>
#      0/0
#     </td>
#     <td>
#      0/3
#     </td>
#    </tr>
#    <tr class="expandable">
#     <td colspan="7">
#      <strong>
#       Description:
#      </strong>
#      Permission of the instructor. This course has variable content and may be taken multiple times for credit. 1 - 21 units.
#     </td>
#    </tr>
#    <tr>
#     <td>
#      9640
#     </td>
#     <td>
#      COMP  790 - 132   Topics in Computer Science
#     </td>
#     <td>
#      MoWe 11:00AM - 12:15PM
#     </td>
#     <td>
#      Cynthia Sturton
#     </td>
#     <td>
#      F Brooks - Sitterson - Rm F009
#     </td>
#     <td>
#      1/30
#     </td>
#     <td>
#      0/0
#     </td>
#     <td>
#      0/2
#     </td>
#    </tr>
#    <tr class="expandable">
#     <td colspan="7">
#      <strong>
#       Description:
#      </strong>
#      Permission of the instructor. This course has variable content and may be taken multiple times for credit. 1 - 21 units.
#     </td>
#    </tr>
#    <tr>
#     <td>
#      13520
#     </td>
#     <td>
#      COMP  790 - 136   Topics in Computer Science
#     </td>
#     <td>
#      Mo 11:00AM - 2:00PM
#     </td>
#     <td>
#      Shahriar Nirjon
#     </td>
#     <td>
#      Sitterson - Rm 0115
#     </td>
#     <td>
#      13/25
#     </td>
#     <td>
#      0/0
#     </td>
#     <td>
#      0/3
#     </td>
#    </tr>
#    <tr class="expandable">
#     <td colspan="7">
#      <strong>
#       Description:
#      </strong>
#      Permission of the instructor. This course has variable content and may be taken multiple times for credit. 1 - 21 units.
#     </td>
#    </tr>
#    <tr>
#     <td>
#      14659
#     </td>
#     <td>
#      COMP  790 - 139   Topics in Computer Science
#     </td>
#     <td>
#      We 11:00AM - 1:30PM
#     </td>
#     <td>
#      Mohit Bansal
#     </td>
#     <td>
#      Sitterson - Rm 0115
#     </td>
#     <td>
#      9/15
#     </td>
#     <td>
#      0/0
#     </td>
#     <td>
#      0/0
#     </td>
#    </tr>
#    <tr class="expandable">
#     <td colspan="7">
#      <strong>
#       Description:
#      </strong>
#      Permission of the instructor. This course has variable content and may be taken multiple times for credit. 1 - 21 units.
#     </td>
#    </tr>
#    <tr>
#     <td>
#      10205
#     </td>
#     <td>
#      COMP  790 - 166   Topics in Computer Science
#     </td>
#     <td>
#      MoWe 11:00AM - 12:15PM
#     </td>
#     <td>
#      Natalie Stanley
#     </td>
#     <td>
#      F Brooks - Sitterson - Rm F007
#     </td>
#     <td>
#      12/30
#     </td>
#     <td>
#      0/0
#     </td>
#     <td>
#      0/3
#     </td>
#    </tr>
#    <tr class="expandable">
#     <td colspan="7">
#      <strong>
#       Description:
#      </strong>
#      Permission of the instructor. This course has variable content and may be taken multiple times for credit. 1 - 21 units.
#     </td>
#    </tr>
#    <tr>
#     <td>
#      11399
#     </td>
#     <td>
#      COMP  790 - 171   Special Topics: Privacy Preserving Technologies
#     </td>
#     <td>
#      MoWe 2:05PM - 3:20PM
#     </td>
#     <td>
#      SABA ESKANDARIAN
#     </td>
#     <td>
#      Sitterson - Rm 0011
#     </td>
#     <td style="color:red">
#      1/1
#     </td>
#     <td>
#      0/0
#     </td>
#     <td>
#      0/2
#     </td>
#    </tr>
#    <tr class="expandable">
#     <td colspan="7">
#      <strong>
#       Description:
#      </strong>
#      Permission of the instructor. This course has variable content and may be taken multiple times for credit. 1 - 21 units.
#     </td>
#    </tr>
#    <tr>
#     <td>
#      11401
#     </td>
#     <td>
#      COMP  790 - 173   Topics in Computer Science
#     </td>
#     <td>
#      TuTh 12:30PM - 1:45PM
#     </td>
#     <td>
#      Danielle Szafir
#     </td>
#     <td>
#      F Brooks - Sitterson - Rm F007
#     </td>
#     <td>
#      10/15
#     </td>
#     <td>
#      0/0
#     </td>
#     <td>
#      0/3
#     </td>
#    </tr>
#    <tr class="expandable">
#     <td colspan="7">
#      <strong>
#       Description:
#      </strong>
#      Permission of the instructor. This course has variable content and may be taken multiple times for credit. 1 - 21 units.
#     </td>
#    </tr>
#    <tr>
#     <td>
#      13521
#     </td>
#     <td>
#      COMP  790 - 178   Topics in Computer Science
#     </td>
#     <td>
#      TuTh 3:30PM - 4:45PM
#     </td>
#     <td>
#      Benjamin Berg
#     </td>
#     <td>
#      F Brooks - Sitterson - Rm F009
#     </td>
#     <td>
#      5/30
#     </td>
#     <td>
#      0/0
#     </td>
#     <td>
#      0/3
#     </td>
#    </tr>
#    <tr class="expandable">
#     <td colspan="7">
#      <strong>
#       Description:
#      </strong>
#      Permission of the instructor. This course has variable content and may be taken multiple times for credit. 1 - 21 units.
#     </td>
#    </tr>
#    <tr>
#     <td>
#      9662
#     </td>
#     <td>
#      COMP  915 - 001   Technical Communication in Computer Science
#     </td>
#     <td>
#      Fr 10:30AM - 12:00PM
#     </td>
#     <td>
#      Multiple
#     </td>
#     <td>
#      F Brooks - Sitterson - Rm F007
#     </td>
#     <td style="color:red">
#      18/18
#     </td>
#     <td>
#      0/0
#     </td>
#     <td>
#      0/2
#     </td>
#    </tr>
#    <tr class="expandable">
#     <td colspan="7">
#      <strong>
#       Description:
#      </strong>
#      Graduate computer science majors or permission of the instructor. Seminar on teaching, short oral presentations, and writing in computer science. 1 units.
#     </td>
#    </tr>
#   </table>
#  </body>
# </html>

# %% [markdown]
# `BeautifulSoup` does a lot more than just printing HTML in a nice way. We can now also find specific elements on the webpage!
#
# Let's find all of the data for the COMP classes. How? Let's take a look at the HTML.
#
# You will find that all of the data is located in the `<table>` element! So, let's try and find that element.

# %%
# Find all table elements on the page
tables = soup.find_all("table")

print("Number of tables: " + str(len(tables)))
print("Tables:")
print(tables)
# Out:
# Number of tables: 1
# Tables:
# [<table>
# <tr>
# <th>Class Number</th>
# <th>Class</th>
# <th>Meeting Time</th>
# <th>Instructor</th>
# <th>Room</th>
# <th>Unreserved Enrollment</th>
# <th>Reserved Enrollment</th>
# <th>Wait List</th>
# </tr>
# <tr><td>4290</td><td>COMP  110 - 001   Introduction to Programming and Data Science</td><td>TuTh 8:00AM - 9:15AM</td><td>Alyssa Byrnes</td><td>Hamilton Hall - Rm 0100</td><td style="color:orange">217/219</td><td style="color:red">81/81</td><td>0/30</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Prerequisite, A C or better in one of the following courses: MATH 130, 152, 210, 231, 129P, or PHIL 155, or STOR 120, 151, 155. Introduces students to programming and data science from a computational perspective. With an emphasis on modern applications in society, students gain experience with problem decomposition, algorithms for data analysis, abstraction design, and ethics in computing. No prior programming experience expected. Foundational concepts include data types, sequences, boolean logic, control flow, functions/methods, recursion, classes/objects, input/output, data organization, transformations, and visualizations. Students may not enroll in COMP 110 after receiving credit for COMP 210 or greater. 3 units.</td></tr>
# <tr><td>10266</td><td>COMP  110 - 002   Introduction to Programming and Data Science</td><td>TuTh 2:00PM - 3:15PM</td><td>Alyssa Byrnes</td><td>Hamilton Hall - Rm 0100</td><td style="color:red">90/90</td><td style="color:red">210/210</td><td>0/30</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Prerequisite, A C or better in one of the following courses: MATH 130, 152, 210, 231, 129P, or PHIL 155, or STOR 120, 151, 155. Introduces students to programming and data science from a computational perspective. With an emphasis on modern applications in society, students gain experience with problem decomposition, algorithms for data analysis, abstraction design, and ethics in computing. No prior programming experience expected. Foundational concepts include data types, sequences, boolean logic, control flow, functions/methods, recursion, classes/objects, input/output, data organization, transformations, and visualizations. Students may not enroll in COMP 110 after receiving credit for COMP 210 or greater. 3 units.</td></tr>
# <tr><td>9610</td><td>COMP  116 - 001   Introduction to Scientific Programming</td><td>TuTh 8:00AM - 9:15AM</td><td>John Majikes</td><td>Hanes Art Center - Rm 0121</td><td>153/240</td><td>0/0</td><td>0/24</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Prerequisite, MATH 231 or 241; a grade of C or better is required. An introduction to programming for computationally oriented scientists. Fundamental programming skills, typically using MATLAB or Python. Problem analysis and algorithm design with examples drawn from simple numerical and discrete problems. 3 units.</td></tr>
# <tr><td>5130</td><td>COMP  126 - 001   Practical Web Design and Development for Everyone</td><td>TuTh 11:00AM - 12:15PM</td><td>Tessa Joseph-Nicholas</td><td>Sitterson - Rm 0014</td><td style="color:orange">101/105</td><td>0/0</td><td>0/11</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>A ground-up introduction to current principles, standards, and best practice in website design, usability, accessibility, development, and management through project-based skills development in HTML5, CSS, and basic JavaScript. Intended for nonmajors. 3 units.</td></tr>
# <tr><td>13454</td><td>COMP  210 - 001   Data Structures and Analysis</td><td>MoWe 2:05PM - 3:20PM</td><td>Paul Stotts</td><td>Hanes Art Center - Rm 0121</td><td style="color:orange">235/240</td><td>0/0</td><td>0/21</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Prerequisites, COMP 110 and MATH 231; Pre- or corequisite, COMP 283 or MATH 381. This course will teach you how to organize the data used in computer programs so that manipulation of that data can be done efficiently on large problems and large data instances.  Rather than learning to use the data structures found in the libraries of programming languages, you will be learning how those libraries are constructed, and why the items that are included in them are there (and why some are excluded). 3 units.</td></tr>
# <tr><td>9609</td><td>COMP  210 - 002   Data Structures and Analysis</td><td>TuTh 3:30PM - 4:45PM</td><td>Muhammad Ghani</td><td>Coker - Rm 0201</td><td style="color:orange">191/195</td><td>0/0</td><td>0/20</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Prerequisites, COMP 110 and MATH 231; Pre- or corequisite, COMP 283 or MATH 381. This course will teach you how to organize the data used in computer programs so that manipulation of that data can be done efficiently on large problems and large data instances.  Rather than learning to use the data structures found in the libraries of programming languages, you will be learning how those libraries are constructed, and why the items that are included in them are there (and why some are excluded). 3 units.</td></tr>
# <tr><td>9611</td><td>COMP  211 - 001   Systems Fundamentals</td><td>TuTh 11:00AM - 12:15PM</td><td>Brent Munsell</td><td>Murray Hall - Rm G202</td><td style="color:orange">175/183</td><td style="color:red">26/26</td><td>0/11</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Prerequisites, COMP 210; COMP 283 or MATH 381; a grade of C or better is required in both prerequisite courses. This is the first course in the introductory systems sequence. Students enter the course having taken an introductory programming course in a high-level programming language (COMP 110) and a course in discrete structures. The overarching goal is to bridge the gap between a students' knowledge of a high-level programming language (COMP 110) and computer organization (COMP 311). 3 units.</td></tr>
# <tr><td>14454</td><td>COMP  211 - 002   Systems Fundamentals</td><td>TuTh 2:00PM - 3:15PM</td><td>Joshua Bakita</td><td>Chapman Hall - Rm 0201</td><td style="color:red">120/120</td><td style="color:red">30/30</td><td>0/10</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Prerequisites, COMP 210; COMP 283 or MATH 381; a grade of C or better is required in both prerequisite courses. This is the first course in the introductory systems sequence. Students enter the course having taken an introductory programming course in a high-level programming language (COMP 110) and a course in discrete structures. The overarching goal is to bridge the gap between a students' knowledge of a high-level programming language (COMP 110) and computer organization (COMP 311). 3 units.</td></tr>
# <tr><td>5040</td><td>COMP  283 - 001   Discrete Structures</td><td>TuTh 2:00PM - 3:15PM</td><td>Jack Snoeyink</td><td>Hanes Art Center - Rm 0121</td><td>126/195</td><td>0/0</td><td>0/20</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Prerequisite, MATH 231 or MATH 241; a grade of C or better is required. Introduces discrete structures (sets, tuples, relations, functions, graphs, trees) and the formal mathematics (logic, proof, induction) used to establish their properties and those of algorithms that work with them. Develops problem-solving skills through puzzles and applications central to computer science. 3 units.</td></tr>
# <tr><td>10200</td><td>COMP  283H - 001   Discrete Structures</td><td>TuTh 2:00PM - 3:15PM</td><td>Jack Snoeyink</td><td>Hanes Art Center - Rm 0121</td><td>0/19</td><td style="color:red">5/5</td><td>0/5</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Prerequisite, MATH 231 or MATH 241; a grade of C or better is required. Introduces discrete structures (sets, tuples, relations, functions, graphs, trees) and the formal mathematics (logic, proof, induction) used to establish their properties and those of algorithms that work with them. Develops problem-solving skills through puzzles and applications central to computer science. 3 units.</td></tr>
# <tr><td>9612</td><td>COMP  301 - 001   Foundations of Programming</td><td>TuTh 8:00AM - 9:15AM</td><td>KETAN MAYER-PATEL</td><td>Genome Sciences Bldg -Rm G100</td><td>271/308</td><td style="color:red">55/55</td><td>0/21</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Prerequisites, COMP 210; COMP 283 or MATH 381; a grade of C or better is required in both prerequisite courses. Students will learn how to reason about how their code is structured, identify whether a given structure is effective in a given context, and look at ways of organizing units of code that support larger programs. In a nutshell, the primary goal of the course is to equip students with tools and techniques that will help them not only in later courses in the major but also in their careers afterwards. 3 units.</td></tr>
# <tr><td>9613</td><td>COMP  311 - 001   Computer Organization</td><td>TuTh 2:00PM - 3:15PM</td><td>Brent Munsell</td><td>Manning - Rm 0209</td><td>14/52</td><td style="color:red">128/128</td><td>0/18</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Prerequisite, COMP 211; a grade of C or better is required. Introduction to computer organization and design. Students will be introduced to the conceptual design of a basic microprocessor, along with assembly programming.  The course includes fundamental concepts such as binary numbers, binary arithmetic, and representing information as well as instructions. Students learn to program in assembly (i.e., machine) language.  The course covers the fundamentals of computer hardware design,  transistors and logic gates, progressing through basic combinational and sequential components, culminating in the conceptual design CPU. 3 units.</td></tr>
# <tr><td>3426</td><td>COMP  380 - 001   Introduction to Digital Culture</td><td>TuTh 9:30AM - 10:45AM</td><td>Multiple</td><td>F Brooks - Sitterson - Rm F009</td><td style="color:red">77/77</td><td>0/0</td><td>0/20</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>An introduction to digital technology and computer science issues in society. Topics may include Internet history, privacy, security, usability, graphics, games, computers in the media, development, economics, social media, AI, IP, computer and Internet ethics, global ethics, current legal issues, etc. 3 units.</td></tr>
# <tr><td>3765</td><td>COMP  380H - 001   Introduction to Digital Culture</td><td>TuTh 2:00PM - 3:15PM</td><td>Tessa Joseph-Nicholas</td><td>Sitterson - Rm 0115</td><td style="color:red">2/2</td><td style="color:red">22/22</td><td>0/3</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>An introduction to digital technology and computer science issues in society. Topics may include Internet history, privacy, security, usability, graphics, games, computers in the media, development, economics, social media, AI, IP, computer and Internet ethics, global ethics, current legal issues, etc. 3 units.</td></tr>
# <tr><td>10238</td><td>COMP  421 - 001   Files and Databases</td><td>TuTh 9:30AM - 10:45AM</td><td>John Majikes</td><td>Murphey - Rm 0116</td><td style="color:orange">41/44</td><td style="color:red">126/126</td><td>0/15</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Prerequisites, COMP 210, 211, and 301; or COMP 401, 410, and 411; a grade of C or better is required in all prerequisite courses. Placement of data on secondary storage. File organization. Database history, practice, major models, system structure and design. Previously offered as COMP 521. 3 units.</td></tr>
# <tr><td>9614</td><td>COMP  426 - 001   Modern Web Programming</td><td>TuTh 5:00PM - 6:15PM</td><td>John Martin</td><td>Hanes Art Center - Rm 0121</td><td style="color:orange">40/42</td><td style="color:red">163/163</td><td>0/21</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Prerequisites, COMP 211 and 301; or COMP 401 and 410; a grade of C or better is required in all prerequisite courses. Developing applications for the World Wide Web including both client-side and server-side programming. Emphasis on Model-View-Controller architecture, AJAX, RESTful Web services, and database interaction. 3 units.</td></tr>
# <tr><td>2168</td><td>COMP  431 - 001   Internet Services and Protocols</td><td>TuTh 12:30PM - 1:45PM</td><td>KEVIN JEFFAY</td><td>Sitterson - Rm 0014</td><td>9/81</td><td style="color:red">24/24</td><td>0/11</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Prerequisites, COMP 210, 211, and 301; or COMP 401, 410, and 411; a grade of C or better is required in all prerequisite courses. Application-level protocols HTTP, SMTP, FTP, transport protocols TCP and UDP, and the network-level protocol IP. Internet architecture, naming, addressing, routing, and DNS. Sockets programming. Physical-layer technologies. Ethernet, ATM, and wireless. 3 units.</td></tr>
# <tr><td>13015</td><td>COMP  447 - 001   Quantum Computing</td><td>MoWeFr 3:35PM - 4:25PM</td><td>Multiple</td><td>Phillips - Rm 0215</td><td>41/74</td><td>0/0</td><td>0/0</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Prerequisites, MATH 232, and PHYS 116 or 118. Recommended preparation, some knowledge of basic linear algebra. An introduction to quantum computing. Basic math and quantum mechanics necessary to understand the operation of quantum bits. Quantum gates, circuits, and algorithms, including Shor's algorithm for factoring and Grover's search algorithm. Entanglement and error correction. Quantum encryption, annealing, and simulation. Brief discussion of technologies. 3 units.</td></tr>
# <tr><td>2166</td><td>COMP  455 - 001   Models of Languages and Computation</td><td>TuTh 9:30AM - 10:45AM</td><td>Thiagarajan Subramanian</td><td>Sitterson - Rm 0014</td><td style="color:red">26/26</td><td style="color:red">64/64</td><td>0/18</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Prerequisites, COMP 210 or 410 and COMP 283 or MATH 381; a grade of C or better in all prerequisite courses is required. Introduction to the theory of computation. Finite automata, regular languages, pushdown automata, context-free languages, and Turing machines. Undecidable problems. 3 units.</td></tr>
# <tr><td>9615</td><td>COMP  455 - 002   Models of Languages and Computation</td><td>TuTh 2:00PM - 3:15PM</td><td>Thiagarajan Subramanian</td><td>Sitterson - Rm 0014</td><td>32/80</td><td style="color:red">15/15</td><td>0/10</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Prerequisites, COMP 210 or 410 and COMP 283 or MATH 381; a grade of C or better in all prerequisite courses is required. Introduction to the theory of computation. Finite automata, regular languages, pushdown automata, context-free languages, and Turing machines. Undecidable problems. 3 units.</td></tr>
# <tr><td>6439</td><td>COMP  488 - 001   Data Science in the Business World</td><td>TuTh 2:00PM - 3:15PM</td><td>Daniel Ringel</td><td>McColl Building - Rm 3250</td><td>0/0</td><td>19/22</td><td>0/1</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Students will acquire hands-on data science skills enabling them to solve real-world business problems. Since data science is an interdisciplinary field, business and computer science students learn and work together in this course. Leveraging each other's skills and knowledge, students create data-driven business insights using modern analytics. 3 units.</td></tr>
# <tr><td>6440</td><td>COMP  488 - 002   Data Science in the Business World</td><td>TuTh 3:30PM - 4:45PM</td><td>Daniel Ringel</td><td>McColl Building - Rm 3250</td><td>0/0</td><td style="color:orange">23/24</td><td>0/2</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Students will acquire hands-on data science skills enabling them to solve real-world business problems. Since data science is an interdisciplinary field, business and computer science students learn and work together in this course. Leveraging each other's skills and knowledge, students create data-driven business insights using modern analytics. 3 units.</td></tr>
# <tr><td>6441</td><td>COMP  488 - 003   Data Science in the Business World</td><td>MoWe 3:30PM - 4:45PM</td><td>Jack Snoeyink</td><td>Sitterson - Rm 0014</td><td>0/0</td><td>27/37</td><td>0/3</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Students will acquire hands-on data science skills enabling them to solve real-world business problems. Since data science is an interdisciplinary field, business and computer science students learn and work together in this course. Leveraging each other's skills and knowledge, students create data-driven business insights using modern analytics. 3 units.</td></tr>
# <tr><td>3110</td><td>COMP  523 - 001   Software Engineering Laboratory</td><td>MoWeFr 8:45AM - 10:00AM</td><td>Paul Stotts</td><td>F Brooks - Sitterson - Rm F009</td><td style="color:red">13/13</td><td style="color:red">47/47</td><td>0/6</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Prerequisites, COMP 301 and 311; or COMP 401, 410, and 411; as well as at least two chosen from COMP 421, 426, 431, 433, 520, 530, 535, 575, 580. Organization and scheduling of software engineering projects, structured programming, and design. Each team designs, codes, and debugs program components and synthesizes them into a tested, documented program product. 4 units.</td></tr>
# <tr><td>3362</td><td>COMP  541 - 001   Digital Logic and Computer Design</td><td>MoWeFr 2:05PM - 3:20PM</td><td>MONTEK SINGH</td><td>F Brooks - Sitterson - Rm F007</td><td>11/14</td><td style="color:red">31/31</td><td>0/5</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Prerequisites, COMP 301 and 311; or COMP 401, 410, and 411; a grade of C or better is required in all prerequisite courses. This course is an introduction to digital logic as well as the structure and electronic design of modern processors. Students will implement a working computer during the laboratory sessions. 4 units.</td></tr>
# <tr><td>2182</td><td>COMP  550 - 001   Algorithms and Analysis</td><td>TuTh 12:30PM - 1:45PM</td><td>Muhammad Ghani</td><td>Hanes Art Center - Rm 0121</td><td style="color:orange">36/38</td><td style="color:red">157/157</td><td>0/20</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Prerequisites, COMP 211 and 301; or COMP 410; a grade of C or better is required in all prerequisite courses. Formal specification and verification of programs. Techniques of algorithm analysis. Problem-solving paradigms. Survey of selected algorithms. 3 units.</td></tr>
# <tr><td>3886</td><td>COMP  555 - 001   Bioalgorithms</td><td>MoWe 2:05PM - 3:20PM</td><td>Anwica Kashfeen</td><td>Sitterson - Rm 0014</td><td>17/57</td><td style="color:red">3/3</td><td>0/0</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Prerequisites, COMP 210, and 211; or COMP 401, and 410; and MATH 231, or 241; or BIOL 452; or MATH 553; or BIOL 525; a grade of C or better is required in all prerequisite courses. Bioinformatics algorithms. Topics include DNA restriction mapping, finding regulatory motifs, genome rearrangements, sequence alignments, gene prediction, graph algorithms, DNA sequencing, protein sequencing, combinatorial pattern matching, approximate pattern matching, clustering and evolution, tree construction, Hidden Markov Models, randomized algorithms. 3 units.</td></tr>
# <tr><td>5605</td><td>COMP  562 - 001   Introduction to Machine Learning</td><td>TuTh 5:00PM - 6:15PM</td><td>Jorge Silva</td><td>Sitterson - Rm 0014</td><td>35/68</td><td style="color:red">52/52</td><td>0/12</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Prerequisites, COMP 211 and 301; or COMP 401 and 410; as well as MATH 233, 347, and STOR 435; a grade of C or better is required in all prerequisite courses; permission of the instructor for students lacking the prerequisites. Machine learning as applied to speech recognition, tracking, collaborative filtering, and recommendation systems. Classification, regression, support vector machines, hidden Markov models, principal component analysis, and deep learning. 3 units.</td></tr>
# <tr><td>14665</td><td>COMP  562H - 002   Introduction to Machine Learning</td><td>TuTh 12:30PM - 1:45PM</td><td>Junier Oliva</td><td>Sitterson - Rm 0011</td><td>10/22</td><td style="color:red">2/2</td><td>0/5</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Prerequisites, COMP 211 and 301; or COMP 401 and 410; as well as MATH 233, 347, and STOR 435; a grade of C or better is required in all prerequisite courses; permission of the instructor for students lacking the prerequisites. Machine learning as applied to speech recognition, tracking, collaborative filtering, and recommendation systems. Classification, regression, support vector machines, hidden Markov models, principal component analysis, and deep learning. 3 units.</td></tr>
# <tr><td>10207</td><td>COMP  590 - 093   Special Topics: User Interfaces</td><td>TuTh 9:30AM - 10:45AM</td><td>Diane Pozefsky</td><td>Sitterson - Rm 0011</td><td style="color:red">7/7</td><td style="color:red">33/33</td><td>0/5</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Permission of the instructor. This course has variable content and may be taken multiple times for credit. Different sections may be taken in the same semester. 3 units.
# <br/><strong>Notes:</strong> Prerequisites, COMP 301 and COMP 311. Self-registration.</td></tr>
# <tr><td>12217</td><td>COMP  590 - 132   Special Topics: Formal Methods and Security</td><td>MoWe 11:00AM - 12:15PM</td><td>Cynthia Sturton</td><td>F Brooks - Sitterson - Rm F009</td><td>7/8</td><td style="color:red">7/7</td><td>0/2</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Permission of the instructor. This course has variable content and may be taken multiple times for credit. Different sections may be taken in the same semester. 3 units.
# <br/><strong>Notes:</strong> Instructor permission required. For more information, see <a href="https://docs.google.com/document/d/1MUDD6y7y2y87DssPeLU_wmlPwkJs3LYzFjDjqzfaHJU/edit#heading=h.h8vorb0okj2">https://docs.google.com/document/d/1MUDD6y7y2y87DssPeLU_wmlPwkJs3LYzFjDjqzfaHJU/edit#heading=h.h8vorb0okj2</a></td></tr>
# <tr><td>13476</td><td>COMP  590 - 139   Special Topics: Connecting Language to Vision</td><td>We 11:00AM - 1:30PM</td><td>Mohit Bansal</td><td>Sitterson - Rm 0115</td><td>2/8</td><td style="color:red">2/2</td><td>0/1</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Permission of the instructor. This course has variable content and may be taken multiple times for credit. Different sections may be taken in the same semester. 3 units.
# <br/><strong>Notes:</strong> Prerequisites, COMP 301 and COMP 211. Self-registration.</td></tr>
# <tr><td>13477</td><td>COMP  590 - 140   Special Topics: Foundations of Software Engineering</td><td>MoWeFr 1:25PM - 2:15PM</td><td>Kris Jordan</td><td>Carroll - Rm 0111</td><td>24/29</td><td style="color:red">179/179</td><td>0/6</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Permission of the instructor. This course has variable content and may be taken multiple times for credit. Different sections may be taken in the same semester. 3 units.
# <br/><strong>Notes:</strong> Prerequisites, COMP 301 and COMP 211. Registration request: <a href="https://bit.ly/comp590-kj-23s">https://bit.ly/comp590-kj-23s</a></td></tr>
# <tr><td>14988</td><td>COMP  590 - 157   Topics in Computer Science</td><td>TuTh 11:00AM - 12:15PM</td><td>Shashank Srivastava</td><td>Sitterson - Rm 0011</td><td>17/38</td><td style="color:red">22/22</td><td>0/0</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Permission of the instructor. This course has variable content and may be taken multiple times for credit. Different sections may be taken in the same semester. 3 units.</td></tr>
# <tr><td>11958</td><td>COMP  590 - 171   Special Topics: Privacy Preserving Technologies</td><td>MoWe 2:05PM - 3:20PM</td><td>SABA ESKANDARIAN</td><td>Sitterson - Rm 0011</td><td>11/13</td><td style="color:red">16/16</td><td>0/3</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Permission of the instructor. This course has variable content and may be taken multiple times for credit. Different sections may be taken in the same semester. 3 units.
# <br/><strong>Notes:</strong> Prerequisites, COMP 283, COMP 210, COMP 211, and COMP 301 (or their equivalents). Self-registration. Course website: <a href="https://www.cs.unc.edu/~saba/priv_class/index.html">https://www.cs.unc.edu/~saba/priv_class/index.html</a></td></tr>
# <tr><td>13478</td><td>COMP  590 - 173   Special Topics: Visualization Design Methods</td><td>TuTh 12:30PM - 1:45PM</td><td>Danielle Szafir</td><td>F Brooks - Sitterson - Rm F007</td><td style="color:red">4/4</td><td style="color:red">16/16</td><td>0/2</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Permission of the instructor. This course has variable content and may be taken multiple times for credit. Different sections may be taken in the same semester. 3 units.
# <br/><strong>Notes:</strong> Prerequisites, COMP 301 and COMP 211. Self-registration.</td></tr>
# <tr><td>14446</td><td>COMP  590 - 177   Special Topics: Computer Vision in the 3D World</td><td>TuTh 2:00PM - 3:15PM</td><td>Soumyadip Sengupta</td><td>F Brooks - Sitterson - Rm F009</td><td>10/33</td><td style="color:red">27/27</td><td>0/10</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Permission of the instructor. This course has variable content and may be taken multiple times for credit. Different sections may be taken in the same semester. 3 units.
# <br/><strong>Notes:</strong> Prerequisites, COMP 301, COMP 311, MATH 233, and MATH 347. Self-registration.</td></tr>
# <tr><td>13479</td><td>COMP  631 - 001   Computer Networks</td><td>TuTh 11:00AM - 12:15PM</td><td>Jasleen Kaur</td><td>F Brooks - Sitterson - Rm F009</td><td>11/60</td><td>0/0</td><td>0/6</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Required preparation, a first course in operating systems, a first course in networking (e.g., COMP 431 and 530), and knowledge of probability and statistics. Topics in computer networks, including link layer protocols, switching, IP, TCP, and congestion control. Additional topics may include peer-to-peer infrastructures, network security, and multimedia applications. 3 units.</td></tr>
# <tr><td>3386</td><td>COMP  662 - 001   Scientific Computation II</td><td>TuTh 12:30PM - 1:45PM</td><td>JINGFANG HUANG</td><td>Phillips - Rm 0224</td><td>1/4</td><td>0/0</td><td>0/0</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Prerequisite, MATH 661. Theory and practical issues arising in linear algebra problems derived from physical applications, e.g., discretization of ODEs and PDEs. Linear systems, linear least squares, eigenvalue problems, singular value decomposition. 3 units.</td></tr>
# <tr><td>13485</td><td>COMP  664 - 101   Deep Learning</td><td>MoWe 12:30PM - 1:45PM</td><td>Colin Raffel</td><td>F Brooks - Sitterson - Rm F009</td><td style="color:orange">56/60</td><td>0/0</td><td>0/6</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Prerequisites, COMP 562, 755, or 565 and MATH 201, 347, or 577 and MATH 233 or 522; permission of the instructor for student lacking the prerequisites. Introduction to the field of deep learning and its applications. Basics of building and optimizing neural networks, including model architectures and training schemes. 3 units.</td></tr>
# <tr><td>13495</td><td>COMP  730 - 138   Operating Systems</td><td>TuTh 9:30AM - 10:45AM</td><td>Donald Porter</td><td>F Brooks - Sitterson - Rm F007</td><td>14/30</td><td>0/0</td><td>0/3</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Prerequisite, COMP 530. Theory, structuring, and design of operating systems. Sequential and cooperating processes. Single processor, multiprocessor, and distributed operating systems. 3 units.</td></tr>
# <tr><td>13497</td><td>COMP  735 - 080   Distributed and Concurrent Algorithms</td><td>TuTh 2:00PM - 3:15PM</td><td>JAMES ANDERSON</td><td>F Brooks - Sitterson - Rm F007</td><td>13/30</td><td>0/0</td><td>0/3</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Prerequisites, COMP 530 and 550. Verification of concurrent systems. Synchronization; mutual exclusion and related problems, barriers, rendezvous, nonblocking algorithms. Fault tolerance: consensus, Byzantine agreement, self-stabilization. Broadcast algorithms. Termination and deadlock detection. Clock synchronization. 3 units.</td></tr>
# <tr><td>13512</td><td>COMP  776 - 001   Computer Vision in our 3D World</td><td>TuTh 2:00PM - 3:15PM</td><td>Soumyadip Sengupta</td><td>F Brooks - Sitterson - Rm F009</td><td>18/30</td><td>0/0</td><td>0/0</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Prerequisites, MATH 566, COMP 550, 665, and 775; permission of the instructor for students lacking the prerequisites. Fundamental problems of computer vision. Projective geometry. Camera models, camera calibration. Shape from stereo, epipolar geometry. Photometric stereo. Optical flow, tracking, motion. Range finders, structured light. Object recognition. 3 units.</td></tr>
# <tr><td>13513</td><td>COMP  777 - 98   Optimal Estimation in Image Analysis</td><td>TuTh 11:00AM - 12:15PM</td><td>MARC NIETHAMMER</td><td>F Brooks - Sitterson - Rm F007</td><td>12/30</td><td>0/0</td><td>0/3</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Prerequisites, MATH 233, MATH 347/547, and MATH 535 or STOR 435. Formulation and numerical solution of optimization problems in image analysis. 3 units.</td></tr>
# <tr><td>13514</td><td>COMP  781 - 001   Robotics</td><td>MoWe 2:05PM - 3:20PM</td><td>RON ALTEROVITZ</td><td>TBA</td><td>18/24</td><td>0/0</td><td>0/0</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Prerequisites, COMP 550 and MATH 347/547; Permission of the instructor for students lacking the prerequisites. Introduction to the design, programming, and control of robotic systems. Topics include kinematics, dynamics, sensing, actuation, control, robot learning, tele-operation, and motion planning. Applications will be discussed including industrial, mobile, assistive, personal, and medical robots. 3 units.</td></tr>
# <tr><td>13519</td><td>COMP  790 - 006   Topics in Computer Science</td><td>TuTh 3:30PM - 4:45PM</td><td>STEPHEN PIZER</td><td>F Brooks - Sitterson - Rm F007</td><td>6/30</td><td>0/0</td><td>0/3</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Permission of the instructor. This course has variable content and may be taken multiple times for credit. 1 - 21 units.</td></tr>
# <tr><td>9640</td><td>COMP  790 - 132   Topics in Computer Science</td><td>MoWe 11:00AM - 12:15PM</td><td>Cynthia Sturton</td><td>F Brooks - Sitterson - Rm F009</td><td>1/30</td><td>0/0</td><td>0/2</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Permission of the instructor. This course has variable content and may be taken multiple times for credit. 1 - 21 units.</td></tr>
# <tr><td>13520</td><td>COMP  790 - 136   Topics in Computer Science</td><td>Mo 11:00AM - 2:00PM</td><td>Shahriar Nirjon</td><td>Sitterson - Rm 0115</td><td>13/25</td><td>0/0</td><td>0/3</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Permission of the instructor. This course has variable content and may be taken multiple times for credit. 1 - 21 units.</td></tr>
# <tr><td>14659</td><td>COMP  790 - 139   Topics in Computer Science</td><td>We 11:00AM - 1:30PM</td><td>Mohit Bansal</td><td>Sitterson - Rm 0115</td><td>9/15</td><td>0/0</td><td>0/0</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Permission of the instructor. This course has variable content and may be taken multiple times for credit. 1 - 21 units.</td></tr>
# <tr><td>10205</td><td>COMP  790 - 166   Topics in Computer Science</td><td>MoWe 11:00AM - 12:15PM</td><td>Natalie Stanley</td><td>F Brooks - Sitterson - Rm F007</td><td>12/30</td><td>0/0</td><td>0/3</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Permission of the instructor. This course has variable content and may be taken multiple times for credit. 1 - 21 units.</td></tr>
# <tr><td>11399</td><td>COMP  790 - 171   Special Topics: Privacy Preserving Technologies</td><td>MoWe 2:05PM - 3:20PM</td><td>SABA ESKANDARIAN</td><td>Sitterson - Rm 0011</td><td style="color:red">1/1</td><td>0/0</td><td>0/2</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Permission of the instructor. This course has variable content and may be taken multiple times for credit. 1 - 21 units.</td></tr>
# <tr><td>11401</td><td>COMP  790 - 173   Topics in Computer Science</td><td>TuTh 12:30PM - 1:45PM</td><td>Danielle Szafir</td><td>F Brooks - Sitterson - Rm F007</td><td>10/15</td><td>0/0</td><td>0/3</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Permission of the instructor. This course has variable content and may be taken multiple times for credit. 1 - 21 units.</td></tr>
# <tr><td>13521</td><td>COMP  790 - 178   Topics in Computer Science</td><td>TuTh 3:30PM - 4:45PM</td><td>Benjamin Berg</td><td>F Brooks - Sitterson - Rm F009</td><td>5/30</td><td>0/0</td><td>0/3</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Permission of the instructor. This course has variable content and may be taken multiple times for credit. 1 - 21 units.</td></tr>
# <tr><td>9662</td><td>COMP  915 - 001   Technical Communication in Computer Science</td><td>Fr 10:30AM - 12:00PM</td><td>Multiple</td><td>F Brooks - Sitterson - Rm F007</td><td style="color:red">18/18</td><td>0/0</td><td>0/2</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Graduate computer science majors or permission of the instructor. Seminar on teaching, short oral presentations, and writing in computer science. 1 units.</td></tr>
# </table>]

# %% [markdown]
# Great! `soup.find_all()` output a **list** of all of the table elements on our page. In this case, there was only one! So, let's select that table.

# %%
# Select the table
table = tables[0]
table
# Out:
# <table>
# <tr>
# <th>Class Number</th>
# <th>Class</th>
# <th>Meeting Time</th>
# <th>Instructor</th>
# <th>Room</th>
# <th>Unreserved Enrollment</th>
# <th>Reserved Enrollment</th>
# <th>Wait List</th>
# </tr>
# <tr><td>4290</td><td>COMP  110 - 001   Introduction to Programming and Data Science</td><td>TuTh 8:00AM - 9:15AM</td><td>Alyssa Byrnes</td><td>Hamilton Hall - Rm 0100</td><td style="color:orange">217/219</td><td style="color:red">81/81</td><td>0/30</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Prerequisite, A C or better in one of the following courses: MATH 130, 152, 210, 231, 129P, or PHIL 155, or STOR 120, 151, 155. Introduces students to programming and data science from a computational perspective. With an emphasis on modern applications in society, students gain experience with problem decomposition, algorithms for data analysis, abstraction design, and ethics in computing. No prior programming experience expected. Foundational concepts include data types, sequences, boolean logic, control flow, functions/methods, recursion, classes/objects, input/output, data organization, transformations, and visualizations. Students may not enroll in COMP 110 after receiving credit for COMP 210 or greater. 3 units.</td></tr>
# <tr><td>10266</td><td>COMP  110 - 002   Introduction to Programming and Data Science</td><td>TuTh 2:00PM - 3:15PM</td><td>Alyssa Byrnes</td><td>Hamilton Hall - Rm 0100</td><td style="color:red">90/90</td><td style="color:red">210/210</td><td>0/30</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Prerequisite, A C or better in one of the following courses: MATH 130, 152, 210, 231, 129P, or PHIL 155, or STOR 120, 151, 155. Introduces students to programming and data science from a computational perspective. With an emphasis on modern applications in society, students gain experience with problem decomposition, algorithms for data analysis, abstraction design, and ethics in computing. No prior programming experience expected. Foundational concepts include data types, sequences, boolean logic, control flow, functions/methods, recursion, classes/objects, input/output, data organization, transformations, and visualizations. Students may not enroll in COMP 110 after receiving credit for COMP 210 or greater. 3 units.</td></tr>
# <tr><td>9610</td><td>COMP  116 - 001   Introduction to Scientific Programming</td><td>TuTh 8:00AM - 9:15AM</td><td>John Majikes</td><td>Hanes Art Center - Rm 0121</td><td>153/240</td><td>0/0</td><td>0/24</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Prerequisite, MATH 231 or 241; a grade of C or better is required. An introduction to programming for computationally oriented scientists. Fundamental programming skills, typically using MATLAB or Python. Problem analysis and algorithm design with examples drawn from simple numerical and discrete problems. 3 units.</td></tr>
# <tr><td>5130</td><td>COMP  126 - 001   Practical Web Design and Development for Everyone</td><td>TuTh 11:00AM - 12:15PM</td><td>Tessa Joseph-Nicholas</td><td>Sitterson - Rm 0014</td><td style="color:orange">101/105</td><td>0/0</td><td>0/11</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>A ground-up introduction to current principles, standards, and best practice in website design, usability, accessibility, development, and management through project-based skills development in HTML5, CSS, and basic JavaScript. Intended for nonmajors. 3 units.</td></tr>
# <tr><td>13454</td><td>COMP  210 - 001   Data Structures and Analysis</td><td>MoWe 2:05PM - 3:20PM</td><td>Paul Stotts</td><td>Hanes Art Center - Rm 0121</td><td style="color:orange">235/240</td><td>0/0</td><td>0/21</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Prerequisites, COMP 110 and MATH 231; Pre- or corequisite, COMP 283 or MATH 381. This course will teach you how to organize the data used in computer programs so that manipulation of that data can be done efficiently on large problems and large data instances.  Rather than learning to use the data structures found in the libraries of programming languages, you will be learning how those libraries are constructed, and why the items that are included in them are there (and why some are excluded). 3 units.</td></tr>
# <tr><td>9609</td><td>COMP  210 - 002   Data Structures and Analysis</td><td>TuTh 3:30PM - 4:45PM</td><td>Muhammad Ghani</td><td>Coker - Rm 0201</td><td style="color:orange">191/195</td><td>0/0</td><td>0/20</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Prerequisites, COMP 110 and MATH 231; Pre- or corequisite, COMP 283 or MATH 381. This course will teach you how to organize the data used in computer programs so that manipulation of that data can be done efficiently on large problems and large data instances.  Rather than learning to use the data structures found in the libraries of programming languages, you will be learning how those libraries are constructed, and why the items that are included in them are there (and why some are excluded). 3 units.</td></tr>
# <tr><td>9611</td><td>COMP  211 - 001   Systems Fundamentals</td><td>TuTh 11:00AM - 12:15PM</td><td>Brent Munsell</td><td>Murray Hall - Rm G202</td><td style="color:orange">175/183</td><td style="color:red">26/26</td><td>0/11</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Prerequisites, COMP 210; COMP 283 or MATH 381; a grade of C or better is required in both prerequisite courses. This is the first course in the introductory systems sequence. Students enter the course having taken an introductory programming course in a high-level programming language (COMP 110) and a course in discrete structures. The overarching goal is to bridge the gap between a students' knowledge of a high-level programming language (COMP 110) and computer organization (COMP 311). 3 units.</td></tr>
# <tr><td>14454</td><td>COMP  211 - 002   Systems Fundamentals</td><td>TuTh 2:00PM - 3:15PM</td><td>Joshua Bakita</td><td>Chapman Hall - Rm 0201</td><td style="color:red">120/120</td><td style="color:red">30/30</td><td>0/10</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Prerequisites, COMP 210; COMP 283 or MATH 381; a grade of C or better is required in both prerequisite courses. This is the first course in the introductory systems sequence. Students enter the course having taken an introductory programming course in a high-level programming language (COMP 110) and a course in discrete structures. The overarching goal is to bridge the gap between a students' knowledge of a high-level programming language (COMP 110) and computer organization (COMP 311). 3 units.</td></tr>
# <tr><td>5040</td><td>COMP  283 - 001   Discrete Structures</td><td>TuTh 2:00PM - 3:15PM</td><td>Jack Snoeyink</td><td>Hanes Art Center - Rm 0121</td><td>126/195</td><td>0/0</td><td>0/20</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Prerequisite, MATH 231 or MATH 241; a grade of C or better is required. Introduces discrete structures (sets, tuples, relations, functions, graphs, trees) and the formal mathematics (logic, proof, induction) used to establish their properties and those of algorithms that work with them. Develops problem-solving skills through puzzles and applications central to computer science. 3 units.</td></tr>
# <tr><td>10200</td><td>COMP  283H - 001   Discrete Structures</td><td>TuTh 2:00PM - 3:15PM</td><td>Jack Snoeyink</td><td>Hanes Art Center - Rm 0121</td><td>0/19</td><td style="color:red">5/5</td><td>0/5</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Prerequisite, MATH 231 or MATH 241; a grade of C or better is required. Introduces discrete structures (sets, tuples, relations, functions, graphs, trees) and the formal mathematics (logic, proof, induction) used to establish their properties and those of algorithms that work with them. Develops problem-solving skills through puzzles and applications central to computer science. 3 units.</td></tr>
# <tr><td>9612</td><td>COMP  301 - 001   Foundations of Programming</td><td>TuTh 8:00AM - 9:15AM</td><td>KETAN MAYER-PATEL</td><td>Genome Sciences Bldg -Rm G100</td><td>271/308</td><td style="color:red">55/55</td><td>0/21</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Prerequisites, COMP 210; COMP 283 or MATH 381; a grade of C or better is required in both prerequisite courses. Students will learn how to reason about how their code is structured, identify whether a given structure is effective in a given context, and look at ways of organizing units of code that support larger programs. In a nutshell, the primary goal of the course is to equip students with tools and techniques that will help them not only in later courses in the major but also in their careers afterwards. 3 units.</td></tr>
# <tr><td>9613</td><td>COMP  311 - 001   Computer Organization</td><td>TuTh 2:00PM - 3:15PM</td><td>Brent Munsell</td><td>Manning - Rm 0209</td><td>14/52</td><td style="color:red">128/128</td><td>0/18</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Prerequisite, COMP 211; a grade of C or better is required. Introduction to computer organization and design. Students will be introduced to the conceptual design of a basic microprocessor, along with assembly programming.  The course includes fundamental concepts such as binary numbers, binary arithmetic, and representing information as well as instructions. Students learn to program in assembly (i.e., machine) language.  The course covers the fundamentals of computer hardware design,  transistors and logic gates, progressing through basic combinational and sequential components, culminating in the conceptual design CPU. 3 units.</td></tr>
# <tr><td>3426</td><td>COMP  380 - 001   Introduction to Digital Culture</td><td>TuTh 9:30AM - 10:45AM</td><td>Multiple</td><td>F Brooks - Sitterson - Rm F009</td><td style="color:red">77/77</td><td>0/0</td><td>0/20</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>An introduction to digital technology and computer science issues in society. Topics may include Internet history, privacy, security, usability, graphics, games, computers in the media, development, economics, social media, AI, IP, computer and Internet ethics, global ethics, current legal issues, etc. 3 units.</td></tr>
# <tr><td>3765</td><td>COMP  380H - 001   Introduction to Digital Culture</td><td>TuTh 2:00PM - 3:15PM</td><td>Tessa Joseph-Nicholas</td><td>Sitterson - Rm 0115</td><td style="color:red">2/2</td><td style="color:red">22/22</td><td>0/3</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>An introduction to digital technology and computer science issues in society. Topics may include Internet history, privacy, security, usability, graphics, games, computers in the media, development, economics, social media, AI, IP, computer and Internet ethics, global ethics, current legal issues, etc. 3 units.</td></tr>
# <tr><td>10238</td><td>COMP  421 - 001   Files and Databases</td><td>TuTh 9:30AM - 10:45AM</td><td>John Majikes</td><td>Murphey - Rm 0116</td><td style="color:orange">41/44</td><td style="color:red">126/126</td><td>0/15</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Prerequisites, COMP 210, 211, and 301; or COMP 401, 410, and 411; a grade of C or better is required in all prerequisite courses. Placement of data on secondary storage. File organization. Database history, practice, major models, system structure and design. Previously offered as COMP 521. 3 units.</td></tr>
# <tr><td>9614</td><td>COMP  426 - 001   Modern Web Programming</td><td>TuTh 5:00PM - 6:15PM</td><td>John Martin</td><td>Hanes Art Center - Rm 0121</td><td style="color:orange">40/42</td><td style="color:red">163/163</td><td>0/21</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Prerequisites, COMP 211 and 301; or COMP 401 and 410; a grade of C or better is required in all prerequisite courses. Developing applications for the World Wide Web including both client-side and server-side programming. Emphasis on Model-View-Controller architecture, AJAX, RESTful Web services, and database interaction. 3 units.</td></tr>
# <tr><td>2168</td><td>COMP  431 - 001   Internet Services and Protocols</td><td>TuTh 12:30PM - 1:45PM</td><td>KEVIN JEFFAY</td><td>Sitterson - Rm 0014</td><td>9/81</td><td style="color:red">24/24</td><td>0/11</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Prerequisites, COMP 210, 211, and 301; or COMP 401, 410, and 411; a grade of C or better is required in all prerequisite courses. Application-level protocols HTTP, SMTP, FTP, transport protocols TCP and UDP, and the network-level protocol IP. Internet architecture, naming, addressing, routing, and DNS. Sockets programming. Physical-layer technologies. Ethernet, ATM, and wireless. 3 units.</td></tr>
# <tr><td>13015</td><td>COMP  447 - 001   Quantum Computing</td><td>MoWeFr 3:35PM - 4:25PM</td><td>Multiple</td><td>Phillips - Rm 0215</td><td>41/74</td><td>0/0</td><td>0/0</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Prerequisites, MATH 232, and PHYS 116 or 118. Recommended preparation, some knowledge of basic linear algebra. An introduction to quantum computing. Basic math and quantum mechanics necessary to understand the operation of quantum bits. Quantum gates, circuits, and algorithms, including Shor's algorithm for factoring and Grover's search algorithm. Entanglement and error correction. Quantum encryption, annealing, and simulation. Brief discussion of technologies. 3 units.</td></tr>
# <tr><td>2166</td><td>COMP  455 - 001   Models of Languages and Computation</td><td>TuTh 9:30AM - 10:45AM</td><td>Thiagarajan Subramanian</td><td>Sitterson - Rm 0014</td><td style="color:red">26/26</td><td style="color:red">64/64</td><td>0/18</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Prerequisites, COMP 210 or 410 and COMP 283 or MATH 381; a grade of C or better in all prerequisite courses is required. Introduction to the theory of computation. Finite automata, regular languages, pushdown automata, context-free languages, and Turing machines. Undecidable problems. 3 units.</td></tr>
# <tr><td>9615</td><td>COMP  455 - 002   Models of Languages and Computation</td><td>TuTh 2:00PM - 3:15PM</td><td>Thiagarajan Subramanian</td><td>Sitterson - Rm 0014</td><td>32/80</td><td style="color:red">15/15</td><td>0/10</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Prerequisites, COMP 210 or 410 and COMP 283 or MATH 381; a grade of C or better in all prerequisite courses is required. Introduction to the theory of computation. Finite automata, regular languages, pushdown automata, context-free languages, and Turing machines. Undecidable problems. 3 units.</td></tr>
# <tr><td>6439</td><td>COMP  488 - 001   Data Science in the Business World</td><td>TuTh 2:00PM - 3:15PM</td><td>Daniel Ringel</td><td>McColl Building - Rm 3250</td><td>0/0</td><td>19/22</td><td>0/1</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Students will acquire hands-on data science skills enabling them to solve real-world business problems. Since data science is an interdisciplinary field, business and computer science students learn and work together in this course. Leveraging each other's skills and knowledge, students create data-driven business insights using modern analytics. 3 units.</td></tr>
# <tr><td>6440</td><td>COMP  488 - 002   Data Science in the Business World</td><td>TuTh 3:30PM - 4:45PM</td><td>Daniel Ringel</td><td>McColl Building - Rm 3250</td><td>0/0</td><td style="color:orange">23/24</td><td>0/2</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Students will acquire hands-on data science skills enabling them to solve real-world business problems. Since data science is an interdisciplinary field, business and computer science students learn and work together in this course. Leveraging each other's skills and knowledge, students create data-driven business insights using modern analytics. 3 units.</td></tr>
# <tr><td>6441</td><td>COMP  488 - 003   Data Science in the Business World</td><td>MoWe 3:30PM - 4:45PM</td><td>Jack Snoeyink</td><td>Sitterson - Rm 0014</td><td>0/0</td><td>27/37</td><td>0/3</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Students will acquire hands-on data science skills enabling them to solve real-world business problems. Since data science is an interdisciplinary field, business and computer science students learn and work together in this course. Leveraging each other's skills and knowledge, students create data-driven business insights using modern analytics. 3 units.</td></tr>
# <tr><td>3110</td><td>COMP  523 - 001   Software Engineering Laboratory</td><td>MoWeFr 8:45AM - 10:00AM</td><td>Paul Stotts</td><td>F Brooks - Sitterson - Rm F009</td><td style="color:red">13/13</td><td style="color:red">47/47</td><td>0/6</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Prerequisites, COMP 301 and 311; or COMP 401, 410, and 411; as well as at least two chosen from COMP 421, 426, 431, 433, 520, 530, 535, 575, 580. Organization and scheduling of software engineering projects, structured programming, and design. Each team designs, codes, and debugs program components and synthesizes them into a tested, documented program product. 4 units.</td></tr>
# <tr><td>3362</td><td>COMP  541 - 001   Digital Logic and Computer Design</td><td>MoWeFr 2:05PM - 3:20PM</td><td>MONTEK SINGH</td><td>F Brooks - Sitterson - Rm F007</td><td>11/14</td><td style="color:red">31/31</td><td>0/5</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Prerequisites, COMP 301 and 311; or COMP 401, 410, and 411; a grade of C or better is required in all prerequisite courses. This course is an introduction to digital logic as well as the structure and electronic design of modern processors. Students will implement a working computer during the laboratory sessions. 4 units.</td></tr>
# <tr><td>2182</td><td>COMP  550 - 001   Algorithms and Analysis</td><td>TuTh 12:30PM - 1:45PM</td><td>Muhammad Ghani</td><td>Hanes Art Center - Rm 0121</td><td style="color:orange">36/38</td><td style="color:red">157/157</td><td>0/20</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Prerequisites, COMP 211 and 301; or COMP 410; a grade of C or better is required in all prerequisite courses. Formal specification and verification of programs. Techniques of algorithm analysis. Problem-solving paradigms. Survey of selected algorithms. 3 units.</td></tr>
# <tr><td>3886</td><td>COMP  555 - 001   Bioalgorithms</td><td>MoWe 2:05PM - 3:20PM</td><td>Anwica Kashfeen</td><td>Sitterson - Rm 0014</td><td>17/57</td><td style="color:red">3/3</td><td>0/0</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Prerequisites, COMP 210, and 211; or COMP 401, and 410; and MATH 231, or 241; or BIOL 452; or MATH 553; or BIOL 525; a grade of C or better is required in all prerequisite courses. Bioinformatics algorithms. Topics include DNA restriction mapping, finding regulatory motifs, genome rearrangements, sequence alignments, gene prediction, graph algorithms, DNA sequencing, protein sequencing, combinatorial pattern matching, approximate pattern matching, clustering and evolution, tree construction, Hidden Markov Models, randomized algorithms. 3 units.</td></tr>
# <tr><td>5605</td><td>COMP  562 - 001   Introduction to Machine Learning</td><td>TuTh 5:00PM - 6:15PM</td><td>Jorge Silva</td><td>Sitterson - Rm 0014</td><td>35/68</td><td style="color:red">52/52</td><td>0/12</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Prerequisites, COMP 211 and 301; or COMP 401 and 410; as well as MATH 233, 347, and STOR 435; a grade of C or better is required in all prerequisite courses; permission of the instructor for students lacking the prerequisites. Machine learning as applied to speech recognition, tracking, collaborative filtering, and recommendation systems. Classification, regression, support vector machines, hidden Markov models, principal component analysis, and deep learning. 3 units.</td></tr>
# <tr><td>14665</td><td>COMP  562H - 002   Introduction to Machine Learning</td><td>TuTh 12:30PM - 1:45PM</td><td>Junier Oliva</td><td>Sitterson - Rm 0011</td><td>10/22</td><td style="color:red">2/2</td><td>0/5</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Prerequisites, COMP 211 and 301; or COMP 401 and 410; as well as MATH 233, 347, and STOR 435; a grade of C or better is required in all prerequisite courses; permission of the instructor for students lacking the prerequisites. Machine learning as applied to speech recognition, tracking, collaborative filtering, and recommendation systems. Classification, regression, support vector machines, hidden Markov models, principal component analysis, and deep learning. 3 units.</td></tr>
# <tr><td>10207</td><td>COMP  590 - 093   Special Topics: User Interfaces</td><td>TuTh 9:30AM - 10:45AM</td><td>Diane Pozefsky</td><td>Sitterson - Rm 0011</td><td style="color:red">7/7</td><td style="color:red">33/33</td><td>0/5</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Permission of the instructor. This course has variable content and may be taken multiple times for credit. Different sections may be taken in the same semester. 3 units.
# <br/><strong>Notes:</strong> Prerequisites, COMP 301 and COMP 311. Self-registration.</td></tr>
# <tr><td>12217</td><td>COMP  590 - 132   Special Topics: Formal Methods and Security</td><td>MoWe 11:00AM - 12:15PM</td><td>Cynthia Sturton</td><td>F Brooks - Sitterson - Rm F009</td><td>7/8</td><td style="color:red">7/7</td><td>0/2</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Permission of the instructor. This course has variable content and may be taken multiple times for credit. Different sections may be taken in the same semester. 3 units.
# <br/><strong>Notes:</strong> Instructor permission required. For more information, see <a href="https://docs.google.com/document/d/1MUDD6y7y2y87DssPeLU_wmlPwkJs3LYzFjDjqzfaHJU/edit#heading=h.h8vorb0okj2">https://docs.google.com/document/d/1MUDD6y7y2y87DssPeLU_wmlPwkJs3LYzFjDjqzfaHJU/edit#heading=h.h8vorb0okj2</a></td></tr>
# <tr><td>13476</td><td>COMP  590 - 139   Special Topics: Connecting Language to Vision</td><td>We 11:00AM - 1:30PM</td><td>Mohit Bansal</td><td>Sitterson - Rm 0115</td><td>2/8</td><td style="color:red">2/2</td><td>0/1</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Permission of the instructor. This course has variable content and may be taken multiple times for credit. Different sections may be taken in the same semester. 3 units.
# <br/><strong>Notes:</strong> Prerequisites, COMP 301 and COMP 211. Self-registration.</td></tr>
# <tr><td>13477</td><td>COMP  590 - 140   Special Topics: Foundations of Software Engineering</td><td>MoWeFr 1:25PM - 2:15PM</td><td>Kris Jordan</td><td>Carroll - Rm 0111</td><td>24/29</td><td style="color:red">179/179</td><td>0/6</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Permission of the instructor. This course has variable content and may be taken multiple times for credit. Different sections may be taken in the same semester. 3 units.
# <br/><strong>Notes:</strong> Prerequisites, COMP 301 and COMP 211. Registration request: <a href="https://bit.ly/comp590-kj-23s">https://bit.ly/comp590-kj-23s</a></td></tr>
# <tr><td>14988</td><td>COMP  590 - 157   Topics in Computer Science</td><td>TuTh 11:00AM - 12:15PM</td><td>Shashank Srivastava</td><td>Sitterson - Rm 0011</td><td>17/38</td><td style="color:red">22/22</td><td>0/0</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Permission of the instructor. This course has variable content and may be taken multiple times for credit. Different sections may be taken in the same semester. 3 units.</td></tr>
# <tr><td>11958</td><td>COMP  590 - 171   Special Topics: Privacy Preserving Technologies</td><td>MoWe 2:05PM - 3:20PM</td><td>SABA ESKANDARIAN</td><td>Sitterson - Rm 0011</td><td>11/13</td><td style="color:red">16/16</td><td>0/3</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Permission of the instructor. This course has variable content and may be taken multiple times for credit. Different sections may be taken in the same semester. 3 units.
# <br/><strong>Notes:</strong> Prerequisites, COMP 283, COMP 210, COMP 211, and COMP 301 (or their equivalents). Self-registration. Course website: <a href="https://www.cs.unc.edu/~saba/priv_class/index.html">https://www.cs.unc.edu/~saba/priv_class/index.html</a></td></tr>
# <tr><td>13478</td><td>COMP  590 - 173   Special Topics: Visualization Design Methods</td><td>TuTh 12:30PM - 1:45PM</td><td>Danielle Szafir</td><td>F Brooks - Sitterson - Rm F007</td><td style="color:red">4/4</td><td style="color:red">16/16</td><td>0/2</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Permission of the instructor. This course has variable content and may be taken multiple times for credit. Different sections may be taken in the same semester. 3 units.
# <br/><strong>Notes:</strong> Prerequisites, COMP 301 and COMP 211. Self-registration.</td></tr>
# <tr><td>14446</td><td>COMP  590 - 177   Special Topics: Computer Vision in the 3D World</td><td>TuTh 2:00PM - 3:15PM</td><td>Soumyadip Sengupta</td><td>F Brooks - Sitterson - Rm F009</td><td>10/33</td><td style="color:red">27/27</td><td>0/10</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Permission of the instructor. This course has variable content and may be taken multiple times for credit. Different sections may be taken in the same semester. 3 units.
# <br/><strong>Notes:</strong> Prerequisites, COMP 301, COMP 311, MATH 233, and MATH 347. Self-registration.</td></tr>
# <tr><td>13479</td><td>COMP  631 - 001   Computer Networks</td><td>TuTh 11:00AM - 12:15PM</td><td>Jasleen Kaur</td><td>F Brooks - Sitterson - Rm F009</td><td>11/60</td><td>0/0</td><td>0/6</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Required preparation, a first course in operating systems, a first course in networking (e.g., COMP 431 and 530), and knowledge of probability and statistics. Topics in computer networks, including link layer protocols, switching, IP, TCP, and congestion control. Additional topics may include peer-to-peer infrastructures, network security, and multimedia applications. 3 units.</td></tr>
# <tr><td>3386</td><td>COMP  662 - 001   Scientific Computation II</td><td>TuTh 12:30PM - 1:45PM</td><td>JINGFANG HUANG</td><td>Phillips - Rm 0224</td><td>1/4</td><td>0/0</td><td>0/0</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Prerequisite, MATH 661. Theory and practical issues arising in linear algebra problems derived from physical applications, e.g., discretization of ODEs and PDEs. Linear systems, linear least squares, eigenvalue problems, singular value decomposition. 3 units.</td></tr>
# <tr><td>13485</td><td>COMP  664 - 101   Deep Learning</td><td>MoWe 12:30PM - 1:45PM</td><td>Colin Raffel</td><td>F Brooks - Sitterson - Rm F009</td><td style="color:orange">56/60</td><td>0/0</td><td>0/6</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Prerequisites, COMP 562, 755, or 565 and MATH 201, 347, or 577 and MATH 233 or 522; permission of the instructor for student lacking the prerequisites. Introduction to the field of deep learning and its applications. Basics of building and optimizing neural networks, including model architectures and training schemes. 3 units.</td></tr>
# <tr><td>13495</td><td>COMP  730 - 138   Operating Systems</td><td>TuTh 9:30AM - 10:45AM</td><td>Donald Porter</td><td>F Brooks - Sitterson - Rm F007</td><td>14/30</td><td>0/0</td><td>0/3</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Prerequisite, COMP 530. Theory, structuring, and design of operating systems. Sequential and cooperating processes. Single processor, multiprocessor, and distributed operating systems. 3 units.</td></tr>
# <tr><td>13497</td><td>COMP  735 - 080   Distributed and Concurrent Algorithms</td><td>TuTh 2:00PM - 3:15PM</td><td>JAMES ANDERSON</td><td>F Brooks - Sitterson - Rm F007</td><td>13/30</td><td>0/0</td><td>0/3</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Prerequisites, COMP 530 and 550. Verification of concurrent systems. Synchronization; mutual exclusion and related problems, barriers, rendezvous, nonblocking algorithms. Fault tolerance: consensus, Byzantine agreement, self-stabilization. Broadcast algorithms. Termination and deadlock detection. Clock synchronization. 3 units.</td></tr>
# <tr><td>13512</td><td>COMP  776 - 001   Computer Vision in our 3D World</td><td>TuTh 2:00PM - 3:15PM</td><td>Soumyadip Sengupta</td><td>F Brooks - Sitterson - Rm F009</td><td>18/30</td><td>0/0</td><td>0/0</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Prerequisites, MATH 566, COMP 550, 665, and 775; permission of the instructor for students lacking the prerequisites. Fundamental problems of computer vision. Projective geometry. Camera models, camera calibration. Shape from stereo, epipolar geometry. Photometric stereo. Optical flow, tracking, motion. Range finders, structured light. Object recognition. 3 units.</td></tr>
# <tr><td>13513</td><td>COMP  777 - 98   Optimal Estimation in Image Analysis</td><td>TuTh 11:00AM - 12:15PM</td><td>MARC NIETHAMMER</td><td>F Brooks - Sitterson - Rm F007</td><td>12/30</td><td>0/0</td><td>0/3</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Prerequisites, MATH 233, MATH 347/547, and MATH 535 or STOR 435. Formulation and numerical solution of optimization problems in image analysis. 3 units.</td></tr>
# <tr><td>13514</td><td>COMP  781 - 001   Robotics</td><td>MoWe 2:05PM - 3:20PM</td><td>RON ALTEROVITZ</td><td>TBA</td><td>18/24</td><td>0/0</td><td>0/0</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Prerequisites, COMP 550 and MATH 347/547; Permission of the instructor for students lacking the prerequisites. Introduction to the design, programming, and control of robotic systems. Topics include kinematics, dynamics, sensing, actuation, control, robot learning, tele-operation, and motion planning. Applications will be discussed including industrial, mobile, assistive, personal, and medical robots. 3 units.</td></tr>
# <tr><td>13519</td><td>COMP  790 - 006   Topics in Computer Science</td><td>TuTh 3:30PM - 4:45PM</td><td>STEPHEN PIZER</td><td>F Brooks - Sitterson - Rm F007</td><td>6/30</td><td>0/0</td><td>0/3</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Permission of the instructor. This course has variable content and may be taken multiple times for credit. 1 - 21 units.</td></tr>
# <tr><td>9640</td><td>COMP  790 - 132   Topics in Computer Science</td><td>MoWe 11:00AM - 12:15PM</td><td>Cynthia Sturton</td><td>F Brooks - Sitterson - Rm F009</td><td>1/30</td><td>0/0</td><td>0/2</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Permission of the instructor. This course has variable content and may be taken multiple times for credit. 1 - 21 units.</td></tr>
# <tr><td>13520</td><td>COMP  790 - 136   Topics in Computer Science</td><td>Mo 11:00AM - 2:00PM</td><td>Shahriar Nirjon</td><td>Sitterson - Rm 0115</td><td>13/25</td><td>0/0</td><td>0/3</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Permission of the instructor. This course has variable content and may be taken multiple times for credit. 1 - 21 units.</td></tr>
# <tr><td>14659</td><td>COMP  790 - 139   Topics in Computer Science</td><td>We 11:00AM - 1:30PM</td><td>Mohit Bansal</td><td>Sitterson - Rm 0115</td><td>9/15</td><td>0/0</td><td>0/0</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Permission of the instructor. This course has variable content and may be taken multiple times for credit. 1 - 21 units.</td></tr>
# <tr><td>10205</td><td>COMP  790 - 166   Topics in Computer Science</td><td>MoWe 11:00AM - 12:15PM</td><td>Natalie Stanley</td><td>F Brooks - Sitterson - Rm F007</td><td>12/30</td><td>0/0</td><td>0/3</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Permission of the instructor. This course has variable content and may be taken multiple times for credit. 1 - 21 units.</td></tr>
# <tr><td>11399</td><td>COMP  790 - 171   Special Topics: Privacy Preserving Technologies</td><td>MoWe 2:05PM - 3:20PM</td><td>SABA ESKANDARIAN</td><td>Sitterson - Rm 0011</td><td style="color:red">1/1</td><td>0/0</td><td>0/2</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Permission of the instructor. This course has variable content and may be taken multiple times for credit. 1 - 21 units.</td></tr>
# <tr><td>11401</td><td>COMP  790 - 173   Topics in Computer Science</td><td>TuTh 12:30PM - 1:45PM</td><td>Danielle Szafir</td><td>F Brooks - Sitterson - Rm F007</td><td>10/15</td><td>0/0</td><td>0/3</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Permission of the instructor. This course has variable content and may be taken multiple times for credit. 1 - 21 units.</td></tr>
# <tr><td>13521</td><td>COMP  790 - 178   Topics in Computer Science</td><td>TuTh 3:30PM - 4:45PM</td><td>Benjamin Berg</td><td>F Brooks - Sitterson - Rm F009</td><td>5/30</td><td>0/0</td><td>0/3</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Permission of the instructor. This course has variable content and may be taken multiple times for credit. 1 - 21 units.</td></tr>
# <tr><td>9662</td><td>COMP  915 - 001   Technical Communication in Computer Science</td><td>Fr 10:30AM - 12:00PM</td><td>Multiple</td><td>F Brooks - Sitterson - Rm F007</td><td style="color:red">18/18</td><td>0/0</td><td>0/2</td></tr>
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Graduate computer science majors or permission of the instructor. Seminar on teaching, short oral presentations, and writing in computer science. 1 units.</td></tr>
# </table>

# %% [markdown]
# Just like how we used `find_all()` on the `soup` object, we can also use this on elements too! Let's try and find all of the *rows*, represented by `<tr>` elements, in the table:

# %%
# Find all rows in the table
rows = table.find_all("tr")

for i in range(0,5):
    print(rows[i])
    print("\n")
# Out:
# <tr>
# <th>Class Number</th>
# <th>Class</th>
# <th>Meeting Time</th>
# <th>Instructor</th>
# <th>Room</th>
# <th>Unreserved Enrollment</th>
# <th>Reserved Enrollment</th>
# <th>Wait List</th>
# </tr>
#
#
# <tr><td>4290</td><td>COMP  110 - 001   Introduction to Programming and Data Science</td><td>TuTh 8:00AM - 9:15AM</td><td>Alyssa Byrnes</td><td>Hamilton Hall - Rm 0100</td><td style="color:orange">217/219</td><td style="color:red">81/81</td><td>0/30</td></tr>
#
#
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Prerequisite, A C or better in one of the following courses: MATH 130, 152, 210, 231, 129P, or PHIL 155, or STOR 120, 151, 155. Introduces students to programming and data science from a computational perspective. With an emphasis on modern applications in society, students gain experience with problem decomposition, algorithms for data analysis, abstraction design, and ethics in computing. No prior programming experience expected. Foundational concepts include data types, sequences, boolean logic, control flow, functions/methods, recursion, classes/objects, input/output, data organization, transformations, and visualizations. Students may not enroll in COMP 110 after receiving credit for COMP 210 or greater. 3 units.</td></tr>
#
#
# <tr><td>10266</td><td>COMP  110 - 002   Introduction to Programming and Data Science</td><td>TuTh 2:00PM - 3:15PM</td><td>Alyssa Byrnes</td><td>Hamilton Hall - Rm 0100</td><td style="color:red">90/90</td><td style="color:red">210/210</td><td>0/30</td></tr>
#
#
# <tr class="expandable"><td colspan="7"><strong>Description: </strong>Prerequisite, A C or better in one of the following courses: MATH 130, 152, 210, 231, 129P, or PHIL 155, or STOR 120, 151, 155. Introduces students to programming and data science from a computational perspective. With an emphasis on modern applications in society, students gain experience with problem decomposition, algorithms for data analysis, abstraction design, and ethics in computing. No prior programming experience expected. Foundational concepts include data types, sequences, boolean logic, control flow, functions/methods, recursion, classes/objects, input/output, data organization, transformations, and visualizations. Students may not enroll in COMP 110 after receiving credit for COMP 210 or greater. 3 units.</td></tr>

# %% [markdown]
# There are certainly a lot of rows in this table! If you notice, the first row is just column headers, and we do not need that (for now). Also, every other row is taken up by a description for a course, so every course is represented by **two rows**. For now to make things simple, we will not save course descriptions. Therefore when scraping data on courses, we need to look at **every other row!**

# %% [markdown]
# Let's take a look at one of the rows further.

# %%
# Print out prettified HTML for row 2 (index 1)
print(rows[1].prettify())
# Out:
# <tr>
#  <td>
#   4290
#  </td>
#  <td>
#   COMP  110 - 001   Introduction to Programming and Data Science
#  </td>
#  <td>
#   TuTh 8:00AM - 9:15AM
#  </td>
#  <td>
#   Alyssa Byrnes
#  </td>
#  <td>
#   Hamilton Hall - Rm 0100
#  </td>
#  <td style="color:orange">
#   217/219
#  </td>
#  <td style="color:red">
#   81/81
#  </td>
#  <td>
#   0/30
#  </td>
# </tr>

# %% [markdown]
# You will notice that HTML rows (`<tr>` elements) have elements inside called `<td>` elements, which represents data within the table!

# %% [markdown]
# Let's now find all of the `<td>` elements inside of this row.

# %%
# Find all <td> elements in the row
tds = rows[1].find_all("td")

# Iterate over all <td> elements and print them out
for td in tds:
    print(td)
# Out:
# <td>4290</td>
# <td>COMP  110 - 001   Introduction to Programming and Data Science</td>
# <td>TuTh 8:00AM - 9:15AM</td>
# <td>Alyssa Byrnes</td>
# <td>Hamilton Hall - Rm 0100</td>
# <td style="color:orange">217/219</td>
# <td style="color:red">81/81</td>
# <td>0/30</td>

# %% [markdown]
# We are almost there! We still have HTML, but one last step will print out nice clean text from our HTML. Let's modify the for loop to just grab the `text` of each of these elements:

# %%
# Iterate over all <td> elements and print out their texts
for td in tds:
    print(td.text)
# Out:
# 4290
# COMP  110 - 001   Introduction to Programming and Data Science
# TuTh 8:00AM - 9:15AM
# Alyssa Byrnes
# Hamilton Hall - Rm 0100
# 217/219
# 81/81
# 0/30

# %% [markdown]
# Amazing! We have just cleaned up the data for the first row of the table. We can extend this exact logic now for **every row** of the table!

# %%
# Iterate over all rows...
for row in rows:
    
    # Find all <td> elements in the row
    tds = row.find_all("td")

    # Iterate over all <td> elements and print out their texts
    for td in tds:
        print(td.text)
        
    # Add line break between data for each row
    print("\n")
# Out:
# 4290
# COMP  110 - 001   Introduction to Programming and Data Science
# TuTh 8:00AM - 9:15AM
# Alyssa Byrnes
# Hamilton Hall - Rm 0100
# 217/219
# 81/81
# 0/30
#
#
# Description: Prerequisite, A C or better in one of the following courses: MATH 130, 152, 210, 231, 129P, or PHIL 155, or STOR 120, 151, 155. Introduces students to programming and data science from a computational perspective. With an emphasis on modern applications in society, students gain experience with problem decomposition, algorithms for data analysis, abstraction design, and ethics in computing. No prior programming experience expected. Foundational concepts include data types, sequences, boolean logic, control flow, functions/methods, recursion, classes/objects, input/output, data organization, transformations, and visualizations. Students may not enroll in COMP 110 after receiving credit for COMP 210 or greater. 3 units.
#
#
# 10266
# COMP  110 - 002   Introduction to Programming and Data Science
# TuTh 2:00PM - 3:15PM
# Alyssa Byrnes
# Hamilton Hall - Rm 0100
# 90/90
# 210/210
# 0/30
#
#
# Description: Prerequisite, A C or better in one of the following courses: MATH 130, 152, 210, 231, 129P, or PHIL 155, or STOR 120, 151, 155. Introduces students to programming and data science from a computational perspective. With an emphasis on modern applications in society, students gain experience with problem decomposition, algorithms for data analysis, abstraction design, and ethics in computing. No prior programming experience expected. Foundational concepts include data types, sequences, boolean logic, control flow, functions/methods, recursion, classes/objects, input/output, data organization, transformations, and visualizations. Students may not enroll in COMP 110 after receiving credit for COMP 210 or greater. 3 units.
#
#
# 9610
# COMP  116 - 001   Introduction to Scientific Programming
# TuTh 8:00AM - 9:15AM
# John Majikes
# Hanes Art Center - Rm 0121
# 153/240
# 0/0
# 0/24
#
#
# Description: Prerequisite, MATH 231 or 241; a grade of C or better is required. An introduction to programming for computationally oriented scientists. Fundamental programming skills, typically using MATLAB or Python. Problem analysis and algorithm design with examples drawn from simple numerical and discrete problems. 3 units.
#
#
# 5130
# COMP  126 - 001   Practical Web Design and Development for Everyone
# TuTh 11:00AM - 12:15PM
# Tessa Joseph-Nicholas
# Sitterson - Rm 0014
# 101/105
# 0/0
# 0/11
#
#
# Description: A ground-up introduction to current principles, standards, and best practice in website design, usability, accessibility, development, and management through project-based skills development in HTML5, CSS, and basic JavaScript. Intended for nonmajors. 3 units.
#
#
# 13454
# COMP  210 - 001   Data Structures and Analysis
# MoWe 2:05PM - 3:20PM
# Paul Stotts
# Hanes Art Center - Rm 0121
# 235/240
# 0/0
# 0/21
#
#
# Description: Prerequisites, COMP 110 and MATH 231; Pre- or corequisite, COMP 283 or MATH 381. This course will teach you how to organize the data used in computer programs so that manipulation of that data can be done efficiently on large problems and large data instances.  Rather than learning to use the data structures found in the libraries of programming languages, you will be learning how those libraries are constructed, and why the items that are included in them are there (and why some are excluded). 3 units.
#
#
# 9609
# COMP  210 - 002   Data Structures and Analysis
# TuTh 3:30PM - 4:45PM
# Muhammad Ghani
# Coker - Rm 0201
# 191/195
# 0/0
# 0/20
#
#
# Description: Prerequisites, COMP 110 and MATH 231; Pre- or corequisite, COMP 283 or MATH 381. This course will teach you how to organize the data used in computer programs so that manipulation of that data can be done efficiently on large problems and large data instances.  Rather than learning to use the data structures found in the libraries of programming languages, you will be learning how those libraries are constructed, and why the items that are included in them are there (and why some are excluded). 3 units.
#
#
# 9611
# COMP  211 - 001   Systems Fundamentals
# TuTh 11:00AM - 12:15PM
# Brent Munsell
# Murray Hall - Rm G202
# 175/183
# 26/26
# 0/11
#
#
# Description: Prerequisites, COMP 210; COMP 283 or MATH 381; a grade of C or better is required in both prerequisite courses. This is the first course in the introductory systems sequence. Students enter the course having taken an introductory programming course in a high-level programming language (COMP 110) and a course in discrete structures. The overarching goal is to bridge the gap between a students' knowledge of a high-level programming language (COMP 110) and computer organization (COMP 311). 3 units.
#
#
# 14454
# COMP  211 - 002   Systems Fundamentals
# TuTh 2:00PM - 3:15PM
# Joshua Bakita
# Chapman Hall - Rm 0201
# 120/120
# 30/30
# 0/10
#
#
# Description: Prerequisites, COMP 210; COMP 283 or MATH 381; a grade of C or better is required in both prerequisite courses. This is the first course in the introductory systems sequence. Students enter the course having taken an introductory programming course in a high-level programming language (COMP 110) and a course in discrete structures. The overarching goal is to bridge the gap between a students' knowledge of a high-level programming language (COMP 110) and computer organization (COMP 311). 3 units.
#
#
# 5040
# COMP  283 - 001   Discrete Structures
# TuTh 2:00PM - 3:15PM
# Jack Snoeyink
# Hanes Art Center - Rm 0121
# 126/195
# 0/0
# 0/20
#
#
# Description: Prerequisite, MATH 231 or MATH 241; a grade of C or better is required. Introduces discrete structures (sets, tuples, relations, functions, graphs, trees) and the formal mathematics (logic, proof, induction) used to establish their properties and those of algorithms that work with them. Develops problem-solving skills through puzzles and applications central to computer science. 3 units.
#
#
# 10200
# COMP  283H - 001   Discrete Structures
# TuTh 2:00PM - 3:15PM
# Jack Snoeyink
# Hanes Art Center - Rm 0121
# 0/19
# 5/5
# 0/5
#
#
# Description: Prerequisite, MATH 231 or MATH 241; a grade of C or better is required. Introduces discrete structures (sets, tuples, relations, functions, graphs, trees) and the formal mathematics (logic, proof, induction) used to establish their properties and those of algorithms that work with them. Develops problem-solving skills through puzzles and applications central to computer science. 3 units.
#
#
# 9612
# COMP  301 - 001   Foundations of Programming
# TuTh 8:00AM - 9:15AM
# KETAN MAYER-PATEL
# Genome Sciences Bldg -Rm G100
# 271/308
# 55/55
# 0/21
#
#
# Description: Prerequisites, COMP 210; COMP 283 or MATH 381; a grade of C or better is required in both prerequisite courses. Students will learn how to reason about how their code is structured, identify whether a given structure is effective in a given context, and look at ways of organizing units of code that support larger programs. In a nutshell, the primary goal of the course is to equip students with tools and techniques that will help them not only in later courses in the major but also in their careers afterwards. 3 units.
#
#
# 9613
# COMP  311 - 001   Computer Organization
# TuTh 2:00PM - 3:15PM
# Brent Munsell
# Manning - Rm 0209
# 14/52
# 128/128
# 0/18
#
#
# Description: Prerequisite, COMP 211; a grade of C or better is required. Introduction to computer organization and design. Students will be introduced to the conceptual design of a basic microprocessor, along with assembly programming.  The course includes fundamental concepts such as binary numbers, binary arithmetic, and representing information as well as instructions. Students learn to program in assembly (i.e., machine) language.  The course covers the fundamentals of computer hardware design,  transistors and logic gates, progressing through basic combinational and sequential components, culminating in the conceptual design CPU. 3 units.
#
#
# 3426
# COMP  380 - 001   Introduction to Digital Culture
# TuTh 9:30AM - 10:45AM
# Multiple
# F Brooks - Sitterson - Rm F009
# 77/77
# 0/0
# 0/20
#
#
# Description: An introduction to digital technology and computer science issues in society. Topics may include Internet history, privacy, security, usability, graphics, games, computers in the media, development, economics, social media, AI, IP, computer and Internet ethics, global ethics, current legal issues, etc. 3 units.
#
#
# 3765
# COMP  380H - 001   Introduction to Digital Culture
# TuTh 2:00PM - 3:15PM
# Tessa Joseph-Nicholas
# Sitterson - Rm 0115
# 2/2
# 22/22
# 0/3
#
#
# Description: An introduction to digital technology and computer science issues in society. Topics may include Internet history, privacy, security, usability, graphics, games, computers in the media, development, economics, social media, AI, IP, computer and Internet ethics, global ethics, current legal issues, etc. 3 units.
#
#
# 10238
# COMP  421 - 001   Files and Databases
# TuTh 9:30AM - 10:45AM
# John Majikes
# Murphey - Rm 0116
# 41/44
# 126/126
# 0/15
#
#
# Description: Prerequisites, COMP 210, 211, and 301; or COMP 401, 410, and 411; a grade of C or better is required in all prerequisite courses. Placement of data on secondary storage. File organization. Database history, practice, major models, system structure and design. Previously offered as COMP 521. 3 units.
#
#
# 9614
# COMP  426 - 001   Modern Web Programming
# TuTh 5:00PM - 6:15PM
# John Martin
# Hanes Art Center - Rm 0121
# 40/42
# 163/163
# 0/21
#
#
# Description: Prerequisites, COMP 211 and 301; or COMP 401 and 410; a grade of C or better is required in all prerequisite courses. Developing applications for the World Wide Web including both client-side and server-side programming. Emphasis on Model-View-Controller architecture, AJAX, RESTful Web services, and database interaction. 3 units.
#
#
# 2168
# COMP  431 - 001   Internet Services and Protocols
# TuTh 12:30PM - 1:45PM
# KEVIN JEFFAY
# Sitterson - Rm 0014
# 9/81
# 24/24
# 0/11
#
#
# Description: Prerequisites, COMP 210, 211, and 301; or COMP 401, 410, and 411; a grade of C or better is required in all prerequisite courses. Application-level protocols HTTP, SMTP, FTP, transport protocols TCP and UDP, and the network-level protocol IP. Internet architecture, naming, addressing, routing, and DNS. Sockets programming. Physical-layer technologies. Ethernet, ATM, and wireless. 3 units.
#
#
# 13015
# COMP  447 - 001   Quantum Computing
# MoWeFr 3:35PM - 4:25PM
# Multiple
# Phillips - Rm 0215
# 41/74
# 0/0
# 0/0
#
#
# Description: Prerequisites, MATH 232, and PHYS 116 or 118. Recommended preparation, some knowledge of basic linear algebra. An introduction to quantum computing. Basic math and quantum mechanics necessary to understand the operation of quantum bits. Quantum gates, circuits, and algorithms, including Shor's algorithm for factoring and Grover's search algorithm. Entanglement and error correction. Quantum encryption, annealing, and simulation. Brief discussion of technologies. 3 units.
#
#
# 2166
# COMP  455 - 001   Models of Languages and Computation
# TuTh 9:30AM - 10:45AM
# Thiagarajan Subramanian
# Sitterson - Rm 0014
# 26/26
# 64/64
# 0/18
#
#
# Description: Prerequisites, COMP 210 or 410 and COMP 283 or MATH 381; a grade of C or better in all prerequisite courses is required. Introduction to the theory of computation. Finite automata, regular languages, pushdown automata, context-free languages, and Turing machines. Undecidable problems. 3 units.
#
#
# 9615
# COMP  455 - 002   Models of Languages and Computation
# TuTh 2:00PM - 3:15PM
# Thiagarajan Subramanian
# Sitterson - Rm 0014
# 32/80
# 15/15
# 0/10
#
#
# Description: Prerequisites, COMP 210 or 410 and COMP 283 or MATH 381; a grade of C or better in all prerequisite courses is required. Introduction to the theory of computation. Finite automata, regular languages, pushdown automata, context-free languages, and Turing machines. Undecidable problems. 3 units.
#
#
# 6439
# COMP  488 - 001   Data Science in the Business World
# TuTh 2:00PM - 3:15PM
# Daniel Ringel
# McColl Building - Rm 3250
# 0/0
# 19/22
# 0/1
#
#
# Description: Students will acquire hands-on data science skills enabling them to solve real-world business problems. Since data science is an interdisciplinary field, business and computer science students learn and work together in this course. Leveraging each other's skills and knowledge, students create data-driven business insights using modern analytics. 3 units.
#
#
# 6440
# COMP  488 - 002   Data Science in the Business World
# TuTh 3:30PM - 4:45PM
# Daniel Ringel
# McColl Building - Rm 3250
# 0/0
# 23/24
# 0/2
#
#
# Description: Students will acquire hands-on data science skills enabling them to solve real-world business problems. Since data science is an interdisciplinary field, business and computer science students learn and work together in this course. Leveraging each other's skills and knowledge, students create data-driven business insights using modern analytics. 3 units.
#
#
# 6441
# COMP  488 - 003   Data Science in the Business World
# MoWe 3:30PM - 4:45PM
# Jack Snoeyink
# Sitterson - Rm 0014
# 0/0
# 27/37
# 0/3
#
#
# Description: Students will acquire hands-on data science skills enabling them to solve real-world business problems. Since data science is an interdisciplinary field, business and computer science students learn and work together in this course. Leveraging each other's skills and knowledge, students create data-driven business insights using modern analytics. 3 units.
#
#
# 3110
# COMP  523 - 001   Software Engineering Laboratory
# MoWeFr 8:45AM - 10:00AM
# Paul Stotts
# F Brooks - Sitterson - Rm F009
# 13/13
# 47/47
# 0/6
#
#
# Description: Prerequisites, COMP 301 and 311; or COMP 401, 410, and 411; as well as at least two chosen from COMP 421, 426, 431, 433, 520, 530, 535, 575, 580. Organization and scheduling of software engineering projects, structured programming, and design. Each team designs, codes, and debugs program components and synthesizes them into a tested, documented program product. 4 units.
#
#
# 3362
# COMP  541 - 001   Digital Logic and Computer Design
# MoWeFr 2:05PM - 3:20PM
# MONTEK SINGH
# F Brooks - Sitterson - Rm F007
# 11/14
# 31/31
# 0/5
#
#
# Description: Prerequisites, COMP 301 and 311; or COMP 401, 410, and 411; a grade of C or better is required in all prerequisite courses. This course is an introduction to digital logic as well as the structure and electronic design of modern processors. Students will implement a working computer during the laboratory sessions. 4 units.
#
#
# 2182
# COMP  550 - 001   Algorithms and Analysis
# TuTh 12:30PM - 1:45PM
# Muhammad Ghani
# Hanes Art Center - Rm 0121
# 36/38
# 157/157
# 0/20
#
#
# Description: Prerequisites, COMP 211 and 301; or COMP 410; a grade of C or better is required in all prerequisite courses. Formal specification and verification of programs. Techniques of algorithm analysis. Problem-solving paradigms. Survey of selected algorithms. 3 units.
#
#
# 3886
# COMP  555 - 001   Bioalgorithms
# MoWe 2:05PM - 3:20PM
# Anwica Kashfeen
# Sitterson - Rm 0014
# 17/57
# 3/3
# 0/0
#
#
# Description: Prerequisites, COMP 210, and 211; or COMP 401, and 410; and MATH 231, or 241; or BIOL 452; or MATH 553; or BIOL 525; a grade of C or better is required in all prerequisite courses. Bioinformatics algorithms. Topics include DNA restriction mapping, finding regulatory motifs, genome rearrangements, sequence alignments, gene prediction, graph algorithms, DNA sequencing, protein sequencing, combinatorial pattern matching, approximate pattern matching, clustering and evolution, tree construction, Hidden Markov Models, randomized algorithms. 3 units.
#
#
# 5605
# COMP  562 - 001   Introduction to Machine Learning
# TuTh 5:00PM - 6:15PM
# Jorge Silva
# Sitterson - Rm 0014
# 35/68
# 52/52
# 0/12
#
#
# Description: Prerequisites, COMP 211 and 301; or COMP 401 and 410; as well as MATH 233, 347, and STOR 435; a grade of C or better is required in all prerequisite courses; permission of the instructor for students lacking the prerequisites. Machine learning as applied to speech recognition, tracking, collaborative filtering, and recommendation systems. Classification, regression, support vector machines, hidden Markov models, principal component analysis, and deep learning. 3 units.
#
#
# 14665
# COMP  562H - 002   Introduction to Machine Learning
# TuTh 12:30PM - 1:45PM
# Junier Oliva
# Sitterson - Rm 0011
# 10/22
# 2/2
# 0/5
#
#
# Description: Prerequisites, COMP 211 and 301; or COMP 401 and 410; as well as MATH 233, 347, and STOR 435; a grade of C or better is required in all prerequisite courses; permission of the instructor for students lacking the prerequisites. Machine learning as applied to speech recognition, tracking, collaborative filtering, and recommendation systems. Classification, regression, support vector machines, hidden Markov models, principal component analysis, and deep learning. 3 units.
#
#
# 10207
# COMP  590 - 093   Special Topics: User Interfaces
# TuTh 9:30AM - 10:45AM
# Diane Pozefsky
# Sitterson - Rm 0011
# 7/7
# 33/33
# 0/5
#
#
# Description: Permission of the instructor. This course has variable content and may be taken multiple times for credit. Different sections may be taken in the same semester. 3 units.
# Notes: Prerequisites, COMP 301 and COMP 311. Self-registration.
#
#
# 12217
# COMP  590 - 132   Special Topics: Formal Methods and Security
# MoWe 11:00AM - 12:15PM
# Cynthia Sturton
# F Brooks - Sitterson - Rm F009
# 7/8
# 7/7
# 0/2
#
#
# Description: Permission of the instructor. This course has variable content and may be taken multiple times for credit. Different sections may be taken in the same semester. 3 units.
# Notes: Instructor permission required. For more information, see https://docs.google.com/document/d/1MUDD6y7y2y87DssPeLU_wmlPwkJs3LYzFjDjqzfaHJU/edit#heading=h.h8vorb0okj2
#
#
# 13476
# COMP  590 - 139   Special Topics: Connecting Language to Vision
# We 11:00AM - 1:30PM
# Mohit Bansal
# Sitterson - Rm 0115
# 2/8
# 2/2
# 0/1
#
#
# Description: Permission of the instructor. This course has variable content and may be taken multiple times for credit. Different sections may be taken in the same semester. 3 units.
# Notes: Prerequisites, COMP 301 and COMP 211. Self-registration.
#
#
# 13477
# COMP  590 - 140   Special Topics: Foundations of Software Engineering
# MoWeFr 1:25PM - 2:15PM
# Kris Jordan
# Carroll - Rm 0111
# 24/29
# 179/179
# 0/6
#
#
# Description: Permission of the instructor. This course has variable content and may be taken multiple times for credit. Different sections may be taken in the same semester. 3 units.
# Notes: Prerequisites, COMP 301 and COMP 211. Registration request: https://bit.ly/comp590-kj-23s
#
#
# 14988
# COMP  590 - 157   Topics in Computer Science
# TuTh 11:00AM - 12:15PM
# Shashank Srivastava
# Sitterson - Rm 0011
# 17/38
# 22/22
# 0/0
#
#
# Description: Permission of the instructor. This course has variable content and may be taken multiple times for credit. Different sections may be taken in the same semester. 3 units.
#
#
# 11958
# COMP  590 - 171   Special Topics: Privacy Preserving Technologies
# MoWe 2:05PM - 3:20PM
# SABA ESKANDARIAN
# Sitterson - Rm 0011
# 11/13
# 16/16
# 0/3
#
#
# Description: Permission of the instructor. This course has variable content and may be taken multiple times for credit. Different sections may be taken in the same semester. 3 units.
# Notes: Prerequisites, COMP 283, COMP 210, COMP 211, and COMP 301 (or their equivalents). Self-registration. Course website: https://www.cs.unc.edu/~saba/priv_class/index.html
#
#
# 13478
# COMP  590 - 173   Special Topics: Visualization Design Methods
# TuTh 12:30PM - 1:45PM
# Danielle Szafir
# F Brooks - Sitterson - Rm F007
# 4/4
# 16/16
# 0/2
#
#
# Description: Permission of the instructor. This course has variable content and may be taken multiple times for credit. Different sections may be taken in the same semester. 3 units.
# Notes: Prerequisites, COMP 301 and COMP 211. Self-registration.
#
#
# 14446
# COMP  590 - 177   Special Topics: Computer Vision in the 3D World
# TuTh 2:00PM - 3:15PM
# Soumyadip Sengupta
# F Brooks - Sitterson - Rm F009
# 10/33
# 27/27
# 0/10
#
#
# Description: Permission of the instructor. This course has variable content and may be taken multiple times for credit. Different sections may be taken in the same semester. 3 units.
# Notes: Prerequisites, COMP 301, COMP 311, MATH 233, and MATH 347. Self-registration.
#
#
# 13479
# COMP  631 - 001   Computer Networks
# TuTh 11:00AM - 12:15PM
# Jasleen Kaur
# F Brooks - Sitterson - Rm F009
# 11/60
# 0/0
# 0/6
#
#
# Description: Required preparation, a first course in operating systems, a first course in networking (e.g., COMP 431 and 530), and knowledge of probability and statistics. Topics in computer networks, including link layer protocols, switching, IP, TCP, and congestion control. Additional topics may include peer-to-peer infrastructures, network security, and multimedia applications. 3 units.
#
#
# 3386
# COMP  662 - 001   Scientific Computation II
# TuTh 12:30PM - 1:45PM
# JINGFANG HUANG
# Phillips - Rm 0224
# 1/4
# 0/0
# 0/0
#
#
# Description: Prerequisite, MATH 661. Theory and practical issues arising in linear algebra problems derived from physical applications, e.g., discretization of ODEs and PDEs. Linear systems, linear least squares, eigenvalue problems, singular value decomposition. 3 units.
#
#
# 13485
# COMP  664 - 101   Deep Learning
# MoWe 12:30PM - 1:45PM
# Colin Raffel
# F Brooks - Sitterson - Rm F009
# 56/60
# 0/0
# 0/6
#
#
# Description: Prerequisites, COMP 562, 755, or 565 and MATH 201, 347, or 577 and MATH 233 or 522; permission of the instructor for student lacking the prerequisites. Introduction to the field of deep learning and its applications. Basics of building and optimizing neural networks, including model architectures and training schemes. 3 units.
#
#
# 13495
# COMP  730 - 138   Operating Systems
# TuTh 9:30AM - 10:45AM
# Donald Porter
# F Brooks - Sitterson - Rm F007
# 14/30
# 0/0
# 0/3
#
#
# Description: Prerequisite, COMP 530. Theory, structuring, and design of operating systems. Sequential and cooperating processes. Single processor, multiprocessor, and distributed operating systems. 3 units.
#
#
# 13497
# COMP  735 - 080   Distributed and Concurrent Algorithms
# TuTh 2:00PM - 3:15PM
# JAMES ANDERSON
# F Brooks - Sitterson - Rm F007
# 13/30
# 0/0
# 0/3
#
#
# Description: Prerequisites, COMP 530 and 550. Verification of concurrent systems. Synchronization; mutual exclusion and related problems, barriers, rendezvous, nonblocking algorithms. Fault tolerance: consensus, Byzantine agreement, self-stabilization. Broadcast algorithms. Termination and deadlock detection. Clock synchronization. 3 units.
#
#
# 13512
# COMP  776 - 001   Computer Vision in our 3D World
# TuTh 2:00PM - 3:15PM
# Soumyadip Sengupta
# F Brooks - Sitterson - Rm F009
# 18/30
# 0/0
# 0/0
#
#
# Description: Prerequisites, MATH 566, COMP 550, 665, and 775; permission of the instructor for students lacking the prerequisites. Fundamental problems of computer vision. Projective geometry. Camera models, camera calibration. Shape from stereo, epipolar geometry. Photometric stereo. Optical flow, tracking, motion. Range finders, structured light. Object recognition. 3 units.
#
#
# 13513
# COMP  777 - 98   Optimal Estimation in Image Analysis
# TuTh 11:00AM - 12:15PM
# MARC NIETHAMMER
# F Brooks - Sitterson - Rm F007
# 12/30
# 0/0
# 0/3
#
#
# Description: Prerequisites, MATH 233, MATH 347/547, and MATH 535 or STOR 435. Formulation and numerical solution of optimization problems in image analysis. 3 units.
#
#
# 13514
# COMP  781 - 001   Robotics
# MoWe 2:05PM - 3:20PM
# RON ALTEROVITZ
# TBA
# 18/24
# 0/0
# 0/0
#
#
# Description: Prerequisites, COMP 550 and MATH 347/547; Permission of the instructor for students lacking the prerequisites. Introduction to the design, programming, and control of robotic systems. Topics include kinematics, dynamics, sensing, actuation, control, robot learning, tele-operation, and motion planning. Applications will be discussed including industrial, mobile, assistive, personal, and medical robots. 3 units.
#
#
# 13519
# COMP  790 - 006   Topics in Computer Science
# TuTh 3:30PM - 4:45PM
# STEPHEN PIZER
# F Brooks - Sitterson - Rm F007
# 6/30
# 0/0
# 0/3
#
#
# Description: Permission of the instructor. This course has variable content and may be taken multiple times for credit. 1 - 21 units.
#
#
# 9640
# COMP  790 - 132   Topics in Computer Science
# MoWe 11:00AM - 12:15PM
# Cynthia Sturton
# F Brooks - Sitterson - Rm F009
# 1/30
# 0/0
# 0/2
#
#
# Description: Permission of the instructor. This course has variable content and may be taken multiple times for credit. 1 - 21 units.
#
#
# 13520
# COMP  790 - 136   Topics in Computer Science
# Mo 11:00AM - 2:00PM
# Shahriar Nirjon
# Sitterson - Rm 0115
# 13/25
# 0/0
# 0/3
#
#
# Description: Permission of the instructor. This course has variable content and may be taken multiple times for credit. 1 - 21 units.
#
#
# 14659
# COMP  790 - 139   Topics in Computer Science
# We 11:00AM - 1:30PM
# Mohit Bansal
# Sitterson - Rm 0115
# 9/15
# 0/0
# 0/0
#
#
# Description: Permission of the instructor. This course has variable content and may be taken multiple times for credit. 1 - 21 units.
#
#
# 10205
# COMP  790 - 166   Topics in Computer Science
# MoWe 11:00AM - 12:15PM
# Natalie Stanley
# F Brooks - Sitterson - Rm F007
# 12/30
# 0/0
# 0/3
#
#
# Description: Permission of the instructor. This course has variable content and may be taken multiple times for credit. 1 - 21 units.
#
#
# 11399
# COMP  790 - 171   Special Topics: Privacy Preserving Technologies
# MoWe 2:05PM - 3:20PM
# SABA ESKANDARIAN
# Sitterson - Rm 0011
# 1/1
# 0/0
# 0/2
#
#
# Description: Permission of the instructor. This course has variable content and may be taken multiple times for credit. 1 - 21 units.
#
#
# 11401
# COMP  790 - 173   Topics in Computer Science
# TuTh 12:30PM - 1:45PM
# Danielle Szafir
# F Brooks - Sitterson - Rm F007
# 10/15
# 0/0
# 0/3
#
#
# Description: Permission of the instructor. This course has variable content and may be taken multiple times for credit. 1 - 21 units.
#
#
# 13521
# COMP  790 - 178   Topics in Computer Science
# TuTh 3:30PM - 4:45PM
# Benjamin Berg
# F Brooks - Sitterson - Rm F009
# 5/30
# 0/0
# 0/3
#
#
# Description: Permission of the instructor. This course has variable content and may be taken multiple times for credit. 1 - 21 units.
#
#
# 9662
# COMP  915 - 001   Technical Communication in Computer Science
# Fr 10:30AM - 12:00PM
# Multiple
# F Brooks - Sitterson - Rm F007
# 18/18
# 0/0
# 0/2
#
#
# Description: Graduate computer science majors or permission of the instructor. Seminar on teaching, short oral presentations, and writing in computer science. 1 units.

# %% [markdown]
# Remember, we wanted *every other row*, so let's do that.

# %%
# Let's use some handy Python list notation:
# We can create a subset of list `a` with `a[start_index:end_index:step]`
# So, if we want every other row of `rows`, we can say `row[1::2]`
#     Note: Remember, we start at index 1 because row 0 is our header rows!
#     Note: Leaving end index blank implies we are going until the list ends!

# Iterate over every other row...
for row in rows[1::2]:
    
    # Find all <td> elements in the row
    tds = row.find_all("td")

    # Iterate over all <td> elements and print out their texts
    for td in tds:
        print(td.text)
        
    # Add line break between data for each row
    print("\n")
# Out:
# 4290
# COMP  110 - 001   Introduction to Programming and Data Science
# TuTh 8:00AM - 9:15AM
# Alyssa Byrnes
# Hamilton Hall - Rm 0100
# 217/219
# 81/81
# 0/30
#
#
# 10266
# COMP  110 - 002   Introduction to Programming and Data Science
# TuTh 2:00PM - 3:15PM
# Alyssa Byrnes
# Hamilton Hall - Rm 0100
# 90/90
# 210/210
# 0/30
#
#
# 9610
# COMP  116 - 001   Introduction to Scientific Programming
# TuTh 8:00AM - 9:15AM
# John Majikes
# Hanes Art Center - Rm 0121
# 153/240
# 0/0
# 0/24
#
#
# 5130
# COMP  126 - 001   Practical Web Design and Development for Everyone
# TuTh 11:00AM - 12:15PM
# Tessa Joseph-Nicholas
# Sitterson - Rm 0014
# 101/105
# 0/0
# 0/11
#
#
# 13454
# COMP  210 - 001   Data Structures and Analysis
# MoWe 2:05PM - 3:20PM
# Paul Stotts
# Hanes Art Center - Rm 0121
# 235/240
# 0/0
# 0/21
#
#
# 9609
# COMP  210 - 002   Data Structures and Analysis
# TuTh 3:30PM - 4:45PM
# Muhammad Ghani
# Coker - Rm 0201
# 191/195
# 0/0
# 0/20
#
#
# 9611
# COMP  211 - 001   Systems Fundamentals
# TuTh 11:00AM - 12:15PM
# Brent Munsell
# Murray Hall - Rm G202
# 175/183
# 26/26
# 0/11
#
#
# 14454
# COMP  211 - 002   Systems Fundamentals
# TuTh 2:00PM - 3:15PM
# Joshua Bakita
# Chapman Hall - Rm 0201
# 120/120
# 30/30
# 0/10
#
#
# 5040
# COMP  283 - 001   Discrete Structures
# TuTh 2:00PM - 3:15PM
# Jack Snoeyink
# Hanes Art Center - Rm 0121
# 126/195
# 0/0
# 0/20
#
#
# 10200
# COMP  283H - 001   Discrete Structures
# TuTh 2:00PM - 3:15PM
# Jack Snoeyink
# Hanes Art Center - Rm 0121
# 0/19
# 5/5
# 0/5
#
#
# 9612
# COMP  301 - 001   Foundations of Programming
# TuTh 8:00AM - 9:15AM
# KETAN MAYER-PATEL
# Genome Sciences Bldg -Rm G100
# 271/308
# 55/55
# 0/21
#
#
# 9613
# COMP  311 - 001   Computer Organization
# TuTh 2:00PM - 3:15PM
# Brent Munsell
# Manning - Rm 0209
# 14/52
# 128/128
# 0/18
#
#
# 3426
# COMP  380 - 001   Introduction to Digital Culture
# TuTh 9:30AM - 10:45AM
# Multiple
# F Brooks - Sitterson - Rm F009
# 77/77
# 0/0
# 0/20
#
#
# 3765
# COMP  380H - 001   Introduction to Digital Culture
# TuTh 2:00PM - 3:15PM
# Tessa Joseph-Nicholas
# Sitterson - Rm 0115
# 2/2
# 22/22
# 0/3
#
#
# 10238
# COMP  421 - 001   Files and Databases
# TuTh 9:30AM - 10:45AM
# John Majikes
# Murphey - Rm 0116
# 41/44
# 126/126
# 0/15
#
#
# 9614
# COMP  426 - 001   Modern Web Programming
# TuTh 5:00PM - 6:15PM
# John Martin
# Hanes Art Center - Rm 0121
# 40/42
# 163/163
# 0/21
#
#
# 2168
# COMP  431 - 001   Internet Services and Protocols
# TuTh 12:30PM - 1:45PM
# KEVIN JEFFAY
# Sitterson - Rm 0014
# 9/81
# 24/24
# 0/11
#
#
# 13015
# COMP  447 - 001   Quantum Computing
# MoWeFr 3:35PM - 4:25PM
# Multiple
# Phillips - Rm 0215
# 41/74
# 0/0
# 0/0
#
#
# 2166
# COMP  455 - 001   Models of Languages and Computation
# TuTh 9:30AM - 10:45AM
# Thiagarajan Subramanian
# Sitterson - Rm 0014
# 26/26
# 64/64
# 0/18
#
#
# 9615
# COMP  455 - 002   Models of Languages and Computation
# TuTh 2:00PM - 3:15PM
# Thiagarajan Subramanian
# Sitterson - Rm 0014
# 32/80
# 15/15
# 0/10
#
#
# 6439
# COMP  488 - 001   Data Science in the Business World
# TuTh 2:00PM - 3:15PM
# Daniel Ringel
# McColl Building - Rm 3250
# 0/0
# 19/22
# 0/1
#
#
# 6440
# COMP  488 - 002   Data Science in the Business World
# TuTh 3:30PM - 4:45PM
# Daniel Ringel
# McColl Building - Rm 3250
# 0/0
# 23/24
# 0/2
#
#
# 6441
# COMP  488 - 003   Data Science in the Business World
# MoWe 3:30PM - 4:45PM
# Jack Snoeyink
# Sitterson - Rm 0014
# 0/0
# 27/37
# 0/3
#
#
# 3110
# COMP  523 - 001   Software Engineering Laboratory
# MoWeFr 8:45AM - 10:00AM
# Paul Stotts
# F Brooks - Sitterson - Rm F009
# 13/13
# 47/47
# 0/6
#
#
# 3362
# COMP  541 - 001   Digital Logic and Computer Design
# MoWeFr 2:05PM - 3:20PM
# MONTEK SINGH
# F Brooks - Sitterson - Rm F007
# 11/14
# 31/31
# 0/5
#
#
# 2182
# COMP  550 - 001   Algorithms and Analysis
# TuTh 12:30PM - 1:45PM
# Muhammad Ghani
# Hanes Art Center - Rm 0121
# 36/38
# 157/157
# 0/20
#
#
# 3886
# COMP  555 - 001   Bioalgorithms
# MoWe 2:05PM - 3:20PM
# Anwica Kashfeen
# Sitterson - Rm 0014
# 17/57
# 3/3
# 0/0
#
#
# 5605
# COMP  562 - 001   Introduction to Machine Learning
# TuTh 5:00PM - 6:15PM
# Jorge Silva
# Sitterson - Rm 0014
# 35/68
# 52/52
# 0/12
#
#
# 14665
# COMP  562H - 002   Introduction to Machine Learning
# TuTh 12:30PM - 1:45PM
# Junier Oliva
# Sitterson - Rm 0011
# 10/22
# 2/2
# 0/5
#
#
# 10207
# COMP  590 - 093   Special Topics: User Interfaces
# TuTh 9:30AM - 10:45AM
# Diane Pozefsky
# Sitterson - Rm 0011
# 7/7
# 33/33
# 0/5
#
#
# 12217
# COMP  590 - 132   Special Topics: Formal Methods and Security
# MoWe 11:00AM - 12:15PM
# Cynthia Sturton
# F Brooks - Sitterson - Rm F009
# 7/8
# 7/7
# 0/2
#
#
# 13476
# COMP  590 - 139   Special Topics: Connecting Language to Vision
# We 11:00AM - 1:30PM
# Mohit Bansal
# Sitterson - Rm 0115
# 2/8
# 2/2
# 0/1
#
#
# 13477
# COMP  590 - 140   Special Topics: Foundations of Software Engineering
# MoWeFr 1:25PM - 2:15PM
# Kris Jordan
# Carroll - Rm 0111
# 24/29
# 179/179
# 0/6
#
#
# 14988
# COMP  590 - 157   Topics in Computer Science
# TuTh 11:00AM - 12:15PM
# Shashank Srivastava
# Sitterson - Rm 0011
# 17/38
# 22/22
# 0/0
#
#
# 11958
# COMP  590 - 171   Special Topics: Privacy Preserving Technologies
# MoWe 2:05PM - 3:20PM
# SABA ESKANDARIAN
# Sitterson - Rm 0011
# 11/13
# 16/16
# 0/3
#
#
# 13478
# COMP  590 - 173   Special Topics: Visualization Design Methods
# TuTh 12:30PM - 1:45PM
# Danielle Szafir
# F Brooks - Sitterson - Rm F007
# 4/4
# 16/16
# 0/2
#
#
# 14446
# COMP  590 - 177   Special Topics: Computer Vision in the 3D World
# TuTh 2:00PM - 3:15PM
# Soumyadip Sengupta
# F Brooks - Sitterson - Rm F009
# 10/33
# 27/27
# 0/10
#
#
# 13479
# COMP  631 - 001   Computer Networks
# TuTh 11:00AM - 12:15PM
# Jasleen Kaur
# F Brooks - Sitterson - Rm F009
# 11/60
# 0/0
# 0/6
#
#
# 3386
# COMP  662 - 001   Scientific Computation II
# TuTh 12:30PM - 1:45PM
# JINGFANG HUANG
# Phillips - Rm 0224
# 1/4
# 0/0
# 0/0
#
#
# 13485
# COMP  664 - 101   Deep Learning
# MoWe 12:30PM - 1:45PM
# Colin Raffel
# F Brooks - Sitterson - Rm F009
# 56/60
# 0/0
# 0/6
#
#
# 13495
# COMP  730 - 138   Operating Systems
# TuTh 9:30AM - 10:45AM
# Donald Porter
# F Brooks - Sitterson - Rm F007
# 14/30
# 0/0
# 0/3
#
#
# 13497
# COMP  735 - 080   Distributed and Concurrent Algorithms
# TuTh 2:00PM - 3:15PM
# JAMES ANDERSON
# F Brooks - Sitterson - Rm F007
# 13/30
# 0/0
# 0/3
#
#
# 13512
# COMP  776 - 001   Computer Vision in our 3D World
# TuTh 2:00PM - 3:15PM
# Soumyadip Sengupta
# F Brooks - Sitterson - Rm F009
# 18/30
# 0/0
# 0/0
#
#
# 13513
# COMP  777 - 98   Optimal Estimation in Image Analysis
# TuTh 11:00AM - 12:15PM
# MARC NIETHAMMER
# F Brooks - Sitterson - Rm F007
# 12/30
# 0/0
# 0/3
#
#
# 13514
# COMP  781 - 001   Robotics
# MoWe 2:05PM - 3:20PM
# RON ALTEROVITZ
# TBA
# 18/24
# 0/0
# 0/0
#
#
# 13519
# COMP  790 - 006   Topics in Computer Science
# TuTh 3:30PM - 4:45PM
# STEPHEN PIZER
# F Brooks - Sitterson - Rm F007
# 6/30
# 0/0
# 0/3
#
#
# 9640
# COMP  790 - 132   Topics in Computer Science
# MoWe 11:00AM - 12:15PM
# Cynthia Sturton
# F Brooks - Sitterson - Rm F009
# 1/30
# 0/0
# 0/2
#
#
# 13520
# COMP  790 - 136   Topics in Computer Science
# Mo 11:00AM - 2:00PM
# Shahriar Nirjon
# Sitterson - Rm 0115
# 13/25
# 0/0
# 0/3
#
#
# 14659
# COMP  790 - 139   Topics in Computer Science
# We 11:00AM - 1:30PM
# Mohit Bansal
# Sitterson - Rm 0115
# 9/15
# 0/0
# 0/0
#
#
# 10205
# COMP  790 - 166   Topics in Computer Science
# MoWe 11:00AM - 12:15PM
# Natalie Stanley
# F Brooks - Sitterson - Rm F007
# 12/30
# 0/0
# 0/3
#
#
# 11399
# COMP  790 - 171   Special Topics: Privacy Preserving Technologies
# MoWe 2:05PM - 3:20PM
# SABA ESKANDARIAN
# Sitterson - Rm 0011
# 1/1
# 0/0
# 0/2
#
#
# 11401
# COMP  790 - 173   Topics in Computer Science
# TuTh 12:30PM - 1:45PM
# Danielle Szafir
# F Brooks - Sitterson - Rm F007
# 10/15
# 0/0
# 0/3
#
#
# 13521
# COMP  790 - 178   Topics in Computer Science
# TuTh 3:30PM - 4:45PM
# Benjamin Berg
# F Brooks - Sitterson - Rm F009
# 5/30
# 0/0
# 0/3
#
#
# 9662
# COMP  915 - 001   Technical Communication in Computer Science
# Fr 10:30AM - 12:00PM
# Multiple
# F Brooks - Sitterson - Rm F007
# 18/18
# 0/0
# 0/2

# %% [markdown]
# Almost done! Let's use Python dictionaries (key-value pairs) to associate a **key** (column headings!) with each of the rows' data, then add each of these dictionaries to a final list for all of our data!

# %%
# Determine column headers
column_headers = ["Class Number", "Class", "Meeting Time", "Instructor", "Room", "Unreserved Enrollment", "Reserved Enrollment", "Wait List"]

#Create list to store final data
final_data_list = []

# Iterate over every other row...
for row in rows[1::2]:
    
    row_data = {}
    
    # Find all <td> elements in the row
    tds = row.find_all("td")

    # Iterate over all <td> elements and print out their texts
    for index, td in enumerate(tds):
        # Get correct column header for the data
        header = column_headers[index]
        # Store the data in the dictionary
        row_data[header] = td.text.replace("\xa0", "")
    
    # Add data to final list    
    final_data_list.append(row_data)

final_data_list
# Out:
# [{'Class Number': '4290',
#   'Class': 'COMP 110 - 001 Introduction to Programming and Data Science',
#   'Meeting Time': 'TuTh 8:00AM - 9:15AM',
#   'Instructor': 'Alyssa Byrnes',
#   'Room': 'Hamilton Hall - Rm 0100',
#   'Unreserved Enrollment': '217/219',
#   'Reserved Enrollment': '81/81',
#   'Wait List': '0/30'},
#  {'Class Number': '10266',
#   'Class': 'COMP 110 - 002 Introduction to Programming and Data Science',
#   'Meeting Time': 'TuTh 2:00PM - 3:15PM',
#   'Instructor': 'Alyssa Byrnes',
#   'Room': 'Hamilton Hall - Rm 0100',
#   'Unreserved Enrollment': '90/90',
#   'Reserved Enrollment': '210/210',
#   'Wait List': '0/30'},
#  {'Class Number': '9610',
#   'Class': 'COMP 116 - 001 Introduction to Scientific Programming',
#   'Meeting Time': 'TuTh 8:00AM - 9:15AM',
#   'Instructor': 'John Majikes',
#   'Room': 'Hanes Art Center - Rm 0121',
#   'Unreserved Enrollment': '153/240',
#   'Reserved Enrollment': '0/0',
#   'Wait List': '0/24'},
#  {'Class Number': '5130',
#   'Class': 'COMP 126 - 001 Practical Web Design and Development for Everyone',
#   'Meeting Time': 'TuTh 11:00AM - 12:15PM',
#   'Instructor': 'Tessa Joseph-Nicholas',
#   'Room': 'Sitterson - Rm 0014',
#   'Unreserved Enrollment': '101/105',
#   'Reserved Enrollment': '0/0',
#   'Wait List': '0/11'},
#  {'Class Number': '13454',
#   'Class': 'COMP 210 - 001 Data Structures and Analysis',
#   'Meeting Time': 'MoWe 2:05PM - 3:20PM',
#   'Instructor': 'Paul Stotts',
#   'Room': 'Hanes Art Center - Rm 0121',
#   'Unreserved Enrollment': '235/240',
#   'Reserved Enrollment': '0/0',
#   'Wait List': '0/21'},
#  {'Class Number': '9609',
#   'Class': 'COMP 210 - 002 Data Structures and Analysis',
#   'Meeting Time': 'TuTh 3:30PM - 4:45PM',
#   'Instructor': 'Muhammad Ghani',
#   'Room': 'Coker - Rm 0201',
#   'Unreserved Enrollment': '191/195',
#   'Reserved Enrollment': '0/0',
#   'Wait List': '0/20'},
#  {'Class Number': '9611',
#   'Class': 'COMP 211 - 001 Systems Fundamentals',
#   'Meeting Time': 'TuTh 11:00AM - 12:15PM',
#   'Instructor': 'Brent Munsell',
#   'Room': 'Murray Hall - Rm G202',
#   'Unreserved Enrollment': '175/183',
#   'Reserved Enrollment': '26/26',
#   'Wait List': '0/11'},
#  {'Class Number': '14454',
#   'Class': 'COMP 211 - 002 Systems Fundamentals',
#   'Meeting Time': 'TuTh 2:00PM - 3:15PM',
#   'Instructor': 'Joshua Bakita',
#   'Room': 'Chapman Hall - Rm 0201',
#   'Unreserved Enrollment': '120/120',
#   'Reserved Enrollment': '30/30',
#   'Wait List': '0/10'},
#  {'Class Number': '5040',
#   'Class': 'COMP 283 - 001 Discrete Structures',
#   'Meeting Time': 'TuTh 2:00PM - 3:15PM',
#   'Instructor': 'Jack Snoeyink',
#   'Room': 'Hanes Art Center - Rm 0121',
#   'Unreserved Enrollment': '126/195',
#   'Reserved Enrollment': '0/0',
#   'Wait List': '0/20'},
#  {'Class Number': '10200',
#   'Class': 'COMP 283H - 001 Discrete Structures',
#   'Meeting Time': 'TuTh 2:00PM - 3:15PM',
#   'Instructor': 'Jack Snoeyink',
#   'Room': 'Hanes Art Center - Rm 0121',
#   'Unreserved Enrollment': '0/19',
#   'Reserved Enrollment': '5/5',
#   'Wait List': '0/5'},
#  {'Class Number': '9612',
#   'Class': 'COMP 301 - 001 Foundations of Programming',
#   'Meeting Time': 'TuTh 8:00AM - 9:15AM',
#   'Instructor': 'KETAN MAYER-PATEL',
#   'Room': 'Genome Sciences Bldg -Rm G100',
#   'Unreserved Enrollment': '271/308',
#   'Reserved Enrollment': '55/55',
#   'Wait List': '0/21'},
#  {'Class Number': '9613',
#   'Class': 'COMP 311 - 001 Computer Organization',
#   'Meeting Time': 'TuTh 2:00PM - 3:15PM',
#   'Instructor': 'Brent Munsell',
#   'Room': 'Manning - Rm 0209',
#   'Unreserved Enrollment': '14/52',
#   'Reserved Enrollment': '128/128',
#   'Wait List': '0/18'},
#  {'Class Number': '3426',
#   'Class': 'COMP 380 - 001 Introduction to Digital Culture',
#   'Meeting Time': 'TuTh 9:30AM - 10:45AM',
#   'Instructor': 'Multiple',
#   'Room': 'F Brooks - Sitterson - Rm F009',
#   'Unreserved Enrollment': '77/77',
#   'Reserved Enrollment': '0/0',
#   'Wait List': '0/20'},
#  {'Class Number': '3765',
#   'Class': 'COMP 380H - 001 Introduction to Digital Culture',
#   'Meeting Time': 'TuTh 2:00PM - 3:15PM',
#   'Instructor': 'Tessa Joseph-Nicholas',
#   'Room': 'Sitterson - Rm 0115',
#   'Unreserved Enrollment': '2/2',
#   'Reserved Enrollment': '22/22',
#   'Wait List': '0/3'},
#  {'Class Number': '10238',
#   'Class': 'COMP 421 - 001 Files and Databases',
#   'Meeting Time': 'TuTh 9:30AM - 10:45AM',
#   'Instructor': 'John Majikes',
#   'Room': 'Murphey - Rm 0116',
#   'Unreserved Enrollment': '41/44',
#   'Reserved Enrollment': '126/126',
#   'Wait List': '0/15'},
#  {'Class Number': '9614',
#   'Class': 'COMP 426 - 001 Modern Web Programming',
#   'Meeting Time': 'TuTh 5:00PM - 6:15PM',
#   'Instructor': 'John Martin',
#   'Room': 'Hanes Art Center - Rm 0121',
#   'Unreserved Enrollment': '40/42',
#   'Reserved Enrollment': '163/163',
#   'Wait List': '0/21'},
#  {'Class Number': '2168',
#   'Class': 'COMP 431 - 001 Internet Services and Protocols',
#   'Meeting Time': 'TuTh 12:30PM - 1:45PM',
#   'Instructor': 'KEVIN JEFFAY',
#   'Room': 'Sitterson - Rm 0014',
#   'Unreserved Enrollment': '9/81',
#   'Reserved Enrollment': '24/24',
#   'Wait List': '0/11'},
#  {'Class Number': '13015',
#   'Class': 'COMP 447 - 001 Quantum Computing',
#   'Meeting Time': 'MoWeFr 3:35PM - 4:25PM',
#   'Instructor': 'Multiple',
#   'Room': 'Phillips - Rm 0215',
#   'Unreserved Enrollment': '41/74',
#   'Reserved Enrollment': '0/0',
#   'Wait List': '0/0'},
#  {'Class Number': '2166',
#   'Class': 'COMP 455 - 001 Models of Languages and Computation',
#   'Meeting Time': 'TuTh 9:30AM - 10:45AM',
#   'Instructor': 'Thiagarajan Subramanian',
#   'Room': 'Sitterson - Rm 0014',
#   'Unreserved Enrollment': '26/26',
#   'Reserved Enrollment': '64/64',
#   'Wait List': '0/18'},
#  {'Class Number': '9615',
#   'Class': 'COMP 455 - 002 Models of Languages and Computation',
#   'Meeting Time': 'TuTh 2:00PM - 3:15PM',
#   'Instructor': 'Thiagarajan Subramanian',
#   'Room': 'Sitterson - Rm 0014',
#   'Unreserved Enrollment': '32/80',
#   'Reserved Enrollment': '15/15',
#   'Wait List': '0/10'},
#  {'Class Number': '6439',
#   'Class': 'COMP 488 - 001 Data Science in the Business World',
#   'Meeting Time': 'TuTh 2:00PM - 3:15PM',
#   'Instructor': 'Daniel Ringel',
#   'Room': 'McColl Building - Rm 3250',
#   'Unreserved Enrollment': '0/0',
#   'Reserved Enrollment': '19/22',
#   'Wait List': '0/1'},
#  {'Class Number': '6440',
#   'Class': 'COMP 488 - 002 Data Science in the Business World',
#   'Meeting Time': 'TuTh 3:30PM - 4:45PM',
#   'Instructor': 'Daniel Ringel',
#   'Room': 'McColl Building - Rm 3250',
#   'Unreserved Enrollment': '0/0',
#   'Reserved Enrollment': '23/24',
#   'Wait List': '0/2'},
#  {'Class Number': '6441',
#   'Class': 'COMP 488 - 003 Data Science in the Business World',
#   'Meeting Time': 'MoWe 3:30PM - 4:45PM',
#   'Instructor': 'Jack Snoeyink',
#   'Room': 'Sitterson - Rm 0014',
#   'Unreserved Enrollment': '0/0',
#   'Reserved Enrollment': '27/37',
#   'Wait List': '0/3'},
#  {'Class Number': '3110',
#   'Class': 'COMP 523 - 001 Software Engineering Laboratory',
#   'Meeting Time': 'MoWeFr 8:45AM - 10:00AM',
#   'Instructor': 'Paul Stotts',
#   'Room': 'F Brooks - Sitterson - Rm F009',
#   'Unreserved Enrollment': '13/13',
#   'Reserved Enrollment': '47/47',
#   'Wait List': '0/6'},
#  {'Class Number': '3362',
#   'Class': 'COMP 541 - 001 Digital Logic and Computer Design',
#   'Meeting Time': 'MoWeFr 2:05PM - 3:20PM',
#   'Instructor': 'MONTEK SINGH',
#   'Room': 'F Brooks - Sitterson - Rm F007',
#   'Unreserved Enrollment': '11/14',
#   'Reserved Enrollment': '31/31',
#   'Wait List': '0/5'},
#  {'Class Number': '2182',
#   'Class': 'COMP 550 - 001 Algorithms and Analysis',
#   'Meeting Time': 'TuTh 12:30PM - 1:45PM',
#   'Instructor': 'Muhammad Ghani',
#   'Room': 'Hanes Art Center - Rm 0121',
#   'Unreserved Enrollment': '36/38',
#   'Reserved Enrollment': '157/157',
#   'Wait List': '0/20'},
#  {'Class Number': '3886',
#   'Class': 'COMP 555 - 001 Bioalgorithms',
#   'Meeting Time': 'MoWe 2:05PM - 3:20PM',
#   'Instructor': 'Anwica Kashfeen',
#   'Room': 'Sitterson - Rm 0014',
#   'Unreserved Enrollment': '17/57',
#   'Reserved Enrollment': '3/3',
#   'Wait List': '0/0'},
#  {'Class Number': '5605',
#   'Class': 'COMP 562 - 001 Introduction to Machine Learning',
#   'Meeting Time': 'TuTh 5:00PM - 6:15PM',
#   'Instructor': 'Jorge Silva',
#   'Room': 'Sitterson - Rm 0014',
#   'Unreserved Enrollment': '35/68',
#   'Reserved Enrollment': '52/52',
#   'Wait List': '0/12'},
#  {'Class Number': '14665',
#   'Class': 'COMP 562H - 002 Introduction to Machine Learning',
#   'Meeting Time': 'TuTh 12:30PM - 1:45PM',
#   'Instructor': 'Junier Oliva',
#   'Room': 'Sitterson - Rm 0011',
#   'Unreserved Enrollment': '10/22',
#   'Reserved Enrollment': '2/2',
#   'Wait List': '0/5'},
#  {'Class Number': '10207',
#   'Class': 'COMP 590 - 093 Special Topics: User Interfaces',
#   'Meeting Time': 'TuTh 9:30AM - 10:45AM',
#   'Instructor': 'Diane Pozefsky',
#   'Room': 'Sitterson - Rm 0011',
#   'Unreserved Enrollment': '7/7',
#   'Reserved Enrollment': '33/33',
#   'Wait List': '0/5'},
#  {'Class Number': '12217',
#   'Class': 'COMP 590 - 132 Special Topics: Formal Methods and Security',
#   'Meeting Time': 'MoWe 11:00AM - 12:15PM',
#   'Instructor': 'Cynthia Sturton',
#   'Room': 'F Brooks - Sitterson - Rm F009',
#   'Unreserved Enrollment': '7/8',
#   'Reserved Enrollment': '7/7',
#   'Wait List': '0/2'},
#  {'Class Number': '13476',
#   'Class': 'COMP 590 - 139 Special Topics: Connecting Language to Vision',
#   'Meeting Time': 'We 11:00AM - 1:30PM',
#   'Instructor': 'Mohit Bansal',
#   'Room': 'Sitterson - Rm 0115',
#   'Unreserved Enrollment': '2/8',
#   'Reserved Enrollment': '2/2',
#   'Wait List': '0/1'},
#  {'Class Number': '13477',
#   'Class': 'COMP 590 - 140 Special Topics: Foundations of Software Engineering',
#   'Meeting Time': 'MoWeFr 1:25PM - 2:15PM',
#   'Instructor': 'Kris Jordan',
#   'Room': 'Carroll - Rm 0111',
#   'Unreserved Enrollment': '24/29',
#   'Reserved Enrollment': '179/179',
#   'Wait List': '0/6'},
#  {'Class Number': '14988',
#   'Class': 'COMP 590 - 157 Topics in Computer Science',
#   'Meeting Time': 'TuTh 11:00AM - 12:15PM',
#   'Instructor': 'Shashank Srivastava',
#   'Room': 'Sitterson - Rm 0011',
#   'Unreserved Enrollment': '17/38',
#   'Reserved Enrollment': '22/22',
#   'Wait List': '0/0'},
#  {'Class Number': '11958',
#   'Class': 'COMP 590 - 171 Special Topics: Privacy Preserving Technologies',
#   'Meeting Time': 'MoWe 2:05PM - 3:20PM',
#   'Instructor': 'SABA ESKANDARIAN',
#   'Room': 'Sitterson - Rm 0011',
#   'Unreserved Enrollment': '11/13',
#   'Reserved Enrollment': '16/16',
#   'Wait List': '0/3'},
#  {'Class Number': '13478',
#   'Class': 'COMP 590 - 173 Special Topics: Visualization Design Methods',
#   'Meeting Time': 'TuTh 12:30PM - 1:45PM',
#   'Instructor': 'Danielle Szafir',
#   'Room': 'F Brooks - Sitterson - Rm F007',
#   'Unreserved Enrollment': '4/4',
#   'Reserved Enrollment': '16/16',
#   'Wait List': '0/2'},
#  {'Class Number': '14446',
#   'Class': 'COMP 590 - 177 Special Topics: Computer Vision in the 3D World',
#   'Meeting Time': 'TuTh 2:00PM - 3:15PM',
#   'Instructor': 'Soumyadip Sengupta',
#   'Room': 'F Brooks - Sitterson - Rm F009',
#   'Unreserved Enrollment': '10/33',
#   'Reserved Enrollment': '27/27',
#   'Wait List': '0/10'},
#  {'Class Number': '13479',
#   'Class': 'COMP 631 - 001 Computer Networks',
#   'Meeting Time': 'TuTh 11:00AM - 12:15PM',
#   'Instructor': 'Jasleen Kaur',
#   'Room': 'F Brooks - Sitterson - Rm F009',
#   'Unreserved Enrollment': '11/60',
#   'Reserved Enrollment': '0/0',
#   'Wait List': '0/6'},
#  {'Class Number': '3386',
#   'Class': 'COMP 662 - 001 Scientific Computation II',
#   'Meeting Time': 'TuTh 12:30PM - 1:45PM',
#   'Instructor': 'JINGFANG HUANG',
#   'Room': 'Phillips - Rm 0224',
#   'Unreserved Enrollment': '1/4',
#   'Reserved Enrollment': '0/0',
#   'Wait List': '0/0'},
#  {'Class Number': '13485',
#   'Class': 'COMP 664 - 101 Deep Learning',
#   'Meeting Time': 'MoWe 12:30PM - 1:45PM',
#   'Instructor': 'Colin Raffel',
#   'Room': 'F Brooks - Sitterson - Rm F009',
#   'Unreserved Enrollment': '56/60',
#   'Reserved Enrollment': '0/0',
#   'Wait List': '0/6'},
#  {'Class Number': '13495',
#   'Class': 'COMP 730 - 138 Operating Systems',
#   'Meeting Time': 'TuTh 9:30AM - 10:45AM',
#   'Instructor': 'Donald Porter',
#   'Room': 'F Brooks - Sitterson - Rm F007',
#   'Unreserved Enrollment': '14/30',
#   'Reserved Enrollment': '0/0',
#   'Wait List': '0/3'},
#  {'Class Number': '13497',
#   'Class': 'COMP 735 - 080 Distributed and Concurrent Algorithms',
#   'Meeting Time': 'TuTh 2:00PM - 3:15PM',
#   'Instructor': 'JAMES ANDERSON',
#   'Room': 'F Brooks - Sitterson - Rm F007',
#   'Unreserved Enrollment': '13/30',
#   'Reserved Enrollment': '0/0',
#   'Wait List': '0/3'},
#  {'Class Number': '13512',
#   'Class': 'COMP 776 - 001 Computer Vision in our 3D World',
#   'Meeting Time': 'TuTh 2:00PM - 3:15PM',
#   'Instructor': 'Soumyadip Sengupta',
#   'Room': 'F Brooks - Sitterson - Rm F009',
#   'Unreserved Enrollment': '18/30',
#   'Reserved Enrollment': '0/0',
#   'Wait List': '0/0'},
#  {'Class Number': '13513',
#   'Class': 'COMP 777 - 98 Optimal Estimation in Image Analysis',
#   'Meeting Time': 'TuTh 11:00AM - 12:15PM',
#   'Instructor': 'MARC NIETHAMMER',
#   'Room': 'F Brooks - Sitterson - Rm F007',
#   'Unreserved Enrollment': '12/30',
#   'Reserved Enrollment': '0/0',
#   'Wait List': '0/3'},
#  {'Class Number': '13514',
#   'Class': 'COMP 781 - 001 Robotics',
#   'Meeting Time': 'MoWe 2:05PM - 3:20PM',
#   'Instructor': 'RON ALTEROVITZ',
#   'Room': 'TBA',
#   'Unreserved Enrollment': '18/24',
#   'Reserved Enrollment': '0/0',
#   'Wait List': '0/0'},
#  {'Class Number': '13519',
#   'Class': 'COMP 790 - 006 Topics in Computer Science',
#   'Meeting Time': 'TuTh 3:30PM - 4:45PM',
#   'Instructor': 'STEPHEN PIZER',
#   'Room': 'F Brooks - Sitterson - Rm F007',
#   'Unreserved Enrollment': '6/30',
#   'Reserved Enrollment': '0/0',
#   'Wait List': '0/3'},
#  {'Class Number': '9640',
#   'Class': 'COMP 790 - 132 Topics in Computer Science',
#   'Meeting Time': 'MoWe 11:00AM - 12:15PM',
#   'Instructor': 'Cynthia Sturton',
#   'Room': 'F Brooks - Sitterson - Rm F009',
#   'Unreserved Enrollment': '1/30',
#   'Reserved Enrollment': '0/0',
#   'Wait List': '0/2'},
#  {'Class Number': '13520',
#   'Class': 'COMP 790 - 136 Topics in Computer Science',
#   'Meeting Time': 'Mo 11:00AM - 2:00PM',
#   'Instructor': 'Shahriar Nirjon',
#   'Room': 'Sitterson - Rm 0115',
#   'Unreserved Enrollment': '13/25',
#   'Reserved Enrollment': '0/0',
#   'Wait List': '0/3'},
#  {'Class Number': '14659',
#   'Class': 'COMP 790 - 139 Topics in Computer Science',
#   'Meeting Time': 'We 11:00AM - 1:30PM',
#   'Instructor': 'Mohit Bansal',
#   'Room': 'Sitterson - Rm 0115',
#   'Unreserved Enrollment': '9/15',
#   'Reserved Enrollment': '0/0',
#   'Wait List': '0/0'},
#  {'Class Number': '10205',
#   'Class': 'COMP 790 - 166 Topics in Computer Science',
#   'Meeting Time': 'MoWe 11:00AM - 12:15PM',
#   'Instructor': 'Natalie Stanley',
#   'Room': 'F Brooks - Sitterson - Rm F007',
#   'Unreserved Enrollment': '12/30',
#   'Reserved Enrollment': '0/0',
#   'Wait List': '0/3'},
#  {'Class Number': '11399',
#   'Class': 'COMP 790 - 171 Special Topics: Privacy Preserving Technologies',
#   'Meeting Time': 'MoWe 2:05PM - 3:20PM',
#   'Instructor': 'SABA ESKANDARIAN',
#   'Room': 'Sitterson - Rm 0011',
#   'Unreserved Enrollment': '1/1',
#   'Reserved Enrollment': '0/0',
#   'Wait List': '0/2'},
#  {'Class Number': '11401',
#   'Class': 'COMP 790 - 173 Topics in Computer Science',
#   'Meeting Time': 'TuTh 12:30PM - 1:45PM',
#   'Instructor': 'Danielle Szafir',
#   'Room': 'F Brooks - Sitterson - Rm F007',
#   'Unreserved Enrollment': '10/15',
#   'Reserved Enrollment': '0/0',
#   'Wait List': '0/3'},
#  {'Class Number': '13521',
#   'Class': 'COMP 790 - 178 Topics in Computer Science',
#   'Meeting Time': 'TuTh 3:30PM - 4:45PM',
#   'Instructor': 'Benjamin Berg',
#   'Room': 'F Brooks - Sitterson - Rm F009',
#   'Unreserved Enrollment': '5/30',
#   'Reserved Enrollment': '0/0',
#   'Wait List': '0/3'},
#  {'Class Number': '9662',
#   'Class': 'COMP 915 - 001 Technical Communication in Computer Science',
#   'Meeting Time': 'Fr 10:30AM - 12:00PM',
#   'Instructor': 'Multiple',
#   'Room': 'F Brooks - Sitterson - Rm F007',
#   'Unreserved Enrollment': '18/18',
#   'Reserved Enrollment': '0/0',
#   'Wait List': '0/2'}]

# %% [markdown]
# We now have extracted all of the data we need! Congratulations!

# %% [markdown]
# ## Part 3: Using the Data

# %% [markdown]
# Now that we have all of this course data, we can now use it for something cool!
#
# Here is an example of the course data in a Pandas dataframe:

# %%
import pandas as pd

df = pd.DataFrame.from_dict(final_data_list)

df.head()
# Out:
#   Class Number                                              Class  \
# 0         4290  COMP 110 - 001 Introduction to Programming and...
# 1        10266  COMP 110 - 002 Introduction to Programming and...
# 2         9610  COMP 116 - 001 Introduction to Scientific Prog...
# 3         5130  COMP 126 - 001 Practical Web Design and Develo...
# 4        13454        COMP 210 - 001 Data Structures and Analysis
#
#              Meeting Time             Instructor                        Room  \
# 0    TuTh 8:00AM - 9:15AM          Alyssa Byrnes     Hamilton Hall - Rm 0100
# 1    TuTh 2:00PM - 3:15PM          Alyssa Byrnes     Hamilton Hall - Rm 0100
# 2    TuTh 8:00AM - 9:15AM           John Majikes  Hanes Art Center - Rm 0121
# 3  TuTh 11:00AM - 12:15PM  Tessa Joseph-Nicholas         Sitterson - Rm 0014
# 4    MoWe 2:05PM - 3:20PM            Paul Stotts  Hanes Art Center - Rm 0121
#
#   Unreserved Enrollment Reserved Enrollment Wait List
# 0               217/219               81/81      0/30
# 1                 90/90             210/210      0/30
# 2               153/240                 0/0      0/24
# 3               101/105                 0/0      0/11
# 4               235/240                 0/0      0/21

# %% [markdown]
# We can now do anything we want with this data! We could:
#
# - Analyze the data
# - Gain new insights from the data
# - Create our very own data science app!

# %% [markdown]
# ## Closing Thoughts

# %% [markdown]
# Remember, it is extremely important to properly attribute data that you scrape from the internet.
#
# **Thank you Professor Saba Eskandarian for creating the UNC classes tool!**
